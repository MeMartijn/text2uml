# %% [markdown]
# # Lesk algorithm
# http://www.nltk.org/howto/wsd.html

# %%
from nltk.wsd import lesk

# %%
sent = 'a customer has a first name'.split(' ')
print(lesk(sent, 'have'))
# Out:
# Synset('rich_person.n.01')

# %%
from nltk.corpus import wordnet as wn

# %%
for ss in wn.synsets('have'):
    print(ss, ss.definition())
# Out:
# Synset('rich_person.n.01') a person who possesses great material wealth
# Synset('have.v.01') have or possess, either in a concrete or an abstract sense
# Synset('have.v.02') have as a feature
# Synset('experience.v.03') go through (mental or physical states or experiences)
# Synset('own.v.01') have ownership or possession of
# Synset('get.v.03') cause to move; cause to be in a certain position or condition
# Synset('consume.v.02') serve oneself to, or consume regularly
# Synset('have.v.07') have a personal or business relationship with someone
# Synset('hold.v.03') organize or be responsible for
# Synset('have.v.09') have left
# Synset('have.v.10') be confronted with
# Synset('have.v.11') undergo
# Synset('have.v.12') suffer from; be ill with
# Synset('induce.v.02') cause to do; cause to act in a specified manner
# Synset('accept.v.02') receive willingly something given or offered
# Synset('receive.v.01') get something; come into possession of
# Synset('suffer.v.02') undergo (as of injuries and illnesses)
# Synset('have.v.17') achieve a point or goal
# Synset('give_birth.v.01') cause to be born
# Synset('take.v.35') have sex with; archaic use

# %% [markdown]
# # ACL 2016 SuperSenses
# https://github.com/UKPLab/acl2016-supersense-embeddings

# %% [markdown]
# # Rungsted
# https://github.com/coastalcph/rungsted

# %% [markdown]
# # AMALGrAM 2.0
# https://github.com/nschneid/pysupersensetagger

# %%
import spacy
import pandas as pd
import os
from nltk import tokenize

nlp = spacy.load("en_core_web_sm")

# %%
def get_supersenses(sent):
    doc = nlp(sent)
    target_file = '../../pysupersensetagger/input'

    if os.path.exists(target_file):
        os.remove(target_file)
        
    with open(target_file, 'a') as inp_file:
        for token in doc:
            inp_file.write(f'{token}\t{token.tag_}\n')
    
    
    os.system(f'cd {"/".join(target_file.split("/")[:-1])} && sh sst.sh {target_file.split("/")[-1]}')
    
    return pd.read_csv('../../pysupersensetagger/input.pred.tags', sep='\t', names=['token', 'lemma', 'POS-tag', 'MWE+supersense tag', 'MWE parent offset', 'MWE attachment strength', 'supersense label', 'sentence ID'])

# %%
def is_important_for_class(supersense_df):
    # Rule 1: there needs to be at least two nouns in the sentences
    if len(supersense_df[supersense_df['POS-tag'] == 'NN']) > 1:
        return True
    else:
        return False
    
def get_class_metadata(supersense_df):
    
    

def apply_bucketing(summary):
    sentences = tokenize.sent_tokenize(summary)
    
    sentences_supersenses = [get_supersenses(sentence) for sentence in sentences]
    
    bucketed_data = {
        'class': list(filter(lambda x: is_important_for_class(x), sentences_supersenses)),
    }
    
    metadata = {
        'class': map(lambda x: get_class_metadata(x), bucketed_data['class']),
    }
    
    return ({
        bucket: [' '.join(df['token'].values) for df in bucketed_data[bucket]]
        for bucket in bucketed_data.keys()
    }, )
# Out:
#   File "<ipython-input-7-c18d74828d13>", line 12
#     def apply_bucketing(summary):
#     ^
# IndentationError: expected an indented block

# %%
apply_bucketing('A reservation is made for a specific time , date and number of people . The reservation also captures the name and phone number of the person making the reservation . Each reservation is assigned a unique reservation number .')
# Out:
# {'classes': ['A reservation is made for a specific time , date and number of people .',
#   'The reservation also captures the name and phone number of the person making the reservation .',
#   'Each reservation is assigned a unique reservation number .']}

# %%
tester = get_supersenses('A reservation is made for a specific time , date and number of people .')

# %%
supersense_df = tester.copy()

# %%
mask = (tester['POS-tag'] == 'DT')


import spacy

nlp = spacy.load("en_core_web_sm")

doc = nlp(' '.join(tester[~mask]['token'].to_list()))

for chunk in doc.noun_chunks:
    print(chunk.text)
# Out:
# reservation
# specific time
# date
# number
# people

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

doc = nlp('A reservation is made for a specific time , date and number of people . The reservation also captures the name and phone number of the person making the reservation . Each reservation is assigned a unique reservation number .')

for chunk in doc.noun_chunks:
    print(chunk.text, chunk.root.text, chunk.root.dep_, chunk.root.head.text)
# Out:
# A reservation reservation nsubjpass made
# a specific time time pobj for
# date date conj time
# number number conj date
# people people pobj of
# The reservation reservation nsubj captures
# the name name dobj captures
# phone number number conj name
# the person person pobj of
# the reservation reservation dobj making
# Each reservation reservation nsubjpass assigned
# a unique reservation number number dobj assigned

# %%
supersense_df = tester.copy()

prepositions = supersense_df[supersense_df['POS-tag'] == 'IN']

metadata = {
    'objects': []
}

# Check if there are groups of nouns
if len(prepositions) > 0:
    # Define target groups
    targets = ['NN', 'NNS']
        
    for pps in prepositions.iterrows():
        # If ending or beginning position, it can't be a group of nouns
        if not (pps[0] == 0 or pps[0] >= len(supersense_df) - 1):
            # Define surroundings
            preword = supersense_df.loc[pps[0] - 1]
            postword = supersense_df.loc[pps[0] + 1]
            
            # Check if surroundings are in target groups
            if preword['POS-tag'] in targets and postword['POS-tag'] in targets:
                # Add grouping to metadata
                metadata['objects'].append(preword.token + ' ' + pps[1].token + ' ' + postword.token)
                
                # Drop extracted groups from selection
                mask = supersense_df.index.isin(list(range(pps[0] -1, pps[0] + 2)))
                supersense_df = supersense_df[~mask]
        
    # Now get all other nouns and add to metadata
    nouns = supersense_df[supersense_df['POS-tag'].isin(targets)]
    metadata['objects'] = metadata['objects'] + nouns['token'].to_list()
# Out:
# {'objects': ['number of people', 'reservation', 'time', 'date']}

# %%
tester
# Out:
#           token        lemma POS-tag MWE+supersense tag  MWE parent offset  \
# 1             A            a      DT                  O                  0
# 2   reservation  reservation      NN        O-COGNITION                  0
# 3            is           be     VBZ               O-`a                  0
# 4          made         make     VBN         O-creation                  0
# 5           for          for      IN                  O                  0
# 6             a            a      DT                  O                  0
# 7      specific     specific      JJ                  O                  0
# 8          time         time      NN             O-TIME                  0
# 9             ,            ,       ,                  O                  0
# 10         date         date      NN             O-TIME                  0
# 11          and          and      CC                  O                  0
# 12       number       number      NN         O-QUANTITY                  0
# 13           of           of      IN                  O                  0
# 14       people       person     NNS           O-PERSON                  0
# 15            .            .       .                  O                  0
#
#     MWE attachment strength supersense label  sentence ID
# 1                       NaN              NaN          NaN
# 2                       NaN        COGNITION          NaN
# 3                       NaN               `a          NaN
# 4                       NaN         creation          NaN
# 5                       NaN              NaN          NaN
# 6                       NaN              NaN          NaN
# 7                       NaN              NaN          NaN
# 8                       NaN             TIME          NaN
# 9                       NaN              NaN          NaN
# 10                      NaN             TIME          NaN
# 11                      NaN              NaN          NaN
# 12                      NaN         QUANTITY          NaN
# 13                      NaN              NaN          NaN
# 14                      NaN           PERSON          NaN
# 15                      NaN              NaN          NaN

# %%
get_supersenses('A reservation is made for a specific time , date and number of people . The reservation also captures the name and phone number of the person making the reservation . Each reservation is assigned a unique reservation number .')
# Out:
#           token        lemma POS-tag MWE+supersense tag  MWE parent offset  \
# 1             A            a      DT                  O                  0
# 2   reservation  reservation      NN        O-COGNITION                  0
# 3            is           be     VBZ               O-`a                  0
# 4          made         make     VBN         O-creation                  0
# 5           for          for      IN                  O                  0
# 6             a            a      DT                  O                  0
# 7      specific     specific      JJ                  O                  0
# 8          time         time      NN             O-TIME                  0
# 9             ,            ,       ,                  O                  0
# 10         date         date      NN             O-TIME                  0
# 11          and          and      CC                  O                  0
# 12       number       number      NN         O-QUANTITY                  0
# 13           of           of      IN                  O                  0
# 14       people       person     NNS           O-PERSON                  0
# 15            .            .       .                  O                  0
# 16          The          the      DT                  O                  0
# 17  reservation  reservation      NN        O-COGNITION                  0
# 18         also         also      RB                  O                  0
# 19     captures      capture     VBZ           O-change                  0
# 20          the          the      DT                  O                  0
# 21         name         name      NN    O-COMMUNICATION                  0
# 22          and          and      CC                  O                  0
# 23        phone        phone      NN    B-COMMUNICATION                  0
# 24       number       number      NN                  Ī                 23
# 25           of           of      IN                  O                  0
# 26          the          the      DT                  O                  0
# 27       person       person      NN           O-PERSON                  0
# 28       making         make     VBG          O-stative                  0
# 29          the          the      DT                  O                  0
# 30  reservation  reservation      NN         O-LOCATION                  0
# 31            .            .       .                  O                  0
# 32         Each         each      DT                  O                  0
# 33  reservation  reservation      NN        O-COGNITION                  0
# 34           is           be     VBZ               O-`a                  0
# 35     assigned       assign     VBN           O-social                  0
# 36            a            a      DT                  O                  0
# 37       unique       unique      JJ                  O                  0
# 38  reservation  reservation      NN        O-COGNITION                  0
# 39       number       number      NN         O-QUANTITY                  0
# 40            .            .       .                  O                  0
#
#    MWE attachment strength supersense label  sentence ID
# 1                      NaN              NaN          NaN
# 2                      NaN        COGNITION          NaN
# 3                      NaN               `a          NaN
# 4                      NaN         creation          NaN
# 5                      NaN              NaN          NaN
# 6                      NaN              NaN          NaN
# 7                      NaN              NaN          NaN
# 8                      NaN             TIME          NaN
# 9                      NaN              NaN          NaN
# 10                     NaN             TIME          NaN
# 11                     NaN              NaN          NaN
# 12                     NaN         QUANTITY          NaN
# 13                     NaN              NaN          NaN
# 14                     NaN           PERSON          NaN
# 15                     NaN              NaN          NaN
# 16                     NaN              NaN          NaN
# 17                     NaN        COGNITION          NaN
# 18                     NaN              NaN          NaN
# 19                     NaN           change          NaN
# 20                     NaN              NaN          NaN
# 21                     NaN    COMMUNICATION          NaN
# 22                     NaN              NaN          NaN
# 23                     NaN    COMMUNICATION          NaN
# 24                       _              NaN          NaN
# 25                     NaN              NaN          NaN
# 26                     NaN              NaN          NaN
# 27                     NaN           PERSON          NaN
# 28                     NaN          stative          NaN
# 29                     NaN              NaN          NaN
# 30                     NaN         LOCATION          NaN
# 31                     NaN              NaN          NaN
# 32                     NaN              NaN          NaN
# 33                     NaN        COGNITION          NaN
# 34                     NaN               `a          NaN
# 35                     NaN           social          NaN
# 36                     NaN              NaN          NaN
# 37                     NaN              NaN          NaN
# 38                     NaN        COGNITION          NaN
# 39                     NaN         QUANTITY          NaN
# 40                     NaN              NaN          NaN

# %% [markdown]
# ### Use cases

# %%
tester = 'A user can buy a beverage, perform scheduled maintenance, make repairs and load items.'
get_supersenses(tester)
# Out:
#           token        lemma POS-tag MWE+supersense tag  MWE parent offset  \
# 1             A            a      DT                  O                  0
# 2          user         user      NN           O-PERSON                  0
# 3           can          can      MD                  O                  0
# 4           buy          buy      VB       O-possession                  0
# 5             a            a      DT                  O                  0
# 6      beverage     beverage      NN             O-FOOD                  0
# 7             ,            ,       ,                  O                  0
# 8       perform      perform      VB               O-`a                  0
# 9     scheduled     schedule     VBN           O-social                  0
# 10  maintenance  maintenance      NN              O-ACT                  0
# 11            ,            ,       ,                  O                  0
# 12         make         make      VB         O-creation                  0
# 13      repairs       repair     NNS              O-ACT                  0
# 14          and          and      CC                  O                  0
# 15         load         load      NN         O-LOCATION                  0
# 16        items         item     NNS         O-ARTIFACT                  0
#
#     MWE attachment strength supersense label  sentence ID
# 1                       NaN              NaN          NaN
# 2                       NaN           PERSON          NaN
# 3                       NaN              NaN          NaN
# 4                       NaN       possession          NaN
# 5                       NaN              NaN          NaN
# 6                       NaN             FOOD          NaN
# 7                       NaN              NaN          NaN
# 8                       NaN               `a          NaN
# 9                       NaN           social          NaN
# 10                      NaN              ACT          NaN
# 11                      NaN              NaN          NaN
# 12                      NaN         creation          NaN
# 13                      NaN              ACT          NaN
# 14                      NaN              NaN          NaN
# 15                      NaN         LOCATION          NaN
# 16                      NaN         ARTIFACT          NaN

# %% [markdown]
# ### Activities

# %%
tester = 'If the bill is higher than 3000 euros, the bill is sent to the finance department.'
get_supersenses(tester)
# Out:
#          token       lemma POS-tag MWE+supersense tag  MWE parent offset  \
# 1           If          if      IN                  O                  0
# 2          the         the      DT                  O                  0
# 3         bill        bill      NN       O-POSSESSION                  0
# 4           is          be     VBZ          O-stative                  0
# 5       higher      higher     JJR                  O                  0
# 6         than        than      IN                  O                  0
# 7         3000        3000      CD                  O                  0
# 8        euros        euro     NNS         O-QUANTITY                  0
# 9            ,           ,       ,                  O                  0
# 10         the         the      DT                  O                  0
# 11        bill        bill      NN       O-POSSESSION                  0
# 12          is          be     VBZ               O-`a                  0
# 13        sent        send     VBN           O-motion                  0
# 14          to          to      IN                  O                  0
# 15         the         the      DT                  O                  0
# 16     finance     finance      NN              O-ACT                  0
# 17  department  department      NN            O-GROUP                  0
# 18           .           .       .                  O                  0
#
#     MWE attachment strength supersense label  sentence ID
# 1                       NaN              NaN          NaN
# 2                       NaN              NaN          NaN
# 3                       NaN       POSSESSION          NaN
# 4                       NaN          stative          NaN
# 5                       NaN              NaN          NaN
# 6                       NaN              NaN          NaN
# 7                       NaN              NaN          NaN
# 8                       NaN         QUANTITY          NaN
# 9                       NaN              NaN          NaN
# 10                      NaN              NaN          NaN
# 11                      NaN       POSSESSION          NaN
# 12                      NaN               `a          NaN
# 13                      NaN           motion          NaN
# 14                      NaN              NaN          NaN
# 15                      NaN              NaN          NaN
# 16                      NaN              ACT          NaN
# 17                      NaN            GROUP          NaN
# 18                      NaN              NaN          NaN

# %% [markdown]
# ### Classes

# %%
tester = 'Each person has name and birthdate and may work at a job.'
get_supersenses(tester)
# Out:
#         token      lemma POS-tag MWE+supersense tag  MWE parent offset  \
# 1        Each       each      DT                  O                  0
# 2      person     person      NN           O-PERSON                  0
# 3         has       have     VBZ          O-stative                  0
# 4        name       name      NN    O-COMMUNICATION                  0
# 5         and        and      CC                  O                  0
# 6   birthdate  birthdate      NN    O-COMMUNICATION                  0
# 7         and        and      CC                  O                  0
# 8         may        may      MD                  O                  0
# 9        work       work      VB           O-social                  0
# 10         at         at      IN                  O                  0
# 11          a          a      DT                  O                  0
# 12        job        job      NN              O-ACT                  0
# 13          .          .       .                  O                  0
#
#     MWE attachment strength supersense label  sentence ID
# 1                       NaN              NaN          NaN
# 2                       NaN           PERSON          NaN
# 3                       NaN          stative          NaN
# 4                       NaN    COMMUNICATION          NaN
# 5                       NaN              NaN          NaN
# 6                       NaN    COMMUNICATION          NaN
# 7                       NaN              NaN          NaN
# 8                       NaN              NaN          NaN
# 9                       NaN           social          NaN
# 10                      NaN              NaN          NaN
# 11                      NaN              NaN          NaN
# 12                      NaN              ACT          NaN
# 13                      NaN              NaN          NaN

# %% [markdown]
# # BookNLP

# %%
# !python3 -m pip install booknlp
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: booknlp in /Users/martijn/Library/Python/3.8/lib/python/site-packages (1.0.7)
# Requirement already satisfied: torch>=1.7.1 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from booknlp) (1.10.1)
# Requirement already satisfied: tensorflow>=1.15 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from booknlp) (2.7.0)
# Requirement already satisfied: spacy>=3 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from booknlp) (3.2.1)
# Requirement already satisfied: transformers>=4.11.3 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from booknlp) (4.15.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from spacy>=3->booknlp) (2.4.2)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from spacy>=3->booknlp) (1.0.1)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from spacy>=3->booknlp) (0.7.5)
# Requirement already satisfied: packaging>=20.0 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from spacy>=3->booknlp) (21.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from spacy>=3->booknlp) (2.26.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from spacy>=3->booknlp) (0.9.0)
# Requirement already satisfied: numpy>=1.15.0 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from spacy>=3->booknlp) (1.22.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from spacy>=3->booknlp) (1.0.6)
# Requirement already satisfied: jinja2 in /Library/Python/3.8/site-packages (from spacy>=3->booknlp) (3.0.1)
# Requirement already satisfied: pathy>=0.3.5 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from spacy>=3->booknlp) (0.6.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from spacy>=3->booknlp) (3.3.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from spacy>=3->booknlp) (3.0.8)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from spacy>=3->booknlp) (8.0.13)
# Requirement already satisfied: setuptools in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages (from spacy>=3->booknlp) (49.2.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from spacy>=3->booknlp) (3.0.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from spacy>=3->booknlp) (2.0.6)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from spacy>=3->booknlp) (0.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Library/Python/3.8/site-packages (from spacy>=3->booknlp) (4.61.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from spacy>=3->booknlp) (1.8.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from spacy>=3->booknlp) (2.0.6)
# Requirement already satisfied: h5py>=2.9.0 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from tensorflow>=1.15->booknlp) (3.6.0)
# Requirement already satisfied: absl-py>=0.4.0 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from tensorflow>=1.15->booknlp) (1.0.0)
# Requirement already satisfied: gast<0.5.0,>=0.2.1 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from tensorflow>=1.15->booknlp) (0.4.0)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages (from tensorflow>=1.15->booknlp) (0.33.1)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from tensorflow>=1.15->booknlp) (1.13.3)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from tensorflow>=1.15->booknlp) (1.6.3)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from tensorflow>=1.15->booknlp) (0.2.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from tensorflow>=1.15->booknlp) (1.1.2)
# Requirement already satisfied: libclang>=9.0.1 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from tensorflow>=1.15->booknlp) (12.0.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from tensorflow>=1.15->booknlp) (1.43.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from tensorflow>=1.15->booknlp) (1.1.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.21.0 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from tensorflow>=1.15->booknlp) (0.23.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from tensorflow>=1.15->booknlp) (4.0.1)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from tensorflow>=1.15->booknlp) (2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from tensorflow>=1.15->booknlp) (3.3.0)
# Requirement already satisfied: tensorflow-estimator<2.8,~=2.7.0rc0 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from tensorflow>=1.15->booknlp) (2.7.0)
# Requirement already satisfied: tensorboard~=2.6 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from tensorflow>=1.15->booknlp) (2.7.0)
# Requirement already satisfied: keras<2.8,>=2.7.0rc0 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from tensorflow>=1.15->booknlp) (2.7.0)
# Requirement already satisfied: protobuf>=3.9.2 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from tensorflow>=1.15->booknlp) (3.19.1)
# Requirement already satisfied: six>=1.12.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages (from tensorflow>=1.15->booknlp) (1.15.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from transformers>=4.11.3->booknlp) (0.2.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from transformers>=4.11.3->booknlp) (6.0)
# Requirement already satisfied: filelock in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from transformers>=4.11.3->booknlp) (3.3.2)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from transformers>=4.11.3->booknlp) (0.10.3)
# Requirement already satisfied: sacremoses in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from transformers>=4.11.3->booknlp) (0.0.46)
# Requirement already satisfied: regex!=2019.12.17 in /Library/Python/3.8/site-packages (from transformers>=4.11.3->booknlp) (2021.7.6)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from packaging>=20.0->spacy>=3->booknlp) (3.0.6)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from pathy>=0.3.5->spacy>=3->booknlp) (5.2.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3->booknlp) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3->booknlp) (2.0.8)
# Requirement already satisfied: idna<4,>=2.5 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3->booknlp) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3->booknlp) (2021.10.8)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from tensorboard~=2.6->tensorflow>=1.15->booknlp) (0.4.6)
# Requirement already satisfied: werkzeug>=0.11.15 in /Library/Python/3.8/site-packages (from tensorboard~=2.6->tensorflow>=1.15->booknlp) (2.0.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from tensorboard~=2.6->tensorflow>=1.15->booknlp) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from tensorboard~=2.6->tensorflow>=1.15->booknlp) (1.8.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from tensorboard~=2.6->tensorflow>=1.15->booknlp) (3.3.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from tensorboard~=2.6->tensorflow>=1.15->booknlp) (2.3.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Library/Python/3.8/site-packages (from typer<0.5.0,>=0.3.0->spacy>=3->booknlp) (8.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Python/3.8/site-packages (from jinja2->spacy>=3->booknlp) (2.0.1)
# Requirement already satisfied: joblib in /Library/Python/3.8/site-packages (from sacremoses->transformers>=4.11.3->booknlp) (1.0.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow>=1.15->booknlp) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow>=1.15->booknlp) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow>=1.15->booknlp) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow>=1.15->booknlp) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow>=1.15->booknlp) (4.10.0)
# Requirement already satisfied: zipp>=0.5 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.6->tensorflow>=1.15->booknlp) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow>=1.15->booknlp) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/martijn/Library/Python/3.8/lib/python/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow>=1.15->booknlp) (3.1.1)

# %%
from booknlp.booknlp import BookNLP
import pandas as pd
import numpy as np

# %%
model_params={
    "pipeline": "entity,supersense,event", 
    "model": "small"
}

booknlp=BookNLP("en", model_params)

def get_annotated_df(filename):
    # File identifier
    file_id = '.'.join(filename.split('.')[:-1])

    # Input file to process
    input_file=f'./../../PurePlainDataset/output/{filename}'

    # Output directory to store resulting files in
    output_directory=f'output/{file_id}/'

    # Publish results
    booknlp.process(input_file, output_directory, file_id)

    # Gather results
    df = pd.read_csv(f'{output_directory}{file_id}.tokens', sep='\t')

    # Gather supersenses
    supersenses = pd.read_csv(f'{output_directory}{file_id}.supersense', sep='\t')

    # Begin merging both dataframes
    df['supersense_category'] = ''

    # Loop over supersense df
    for index, row in supersenses.iterrows():
        # Add supersense to all rows in range of starting and ending tokens
        for token in range(row.start_token, row.end_token + 1):
            df.loc[df.token_ID_within_document == token, 'supersense_category'] = row.supersense_category
    
    # Gather entities
    supersenses = pd.read_csv(f'{output_directory}{file_id}.entities', sep='\t')

    # Begin merging entities
    df['prop'] = ''
    df['cat'] = ''
    df['COREF'] = np.nan

    # Loop over entity df
    for index, row in supersenses.iterrows():
        # Add entities to all rows in range of starting and ending tokens
        for token in range(row.start_token, row.end_token + 1):
            df.loc[df.token_ID_within_document == token, ['prop', 'cat', 'COREF']] = [row.prop, row['cat'], row.COREF]
    
    sent_groups = df.groupby('sentence_ID')
    return [sent_groups.get_group(x) for x in sent_groups.groups]
# Out:
# {'pipeline': 'entity,supersense,event', 'model': 'small'}
# --- startup: 7.021 seconds ---

# %%
dfs = get_annotated_df('0000 - cctns.txt')
# Out:
# --- spacy: 0.816 seconds ---
# --- entities: 7.964 seconds ---
# --- quotes: 0.010 seconds ---
# --- name coref: 0.001 seconds ---
# --- TOTAL (excl. startup): 11.654 seconds ---, 5430 words
