# %%
import spacy
from spacy import displacy
from diaparser.parsers import Parser

# %%
target_sent = 'A customer can place an order and check the order status.'

# %% [markdown]
# # SpaCy
#
# ## Base

# %%
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp(target_sent)
displacy.render(doc, style='dep', options={'compact': True, 'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="089d01cfd8c8456bb90c6aa0a62590fd-0" class="displacy" width="1370" height="377.0" direction="ltr" style="max-width: none; height: 377.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">A</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">customer</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">can</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">place</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">an</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">order</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">check</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">order</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">status.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-089d01cfd8c8456bb90c6aa0a62590fd-0-0" stroke-width="2px" d="M62,242.0 62,222.0 161.0,222.0 161.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-089d01cfd8c8456bb90c6aa0a62590fd-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,244.0 L58,236.0 66,236.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-089d01cfd8c8456bb90c6aa0a62590fd-0-1" stroke-width="2px" d="M182,242.0 182,202.0 404.0,202.0 404.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-089d01cfd8c8456bb90c6aa0a62590fd-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M182,244.0 L178,236.0 186,236.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-089d01cfd8c8456bb90c6aa0a62590fd-0-2" stroke-width="2px" d="M302,242.0 302,222.0 401.0,222.0 401.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-089d01cfd8c8456bb90c6aa0a62590fd-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M302,244.0 L298,236.0 306,236.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-089d01cfd8c8456bb90c6aa0a62590fd-0-3" stroke-width="2px" d="M542,242.0 542,222.0 641.0,222.0 641.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-089d01cfd8c8456bb90c6aa0a62590fd-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M542,244.0 L538,236.0 546,236.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-089d01cfd8c8456bb90c6aa0a62590fd-0-4" stroke-width="2px" d="M422,242.0 422,202.0 644.0,202.0 644.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-089d01cfd8c8456bb90c6aa0a62590fd-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M644.0,244.0 L648.0,236.0 640.0,236.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-089d01cfd8c8456bb90c6aa0a62590fd-0-5" stroke-width="2px" d="M422,242.0 422,182.0 767.0,182.0 767.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-089d01cfd8c8456bb90c6aa0a62590fd-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M767.0,244.0 L771.0,236.0 763.0,236.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-089d01cfd8c8456bb90c6aa0a62590fd-0-6" stroke-width="2px" d="M422,242.0 422,162.0 890.0,162.0 890.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-089d01cfd8c8456bb90c6aa0a62590fd-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M890.0,244.0 L894.0,236.0 886.0,236.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-089d01cfd8c8456bb90c6aa0a62590fd-0-7" stroke-width="2px" d="M1022,242.0 1022,202.0 1244.0,202.0 1244.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-089d01cfd8c8456bb90c6aa0a62590fd-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1022,244.0 L1018,236.0 1026,236.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-089d01cfd8c8456bb90c6aa0a62590fd-0-8" stroke-width="2px" d="M1142,242.0 1142,222.0 1241.0,222.0 1241.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arr

# %% [markdown]
# ## RoBERTa

# %%
nlp = spacy.load('en_core_web_trf')

# %%
doc = nlp(target_sent)
displacy.render(doc, style='dep', options={'compact': True, 'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="7bf95a78096e4b018bab663c101307af-0" class="displacy" width="1370" height="377.0" direction="ltr" style="max-width: none; height: 377.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">A</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">customer</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">can</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">place</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">an</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">order</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">check</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">order</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">status.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7bf95a78096e4b018bab663c101307af-0-0" stroke-width="2px" d="M62,242.0 62,222.0 161.0,222.0 161.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7bf95a78096e4b018bab663c101307af-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,244.0 L58,236.0 66,236.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7bf95a78096e4b018bab663c101307af-0-1" stroke-width="2px" d="M182,242.0 182,202.0 404.0,202.0 404.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7bf95a78096e4b018bab663c101307af-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M182,244.0 L178,236.0 186,236.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7bf95a78096e4b018bab663c101307af-0-2" stroke-width="2px" d="M302,242.0 302,222.0 401.0,222.0 401.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7bf95a78096e4b018bab663c101307af-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M302,244.0 L298,236.0 306,236.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7bf95a78096e4b018bab663c101307af-0-3" stroke-width="2px" d="M542,242.0 542,222.0 641.0,222.0 641.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7bf95a78096e4b018bab663c101307af-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M542,244.0 L538,236.0 546,236.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7bf95a78096e4b018bab663c101307af-0-4" stroke-width="2px" d="M422,242.0 422,202.0 644.0,202.0 644.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7bf95a78096e4b018bab663c101307af-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M644.0,244.0 L648.0,236.0 640.0,236.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7bf95a78096e4b018bab663c101307af-0-5" stroke-width="2px" d="M422,242.0 422,182.0 767.0,182.0 767.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7bf95a78096e4b018bab663c101307af-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M767.0,244.0 L771.0,236.0 763.0,236.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7bf95a78096e4b018bab663c101307af-0-6" stroke-width="2px" d="M422,242.0 422,162.0 890.0,162.0 890.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7bf95a78096e4b018bab663c101307af-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M890.0,244.0 L894.0,236.0 886.0,236.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7bf95a78096e4b018bab663c101307af-0-7" stroke-width="2px" d="M1022,242.0 1022,202.0 1244.0,202.0 1244.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7bf95a78096e4b018bab663c101307af-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1022,244.0 L1018,236.0 1026,236.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7bf95a78096e4b018bab663c101307af-0-8" stroke-width="2px" d="M1142,242.0 1142,222.0 1241.0,222.0 1241.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arr

# %% [markdown]
# # DiaParser

# %%
parser = Parser.load('en_ewt-electra')
# Out:
# Using bos_token, but it is not set yet.
# Using eos_token, but it is not set yet.

# %%
dataset = parser.predict(target_sent, text='en')
sent = dataset.sentences[0]

displacy.render(sent.to_displacy(), style='dep', manual=True, options={'compact': True, 'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="95318a56c7194b1bb40f75cd2f449b1d-0" class="displacy" width="1610" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">ROOT</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">A</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">customer</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">can</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">place</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">an</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">order</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">check</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">order</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">status</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490"></tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-95318a56c7194b1bb40f75cd2f449b1d-0-0" stroke-width="2px" d="M182,302.0 182,282.0 278.0,282.0 278.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-95318a56c7194b1bb40f75cd2f449b1d-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M182,304.0 L178,296.0 186,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-95318a56c7194b1bb40f75cd2f449b1d-0-1" stroke-width="2px" d="M302,302.0 302,262.0 521.0,262.0 521.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-95318a56c7194b1bb40f75cd2f449b1d-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M302,304.0 L298,296.0 306,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-95318a56c7194b1bb40f75cd2f449b1d-0-2" stroke-width="2px" d="M422,302.0 422,282.0 518.0,282.0 518.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-95318a56c7194b1bb40f75cd2f449b1d-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M422,304.0 L418,296.0 426,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-95318a56c7194b1bb40f75cd2f449b1d-0-3" stroke-width="2px" d="M62,302.0 62,222.0 527.0,222.0 527.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-95318a56c7194b1bb40f75cd2f449b1d-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">root</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M527.0,304.0 L531.0,296.0 523.0,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-95318a56c7194b1bb40f75cd2f449b1d-0-4" stroke-width="2px" d="M662,302.0 662,282.0 758.0,282.0 758.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-95318a56c7194b1bb40f75cd2f449b1d-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M662,304.0 L658,296.0 666,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-95318a56c7194b1bb40f75cd2f449b1d-0-5" stroke-width="2px" d="M542,302.0 542,262.0 761.0,262.0 761.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-95318a56c7194b1bb40f75cd2f449b1d-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M761.0,304.0 L765.0,296.0 757.0,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-95318a56c7194b1bb40f75cd2f449b1d-0-6" stroke-width="2px" d="M902,302.0 902,282.0 998.0,282.0 998.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-95318a56c7194b1bb40f75cd2f449b1d-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M902,304.0 L898,296.0 906,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-95318a56c7194b1bb40f75cd2f449b1d-0-7" stroke-width="2px" d="M542,302.0 542,222.0 1007.0,222.0 1007.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-95318a56c7194b1bb40f75cd2f449b1d-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textP

# %%
import nltk

# %%
from nltk.corpus import verbnet
from xml.etree import ElementTree
from nltk.stem import WordNetLemmatizer

# %%
nltk.download('verbnet')
nlkt.download('wordnet')

# %%
lemmatizer = WordNetLemmatizer()
lemmatized_verb = lemmatizer.lemmatize("place")
stem = verbnet.classids(lemma=lemmatized_verb)
print(stem)

verbnet.vnclass(stem[0])

print(verbnet.pprint(stem[0]))
# Out:
# ['put-9.1-2']
# put-9.1-2
#   Subclasses: (none)
#   Members: place set put
#   Thematic roles:
#     * Theme[+abstract]
#   Frames:
#     PP-NP (upon/on-PP)
#       Example: They put upon me a brilliant, red helm.
#       Syntax: NP[Agent] VERB PREP[on upon] NP[Destination] NP[Theme]
#       Semantics:
#         * motion(during(E), Theme)
#         * Prep(start(E), Theme, Destination)
#         * Prep(end(E), Theme, Destination)
#         * cause(Agent, E)

# %%
lemmatizer = WordNetLemmatizer()
lemmatized_verb = lemmatizer.lemmatize("drop")
stem = verbnet.classids(lemma=lemmatized_verb)
print(stem)

verbnet.vnclass(stem[1])

print(verbnet.pprint(stem[0]))
# Out:
# ['calibratable_cos-45.6-1', 'meander-47.7', 'put_direction-9.4', 'roll-51.3.1']
# calibratable_cos-45.6-1
#   Subclasses: (none)
#   Members: appreciate balloon climb decline decrease depreciate differ
#     diminish drop fall fluctuate gain grow increase jump mushroom
#     plummet plunge rocket rise skyrocket soar surge tumble vary dip
#     lower swell
#   Thematic roles:
#
#   Frames:
#     Intransitive (Attribute Subject)
#       Example: Oil's price soared.
#       Syntax: NP[Patient] LEX['s] NP[Attribute] VERB
#       Semantics:
#         * change_value(during(E), Direction, Attribute, Patient)
