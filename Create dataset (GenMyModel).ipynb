# %%
import pandas as pd
from tqdm.auto import tqdm
from collections import Counter
import numpy as np
import os, json, fasttext, re
from lxml import etree as ET
import copy
import unicodedata as ud

# %%
# Enable tqdm for pandas
tqdm.pandas()

# Create a flatten function
flatten = lambda t: [item for sublist in t for item in sublist]
# Out:
# /Users/martijn/opt/anaconda3/lib/python3.8/site-packages/tqdm/std.py:697: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %% [markdown]
# # Initial data cleaning

# %%
data_root = 'data/repo-genmymodel-uml/data'

# %%
filenames = next(os.walk(data_root), (None, None, []))[2]

# %% [markdown]
# # Start wrangling

# %%
len(filenames)
# Out:
# 352216

# %%
filenames[0]
# Out:
# '_cDm6cGfBEeepGY91r9Nuow.xmi.uml'

# %% [markdown]
# ## Defining patterns

# %% [markdown]
# ### XML UML tag patterns
#
# In ed9c3064-7fb5-4ec0-bded-c114251076fa.xmi.uml, packagedElement tags are used to define classes (```uml:Class```):
#
# ```
# <packagedElement xsi:type="uml:Class" xmi:id="_eI6xoFdMEDCGTb6ZuLm3Mw" name="Client">
# ```
#
# The ownedAttribute tag holds attribute names:
#
# ```
# <ownedAttribute xmi:id="_GVIe2JUXEeqqGZh46IEtXQ" name="id">
# ```

# %% [markdown]
# ## Search for patterns in files

# %%
def get_classes_and_attributes_from_uml(filepath):
    root = ET.parse(data_root + '/' + filepath)
    
    # Gather classes and attributes using defined patterns
    classes = root.xpath("//packagedElement[@xsi:type='uml:Class']/@name", namespaces={'xsi': 'http://www.w3.org/2001/XMLSchema-instance'})
    attributes = root.xpath("//packagedElement[@xsi:type='uml:Class']/ownedAttribute/@name", namespaces={'xsi': 'http://www.w3.org/2001/XMLSchema-instance'})
    
    # Save classes and attributes in list if they hold values
    found_data = {}
    if len(classes) > 0:
        found_classes = [x for x in [x.strip() for x in classes] if x != '']
        if len(found_classes) > 0:
            found_data['classes'] = found_classes
    if len(attributes) > 0:
        found_attributes = [x for x in [x.strip() for x in attributes] if x != '']
        if len(found_classes) > 0:
            found_data['attributes'] = found_attributes
    
    return found_data

# %%
get_classes_and_attributes_from_uml('ed9c3064-7fb5-4ec0-bded-c114251076fa.xmi.uml')
# Out:
# {'classes': ['Client', 'Adaptor', 'Adaptee']}

# %%
data_dict = {}

for file in tqdm(filenames):
    try:
        data = get_classes_and_attributes_from_uml(file)
    except Exception as e:
        print(e)
    
    if len(data.keys()) > 0:
        data_dict[file] = data
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=352216.0), HTML(value='')))
# Start tag expected, '<' not found, line 1, column 1 (_mu7qEH1yEeShroDxTnL5_A.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_m_Rk4KwTEea217yLRs2OoA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_QccQIO_IEeSujetaMhozjg.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (2f9d0cc3-7598-4e0e-a1ce-5aa700687522.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_5yFvIKYsEei1evnFuWTWfg.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_TPfGIDM0EeSm5tDnu9wFCA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_9y-TQJ4sEeiGsdp6eB6oaw.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_y2OWACeREeShcfbUiDP6ug.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_9w0aYK1CEDGNWLI2ml8Hng.xmi.uml, line 1)
# Opening and ending tag mismatch: link line 1 and head, line 1, column 259 (_jOJ8gOS7EeekKLRLyKXO4Q.xmi.uml, line 1)
# Opening and ending tag mismatch: link line 1 and head, line 1, column 442 (_TvGJsHVwEemwWpuaZV3QLQ.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_ymZaMFVUEemYjay6yoFVQw.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_oRlxgMIzEei9yqzfX9cFYA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (d18070d7-cbaf-45cf-9612-ab466681f58a.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (65db5b5e-d3e8-4b6e-bc77-26678f594a45.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (c9ae9ade-fa32-4563-82b0-f507e9236598.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_pKP8gHalEeWHj6FRYjbDrA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_AAoo0GuhEeSxQ--xWSR1cw.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_zAuHoCCzEeSehIZyjLU8AQ.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_4z2rUHDWEeWQ-ePoxTR2kA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_Xfms4BVFEeepM-R8YBkuKA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (__ZHJADkPEeSWIoeppx7IKQ.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_1Bq7sOYdEeWGb_05Qs2etQ.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_dOY-MMQxEDG1vfE2XINvog.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_oS4nsLk1EeWh17zD5SB95Q.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_ZZ4_wDHfEDGYBdxM6XQ8Qw.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_aJXoEHCtEDGZRv1Ax7bzSg.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_KBmC0LukEean1qUSNTq6fA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_FHH08Ev5EeS_velUIC8tvA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_F9tZYdEzEDCIQdHQJTgRGA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_fBhYQOkpEeaowdqlt8Dqsg.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_yLMFoPz5EeW9zv77lynsJg.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_9RPxsF27EeSmRKwulsG6-Q.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_XLkVwEevEeSygayfuMsNCA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_bXw6oOnoEeSZJMJfWKmK3w.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_pZJN0B6nEeeY6dVJSDALDQ.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_WiECgF6LEDGbo7ZgBahqKQ.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_VKzWkIjwEeWSIKoWblTvZg.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_DoOesL0SEDG1vfE2XINvog.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (142834e3-b25c-4898-bce9-56ca214afbb8.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_Y7MeUEfFEeSygayfuMsNCA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_Ebm6UFR5EeeTnI9B59buBQ.xmi.uml, line 1)
# Opening and ending tag mismatch: link line 1 and head, line 1, column 442 (34767317-dca5-41ac-a383-dc6e771b3c1b.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_NaR5YDW9EeSWxti7Zl7lSQ.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (ddc391f0-efe1-4149-bda6-ef95289a9743.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_OhiFsG2hEDG0Q87Md8EQjQ.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (c51d04ff-1271-452e-ac23-82d290cfaf0e.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_Ret4sFv_EDGW_vbL194_8Q.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (ff8b38e5-da45-48ed-acf7-609bef45c6c5.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_fcERkPdTEead4oPeTNh7TQ.xmi.uml, line 1)
# Opening and ending tag mismatch: link line 1 and head, line 1, column 442 (_f5jnQE5lEeeu8_4LH_yuyg.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_NTTS4G89EeSQQ4inw3dTxQ.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_VhRTEMDyEeacM55raX9d3Q.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (73b32438-ccfb-4d2f-8395-b608a47d154a.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_P4STgE2QEeS9L4cMWDc7Qg.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (7c5571d5-07f0-450a-ae36-ccec28c41972.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_Hmi7kDTYEeewJqDqgRk6VA.xmi.uml, line 1)
# xmlParseEntityRef: no name, line 296, column 155 (_BqF3UDorEei8ofcXF4tHnw.xmi.uml, line 296)
# Start tag expected, '<' not found, line 1, column 1 (_ZkXdoMBXEeSBntdMhqoN9Q.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_nV8rQAlJEeSTSdbiZM5D2w.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_qeRKoAcmEeSc6-5ILiz_HQ.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_bOMkIItyEDGF7OMzq3iQ-w.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_tQgvgKiaEeS9iunt9iMoeg.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_GqY0sAULEemehb_jYViW8w.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_sKBUsPqXEeOTCK1Mp6laew.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_LIbu8GdgEeWj-NpUY7FLqQ.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_o2pJgBs0EeaOIPl65G1Tcw.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (5e05fa4c-67fa-486a-bfbc-319e4cbee5a5.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_rkcjMBT5Eeirparnd37rPA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (8d7afdd5-a44c-4265-95e6-f4ed5497aa19.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (1b1faaf9-c70b-482c-8d6c-da09be8e7f87.xmi.uml, line 1)
# Opening and ending tag mismatch: link line 1 and head, line 1, column 1489 (_xkGOIL-qEeeEXb8Dudo6PQ.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_4twFwCLYEeebMd4KpxnGEA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_tJGX4FklEeSX4NW4yDdo9Q.xmi.uml, line 1)
# Opening and ending tag mismatch: link line 1 and head, line 1, column 442 (_CFxnsBvNEem0-NW0ozK2Pg.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (1635bc6f-30e8-475a-a1a8-a8a8ccd3002b.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (d14e4ecd-d53c-4fbd-9a2d-9f278b6e383b.xmi.uml, line 1)
# local variable 'found_classes' referenced before assignment
# Start tag expected, '<' not found, line 1, column 1 (_Udwa0ALfEeWIurmVlS1tXA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_IX86IAo1EeeoBvzX9wJhsQ.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_XdV_kMy0EeSFdJ-PF1a9Cw.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_t3yk0JS4EeS67M2cXIV9Bg.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (8e23d100-76e9-4be4-8c18-83bbecfc33aa.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (19f2e7d5-82d2-4801-ba02-75700a6dfe3c.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_ofzqkLpaEeiBfp11hItRuw.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (54749843-b387-4ee8-8f4b-c2630321f1af.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_uW1j8CUfEDGlaJTZcof-Dw.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_g24SgCtMEDGWq_RLO4Gl4w.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_YtikoEm5EeS_velUIC8tvA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (6e20cd3f-25ed-44d9-b339-5ba8a2e148bb.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (f12c8f43-8bad-4035-9fb0-3a77f60d0472.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (5d02602f-7397-4b4d-a50d-f7302baab3f0.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_5x-WEJzsEeWWRMvT9FgLDg.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (031bbef7-da12-4a68-a65d-90fe85b86bc7.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_T1bakHQIEeSZWo9AFr5YZg.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_KXCbsEK_EeSyYeDoyPirvg.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_wWkk8HcrEeSfPZ7vcufCPw.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_SFBKQF56EeSmRKwulsG6-Q.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_abd6cATFEeeUMouUWv9oWw.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_dBoRkAUNEemehb_jYViW8w.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (df49b03c-8b51-47a2-91f4-d1d6af788de6.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_ZeLWgFBBEeaQi6kdrfnezw.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_7Az1EH7YEDGZRv1Ax7bzSg.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_dSnRMGO2EeSLGdVI-XsN4w.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_iuvpIBrHEeejtu_xKNOcrQ.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (1f5da28d-cf4a-44a0-83e2-01694aa7089e.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (71d32b8b-2a96-4618-a39a-c52d68e21e5e.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (6ba2b26a-ceab-4172-a2ff-7c35f72e1327.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_gT_toHAFEDGZRv1Ax7bzSg.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_aU6CEBCPEeeoBvzX9wJhsQ.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_gCxY8NQ2EeSyKtHqJeGVMw.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_FToywDZiEeewJqDqgRk6VA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_4VNxEB2qEDGdRLiddL-cCA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_uTYFkJYhEeS67M2cXIV9Bg.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_U57JILNUEeie5eCRSnD_uQ.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_F-cLwJGSEeeaCsv2qBF4QA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_asUecDJgEeSm5tDnu9wFCA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_2hpNoOw7EeSTzO_7wOExMA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_bhqegN4BEeWlnZT785H8fA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_qqgNULNgEeSwG8dHYUky5Q.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (5ff88e31-6af1-496c-8288-3a7f906d5e23.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (844441a9-1eff-4437-923d-c5a11e34c2da.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (ddbb6a9d-8a69-4a96-846f-9e195372ec70.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_wMpLsCu7EeWNN9jB-PYuYA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_5xSmUJMCEDG_H5RkFjJqjg.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_Gm8PwFQ6EeSu48YT12vqpQ.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (4439a3c3-18bf-4878-b1c7-abd543d7dfca.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (9a7d9b9e-17f0-4fa9-934a-b3733af7d015.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_mPrjUBjjEeWYv5tJGtHyjA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_Lv9A4MhxEeiZ3fREAmKE6g.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_7MOwAJm1EDGdyoFyp4l9hw.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_l8cDsGdZEeS3yOrtnopAkA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (95f92741-b28e-43be-ac0e-e20283315186.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_n4QS8LzfEeWM0I0nquuJQA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_BvFw0M4cEeSFdJ-PF1a9Cw.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_nlbVoA_OEeeoBvzX9wJhsQ.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_7w0FEKusEeS57ICseEaz5A.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_WJU7AKocEea217yLRs2OoA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (4448aa9c-4c27-47fa-9f84-658e83d32182.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_2tFS0NojEeWlnZT785H8fA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_I1bUoN1kEea4oJwuIIj5Zg.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_slgdsP6cEeSpvbjLqY_W3Q.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_PxDUkCIWEeSehIZyjLU8AQ.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_VftNII5iEeW2I_OUujANxA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (8984bf23-d038-4065-a232-5ddacf390e72.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_FRPqoLyTEean1qUSNTq6fA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_ICmHIHE1EDGZRv1Ax7bzSg.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (58722a3f-bdc5-43dc-b72f-fc84fbc8c5b8.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_cKPCoJ1aEDGn1-aaBa6y3w.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_jTmYcHVrEeSfPZ7vcufCPw.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (05d23274-77ed-4ba7-bd7f-e7d6998edaa7.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_LNAygD7JEeeTJ_4Vl2J2rQ.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (14ac94f2-bf63-486b-a65f-8bb220df2752.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (ed760345-7751-4da6-9f01-6e6ed051f979.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_W3xocI1TEeW2I_OUujANxA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_8_N3ACy2Eems_sBI210k3g.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_CvU78GQHEeSLGdVI-XsN4w.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_DQ2n4BCgEeeoBvzX9wJhsQ.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_BNSFgKtnEDGNWLI2ml8Hng.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (8c2a0913-7c2a-4acc-8a6b-24d25f19e75c.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (7c651c64-2f3e-4f02-b8e1-e990d87c9ded.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_soJskN_rEeeAyLDAJ12_fg.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (6b915fe0-2411-4158-8629-580ae832eecf.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_MUTtsDnMEeSWIoeppx7IKQ.xmi.uml, line 1)
# Opening and ending tag mismatch: link line 1 and head, line 1, column 442 (_b57_4IWlEemg3PWSmqBV3A.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (__5-aIDD1EeerNZyIpikxPQ.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_Rt8PIDGzEeerNZyIpikxPQ.xmi.uml, line 1)
# Opening and ending tag mismatch: link line 1 and head, line 1, column 442 (_yOd6UFk6EeqK2M3E1LfZ7Q.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (cb20410d-6ab4-4cdb-b95b-d9831155310e.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_tb5msO-UEeSujetaMhozjg.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_cKV-kDzHEeSn3ZXpVIPWYw.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_jbCAEAquEeWNVPA9hBwttA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_D9v3ELwQEeSvIovPojnUsw.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (1648bfb8-15cc-4d99-be61-9bbf29974caf.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (f2aa59dc-3aeb-4787-aaee-1a28414022bd.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_DLNxgOx6EeW6A_AbwsZiiQ.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_rZiSsDNdEeSm5tDnu9wFCA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_dUA9wNHzEeSyKtHqJeGVMw.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_YVGuYA7pEeWa5JwclR5VRw.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_LlPj8Dn1EeewJqDqgRk6VA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (4847db89-182b-474b-ad98-37e2cb8a9db0.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_bcpIgKuvEeiHR4AK89CXpg.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_0d7lYP5CEeSpvbjLqY_W3Q.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_Px5QIE8bEeSEhtn4CKXkiA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_hY2p8APVEeaCaNzs6cfLZA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_OCV9MCRAEDGlaJTZcof-Dw.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_wK1sMFnQEeeY7OxVsdADhA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (3a453767-f5c2-4af5-9526-f084b9de97b2.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_UtZU0NhXEeS-UKCgVrbTiA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_UW21MBrVEeejtu_xKNOcrQ.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_7HlB0JGPEeeaCsv2qBF4QA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (524b516d-8726-4e41-8c1d-a7d04f3ebbe8.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_NqvCMKEVEeawbN_F_HFDxg.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_iK9YADkCEeewJqDqgRk6VA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (27bbca59-b778-43dc-8af8-39aa32ea11ea.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_eZPg8LNpEeSwG8dHYUky5Q.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_N6eq0Ng8EeS-UKCgVrbTiA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_DUUNoJDSEeaAUfyMaYUNEA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (cd2c7d88-784a-4389-8bfc-9807d3e4a7fe.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_SEM1QOSdEeSNGZq_xSbn1w.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_5okl0EdJEeSygayfuMsNCA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_0akXgIu1EeaMz8P8myXedA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_R3sbcEYUEeeTJ_4Vl2J2rQ.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_GyTGQPR2EeOxcf3LRXD4wA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (41f035f8-352e-4fb4-a809-b5b0c1863e52.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (cde4181d-d3a8-43e2-80f5-567c9bf97992.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (a2f2973d-6747-4bfa-a52f-bba0b1a35524.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_SYMcgJ94EeawbN_F_HFDxg.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_0qQVwF7DEeSmRKwulsG6-Q.xmi.uml, line 1)
# xmlParseEntityRef: no name, line 277, column 91 (_3Y1qQEv2Eeeu8_4LH_yuyg.xmi.uml, line 277)
# Start tag expected, '<' not found, line 1, column 1 (_MLHBUCvLEeal2NWrrWbdYQ.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_vJn70I01EeaMz8P8myXedA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_-IRfMBo-Eem5SYGU4M47UA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_oUBQINaBEeWUcZFfD54kTA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_jcRD8LLJEee7sYPkE4-GPA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_CQ2McCBDEeeOINGRvT6ccg.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_V3PUYG-jEea5146oo2aJcA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_gFNs0FBWEeeTnI9B59buBQ.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_A--aUEp5EeS_velUIC8tvA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (96dcefc0-1d4f-49e1-b9b9-32da19e44c8c.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_Vlu6UNE3EDCIQdHQJTgRGA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_1oaK4NXGEeSdItLCkmVTpw.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (0eb997d4-f577-48cf-b87f-528edf7a6c70.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_xVwNcIBUEeSJh_bONjDKhQ.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_Rhz64IDSEeW4cd-qm4QbpA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_bN8Z8JGTEeeaCsv2qBF4QA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_4zpV0LiQEeSzkacHLregNQ.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_GRgNIESVEeSWhcMY2AoZUA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (70927733-6a8a-487a-a8bf-3971b75d7791.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_PqjQoLprEDGNA-fLnGUDhg.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_Z3k_sIFHEeeEVMtrU1Znfg.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_2nj3cJMREDG_H5RkFjJqjg.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_4k3C0E9cEeSEhtn4CKXkiA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_580UkD5GEei-35aR1OYsWA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_iDTuQFyaEemgt8AXxJFj9g.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_-XjcEM_CEeSyKtHqJeGVMw.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_pXOCgJawEeaLdJY0NVKqzQ.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_oAf6kKbhEei1evnFuWTWfg.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_4XPRsC6bEeSxYsF3O4XI1g.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (352985c5-fc33-4b33-b529-09e330ae7a51.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_K1AWgKtuEea217yLRs2OoA.xmi.uml, line 1)
# Opening and ending tag mismatch: link line 1 and head, line 1, column 259 (_1wUrwNvqEeem5ei4kKw8dQ.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_rUCisIc8EeWYk8SDImYsCA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_79nvIHMpEee5HMQDnOR-kg.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (__PR_QEsxEeS_velUIC8tvA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_QaA38LDkEealN5YbbDMqoA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_v0jVUPxnEeSE6sazzutmkA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_kPv8sK1JEeadI_1JHqLxag.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (734857bb-10e1-48ee-8ef4-9a34d8ad3f5e.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_OXyJUJZdEDGdyoFyp4l9hw.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_mosEgGBFEeW9D6sWhFfmrA.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_HCY4kDoCEeSWIoeppx7IKQ.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_EfKZIL5DEDG1vfE2XINvog.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_Jk4CYL6nEeSBntdMhqoN9Q.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_jBy1oIhuEeWSIKoWblTvZg.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (__SM48KzwEeS57ICseEaz5A.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_aXCtoPgDEeSJkrdQR2VoEQ.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (5cf8aafe-fb28-4cd7-ad7f-99d42f938248.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_pAJ10J44EeWWRMvT9FgLDg.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (4223130b-d098-41d8-9acf-f5ef087d71cf.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_6CcSAFO4EeS7SK6lkmJgjw.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_fxlTwNlDEeSpEswBeJxMRQ.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (639942fa-1753-433a-acf2-c189766be951.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (8e81eb17-37f5-4370-99eb-8310b36807b8.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (bbf5e29f-ecb6-473e-821e-f47704a9224b.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_rZpWwAHhEeSc6-5ILiz_HQ.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_6ws_sDpdEeSWIoeppx7IKQ.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_CAh74K2tEeadI_1JHqLxag.xmi.uml, line 1)
# Opening and ending tag mismatch: link line 1 and head, line 1, column 442 (_IkVIwOS8EeekKLRLyKXO4Q.xmi.uml, line 1)
# Start tag expected, '<' not found, line 1, column 1 (_2dak0D-2EeeTJ_4Vl2J2rQ.xmi.uml, line 1)

# %%
data_dict
# Out:
# {'5fae885c-3fde-430f-a3c5-ff44b81f2668.xmi.uml': {'classes': ['ClassA',
#    'ClassB',
#    'ClassC',
#    'ClassD',
#    'ClassE',
#    'ClassF',
#    'ClassG',
#    'ClassH',
#    'ClassI']},
#  '_oVCEUIHiEeeveJPbhFhy-g.xmi.uml': {'classes': ['SitePage', 'SiteSection'],
#   'attributes': ['id',
#    'status',
#    'name',
#    'url',
#    'id',
#    'locked',
#    'name',
#    'defaultPage']},
#  '20b51f77-a952-4206-b35c-b47acd0c631f.xmi.uml': {'classes': ['MoteurImpl',
#    'Buffer',
#    'Selection',
#    'PressePapier'],
#   'attributes': ['texte', 'sel', 'attribute']},
#  'e8a7e84d-73b3-40d2-ac78-f550566b4de8.xmi.uml': {'classes': ['Client',
#    'AdapterImpl',
#    'Adaptee',
#    'Context',
#    'StateA',
#    'StateB',
#    'Singleton',
#    'Abstraction',
#    'RefinedAbstraction',
#    'ConcreteImplementor',
#    'CreatorImpl',
#    'Product',
#    'ConcreteObserver',
#    'ConcreteSubject'],
#   'attributes': ['instance']},
#  '_oWwJoHfLEeqeQcxm9hmzHw.xmi.uml': {'classes': ['ShoppingCart',
#    'Order',
#    'LineItem',
#    'Account',
#    'Customer'],
#   'attributes': ['creationDate', 'id', 'quantity', 'price', 'id']},
#  '_wWY9wDZWEeewJqDqgRk6VA.xmi.uml': {'classes': ['bilal']},
#  '_OR8QgFq_EeeTF9GWmq2Xvg.xmi.uml': {'classes': ['Exam',
#    'Question',
#    'LeadExam',
#    'School',
#    'LeadReport',
#    'LeadSchool',
#    'Class'],
#   'attributes': ['id',
#    'name',
#    'response_columns',
#    'description',
#    'id',
#    'text',
#    'video_unit',
#    'unit_title',
#    'video_chapter',
#    'subject',
#    'id',
#    'lead_name',
#    'lead_phone',
#    'lead_last_name',
#    'group',
#    'school',
#    'result',
#    'exam',
#    'application_date',
#    'id',
#    'identifier',
#    'kind',
#    'maximum_score',
#    'minimum_score',
#    'name',
#    'city',
#    'state',
#    'country',
#    'id',
#    'school',
#    'exam',
#    'lead_exam',
#    'lead_name',
#    'school_name',
#    'school_group',
#    'rank',
#    'version',
#    'correct_answers',
#    'subject_diagnostic',
#    'study_plan',
#    'id',
#    'lead_reports',
#    'school_name',
#    'school_average',
#    'group_diagnostic',
#    'area_diagnostic',
#    'version']},
#  '331af011-1b93-4a9b-abb7-f53d3cfb2a88.xmi.uml': {'classes': ['Client',
#    'Adaptor',
#    'Adaptee']},
#  '9f510af6-1690-4d09-b973-5069cf83647a.xmi.uml': {'classes': ['System',
#    'Sensor',
#    'Motion Sensor',
#    'PressureSensor',
#    'Home Security System',
#    'Alert',
#    'Door',
#    'Camera',
#    'Speakers',
#    'MicroPhone',
#    'Light',
#    'Start Of Day',
#    'End Of Day',
#    'TV',
#    'HomeTheatre',
#    'HouseHolds',
#    'Entertainment'],
#   'attributes': ['Status',
#    'Update',
#    'SensorID',
#    'SensorType',
#    'UserID',
#    'AlertID',
#    'DoorID',
#    'CameraID',
#    'SpeakerID',
#    'MicID',
#    'LightID',
#    'SOT',
#    'EOT',
#    'TVID',
#    'HTID',
#    'TimeID',
#    'Coffee',
#    'DishWasher',
#    'Alarm',
#    'WashingMachine',
#    'DeviceID']},
#  '_3tGxoCVhEeiYD9TOdwevwA.xmi.uml': {'classes': ['Collaborateur',
#    'Pronostique',
#    'Poule',
#    'Competition',
#    'Match',
#    'Equipe'],
#   'attributes': ['id_collaborateur',
#    'nom',
#    'prenom',
#    'email',
#    'password',
#    'role',
#    'id_collaborateur',
#    'id_match',
#    'scoreDomicile',
#    'scoreExterieur',
#    'id_poule',
#    'competition',
#    'libele',
#    'id_competition',
#    'libele',
#    'nombre_poules',
#    'id_match',
#    'poule',
#    'date',
#    'equipeDomicile',
#    'equipeExterieur',
#    'scoreDomicile',
#    'scoreExterieur',
#    'id_equipe',
#    'logo']},
#  '_CFTYQLf4Eee7sYPkE4-GPA.xmi.uml': {'classes': ['MyClass']},
#  '_AkJqwL2EEeirD7wkg7WdAw.xmi.uml': {'classes': ['CUSTOMER', 'USER'],
#   'attributes': ['csname',
#    'cs_phon no.',
#    'address',
#    'credit_cardinfo',
#    'email',
#    'user_id',
#    'password',
#    'login_status']},
#  '_B4ZY0F8QEeepGY91r9Nuow.xmi.uml': {'classes': ['Vente',
#    'Promotion',
#    'Magasin',
#    'Article',
#    'Periode'],
#   'attributes': ['id_magasin',
#    'id_client',
#    'id_periode',
#    'id_article',
#    'id_promotion',
#    'montant_vente',
#    'taxe',
#    'unités_vendes',
#    'numero_ticket_caisse',
#    'id_promotion',
#    'nom_promotion',
#    'taux_remise',
#    'id_magasin',
#    'nom_magasin',
#    'adresse_magasin',
#    'nom_gérant',
#    'département',
#    'id_article',
#    'nom_article',
#    'marque_article',
#    'attribute',
#    'id_periode',
#    'année',
#    'mois',
#    'jour']},
#  '_xoz1gHe2EeiFX4HwoivBqg.xmi.uml': {'classes': ['Batisseur',
#    'Case',
#    'Domino',
#    'IHMKingdomino',
#    'IHMSantorini',
#    'Index',
#    'KingDomino',
#    'PiocheDomino',
#    'Plateau',
#    'Santorini',
#    'javax.swing.JFrame',
#    'javax.swing.JPanel',
#    'javax.swing.JButton',
#    'java.awt.event.ActionEvent'],
#   'attributes': ['posX',
#    'posY',
#    'hauteur',
#    'nom',
#    'nbCouronnes',
#    'numero',
#    'roi',
#    'pPrincipal',
#    'grille1',
#    'grille2',
#    'pDomino',
#    'pBasDroite',
#    'pBouton',
#    'pDirection',
#    'ensDominos',
#    'ensBoutonsGauche',
#    'ensBoutonsDroite',
#    'ensDominos1',
#    'boutonNord',
#    'boutonSud',
#    'boutonEst',
#    'boutonOuest',
#    'retour',
#    'regles',
#    'quitter',
#    'action',
#    'ligne',
#    'colonne',
#    'nbTours',
#    'ordre',
#    'principal',
#    'visionJeu',
#    'buttonJeu',
#    'panelDroite',
#    'panelLogo',
#    'retour',
#    'regle',
#    'quitter',
#    'bouton',
#    'action',
#    'conteurBati',
#    'choixBati',
#    'tourJoueur',
#    'tempPosX',
#    'tempPosY',
#    'posX',
#    'posY',
#    'tempEtage',
#    'ensBati',
#    'principal',
#    'santorini',
#    'regleSantorini',
#    'kingDomino',
#    'allRois',
#    'nbRois',
#    'nbJoueurs',
#    'nbDominos',
#    'player',
#    'royaumeJoueur1',
#    'royaumeJoueur2',
#    'plateau',
#    'ensBati',
#    'conteurBati',
#    'joueur1',
#    'joueur2']},
#  '_C3TewPaFEeWolbMxsR5EUQ.xmi.uml': {'classes': ['File'],
#   'attributes': ['File server', 'File local']},
#  '_2Jq9QK0KEDGNWLI2ml8Hng.xmi.uml': {'classes': ['Lab3',
#    'ServerConnection',
#    'Gameboard',
#    'JFrame',
#    'JPanel',
#    'Server']},
#  '_GbX-wK10EemHYc7DDM2g2A.xmi.uml': {'classes': ['Animal',
#    'Employee',
#    'Tortoise',
#    'Otter',
#    'Slow Loris',
#    'Sea Urchin',
#    'Creep',
#    'Lobby',
#    'Bathroom',
#    'Visitor Center'],
#   'attributes': ['name',
#    'id',
#    'age',
#    'weight',
#    'name',
#    'employeeId',
#    'phone',
#    'department',
#    'whiskerLength']},
#  '_WZQeEMJ8EeSII650IQ0Z1w.xmi.uml': {'classes': ['ReportSettings<T>',
#    'ReportSettingsAccessor',
#    'ReportDataManager<T>',
#    'ReportAccessor<T>',
#    'Report<T>',
#    'reportconfigurationblade.proxy.aspx.cs',
#    'aaaa']},
#  '_rGklUKQCEeWJIdgJ_zFBoQ.xmi.uml': {'classes': ['ENTREPRISE',
#    'PRODUIT',
#    'MyClass'],
#   'attributes': ['Nom', 'NomProd', 'Num']},
#  '_n6vpQN9FEea4oJwuIIj5Zg.xmi.uml': {'classes': ['Golpes', 'Tipo'],
#   'attributes': ['codigo', 'nome', 'tipo', 'categoria', 'codigo', 'nome']},
#  '_UBfU4MCnEeeEXb8Dudo6PQ.xmi.uml': {'classes': ['CloneDetectionNewUI',
#    'ddgRightDialog',
#    'ddgBottomDialog',
#    'historySpreadSheetSource',
#    'SpreadSheetObjectTreeView',
#    'treeViewSpreadSheetSource',
#    'SpreadSheetObjectListView',
#    'listViewSpreadSheetSource',
#    'HistorySpreadSheetObj',
#    'SimilarityPlotSpreadSheetObj',
#    'similarityPlotSpredSheetSource']},
#  '_TCwTALi_Eeaud6jyFEReOw.xmi.uml': {'classes': ['Casino',
#    'admin',
#    'game',
#    'table',
#    'player',
#    'gametype',
#    'rule'],
#   'attributes': ['id',
#    'name',
#    'id',
#    'password',
#    'starttime',
#    'number',
#    'connectedplrs',
#    'id',
#    'password',
#    'balance',
#    'game',
#    'maxplayer',
#    'id',
#    'desc']},
#  '_Eta50N0oEeS1iL_C3WP8Cw.xmi.uml': {'classes': ['tblUsers', 'tblOrder'],
#   'attributes': ['UserID',
#    'UserName',
#    'Password',
#    'FullName',
#    'Role',
#    'VIP',
#    'Status',
#    'OrderID',
#    'UserName',
#    'Password',
#    'FullName',
#    'Role',
#    'VIP',
#    'Status']},
#  '_YlTgsCASEeiv8MB6k6XBAg.xmi.uml': {'classes': ['MyFrame',
#    'ControlPanel',
#    'DrawingPanel',
#    'Rect',
#    'Class',
#    'Graphics',
#    'DrawingPanel',
#    'Shape',
#    'Circle',
#    'Rect',
#    'DrawingPanel',
#    'Circle',
#    'Rect',
#    'Circle',
#    'DrawingPanel',
#    'Rect',
#    'DrawingPanel',
#    'Shape',
#    'Circle',
#    'Dog',
#    'Test',
#    'IdGenerator',
#    'Cat',
#    'Rect',
#    'CanBeDrawn',
#    'PolyGen',
#    'Slacker'],
#   'attributes': ['name', 'id', 'CURRENT_ID', 'id', 'name']},
#  '_O9PI8GyeEDGXH9FO528ZpA.xmi.uml': {'classes': ['DVD',
#    'Book',
#    'Library_Managnment_System',
#    'Item',
#    'Staff',
#    'Libarian',
#    'Member',
#    'Clerk'],
#   'attributes': ['Type',
#    'count1',
#    'Type',
#    'count',
#    'ItemLinker',
#    'Mem',
#    'Cler',
#    'availability',
#    'issued',
#    'onloan',
#    'reference',
#    'Name',
#    'ID',
#    'Name',
#    'ID']},
#  '93552bd2-6e15-45b3-b1dd-3a4aa6b3b0b3.xmi.uml': {'classes': ['ChatServer',
#    'ChatClient',
#    'Couleur',
#    'History',
#    'User',
#    'Session',
#    'JFrame'],
#   'attributes': ['getValue']},
#  '_UWr2cM_JEeeLcIicqHdTUQ.xmi.uml': {'classes': ['CurrencyConverter',
#    'USCurrencyConverter',
#    'CanadianCurrencyConverter',
#    'TaskController',
#    'SalesOrder',
#    'MyClass',
#    'CalcTax'],
#   'attributes': ['getCurrencyForCountry()', 'getTaxRulesForCountry()']},
#  '_tGyV0EbLEeeTJ_4Vl2J2rQ.xmi.uml': {'classes': ['ExampleInstrumentedTest',
#    'FightScreen',
#    'StartMenu',
#    'AboutFragment',
#    'CustomHealthBar',
#    'CustomManaBar',
#    'CustomMenuButton',
#    'CustomMenuPlayButton',
#    'LogoFragment',
#    'SettingsFragment',
#    'Game',
#    'GamePanel',
#    'MainThread',
#    'Singleton',
#    'BitmapCache',
#    'Character',
#    'Dummy',
#    'Enemy',
#    'Exit',
#    'GameObject',
#    'Ground',
#    'Player',
#    'Wall',
#    'Level',
#    'Section',
#    'ExampleUnitTest',
#    'android.app.Activity',
#    'android.app.Fragment',
#    'android.widget.LinearLayout',
#    'android.view.SurfaceView',
#    'java.lang.Thread',
#    'java.util.HashMap'],
#   'attributes': ['playerHealthText',
#    'enemyHealthText',
#    'playerManaText',
#    'playerActionText',
#    'enemyActionText',
#    'playerImage',
#    'enemyImage',
#    'healthPotionButton',
#    'manaPotionButton',
#    'attackButton',
#    'specialAttackButton',
#    'MAX_VOLUME',
#    'mediaPlayer',
#    'volumeForPlayer',
#    'health',
#    'maxHealth',
#    'blackPaint',
#    'redPaint',
#    'mana',
#    'maxMana',
#    'blackPaint',
#    'bluePaint',
#    'WIDTH',
#    'HEIGHT',
#    'horizontalTiles',
#    'verticalTiles',
#    'tileWidth',
#    'tileHeight',
#    'paint',
#    'FPS',
#    'averageFPS',
#    'surfaceHolder',
#    'running',
#    'canvas',
#    'context',
#    'cache',
#    'name',
#    'health',
#    'maxHealth',
#    'attack',
#    'health',
#    'attack',
#    'maxHealth',
#    'specialAtack',
#    'maxMana',
#    'mana',
#    'name',
#    'amountOfHealthPotions',
#    'amountOfManaPotions',
#    'toSection',
#    'x',
#    'y',
#    'solid',
#    'image',
#    'imageRef',
#    'amountOfHealthPotions',
#    'amountOfManaPotions',
#    'mana',
#    'maxMana',
#    'specialAttack']},
#  '_rRbrsL2FEeedTfUoC-GfaA.xmi.uml': {'classes': ['Snake'],
#   'attributes': ['attribute']},
#  '_r3GXcCFEEeiv8MB6k6XBAg.xmi.uml': {'classes': ['Utilisateur',
#    'Profil',
#    'Système',
#    'Base de données',
#    'Serveur'],
#   'attributes': ['profil', 'nom', 'âge', 'mot de passe', 'genre']},
#  '_UvEXMEGiEemokbRu9Ld3Pw.xmi.uml': {'classes': ['Individu',
#    'Film',
#    'Cinéma',
#    'Séance',
#    'Individu',
#    'Groupe',
#    'Contacts',
#    'Individu2',
#    'Film2',
#    'Cinéma2',
#    'Séance2',
#    'Groupe',
#    'Contact'],
#   'attributes': ['Nom',
#    'Age',
#    'Nom',
#    'Nom',
#    'Ville',
#    'Date',
#    'Heure',
#    'Nom',
#    'Age',
#    'Nom',
#    'Nom',
#    'Ville',
#    'Date',
#    'Heure']},
#  '_0se6kFNjEeS7SK6lkmJgjw.xmi.uml': {'classes': ['$.insmRegionView',
#    '$.insmBase',
#    '$.insmRestService',
#    '$.insmAssetLoaderIndicator',
#    'insmRegionEventConstant',
#    '$.insmPlayListGrid',
#    'insmPlayListGridEventConstant',
#    '$.insmPlayListManager',
#    'insmPlayListManagerEventConstant',
#    'Object',
#    '$.insmPlayListEditor',
#    '$.insmAddNewPopup'],
#   'attributes': ['CurrentSelectedNodes',
#    'tag',
#    '$.deffer',
#    'RegionDatacollection',
#    'PlayListItems',
#    'AddOnTeamplateCollection',
#    'ONCHECKNODE',
#    'ONCLICKNODE',
#    'CurrentSelectedRow',
#    'ONREMOVEITEM',
#    'ONEDITITEM',
#    'SEARCHREGION',
#    'CLEARRELATION',
#    'REMOVESELECTION',
#    'SEARCHPLAYLIST',
#    'GETDATA',
#    'CurrentMediaType',
#    'Settings']},
#  '48ecca9d-91d4-44f2-a21f-b0285228d504.xmi.uml': {'classes': ['jsdf',
#    'className',
#    'MyClass'],
#   'attributes': ['dfsd']},
#  '45467683-bfda-4a59-aee6-262b47b819db.xmi.uml': {'classes': ['Level',
#    'Category'],
#   'attributes': ['State', 'Name', 'id', 'level']},
#  '_qlo-cJalEeaLdJY0NVKqzQ.xmi.uml': {'classes': ['User']},
#  '_bTMxUGfCEDGY580vxrGduA.xmi.uml': {'classes': ['MyClass']},
#  '_IjzBoFWBEemYjay6yoFVQw.xmi.uml': {'classes': ['Prodavac',
#    'Nabavka',
#    'Dobavljač',
#    'Račun',
#    'Proizvod',
#    'Vrsta proizvoda',
#    'Kupac',
#    'Plaćanje u gotovini',
#    'Plaćanje',
#    'Plaćanje sa karticom',
#    'Plaćanje karticom',
#    'Plaćanje u gotovini'],
#   'attributes': ['ProdavacID',
#    'Ime',
#    'Prezime',
#    'e-mail',
#    'Kontakt telefon',
#    'Napomena',
#    'NabavkaID',
#    'Datum',
#    'Kolicina',
#    'Iznos',
#    'Vreme',
#    'Napomena',
#    'ProdavacID',
#    'DobavljacID',
#    'ProizvodID',
#    'DobavljacID',
#    'Naziv',
#    'Maticni broj',
#    'Kontakt telefon',
#    'Adresa',
#    'Mesto',
#    'Napomena',
#    'RacunID',
#    'Datum',
#    'Vreme',
#    'Kolicina',
#    'Iznos',
#    'ProdavacID',
#    'Napomena',
#    'PlaćanjeID',
#    'ProizvodID',
#    'Naziv',
#    'Napomena',
#    'DobavljacID',
#    'VrstaProizvodaID',
#    'NabavkaID',
#    'Iznos',
#    'Napomena',
#    'ProdavacID',
#    'Ime',
#    'Prezime',
#    'e-mail',
#    'Kontakt telefon',
#    'Napomena',
#    'ProdavacID',
#    'Ime',
#    'Prezime',
#    'e-mail',
#    'Kontakt telefon',
#    'Napomena',
#    'ProizvodID',
#    'RačunID',
#    'ProdavacID',
#    'Ime',
#    'Prezime',
#    'Kontakt telefon',
#    'ProizvodID',
#    'RačunID',
#    'ProizvodID',
#    'RačunID']},
#  '_kUTfkMkMEeeM1PgT03-3Vg.xmi.uml': {'classes': ['LoginTbl',
#    'AddNewsTbl',
#    'FeedbackTbl',
#    'EmployeeTbl',
#    'RegistrationTbl'],
#   'attributes': ['UserName',
#    'Password',
#    'ID',
#    'News_Image',
#    'News_Description',
#    'Bookmark',
#    'ID',
#    'feedback',
#    'ID',
#    'MailAddress',
#    'UserName',
#    'Password',
#    'City',
#    'Dob',
#    'Gender']},
#  '_89yH0D-DEeWH0sFqYQQ8Cg.xmi.uml': {'classes': ['Server'],
#   'attributes': ['var1']},
#  '_Mx7t0OmWEeaowdqlt8Dqsg.xmi.uml': {'classes': ['Déplacement',
#    'Etape',
#    'Station',
#    'StationExtrémité',
#    'StationNoeud'],
#   'attributes': ['idContainer',
#    'date',
#    'heureDépart',
#    'heureArrivée',
#    'priorité',
#    'numEtape',
#    'heureArrivée',
#    'heureDépart',
#    'idStation',
#    'nom',
#    'localisation',
#    'tailleZoneDeGroupage',
#    'occupée']},
#  '_m43vEEhOEemB7r6RYSs12w.xmi.uml': {'classes': ['Ads', 'Event', 'Product']},
#  '_pBW_QHLCEee5HMQDnOR-kg.xmi.uml': {'classes': ['Crew',
#    'CrewPilot',
#    'Plane',
#    'Schedule'],
#   'attributes': ['crewID',
#    'crewName',
#    'crewAddress',
#    'crewPhone',
#    'pilotLicense',
#    'planeID',
#    'scheduleTime',
#    'schedulePlane',
#    'scheduleCrew',
#    'scheduleDeparture',
#    'scheduleNote',
#    'scheduleArrival']},
#  '_7Qd5sHVJEeSZWo9AFr5YZg.xmi.uml': {'classes': ['Benchmark-Controller',
#    'LoadDriver',
#    'Database',
#    'Transaktions',
#    'Remote',
#    'InitDatabase']},
#  '4465670b-b7f1-4505-8c09-e163b6a629a7.xmi.uml': {'classes': ['ShoppingCart']},
#  'b66a0071-5321-4795-a59c-96ff8cc34f37.xmi.uml': {'classes': ['Worker',
#    'People',
#    'Customer',
#    'Cook',
#    'Waiter',
#    'Cashier'],
#   'attributes': ['name']},
#  '42797400-89dc-4192-8cac-7f67e4e4fbc3.xmi.uml': {'classes': ['Registration'],
#   'attributes': ['attribute']},
#  '19cf5401-6e76-4e4d-81d8-309f156151f5.xmi.uml': {'classes': ['SessionRepositoryFilter',
#    'ExpiringSessionHttpSession',
#    'MultiHttpSessionStrategyAdapter',
#    'HeaderHttpSessionStrategy',
#    'ExpiringSession']},
#  '_GhGBELsKEeWdWJbDFmNa8w.xmi.uml': {'classes': ['Conta', 'Ganho', 'Pessoa'],
#   'attributes': ['numero',
#    'nome',
#    'valor',
#    'situacao',
#    'id',
#    'nome',
#    'valor',
#    'situacao',
#    'id']},
#  '_zeUN8FJjEeeTnI9B59buBQ.xmi.uml': {'classes': ['AdminHomeActivity',
#    'BackgroundMaterialActivity',
#    'CategoryActivity',
#    'EditDomainsActivity',
#    'LeaderboardActivity',
#    'PasswordResetActivity',
#    'PerformanceActivity',
#    'QuizActivity',
#    'RemoveUserActivity',
#    'DomainAdapter',
#    'LeaderboardAdapter',
#    'QuestionAdapter',
#    'UserAdapter',
#    'Answer',
#    'CategoryContent',
#    'Material',
#    'Question',
#    'QuestionItem',
#    'Score',
#    'User',
#    'UserScore',
#    'LoginFragment',
#    'PasswordRecoveryFragment',
#    'PasswordResetFragment',
#    'QuizResultDialogFragment',
#    'RegisterFragment',
#    'Constants',
#    'StringUtils',
#    'android.support.v7.app.AppCompatActivity',
#    'android.app.ListActivity',
#    'android.support.v4.app.Fragment',
#    'android.support.v4.app.FragmentPagerAdapter',
#    'android.widget.BaseAdapter',
#    'android.support.v4.app.DialogFragment',
#    'java.lang.Object',
#    'ArrayAdapter<String>',
#    'ArrayAdapter<QuestionItem>',
#    'ArrayAdapter<User>'],
#   'attributes': ['mAuth',
#    'mAuthStateListener',
#    'mLeaderboardBtn',
#    'mEditDomainsBtn',
#    'mAddUserBtn',
#    'mRemoveUserBtn',
#    'mLogoutBtn',
#    'mCategory',
#    'mCategoryTextView',
#    'mStartQuizBtn',
#    'mBackgroundText',
#    'mDatabase',
#    'mCategoryList',
#    'mProgressDialog',
#    'mListView',
#    'mBtnContainer',
#    'addDomainBtn',
#    'saveDomainBtn',
#    'mDatabase',
#    'mDomains',
#    'mKeys',
#    'mDomain',
#    'mPosition',
#    'mEditMode',
#    'mDatabase',
#    'mProgressDialog',
#    'tabLayout',
#    'mViewPager',
#    'mAuth',
#    'user',
#    'mCurrentPasswordView',
#    'mNewPasswordView',
#    'mNewPassword2View',
#    'mChangePasswordButton',
#    'mCancelButton',
#    'mResetProgressView',
#    'mPasswordResetFormView',
#    'cancel',
#    'focusView',
#    'mQuizzesTextView',
#    'mScoreTextView',
#    'mCurrentRankTextView',
#    'mBestRankTextView',
#    'mProgressDialog',
#    'mDatabase',
#    'mCategory',
#    'mDatabase',
#    'mQuizScore',
#    'isReviewMode',
#    'mQuestionListView',
#    'mCategoryTextView',
#    'mViewPager',
#    'mResultTextView',
#    'mListView',
#    'mDatabase',
#    'mUserKeyList',
#    'mAuth',
#    'mDomains',
#    'mContext',
#    'mEditableList',
#    'mEditableBtnList',
#    'mEditedDomainName',
#    'mActivity',
#    'mContext',
#    'mQuestions',
#    'mLayoutId',
#    'isReview',
#    'mTextView',
#    'mActivity',
#    'text',
#    'isCorrect',
#    'img',
#    'isSelected',
#    'questions',
#    'text',
#    'imgs',
#    'text',
#    'img',
#    'answers',
#    'isAnswered',
#    'number',
#    'isSelected',
#    'isCorrect',
#    'isAttempted',
#    'correct',
#    'quizzes',
#    'bestRank',
#    'currentRank',
#    'percentage',
#    'firstName',
#    'lastName',
#    'email',
#    'password',
#    'isAdmin',
#    'mEmailView',
#    'mPasswordView',
#    'mProgressView',
#    'mLoginFormView',
#    'mEmailEditText',
#    'mUrl',
#    'ARG_PARAM_URL',
#    'mWebView',
#    'mProgressDialog',
#    'mQuizResultTextView',
#    'mEmailView',
#    'mPasswordView',
#    'mPasswordView2',
#    'mFirstName',
#    'mLastName',
#    'mProgressView',
#    'mRegisterFormView',
#    'mRegisterButton',
#    'ARG_PARAM1',
#    'ARG_PARAM2',
#    'mParam1',
#    'mParam2',
#    'mDatabase',
#    'domainRef',
#    'mDomains',
#    'CATEGORY_NAME',
#    'NUM_QUESTIONS_PER_QUIZ',
#    'QUESTION_PREFIX',
#    'COLOR_QUESTION_SELECTED',
#    'COLOR_QUESTION_CORRECT',
#    'COLOR_QUESTION_INCORRECT',
#    'DB_QUESTIONS',
#    'DB_SCORES',
#    'DB_SCORES_UPDATED',
#    'DB_USERS',
#    'DB_DOMAINS',
#    'HOST']},
#  '_8y0sAIKDEeeveJPbhFhy-g.xmi.uml': {'classes': ['STUDENT REGISTRATION',
#    'TEACHERS REGISTRATION',
#    'MyClass']},
#  '_YRK-gLc7EeWh17zD5SB95Q.xmi.uml': {'classes': ['Request',
#    'Status',
#    'Department',
#    'ApplicationUser',
#    'RequestEvent',
#    'RequestEventDetail'],
#   'attributes': ['id',
#    'topic',
#    'status',
#    'department',
#    'citizen',
#    'assignee',
#    'events',
#    'id',
#    'comment',
#    'date',
#    'attribute',
#    'isPublic',
#    'Author',
#    'details',
#    'id',
#    'text']},
#  '_0fYbULfaEee7sYPkE4-GPA.xmi.uml': {'classes': ['library',
#    'librarian',
#    'books database',
#    'student',
#    'vendor',
#    'student record'],
#   'attributes': ['location',
#    'name',
#    'book title',
#    'author',
#    'book id',
#    'details',
#    'book details',
#    'attribute',
#    'name',
#    'address',
#    'phone number',
#    'fines']},
#  '_P5FiwC-mEeme-prEJQaJbA.xmi.uml': {'classes': ['Ebook',
#    'Configuracoes',
#    'Decodificador',
#    'CelulaBraille']},
#  '_VTRjAHomEeSdXJMJcKNKoQ.xmi.uml': {'classes': ['Personal',
#    'Användare',
#    'Elev',
#    'Lågstadiet',
#    'Mellanstad',
#    'MyClass'],
#   'attributes': ['namn',
#    'behörighet',
#    'ID',
#    'yrkesroll',
#    'namn',
#    'behörighet',
#    'Id',
#    'namn',
#    'behörighet',
#    'Id',
#    'attribute']},
#  '_Vfe9wHL5EeSxHp9pHOThjg.xmi.uml': {'classes': ['Trader']},
#  'a093a6c4-4491-4b65-b79a-19be1bd57765.xmi.uml': {'classes': ['Customer',
#    'Payment',
#    'ShoppingCart',
#    'Account',
#    'WebUser',
#    'Order',
#    'LineItem',
#    'Product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paidDate',
#    'total',
#    'details',
#    'creationDate',
#    'billingAddress',
#    'open',
#    'closed',
#    'isClosed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'shipTo',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description']},
#  '_NpOgoK7zEee6S77dw3LIvQ.xmi.uml': {'classes': ['AppPartidoBasketball',
#    'Equipo',
#    'PartidoBasketball',
#    'Jugador'],
#   'attributes': ['nombre',
#    'ciudad',
#    'titulo: String',
#    'dia: byte',
#    'nombre',
#    'apellido',
#    'estatura']},
#  '_2A0eUK99EealN5YbbDMqoA.xmi.uml': {'classes': ['Modification',
#    'DegreeModifacion',
#    'ModuleModification',
#    'Obsever',
#    'Observable',
#    'ModifyDegree',
#    'DeleteDegree',
#    'ModifyModule',
#    'DeleteModule'],
#   'attributes': ['modId',
#    'status',
#    'title',
#    'degreeCode',
#    'level',
#    'moduleCode',
#    'level',
#    'update',
#    'addObserver(observer:Observer',
#    'removeObserver(observer:Observer',
#    'notifyAll']},
#  '_fRRYMELoEeavkcsFwndrbA.xmi.uml': {'classes': ['Animal'],
#   'attributes': ['name', 'size', 'color']},
#  '_xOaacKYVEeaiBJ7PH1W80g.xmi.uml': {'classes': ['Personel',
#    'Ticket',
#    'Yetkilendirme'],
#   'attributes': ['PersonelID',
#    'Personelİsim',
#    'PersonelMevki',
#    'PersonelBolum',
#    'TicketID',
#    'TicketTarih',
#    'TicketDetay',
#    'PersonelID',
#    'TicketDurum',
#    'SorunCesidi',
#    'Cozum',
#    'TicketID',
#    'PersonelID']},
#  '_bunGYGkdEeSmTqqtE6wM_Q.xmi.uml': {'classes': ['Guest',
#    'User',
#    'Player',
#    'Moderator',
#    'Email Server',
#    'Database',
#    'Android Application Instance',
#    'Clarification Request',
#    'Game',
#    'Mission',
#    'Kill',
#    'GeoFence',
#    'GeoPoint',
#    'Page',
#    'Global Update',
#    'Dynamic Game Map'],
#   'attributes': ['roleID',
#    'HVZID',
#    'email',
#    'password',
#    'firstName',
#    'lastName',
#    'kills',
#    'createdAt',
#    'playedGames',
#    'paidDues',
#    'isSubscribed',
#    'phoneNumber',
#    'playerType',
#    'inGame',
#    'GPSTrackingOn',
#    'name',
#    'IP',
#    'subscribedEmails',
#    'username',
#    'password',
#    'emailsToSend',
#    'name',
#    'IP',
#    'username',
#    'password',
#    'instanceID',
#    'userLoggedIn',
#    'deviceName',
#    'latitude',
#    'longitude',
#    'timeOfGPS',
#    'isTracking',
#    'missionID',
#    'isAnswered',
#    'responseUser',
#    'sourceUser',
#    'message',
#    'response',
#    'gameID',
#    'missions',
#    'description',
#    'players',
#    'isCurrent',
#    'missionID',
#    'gameID',
#    'geoFences',
#    'geoPoints',
#    'description',
#    'roleID',
#    'vicitmUser',
#    'killerUser',
#    'timeOfDeath',
#    'inGameID',
#    'centerLatitude',
#    'centerLongitude',
#    'radius',
#    'triggerPlayers',
#    'score',
#    'scoreModifier',
#    'endScore',
#    'description',
#    'inMissionID',
#    'triggerRate',
#    'seenByPlayers',
#    'isVisible',
#    'latitude',
#    'longitude',
#    'description',
#    'inMissionID',
#    'seenByPlayers',
#    'isVisible',
#    'url',
#    'information',
#    'title',
#    'message',
#    'sourceUser',
#    'pushNotificationSent',
#    'emailNotificationSent',
#    'mission']},
#  'dc7ae9ed-7cf7-4298-844e-489bbc9faeea.xmi.uml': {'classes': ['ShoppingCart']},
#  '_zkx8wOKPEeiZY7VjYQykuQ.xmi.uml': {'classes': ['Control',
#    'SuperBKCompare',
#    'BKCompareWriteToExcel',
#    'BKCompareWriteToText',
#    'SuperBKReader',
#    'BKWriter']},
#  '_SaUicIB4Eei-m5BAOg12zA.xmi.uml': {'classes': ['Character',
#    'SavingThrow',
#    'Weapon'],
#   'attributes': ['name',
#    'race',
#    'vocation',
#    'isPlayer',
#    'str',
#    'dex',
#    'cons',
#    'intel',
#    'wis',
#    'chr',
#    'saveThrow',
#    'hp',
#    'hitDice',
#    'equipped',
#    'isProficient',
#    'profBonus',
#    'name',
#    'range',
#    'damage',
#    'atkBonus']},
#  '_Sefo0H_cEDGdNIjA6xbcew.xmi.uml': {'classes': ['UITextView',
#    'UIImagePickerController',
#    'UITextField',
#    'UIAlertView',
#    'UIImageView',
#    'UIView',
#    'UIControl',
#    'Button',
#    'UIActivityIndicatorView',
#    'PerformEncript',
#    'StagoCustomView',
#    'StagoDisplayUpdater',
#    'PerformDecrypt',
#    'StaganographyManager']},
#  '_34klgCFXEeqqcaoAsxFIeg.xmi.uml': {'classes': ['Book',
#    'Reader',
#    'Librarian',
#    'Borrowing',
#    'User'],
#   'attributes': ['id',
#    'name',
#    'no',
#    'writer',
#    'press',
#    'address',
#    'total',
#    'id',
#    'name',
#    'no',
#    'age',
#    'sex',
#    'department',
#    'telephoneNumber',
#    'id',
#    'name',
#    'no',
#    'sex',
#    'age',
#    'telephoneNumber',
#    'date',
#    'id',
#    'username',
#    'password']},
#  '_JuQ-QJvREeSW9selBczv3Q.xmi.uml': {'classes': ['IFigura',
#    'IColor',
#    'Rectangulo',
#    'Circulo',
#    'Cuadrilatero'],
#   'attributes': ['PI', 'base', 'altura', 'radio']},
#  '_lC7ZAGxcEem8aOzn3EOqfg.xmi.uml': {'classes': ['Order']},
#  '_tHhBAFSKEei2efM7H4gIXw.xmi.uml': {'classes': ['Boleto',
#    'Contrato',
#    'Parcela',
#    'flo'],
#   'attributes': ['numBoleto',
#    'codCliente',
#    'codBarra',
#    'datReneg',
#    'datVencimento',
#    'valSaldoDev',
#    'valSaldoReneg',
#    'valPercDesc',
#    'indCampanha',
#    'numQtdeParc',
#    'valPrest',
#    'valDescPrest',
#    'valLiquPrest',
#    'numBoleto',
#    'codCliente',
#    'codProduto',
#    'numContrato',
#    'nomProduto',
#    'valSaldoDev',
#    'valSaldoReneg',
#    'valEncargo',
#    'valTarifa',
#    'numBoleto',
#    'codProduto',
#    'numContrato',
#    'numParcela']},
#  '1071140d-9c5d-46d3-aa90-f9b348ebfac9.xmi.uml': {'classes': ['Customer',
#    'Payment',
#    'ShoppingCart',
#    'Account',
#    'WebUser',
#    'Order',
#    'LineItem',
#    'Product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paidDate',
#    'total',
#    'details',
#    'creationDate',
#    'billingAddress',
#    'open',
#    'closed',
#    'isClosed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'shipTo',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description']},
#  '72bffa82-db26-4d26-a139-b38884dada59.xmi.uml': {'classes': ['Clients',
#    'Login',
#    'Administrator',
#    'WhoMadeChanges',
#    'AccountExpired',
#    'MakePay',
#    'ChangePassword',
#    'Events',
#    'AddAdditionalData',
#    'AdvanceSearch']},
#  '_z-y1oKPNEeikWfbDNPV9UQ.xmi.uml': {'classes': ['Class']},
#  '_iAN1sIYZEeS_9vPfFC3tSQ.xmi.uml': {'classes': ['Dog',
#    'Lab',
#    'Poodle',
#    'Shepard',
#    'Pitbull',
#    'Pug',
#    'Beagle'],
#   'attributes': ['gender', 'breed', 'weight', 'color', 'eyeColor']},
#  '43125ec2-0e31-4d4d-98d2-2ca18c1a08ba.xmi.uml': {'classes': ['Client',
#    'Adaptor',
#    'Adaptee']},
#  'b11d83f2-57be-4197-b073-33b29a12e551.xmi.uml': {'classes': ['Worker',
#    'People',
#    'Customer',
#    'Cook',
#    'Waiter',
#    'Cashier'],
#   'attributes': ['name']},
#  '_CwucMBNMEeSTV6l4790RsQ.xmi.uml': {'classes': ['Mensagem',
#    'Twitter',
#    'Facebook',
#    'Utilizador']},
#  '_ozUCAFmYEeaQF8q9ZsVYhQ.xmi.uml': {'classes': ['SingleDataCombiner',
#    'LatestValueCombiner',
#    'GreatestValueCombiner',
#    'CustomCombiner',
#    'CombinedCombiner',
#    'PriorityCombiner',
#    'RuleBasedCombiner']},
#  '_mu7qEH1yEeShroDxTnL5_A.xmi.uml': {'classes': ['SingleDataCombiner',
#    'LatestValueCombiner',
#    'GreatestValueCombiner',
#    'CustomCombiner',
#    'CombinedCombiner',
#    'PriorityCombiner',
#    'RuleBasedCombiner']},
#  '_vgKXsMUIEeadwOIOqK-0Fw.xmi.uml': {'classes': ['MyClass']},
#  'd5c157b6-912e-4995-9d8f-bd5f2aa2ee9f.xmi.uml': {'classes': ['Client',
#    'AdapterImpl',
#    'Adaptee',
#    'Context',
#    'StateA',
#    'StateB',
#    'Singleton',
#    'Abstraction',
#    'RefinedAbstraction',
#    'ConcreteImplementor',
#    'CreatorImpl',
#    'Product',
#    'ConcreteObserver',
#    'ConcreteSubject'],
#   'attributes': ['instance']},
#  '_Hr1JoIwLEeewrIfYd5mf8Q.xmi.uml': {'classes': ['MonetateEvent',
#    'MonetateEventProductView',
#    'MonetateEventPurchase',
#    'MonetateProcessor',
#    'Product',
#    'MessageProcessor'],
#   'attributes': ['eventType',
#    'products',
#    'purchaseLines',
#    'NAME',
#    'SETTING_API_KEY',
#    'SETTING_MAILING_LIST_ID',
#    'domain',
#    'instance',
#    'accountId',
#    'apiURL',
#    'sku',
#    'pid',
#    'quantity',
#    'currency',
#    'value']},
#  '_1ybHgIT-EeS-18kfrtGUQQ.xmi.uml': {'classes': ['Quran surah'],
#   'attributes': ['Surah_no', 'Name_of_surah', 'Type_of_surah']},
#  'f959fb74-a45e-4e26-a37d-ff5dad352c49.xmi.uml': {'classes': ['Worker',
#    'People',
#    'Customer',
#    'Cook',
#    'Waiter',
#    'Cashier'],
#   'attributes': ['name']},
#  'e62c26ba-de91-443d-8dec-baa035e40d26.xmi.uml': {'classes': ['ShoppingCart',
#    'Order',
#    'LineItem',
#    'Account',
#    'Customer'],
#   'attributes': ['creationDate', 'id', 'quantity', 'price', 'id']},
#  '_SHt8QP2_EeOTCK1Mp6laew.xmi.uml': {'classes': ['Main_class',
#    'About',
#    'Documents',
#    'Encryption',
#    'Decryption',
#    'SS_generator',
#    'App_Password']},
#  '_tWiXAE-oEeeu8_4LH_yuyg.xmi.uml': {'classes': ['_core', 'person', 'company'],
#   'attributes': ['id', 'value', 'PersonCode', 'RegistrationNr', 'VATNr']},
#  '_0ato4He_EeeZ3IbHHpTTiA.xmi.uml': {'classes': ['AdapterFactory',
#    'GoogleAdapterFactory',
#    'Class',
#    'Adapter',
#    'Class2',
#    'AmazonAdapterFactory',
#    'GoogleAdapter',
#    'AmazonAdapter',
#    'GenericRequestStreamHandler'],
#   'attributes': ['OBJECT_MAPPER']},
#  '_yIWRYChXEeShcfbUiDP6ug.xmi.uml': {'classes': ['MyClass', 'MyClass2'],
#   'attributes': ['name']},
#  '67ed9d27-56e3-4b81-8050-6e03eda242b5.xmi.uml': {'classes': ['Worker',
#    'People',
#    'Customer',
#    'Cook',
#    'Waiter',
#    'Cashier'],
#   'attributes': ['name']},
#  '_cOog0CIgEeisAYMSV00L2Q.xmi.uml': {'classes': ['FieldsModification',
#    'CreatedUserModification',
#    'DeletedUserModification',
#    'UserMovedToGroupModification',
#    'GridIndex',
#    'GridIndex2']},
#  'a670164a-9f45-46fe-bade-23f443485ab4.xmi.uml': {'classes': ['Customer',
#    'Account',
#    'Transaction',
#    'CheckingAccount',
#    'SavingsAccount',
#    'Login',
#    'DepositTransaction',
#    'WithdrawTransaction',
#    'TransferTransaction',
#    'CertificatesOfDepositAccount'],
#   'attributes': ['name',
#    'dateOfBirth',
#    'address',
#    'phoneNumber',
#    'emailAddress',
#    'accountNo',
#    'type',
#    'balance',
#    'id',
#    'type',
#    'transactionTime',
#    'amount',
#    'interestRate',
#    'username',
#    'password',
#    'securityQuestion',
#    'securityAnswer',
#    'lastLoginTime',
#    'targetAccount',
#    'sourceAccount',
#    'interestRate',
#    'timePeriod']},
#  'efd35011-a6c9-4b9a-b62e-d5daa9b58968.xmi.uml': {'classes': ['user'],
#   'attributes': ['attribute']},
#  'd779e6fe-c0ae-4f71-816a-5cdd632e89f1.xmi.uml': {'classes': ['Customer',
#    'Payment',
#    'ShoppingCart',
#    'Account',
#    'WebUser',
#    'Order',
#    'LineItem',
#    'Product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paidDate',
#    'total',
#    'details',
#    'creationDate',
#    'billingAddress',
#    'open',
#    'closed',
#    'isClosed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'shipTo',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description']},
#  '597093bc-31ce-4808-b763-c29d6f680f32.xmi.uml': {'classes': ['чч',
#    'MyClass',
#    'MyClass2']},
#  '_OxdDoEymEeS9L4cMWDc7Qg.xmi.uml': {'classes': ['core.php',
#    '_base.controller.php',
#    '_core.model.php'],
#   'attributes': ['load']},
#  '_I_lnENTGEeehRMl7r1-c5g.xmi.uml': {'classes': ['CurvedLine',
#    'SketchyEllipse',
#    'SketchyRectangle',
#    'ShapeCreator',
#    'LineDrawer',
#    'ShapeMover',
#    'ShapeResizer',
#    'ShapeRotater',
#    'ShapeFiller',
#    'ShapeDeleter',
#    'ShapeRaiser',
#    'ShapeLowerer']},
#  '_zTvrkGm3EDGB-uCsYzbtRg.xmi.uml': {'classes': ['GameWindow']},
#  'af8ad990-19e3-488e-b4b8-846b6643f25b.xmi.uml': {'classes': ['Customer',
#    'Payment',
#    'ShoppinCart',
#    'Account',
#    'WebUser',
#    'Order',
#    'LineItem',
#    'Product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paidDate',
#    'total',
#    'details',
#    'creationDate',
#    'billingAddress',
#    'open',
#    'closed',
#    'isClosed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'shipTo',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description']},
#  'd6ed4740-d12b-4899-a2db-2374a6c7c4b5.xmi.uml': {'classes': ['Client',
#    'AdapterImpl',
#    'Adaptee',
#    'Context',
#    'StateA',
#    'StateB',
#    'Singleton',
#    'Abstraction',
#    'RefinedAbstraction',
#    'ConcreteImplementor',
#    'CreatorImpl',
#    'Product',
#    'ConcreteObserver',
#    'ConcreteSubject',
#    'MethodClass',
#    'ClassObject'],
#   'attributes': ['instance']},
#  '_NI0-EMYEEeeWu-SLkciAbg.xmi.uml': {'classes': ['temp sensor', 'arduino'],
#   'attributes': ['a', 'b', 'c', 'vout', 'volts', 'celsius', 'farfahrenheit']},
#  'b9dfe65c-12b6-498b-a151-0343da867aef.xmi.uml': {'classes': ['Client',
#    'AdapterImpl',
#    'Adaptee',
#    'Context',
#    'StateA',
#    'StateB',
#    'Singleton',
#    'Abstraction',
#    'RefinedAbstraction',
#    'ConcreteImplementor',
#    'CreatorImpl',
#    'Product',
#    'ConcreteObserver',
#    'ConcreteSubject'],
#   'attributes': ['instance']},
#  '0d0ec5dd-c762-405a-8a86-9d23a126537b.xmi.uml': {'classes': ['MyClassAOim'],
#   'attributes': ['attribute']},
#  '_RwyPkIPfEeaY2ZFk8hIg9A.xmi.uml': {'classes': ['DBObject'],
#   'attributes': ['TABLE',
#    'INDEX',
#    'UID',
#    'UID_LENGTH',
#    'DELETE',
#    '_columns',
#    '_fillable',
#    '_hidden',
#    '_generators']},
#  '431e2d5d-fa76-4ca1-a879-a927d293c394.xmi.uml': {'classes': ['Client',
#    'AdapterImpl',
#    'Adaptee',
#    'Context',
#    'StateA',
#    'StateB',
#    'Singleton',
#    'Abstraction',
#    'RefinedAbstraction',
#    'ConcreteImplementor',
#    'CreatorImpl',
#    'Product',
#    'ConcreteObserver',
#    'ConcreteSubject'],
#   'attributes': ['instance']},
#  '_42UqgMaLEeWmANB_14dU0A.xmi.uml': {'classes': ['prueba', 'prueba2'],
#   'attributes': ['nombre', 'lugar', 'pais', 'color', 'tamanio']},
#  '_OJVuMFlJEeWH7tmnkVHu6g.xmi.uml': {'classes': ['Patrons', 'LibraryStaff'],
#   'attributes': ['holder',
#    'name',
#    'date',
#    'student',
#    'faculty',
#    'libraryStaff',
#    'books',
#    'overdueFee',
#    'checkOutTime']},
#  '_butz8NjbEeWjYr7I4V0e0A.xmi.uml': {'classes': ['Charge Account'],
#   'attributes': ['CustomerNo(key)', 'attribute']},
#  '310b8bef-1a4e-4692-b437-a6a5453e1c31.xmi.uml': {'classes': ['Customer',
#    'Payment',
#    'ShoppingCart',
#    'Account',
#    'WebUser',
#    'Order',
#    'LineItem',
#    'Product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paidDate',
#    'total',
#    'details',
#    'creationDate',
#    'billingAddress',
#    'open',
#    'closed',
#    'isClosed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'shipTo',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description']},
#  '7aff64ad-90b0-450f-bf8c-1f4b9c3b8f37.xmi.uml': {'classes': ['ShoppingCart']},
#  'f34f1233-c3f1-48df-b830-6c1e81f51751.xmi.uml': {'classes': ['Abstraction',
#    'RefinedAbstraction',
#    'ConcreteImplementor']},
#  'f6e1ef7a-107f-419e-ab7d-a51aa49c13d2.xmi.uml': {'classes': ['Snake',
#    'Game',
#    'Program',
#    'Food',
#    'Display',
#    'Player',
#    'Unit',
#    'Random'],
#   'attributes': ['x,y',
#    'face',
#    'speed',
#    'size',
#    '[]unit',
#    'snake',
#    'food',
#    'display',
#    'player',
#    'life',
#    'x,y',
#    'face',
#    'toBe',
#    'height',
#    'width',
#    'space',
#    'wall',
#    'scorePosition',
#    'gameResumePosition',
#    'gameOverPostion',
#    'command',
#    'x,y']},
#  '_-g260KW7EeaiBJ7PH1W80g.xmi.uml': {'classes': ['Event',
#    'Customer',
#    'Agency',
#    'SevenUser',
#    'UserActivityRelation',
#    'UserRegisterEventRelation',
#    'Activity',
#    'LogAttendee',
#    'AttendeeActivity',
#    'Survey',
#    'Question',
#    'ResponseAttendee',
#    'Attendee',
#    'RoleMapping'],
#   'attributes': ['id',
#    'title',
#    'dateCreated',
#    'dateStarted',
#    'description',
#    'place',
#    'status',
#    'stage',
#    'brochure',
#    'timezone',
#    'userId',
#    'customerId',
#    'id',
#    'name',
#    'description',
#    'agencyId',
#    'userId',
#    'id',
#    'name',
#    'description',
#    'userId',
#    'id',
#    'type',
#    'firstname',
#    'lastname',
#    'email',
#    'created',
#    'lastupdated',
#    'imageUser',
#    'id',
#    'sevenuserId',
#    'activityId',
#    'id',
#    'sevenuserId',
#    'eventId',
#    'id',
#    'name',
#    'description',
#    'start',
#    'duration',
#    'limit',
#    'eventId',
#    'userId',
#    'onDemandCount',
#    'evaluationCount',
#    'registers',
#    'spaceAvailbale',
#    'id',
#    'status',
#    'date',
#    'attendeeId',
#    'eventId',
#    'id',
#    'attendeeId',
#    'activityId',
#    'id',
#    'eventId',
#    'activityId',
#    'userId',
#    'id',
#    'text',
#    'type',
#    'answer',
#    'time',
#    'send',
#    'surveyId',
#    'id',
#    'date',
#    'response',
#    'attendeeId',
#    'questionId',
#    'id',
#    'age',
#    'emailOriginal',
#    'organization',
#    'status',
#    'location',
#    'birthyear',
#    'notification',
#    'email',
#    'platform',
#    'typecheck',
#    'eventId',
#    'userId',
#    'id',
#    'sevenuserId',
#    'roleId',
#    'type']},
#  '19515821-de9c-4371-ab13-0c10c1f0741e.xmi.uml': {'classes': ['Client',
#    'AdapterImpl',
#    'Adaptee',
#    'Context',
#    'StateA',
#    'StateB',
#    'Singleton',
#    'Abstraction',
#    'RefinedAbstraction',
#    'ConcreteImplementor',
#    'CreatorImpl',
#    'Product',
#    'ConcreteObserver',
#    'ConcreteSubject'],
#   'attributes': ['instance']},
#  '_iY65cGqwEeepGY91r9Nuow.xmi.uml': {'classes': ['order'],
#   'attributes': ['userName',
#    'attribute2',
#    'attribute3',
#    'attribute4',
#    'attribute5',
#    'attribute6',
#    'attribute7',
#    'attribute8',
#    'attribute9',
#    'attribute10']},
#  '_ICx4IDeZEemHKq5iZQi_Zw.xmi.uml': {'classes': ['Estudiante',
#    'Profesor',
#    'Materias',
#    'Salones',
#    'Rol',
#    'Edificio',
#    'Programa',
#    'Facultad',
#    'Horario'],
#   'attributes': ['id_estudiante',
#    'nombre',
#    'apellidos',
#    'cedula',
#    'correo',
#    'estado',
#    'id_rol',
#    'id_programa',
#    'id_profesor',
#    'nombre',
#    'cedula',
#    'correo',
#    'id_salon',
#    'id_rol',
#    'id_materia',
#    'nombre',
#    'NRC',
#    'cupo',
#    'creditos',
#    'id_estudiante',
#    'id_profesor',
#    'id_salon',
#    'id_horario',
#    'id_salon',
#    'piso',
#    'numero_salon',
#    'capacidad',
#    'id_edificio',
#    'id_horario',
#    'id_rol',
#    'nombre',
#    'id_edificio',
#    'nombre',
#    'id_programa',
#    'nombre',
#    'ISUM',
#    'id_facultad',
#    'id_facultad',
#    'nombre',
#    'id_horario',
#    'hora_inicio',
#    'hora_final']},
#  '_w3lJ8AP7Eeewntt9CKbg3g.xmi.uml': {'classes': ['User',
#    'Team',
#    'Channel',
#    'Message',
#    'UserSettings',
#    'TeamSettings',
#    'ChannelSettings',
#    'ChannelActivity',
#    'UserAccount',
#    'DirrectMessage'],
#   'attributes': ['username',
#    'team',
#    'name',
#    'url',
#    'name',
#    'status',
#    'purpose',
#    'date',
#    'content',
#    'notifications',
#    'sound',
#    'display',
#    'threads',
#    'highlightWords',
#    'doNotDisturbFrom',
#    'doNotDisturbTo',
#    'signUpMode',
#    'defaultChannels',
#    'usernameGuidelines',
#    'nameDisplay',
#    'requireForMention',
#    'emailDisplay',
#    'doNotDisturbFrom',
#    'doNotDisturbTo',
#    'hideUrl',
#    'enableCalls',
#    'callingApp',
#    'messageRetention',
#    'fileRetention',
#    'teamIcon',
#    'desktopNotifications',
#    'pushNotificationa',
#    'muteChannel',
#    'includeUserGroupMentions',
#    'includeChannelMentions',
#    'firstName',
#    'lastName',
#    'whatIDo',
#    'email',
#    'phone',
#    'timezone',
#    'skypeId',
#    'photo',
#    'password']},
#  'e9599e4d-25c4-48e4-8fe3-fc14e2c55dce.xmi.uml': {'classes': ['Employee',
#    'Salary',
#    'Authenticate_staff',
#    'Leave',
#    'Attendance',
#    'Login'],
#   'attributes': ['Emp_Id',
#    'Emp_Name',
#    'Emp_ContactNo',
#    'Emp_Email',
#    'Emp_NIC',
#    'Emp_Address',
#    'Emp_DOB',
#    'Emp_Department',
#    'Emp-Date_Of_Joint',
#    'Emp_Position',
#    'Emp_Salary',
#    'Emp_Id',
#    'Sly_Basic',
#    'Sly_Increment',
#    'Sly_Decrement',
#    'Sly_Netgross',
#    'OverTime',
#    'UserName',
#    'Password',
#    'Authendication_Mood',
#    'leave_id',
#    'Emp_Id',
#    'Leave_Title',
#    'Leave_detail',
#    'Leave_ApplyDate',
#    'Leave_StartDate',
#    'Leave_EndDate',
#    'Leave_NoOfDays',
#    'Leave_Status',
#    'Attend_date',
#    'Emp_id',
#    'AttendTime',
#    'Leaving_Time',
#    'UserName',
#    'Password']},
#  '49a9a179-f2f3-4517-994e-148391be8053.xmi.uml': {'classes': ['Client',
#    'Adaptor',
#    'Adaptee',
#    'MyClass']},
#  '_1fv_cGAzEeepGY91r9Nuow.xmi.uml': {'classes': ['Category',
#    'Products',
#    'ProductSize',
#    'OrderDetails',
#    'MyClass',
#    'MyClass2',
#    'MyClass3',
#    'MyClass4',
#    'MyClass5',
#    'Orders',
#    'OrderCategory',
#    'MyClass8',
#    'MyClass9',
#    'MyClass10'],
#   'attributes': ['categoryId',
#    'categoryDescription',
#    'productID',
#    'productName',
#    'Image',
#    'categoryId',
#    'isActive',
#    'prodSizeId',
#    'productId',
#    'sizeId',
#    'Price',
#    'orderDetailsId',
#    'orderId',
#    'productSizeId',
#    'Quantity',
#    'pricePerProduct',
#    'orderId',
#    'adderess',
#    'clientId',
#    'orderDate',
#    'centerId',
#    'categoryId',
#    'orderCatId',
#    'categoryDesc']},
#  '8b08c90b-c7d3-4afd-b0e9-3dfe67ed7de3.xmi.uml': {'classes': ['ShoppingCart',
#    'Order',
#    'LineItem',
#    'Account',
#    'Customer'],
#   'attributes': ['creationDate', 'id', 'quantity', 'price', 'id']},
#  'd29cd2f3-9ae8-4c52-97f5-7cf07f4cdd10.xmi.uml': {'classes': ['Singleton'],
#   'attributes': ['instance']},
#  '6c84d80a-0e28-40ab-957c-531b57921306.xmi.uml': {'classes': ['Customer',
#    'Payment',
#    'ShoppingCart',
#    'Account',
#    'WebUser',
#    'Order',
#    'LineItem',
#    'Product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paidDate',
#    'total',
#    'details',
#    'creationDate',
#    'billingAddress',
#    'open',
#    'closed',
#    'isClosed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'shipTo',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description']},
#  '9232d81e-dab5-49d8-9e89-8a4ff91278b1.xmi.uml': {'classes': ['Create Analysis Action',
#    'Service',
#    'AnalysisDAO',
#    'AnalysisDAO'],
#   'attributes': ['analysisName']},
#  '_WfyX0MIFEeacM55raX9d3Q.xmi.uml': {'classes': ['ProducerTextGenerator',
#    'Text',
#    'ConsumerTextAnalyz',
#    'ScannerText']},
#  '_KlkTALgHEeSzkacHLregNQ.xmi.uml': {'classes': ['Order'],
#   'attributes': ['OrderID;', '+Order(...)', 'CalculateTotatl()']},
#  '_XgXMwH_9EeW4cd-qm4QbpA.xmi.uml': {'classes': ['Employee', 'Rooms'],
#   'attributes': ['id', 'first_name', 'last_name', 'Number']},
#  '40adfe9e-25a9-426a-806e-9ff9a56b4da2.xmi.uml': {'classes': ['Worker',
#    'People',
#    'Customer',
#    'Cook',
#    'Waiter',
#    'Cashier'],
#   'attributes': ['name']},
#  '_lWq_kF4WEeSmRKwulsG6-Q.xmi.uml': {'classes': ['user',
#    'massage',
#    'profile',
#    'post',
#    'group',
#    'friends',
#    'login',
#    'notification',
#    'admin',
#    'member']},
#  '2c3b7982-340a-4627-9c85-6b1a36347b78.xmi.uml': {'classes': ['TimetableEvent',
#    'TimetableReader',
#    'TimetableValidator',
#    'TimetableValidationError',
#    'CalendarImporter',
#    'GoogleCalendarImporter']},
#  '_JkGroH2TEeShroDxTnL5_A.xmi.uml': {'classes': ['Caisse'],
#   'attributes': ['test']},
#  '9462f4aa-aea2-4c9e-afcb-cfcfbd414c85.xmi.uml': {'classes': ['ShoppingCart',
#    'Order',
#    'LineItem',
#    'Account',
#    'Customer'],
#   'attributes': ['creationDate', 'id', 'quantity', 'price', 'id']},
#  '538864d8-e066-49c5-8edd-4ab0fca7f62b.xmi.uml': {'classes': ['Person',
#    'Professor',
#    'Employee',
#    'FullProfessor',
#    'Associate',
#    'Assistant',
#    'Office',
#    'University',
#    'Classroom',
#    'Room',
#    'Building'],
#   'attributes': ['id', 'name', 'seatsNumber', 'floor', 'number']},
#  '_5pZpkNHiEeaJwt5yAqWnTg.xmi.uml': {'classes': ['Class',
#    'Class2',
#    'Wifi',
#    'Class3',
#    'Simcard',
#    'System',
#    'Database']},
#  'e12b7943-feab-4c7d-9330-61358c7afece.xmi.uml': {'classes': ['Customer',
#    'Payment',
#    'ShoppingCart',
#    'Account',
#    'WebUser',
#    'Order',
#    'LineItem',
#    'Product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paidDate',
#    'total',
#    'details',
#    'creationDate',
#    'billingAddress',
#    'open',
#    'closed',
#    'isClosed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'shipTo',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description']},
#  '_IC_G0MiPEeeM1PgT03-3Vg.xmi.uml': {'classes': ['Physical Users',
#    'Online Users',
#    'Clerk',
#    'Admin',
#    'Database',
#    'Payment',
#    'Mobile User',
#    'Online Ticket',
#    'Physical Ticket']},
#  '_P7zdMN_uEeS6FO4vn2oOjA.xmi.uml': {'classes': ['suit'],
#   'attributes': ['inputCode']},
#  '3d99155b-5099-4121-bba7-934dfece62cb.xmi.uml': {'classes': ['ShoppingCart',
#    'Order',
#    'LineItem',
#    'Account',
#    'Customer',
#    'Class',
#    'Client',
#    'Client',
#    'Platform'],
#   'attributes': ['creationDate', 'id', 'quantity', 'price', 'id']},
#  '_DF3R0BwbEeig8qiayYYCew.xmi.uml': {'classes': ['Person',
#    'Faculty',
#    'Student',
#    'Raffle',
#    'Prize'],
#   'attributes': ['firstName',
#    'lastName',
#    'Gender',
#    'yearsOfService',
#    'subjectArea',
#    'prize',
#    'class',
#    'age',
#    'prize',
#    'registrants',
#    'sortedRegistrants',
#    'prizes',
#    'name',
#    'companyName']},
#  '_-WIY4KnoEeS9iunt9iMoeg.xmi.uml': {'classes': ['AbstractGame',
#    'Chess',
#    'Monopoly']},
#  '_FOQ0QCMXEeisAYMSV00L2Q.xmi.uml': {'classes': ['CourrierCUAU'],
#   'attributes': ['CelluleAUCU',
#    'ServiceInstructeur',
#    'Interlocuteur',
#    'Objet',
#    'Date',
#    'VotreConseiller']},
#  'cccd46b7-9b3e-44d4-84fc-e2153cf70d58.xmi.uml': {'classes': ['Client',
#    'Adaptor',
#    'Adaptee']},
#  '_6I0ZIPjzEeSE6sazzutmkA.xmi.uml': {'classes': ['ScheduleTimezoneConverter',
#    'ScheduleMgmtApiResponseDetVO',
#    'AllSchedules',
#    'CustomScheduleJSON_VO',
#    'DailyScheduleJSON_VO',
#    'OneTimeScheduleJSON_VO'],
#   'attributes': ['scheduleTimezoneConverter',
#    'SHIFT_LABEL_RIGHT',
#    'SHIFT_LABEL_LEFT',
#    'SHIFT_LABEL_NA']},
#  '_bEYN8LBCEee6S77dw3LIvQ.xmi.uml': {'classes': ['Person', 'Class'],
#   'attributes': ['name', 'email']},
#  '_2p9bEMasEeadwOIOqK-0Fw.xmi.uml': {'classes': ['PayU',
#    'OrderStatusAbstract',
#    'PaymentStatus',
#    'Con',
#    'Configuration'],
#   'attributes': ['$configuration']},
#  '3bddae18-8bff-498f-b478-8d075c718bdb.xmi.uml': {'classes': ['Adaptor',
#    'Adaptee',
#    'MyClass2']},
#  '813d3f22-4f16-4bd5-8e87-290334d4102b.xmi.uml': {'classes': ['Advokat',
#    'Predmet Advokatske kancelarije',
#    'Rociste',
#    'Stranka',
#    'Punomocje',
#    'TipPunomocja',
#    'Obaveza',
#    'IzlaznaFaktura'],
#   'attributes': ['IDadvokat',
#    'ImeAdvokata',
#    'BrojTelefona',
#    'PrezimeAdvokata',
#    'EmailAdresa',
#    'AdresaAdvokata',
#    'Username',
#    'Password',
#    'BrojPredmetaAK',
#    'DatumPokretanja',
#    'DatumZavrsetka',
#    'NazivPredmeta',
#    'VrednostSpora',
#    'IDAdvokat',
#    'IDPunomocja',
#    'IDRocista',
#    'ImeSudije',
#    'PrezimeSudije',
#    'IDStranke',
#    'IDAdvokat',
#    'IDStranke',
#    'NazivStranke',
#    'BrojTelefonaStranke',
#    'EmailStranke',
#    'AdresaStranke',
#    'MestoStanovanjaStranke',
#    'IDPunomocja',
#    'PeriodVazenjaPun',
#    'DatumPotpisivanjaPun',
#    'IDTipPun',
#    'IDStranke',
#    'IDTipPun',
#    'NazivPun',
#    'IDObaveze',
#    'NazivObaveze',
#    'VremeObaveze',
#    'DatumObaveze',
#    'IDAdvokata',
#    'IDIzlazneFakture',
#    'DatumFakturisanja',
#    'IznosFakture',
#    'PrimalacFakture',
#    'BrojRacuna',
#    'IDAdvokat']},
#  '_AhnLoDyqEeW9u4XU-cgAEg.xmi.uml': {'classes': ['Users',
#    'Administrator',
#    'Moderator'],
#   'attributes': ['username',
#    'userId',
#    'password',
#    'email',
#    'isReported',
#    'reportedBy',
#    'gender',
#    'interests',
#    'level']},
#  '7f09e59b-ca7a-4f32-ba33-39e6aad74ffb.xmi.uml': {'classes': ['Fascia',
#    'MyClass',
#    'MyClass2',
#    'MyClass3',
#    'MyClass4',
#    'MyClass5',
#    'MyClass6',
#    'MyClass7',
#    'MyClass8',
#    'MyClass9'],
#   'attributes': ['sku', 'location']},
# ...
#    'permission']},
#  'a3ce5833-8912-4abf-b4e8-71f93a5fcbbd.xmi.uml': {'classes': ['WebSocketConfig',
#    'HomeController',
#    'DrJ',
#    'DrS',
#    'Game',
#    'InfoPlayers',
#    'Player',
#    'StJ',
#    'StS',
#    'Message',
#    'Move',
#    'org.springframework.web.socket.config.annotation.AbstractWebSocketMessageBrokerConfigurer',
#    'java.lang.Exception',
#    'java.util.Timer'],
#   'attributes': ['index',
#    'dreaptaJos',
#    'DrJ1',
#    'DrJ2',
#    'DrJ3',
#    'index',
#    'dreaptaSus',
#    'DrS1',
#    'DrS2',
#    'DrS3',
#    'board',
#    'HYDE_TIME',
#    'GAME_TIME',
#    'FRAME_TIME',
#    'currentState',
#    'mrHydeTimer',
#    'gameTimer',
#    'refreshTimer',
#    'configFile',
#    'scoreFile',
#    'hydeIndex',
#    'positionOx',
#    'positionOy',
#    'score',
#    'name',
#    'index',
#    'stangaJos',
#    'StJ1',
#    'StJ2',
#    'StJ3',
#    'index',
#    'stangaSus',
#    'StS1',
#    'StS2',
#    'StS3',
#    'content',
#    'playerName',
#    'move']},
#  '9be0de02-1694-4382-8676-000ea2b52a4b.xmi.uml': {'classes': ['Abstraction',
#    'RefinedAbstraction',
#    'ConcreteImplementor']},
#  '_eiM3UKj9EeeEQN1ZyOr-_g.xmi.uml': {'classes': ['Fan'],
#   'attributes': ['SLOW', 'MEDIUM', 'FAST', 'on', 'radius', 'color', 'speed']},
#  'bbdccdb0-a574-46c3-9660-8e8e53cb3600.xmi.uml': {'classes': ['players',
#    'tableSearcher',
#    'systemManager',
#    'tableParser',
#    'centerOfTheTable',
#    'cardsOnTableState',
#    'cardsOnHandsState',
#    'cardsOnHandsListener',
#    'cardsOnTableListener',
#    'screenShotMaker',
#    'tableCardsreader',
#    'handsCardsReader',
#    'cardsOnTable',
#    'cardsOnHands']},
#  'e73da33d-a498-4ba9-907b-a1800df34998.xmi.uml': {'classes': ['Client',
#    'AdapterImpl',
#    'Adaptee',
#    'Context',
#    'StateA',
#    'StateB',
#    'Singleton',
#    'Abstraction',
#    'RefinedAbstraction',
#    'ConcreteImplementor',
#    'CreatorImpl',
#    'Product',
#    'ConcreteObserver',
#    'ConcreteSubject'],
#   'attributes': ['instance']},
#  '_lrCmsDchEDGTp7v8NTrInw.xmi.uml': {'classes': ['Flight',
#    'Aerobatic',
#    'Scenic',
#    'Custom Flight'],
#   'attributes': ['attribute']},
#  '5a35d6a5-c851-4a85-8b21-330c58625831.xmi.uml': {'classes': ['ShoppingCart']},
#  '_g48V0Mw-EeaAf-R7dg0GCw.xmi.uml': {'classes': ['TramTicketMachine',
#    'CashChecker',
#    'DisplayScreen',
#    'TicketDispenser',
#    'CardTransaction',
#    'ATMCard',
#    'TramCard',
#    'CardScanner',
#    'TramUser'],
#   'attributes': ["company's_name",
#    'isCurrencyNote',
#    'isCurrencyCoins',
#    'Amount',
#    'inputEntered',
#    'no_of_available_ticket',
#    'cardID',
#    'pin',
#    'bankCard',
#    'tramCard']},
#  '_bK7soLVKEee7sYPkE4-GPA.xmi.uml': {'classes': ['Hero'],
#   'attributes': ['returnHP();']},
#  '_wyN9EONxEeSyAtfQFgWBxA.xmi.uml': {'classes': ['as', 'asd']},
#  '4eee6bdf-ab66-4aa5-adcf-8217d11926fe.xmi.uml': {'classes': ['ShoppingCart',
#    'Order',
#    'LineItem',
#    'Account',
#    'Customer',
#    'Class'],
#   'attributes': ['creationDate', 'id', 'quantity', 'price', 'id']},
#  '_52gvsJwlEDGdyoFyp4l9hw.xmi.uml': {'classes': ['SistemskeOperacije(SO)']},
#  '_DErG4HseEeSdXJMJcKNKoQ.xmi.uml': {'classes': ['user', 'IT Website', 'User'],
#   'attributes': ['attribute', 'ID', 'Password']},
#  '_8-EMANc5Eei47sN0sCkjiA.xmi.uml': {'classes': ['LAla'],
#   'attributes': ['sd']},
#  '3c85cf04-8dba-4aee-bb97-59cb0048da7b.xmi.uml': {'classes': ['Client',
#    'Adaptor',
#    'Adaptee']},
#  '_FzAzoMENEeeEXb8Dudo6PQ.xmi.uml': {'classes': ['Avion',
#    'Pasajero',
#    'Silla',
#    'java.lang.Exception',
#    'javax.swing.JFrame',
#    'javax.swing.JPanel',
#    'javax.swing.ImageIcon',
#    'java.awt.Graphics',
#    'javax.swing.JButton',
#    'java.awt.event.ActionEvent',
#    'javax.swing.JComboBox',
#    'javax.swing.JTextField'],
#   'attributes': ['SILLAS_EJECUTIVAS',
#    'SILLAS_ECONOMICAS',
#    'cedula',
#    'nombre',
#    'CLASE_EJECUTIVA',
#    'CLASE_ECONOMICA',
#    'VENTANA',
#    'CENTRAL',
#    'PASILLO',
#    'numero',
#    'clase',
#    'ubicacion']},
#  '08440044-d6fd-4fe9-b4b9-485af8ec84ab.xmi.uml': {'classes': ['Worker',
#    'People',
#    'Customer',
#    'Cook',
#    'Waiter',
#    'Cashier'],
#   'attributes': ['name']},
#  '_8MyUoObSEeiDGLvZhbPYyA.xmi.uml': {'classes': ['Person', 'MALE']},
#  '_TgYHsEMgEeSyYeDoyPirvg.xmi.uml': {'classes': ['Event',
#    'FlightManager',
#    'FlightPlanning',
#    'InterventionPlanning',
#    'Planning',
#    'EmployeeManager',
#    'EmployeePlanning',
#    'ReportManager',
#    'Report',
#    'DistributionManager',
#    'MarketingManager',
#    'TicketDistributorManager',
#    'ProviderManager',
#    'FlightEvent',
#    'PlaneIntervention',
#    'PlaneRevision',
#    'PlaneImmobilization',
#    'PlaneFuel',
#    'CleaningService',
#    'Steward',
#    'Pilot',
#    'AirportEmployee',
#    'Employee',
#    'Company',
#    'Airport',
#    'StandardFlight',
#    'Flight',
#    'FreeTimeFlight',
#    'Plane',
#    'Fuel',
#    'FuelProvider',
#    'ConsomationProvider',
#    'Consomation',
#    'ServiceProvider',
#    'Provider',
#    'ConsomationStock',
#    'Ticket',
#    'BoardingPass',
#    'Customer',
#    'TicketDistributor',
#    'Promotion',
#    'Advertising',
#    'News',
#    'Reservation',
#    'FreeMiles',
#    'EarlyOrder',
#    'EmployeeManagerView',
#    'TicketDistributionView',
#    'CompanyManagementView'],
#   'attributes': ['_dateBegin',
#    '_dateEnd',
#    '_title',
#    'isSuperUser',
#    'date',
#    'category',
#    'flight',
#    'millesOnIntervention',
#    'plane',
#    'flight',
#    'plane',
#    'airport',
#    'plane',
#    'airport',
#    'airport',
#    'dayByWeek',
#    'name',
#    'gender',
#    'JobType',
#    'isSuperUser',
#    'name',
#    'stewards',
#    'pilots',
#    'airportEmployees',
#    'city',
#    'ticketPrice',
#    'ticketCharges',
#    'beginSchedule',
#    'endSchedule',
#    'surbookingPercent',
#    'reservationPercent',
#    'airportFrom',
#    'airportTo',
#    '/duration',
#    'flightType',
#    'schedule',
#    '/miles',
#    'confirmationPercent',
#    'row',
#    'seatPerRow',
#    '/seat',
#    'nbPilote',
#    'nbSteward',
#    '/crew',
#    '/millesFlyed',
#    '/flySinceRefuel',
#    '/state',
#    '/location',
#    '/millesSinceRevisionned',
#    'date',
#    '/price',
#    'volme',
#    'plane',
#    'name',
#    'pricePerUnit',
#    'pricePerUnit',
#    'name',
#    '_capacity',
#    'from',
#    'payment',
#    '/price',
#    'promotion',
#    'isRegistered',
#    '_numberPlace',
#    'price',
#    'row',
#    'seat',
#    'isValidated',
#    'dateOfPurchase',
#    'flight',
#    '/milesFlyed',
#    'Luggage',
#    'name',
#    'surbooking',
#    'freeFlyPerWeek',
#    'from',
#    'payment',
#    '/discount',
#    'percentPerFlight',
#    'picture',
#    'date',
#    'text',
#    'title',
#    'discountPercent',
#    'millesPerMillesPromotion',
#    'cashPerMilesPromotion',
#    'discountPercent']},
#  '_L7BoAFTIEeSu48YT12vqpQ.xmi.uml': {'classes': ['Player'],
#   'attributes': ['Name', 'Score', 'CardContainer']},
#  '9e620e9c-e98c-44f2-be8d-849cc420126d.xmi.uml': {'classes': ['Customer',
#    'Payment',
#    'ShoppingCart',
#    'Account',
#    'WebUser',
#    'Order',
#    'LineItem',
#    'Product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paidDate',
#    'total',
#    'details',
#    'creationDate',
#    'billingAddress',
#    'open',
#    'closed',
#    'isClosed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'shipTo',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description']},
#  '_PbRXUNuREeiJYbNjsZ3wUw.xmi.uml': {'classes': ['TypeatorContainer',
#    'DefaultTypeator',
#    'TypeatorFactory',
#    'TypeatorRunner']},
#  'd5320ba4-ef0b-4a62-9a28-70d63e9861f7.xmi.uml': {'classes': ['BankAccount',
#    'ClassA',
#    'ClassB',
#    'ClassC',
#    'ClassD',
#    'ClassE',
#    'ClassF',
#    'ClassG',
#    'ClassJ',
#    'ClassH',
#    'ClassK',
#    'ClassM',
#    'ClassN',
#    'ClassP',
#    'ClassQ',
#    'ClassR',
#    'ClassS',
#    'ClassT',
#    'ClassU',
#    'ClassV'],
#   'attributes': ['ownerName',
#    'balance',
#    'publicAttribute',
#    'privateAttribute',
#    'protectedAttribute',
#    'packageAttribute',
#    'publicAttribute',
#    'privateAttribute',
#    'protectedAttribute',
#    'packageAttribute']},
#  '_zmijUKT-EeScLuNN63kNaQ.xmi.uml': {'classes': ['Sensor', 'Device', 'Menu'],
#   'attributes': ['Sensor']},
#  '_WhW-AJc2EeS67M2cXIV9Bg.xmi.uml': {'classes': ['Dienblad',
#    'Docent',
#    'Student',
#    'KantineMedewerker',
#    'PersoonsVergelijker',
#    'KassaRij',
#    'Kantine',
#    'Kassa',
#    'Administratie'],
#   'attributes': ['artikelen',
#    'Totaalprijs',
#    'afkorting',
#    'afdeling',
#    'studentnummer',
#    'studierichting',
#    'medewerkersnummer',
#    'magAchterKassa',
#    'kassaRij',
#    'kassa',
#    'kassarij',
#    'persoon1',
#    'dienblad1',
#    'artikel1',
#    'artikel2',
#    'kantineaanbod',
#    'rij',
#    'artikelen',
#    'geld',
#    'aantalKlanten',
#    'DAYS_IN_WEEK']},
#  '3dabd4fe-d23c-4cf6-bbe6-510a8a5b7722.xmi.uml': {'classes': ['Client',
#    'Adaptor',
#    'Adaptee']},
#  '_-iZxYP76EeSpvbjLqY_W3Q.xmi.uml': {'classes': ['User'],
#   'attributes': ['userID',
#    'userType',
#    'firstName',
#    'lastName',
#    'employeeID',
#    'dateJoined',
#    'role',
#    'allocationStatus',
#    'email',
#    'phone',
#    'officeAddress',
#    'baseBranch',
#    'city',
#    'state',
#    'country',
#    'specialization',
#    'institution',
#    'years_company',
#    'profile_picture']},
#  '_FIzVsGTjEDGvYZ_luPE2qw.xmi.uml': {'classes': ['Curso',
#    'Seccion',
#    'Estudiante',
#    'SistemaArchivos',
#    'Archivo'],
#   'attributes': ['profesor', 'salon', 'hora']},
#  '_v6vVID3VEDG1DfFOPLjuGA.xmi.uml': {'classes': ['OrderingSystem',
#    'OrderingSystem',
#    'OrderingSystem',
#    'List',
#    'OrderingSystem',
#    'List'],
#   'attributes': ['costCoffeeA',
#    'costCoffeeB',
#    'costCoffeeC',
#    'costCoffeeD',
#    'costCoffeeA',
#    'costCoffeeB',
#    'costCoffeeC',
#    'costCoffeeD',
#    'costCondimentA',
#    'costCondimentB',
#    'costCondimentC',
#    'listCostCoffee',
#    'listCostCondiment',
#    'values',
#    'names',
#    'listCost',
#    'values',
#    'names']},
#  'e2b23b9a-8b69-4537-95d9-9a62d0468ccf.xmi.uml': {'classes': ['Customer',
#    'Payment',
#    'ShoppingCart',
#    'Account',
#    'WebUser',
#    'Order',
#    'LineItem',
#    'Product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paidDate',
#    'total',
#    'details',
#    'creationDate',
#    'billingAddress',
#    'open',
#    'closed',
#    'isClosed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'shipTo',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description']},
#  'fe31c34b-968d-4bcd-a8e7-6fd9b9dfa284.xmi.uml': {'classes': ['Game1',
#    'Car',
#    'Rock',
#    'Wheel',
#    'Player',
#    'Score'],
#   'attributes': ['speed', 'colission']},
#  '_0FTU8KveEeiHR4AK89CXpg.xmi.uml': {'classes': ['Buffer',
#    'int',
#    'Productor',
#    'Consumidor'],
#   'attributes': ['capacidad', 'buffer', 'i', 'n', 'n']},
#  '_K-stgPXsEei5Pecz43plcg.xmi.uml': {'classes': ['MacAuto',
#    'Cuenta',
#    'JFrame',
#    'ArithmeticException',
#    'Refresco',
#    'Hamburguesa',
#    'papas',
#    'Nombre',
#    'Maquina',
#    'Creditos',
#    'Variables',
#    'Maquina2',
#    'JFrame'],
#   'attributes': ['MacAuto()',
#    'actionPerformed()',
#    'Hamburguesa()',
#    'Refresco()',
#    'Papas()',
#    'nohaynada()',
#    'imprimirConjunto()',
#    'toString()',
#    'toString()',
#    'toString()',
#    'Maquina()',
#    'ActionPerformed()',
#    'Creditos',
#    'Cambio',
#    'Total']},
#  '_VFimkNVkEeWUcZFfD54kTA.xmi.uml': {'classes': ['ConfigurationRoot',
#    'SDPServices',
#    'ConfigureAndActivateService',
#    'SDPServicesMethodsIL']},
#  '7602e9c9-601a-4f92-8c40-09e8901b162b.xmi.uml': {'classes': ['ShoppingCart']},
#  '_XuwfQHz2EeW4cd-qm4QbpA.xmi.uml': {'classes': ['FileBuffer',
#    'ParentModul',
#    'Work Modul A',
#    'GUI',
#    'Visualisation'],
#   'attributes': ['originalData']},
#  '_Wk5_IAdjEeeoBvzX9wJhsQ.xmi.uml': {'classes': ['Super_Parser',
#    'Sub_Parser',
#    'logger.py',
#    'String []'],
#   'attributes': ['parser_name',
#    'covered_program',
#    'start_time',
#    'end_time',
#    'String',
#    'active_parser',
#    'parser_stack',
#    'log_stack']},
#  '8a4b7913-39fb-43c6-a37e-5ae3264dc75d.xmi.uml': {'classes': ['Equipo',
#    'Jugador',
#    'Entrenador',
#    'Arbitro',
#    'Partido',
#    'Evento',
#    'TipoDeEvento',
#    'Lesion',
#    'Liga',
#    'Clasificacion',
#    'Persona',
#    'Estadio'],
#   'attributes': ['Cod_equipo',
#    'Nombre',
#    'F_fundacion',
#    'Ciudad',
#    'Titulos',
#    'Cod_Entrenador',
#    'Cod_jugador',
#    'Dorsal',
#    'Posicion',
#    'Altura',
#    'Peso',
#    'Titulos',
#    'Cod_equipo',
#    'Cod_persona',
#    'Cod_Entrenador',
#    'Titulos',
#    'Cod_persona',
#    'Cod_Arbitro',
#    'Partidos',
#    'Cod_persona',
#    'Cod_partido',
#    'Fecha',
#    'Hora',
#    'Local',
#    'Visita',
#    'GolLocal',
#    'GolVisita',
#    'Ganador',
#    'Cod_liga',
#    'Cod_partido',
#    'Cod_jugador',
#    'Cod_TipodeEvento',
#    'Cod_TipodeEvento',
#    'Evento',
#    'Cod_jugador',
#    'FechaLesion',
#    'TiempoLesion',
#    'Condicion',
#    'Cod_liga',
#    'Nombre',
#    'Num_equipos',
#    'Superior',
#    'Inferior',
#    'Cod_Clasificacion',
#    'Cod_Equipo',
#    'Posicion',
#    'JJ',
#    'JP',
#    'JE',
#    'JG',
#    'GF',
#    'GC',
#    'DG',
#    'Puntos',
#    'Cod_persona',
#    'Nombre',
#    'Apellido',
#    'NombreCorto',
#    'FechaNacimiento',
#    'Nacionalidad',
#    'Cod_Estadio',
#    'Nombre',
#    'Ubicacion',
#    'Capacidad',
#    'Terreno',
#    'Ubicacion',
#    'Cod_equipo']},
#  '07ebe3fa-a9ec-466e-9aab-4c84c0e06b8f.xmi.uml': {'classes': ['Customer',
#    'Payment',
#    'ShoppingCart',
#    'Account',
#    'WebUser',
#    'Order',
#    'LineItem',
#    'Product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paidDate',
#    'total',
#    'details',
#    'creationDate',
#    'billingAddress',
#    'open',
#    'closed',
#    'isClosed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'shipTo',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description']},
#  '90de3c08-1e92-4c95-a8d2-6e9b6e6a3bb2.xmi.uml': {'classes': ['Singleton'],
#   'attributes': ['instance']},
#  '_7o7moCfVEeiYD9TOdwevwA.xmi.uml': {'classes': ['Operador',
#    'Hotel',
#    'Hostal',
#    'Reserva',
#    'Cliente',
#    'HabitacionPersona',
#    'ApartamentoAlquiler',
#    'ViviendaPersona',
#    'ViviendaUniversitaria',
#    'Persona',
#    'MiembroComunidad',
#    'Empresa',
#    'HabitacionHotel',
#    'Habitacion',
#    'HabitacionVivienda',
#    'ReservaColectiva'],
#   'attributes': ['id',
#    'tipoOperador',
#    'restaurante',
#    'piscina',
#    'parqueadero',
#    'wifi',
#    'TVCable',
#    'Recepcion24Horas',
#    'estaDeshabilitado',
#    'horarioApertura',
#    'horarioCierre',
#    'Capacidad',
#    'precioNoche',
#    'estaDeshabilitado',
#    'id',
#    'FechaIncioServicio',
#    'FechaReserva',
#    'dias',
#    'tipo',
#    'FechaPago',
#    'fueCancelado',
#    'idReservaColectiva',
#    'Capacidad',
#    'Comidas',
#    'accesoCocina',
#    'tipoBaño',
#    'tipoHabitacion',
#    'costoLuz',
#    'costoTelefono',
#    'costoTV',
#    'costoInternet',
#    'costoAgua',
#    'PrecioMes',
#    'DescuentoMesPrepagado',
#    'PrecioMes',
#    'costoTelefono',
#    'costoLuz',
#    'costoTV',
#    'costoInternet',
#    'costoAgua',
#    'administracionCosto',
#    'capacidad',
#    'estaDeshabilitado',
#    'capacidad',
#    'numeroHabitaciones',
#    'Ubicacion',
#    'CostoDia',
#    'caracteristicasSeguro',
#    'estaDeshabilitado',
#    'amoblamientoBasico',
#    'cocineta',
#    'Internet',
#    'Tv',
#    'aseo',
#    'apoyoSocial',
#    'apoyoAcedemico',
#    'RestauranteCosto',
#    'SalasEstudioCosto',
#    'SalasEsparcimiento',
#    'GimnasioCosto',
#    'estaDeshabilitado',
#    'id',
#    'tipoPersona',
#    'tipoMiembro',
#    'id',
#    'numerCamaraComercio',
#    'tipo',
#    'Banera',
#    'jacuzzi',
#    'sala',
#    'cocineta',
#    'PrecioNoche',
#    'capacidad',
#    'tipo',
#    'tipoMenaje',
#    'capacidad',
#    'PrecioNoche',
#    'PrecioMes',
#    'PrecioSemestre',
#    'id',
#    'tipo',
#    'cantidad',
#    'idCliente']},
#  '_XPjZsGdzEeS3yOrtnopAkA.xmi.uml': {'classes': ['Document',
#    'Livre',
#    'Revue',
#    'Dictionnaire',
#    'Roman',
#    'Manuel',
#    'Animal',
#    'Mammifere',
#    'Chien',
#    'Cheval']},
#  '0d92d5b5-5707-41da-8461-a9e9de0fc0f0.xmi.uml': {'classes': ['Sword',
#    'Axe',
#    'EnchancedWeapon',
#    'FireWeapon',
#    'HolyWeapon'],
#   'attributes': ['weapon']},
#  '_iiwTkHbaEeSfPZ7vcufCPw.xmi.uml': {'classes': ['Location',
#    'Zuordnung',
#    'Software'],
#   'attributes': ['Location_ID',
#    'Netz_ID',
#    'Route',
#    'Raumname',
#    'Betreuer',
#    'Location_ID',
#    'Software_ID',
#    'Software_ID',
#    'Softwarename']},
#  ...}

# %%
for file in data_dict.keys():
    if 'classes' not in data_dict[file].keys() or len(data_dict[file]['classes']) == 0:
        print(file)
        print(data_dict[file])

# %%
# Get total amount of unique classes
print(len(np.unique(np.array(list(map(lambda x: x.strip(), flatten([data_dict[file]['classes'] for file in data_dict.keys()])))))))

# Get total amount of unique attributes
print(len(np.unique(np.array(flatten([[str(attr).strip() for attr in values['attributes']] for values in data_dict.values() if 'attributes' in values.keys()])))))
# Out:
# 344981
# 455730

# %%
with open('data/genmymodel_uml_extracted_metadata.json', 'w') as fp:
    json.dump(data_dict, fp)

# %% [markdown]
# ## First "raw" data cleaning cycle

# %%
with open('data/genmymodel_uml_extracted_metadata.json') as json_file:
    data_dict = json.load(json_file)

# %%
def should_be_kept(text):
    # Check if larger than 1 character
    if len(text) > 1:
        # Remove function calls '_8Ux_QFaxEeSu48YT12vqpQ.xmi.uml'
        if text[-2:] == '()':
            return False

        # Remove getters and setters '_UWr2cM_JEeeLcIicqHdTUQ.xmi.uml' '_va9xEFzhEeqK2M3E1LfZ7Q.xmi.uml'
        if re.search(r'^[gs]et(?:[A-Z]|_)\w+', text):
            return False

        # Remove dot seperated widgets/views and filenames '_tGyV0EbLEeeTJ_4Vl2J2rQ.xmi.uml' '_WZQeEMJ8EeSII650IQ0Z1w.xmi.uml'
        if re.search(r'^\w+\.\w+(?:\.\w+)*', text):
            return False

        # Remove comma-separated attributes 'f6e1ef7a-107f-419e-ab7d-a51aa49c13d2.xmi.uml'
        if re.search(r'^\w+?(?:,\w+?)+', text):
            return False
    else: 
        return False
    
    # All cases do not match, text may stay
    return True

data_dict = {
    filename: {
        metadata: list(filter(lambda x: should_be_kept(x), texts))
        for metadata, texts in extracted_data.items()
    }
    for filename, extracted_data in tqdm(data_dict.items())
}
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=187108.0), HTML(value='')))

# %%
# Get total amount of unique classes
print(len(np.unique(np.array(list(map(lambda x: x.strip(), flatten([data_dict[file]['classes'] for file in data_dict.keys()])))))))

# Get total amount of unique attributes
print(len(np.unique(np.array(flatten([[str(attr).strip() for attr in values['attributes']] for values in data_dict.values() if 'attributes' in values.keys()])))))
# Out:
# 336395
# 447945

# %%
# Remove classes/attributes keys if they don't hold any values
iteration_copy = copy.deepcopy(data_dict)
for file in tqdm(iteration_copy.keys()):
    for metadata in iteration_copy[file].keys():
        if len(iteration_copy[file][metadata]) == 0:
            del data_dict[file][metadata]

# Remove files from dataset if they don't hold any classes and attributes anymore
iteration_copy = copy.deepcopy(data_dict)
for file in tqdm(iteration_copy.keys()):
    if len(iteration_copy[file].keys()) == 0:
        del data_dict[file]

# Clear up memory
del iteration_copy
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=187108.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=187108.0), HTML(value='')))

# %%
with open('data/genmymodel_uml_extracted_metadata_cleaned1.json', 'w') as fp:
    json.dump(data_dict, fp)

# %%
data_dict
# Out:
# {'5fae885c-3fde-430f-a3c5-ff44b81f2668.xmi.uml': {'classes': ['ClassA',
#    'ClassB',
#    'ClassC',
#    'ClassD',
#    'ClassE',
#    'ClassF',
#    'ClassG',
#    'ClassH',
#    'ClassI']},
#  '_oVCEUIHiEeeveJPbhFhy-g.xmi.uml': {'classes': ['SitePage', 'SiteSection'],
#   'attributes': ['id',
#    'status',
#    'name',
#    'url',
#    'id',
#    'locked',
#    'name',
#    'defaultPage']},
#  '20b51f77-a952-4206-b35c-b47acd0c631f.xmi.uml': {'classes': ['MoteurImpl',
#    'Buffer',
#    'Selection',
#    'PressePapier'],
#   'attributes': ['texte', 'sel', 'attribute']},
#  'e8a7e84d-73b3-40d2-ac78-f550566b4de8.xmi.uml': {'classes': ['Client',
#    'AdapterImpl',
#    'Adaptee',
#    'Context',
#    'StateA',
#    'StateB',
#    'Singleton',
#    'Abstraction',
#    'RefinedAbstraction',
#    'ConcreteImplementor',
#    'CreatorImpl',
#    'Product',
#    'ConcreteObserver',
#    'ConcreteSubject'],
#   'attributes': ['instance']},
#  '_oWwJoHfLEeqeQcxm9hmzHw.xmi.uml': {'classes': ['ShoppingCart',
#    'Order',
#    'LineItem',
#    'Account',
#    'Customer'],
#   'attributes': ['creationDate', 'id', 'quantity', 'price', 'id']},
#  '_wWY9wDZWEeewJqDqgRk6VA.xmi.uml': {'classes': ['bilal']},
#  '_OR8QgFq_EeeTF9GWmq2Xvg.xmi.uml': {'classes': ['Exam',
#    'Question',
#    'LeadExam',
#    'School',
#    'LeadReport',
#    'LeadSchool',
#    'Class'],
#   'attributes': ['id',
#    'name',
#    'response_columns',
#    'description',
#    'id',
#    'text',
#    'video_unit',
#    'unit_title',
#    'video_chapter',
#    'subject',
#    'id',
#    'lead_name',
#    'lead_phone',
#    'lead_last_name',
#    'group',
#    'school',
#    'result',
#    'exam',
#    'application_date',
#    'id',
#    'identifier',
#    'kind',
#    'maximum_score',
#    'minimum_score',
#    'name',
#    'city',
#    'state',
#    'country',
#    'id',
#    'school',
#    'exam',
#    'lead_exam',
#    'lead_name',
#    'school_name',
#    'school_group',
#    'rank',
#    'version',
#    'correct_answers',
#    'subject_diagnostic',
#    'study_plan',
#    'id',
#    'lead_reports',
#    'school_name',
#    'school_average',
#    'group_diagnostic',
#    'area_diagnostic',
#    'version']},
#  '331af011-1b93-4a9b-abb7-f53d3cfb2a88.xmi.uml': {'classes': ['Client',
#    'Adaptor',
#    'Adaptee']},
#  '9f510af6-1690-4d09-b973-5069cf83647a.xmi.uml': {'classes': ['System',
#    'Sensor',
#    'Motion Sensor',
#    'PressureSensor',
#    'Home Security System',
#    'Alert',
#    'Door',
#    'Camera',
#    'Speakers',
#    'MicroPhone',
#    'Light',
#    'Start Of Day',
#    'End Of Day',
#    'TV',
#    'HomeTheatre',
#    'HouseHolds',
#    'Entertainment'],
#   'attributes': ['Status',
#    'Update',
#    'SensorID',
#    'SensorType',
#    'UserID',
#    'AlertID',
#    'DoorID',
#    'CameraID',
#    'SpeakerID',
#    'MicID',
#    'LightID',
#    'SOT',
#    'EOT',
#    'TVID',
#    'HTID',
#    'TimeID',
#    'Coffee',
#    'DishWasher',
#    'Alarm',
#    'WashingMachine',
#    'DeviceID']},
#  '_3tGxoCVhEeiYD9TOdwevwA.xmi.uml': {'classes': ['Collaborateur',
#    'Pronostique',
#    'Poule',
#    'Competition',
#    'Match',
#    'Equipe'],
#   'attributes': ['id_collaborateur',
#    'nom',
#    'prenom',
#    'email',
#    'password',
#    'role',
#    'id_collaborateur',
#    'id_match',
#    'scoreDomicile',
#    'scoreExterieur',
#    'id_poule',
#    'competition',
#    'libele',
#    'id_competition',
#    'libele',
#    'nombre_poules',
#    'id_match',
#    'poule',
#    'date',
#    'equipeDomicile',
#    'equipeExterieur',
#    'scoreDomicile',
#    'scoreExterieur',
#    'id_equipe',
#    'logo']},
#  '_CFTYQLf4Eee7sYPkE4-GPA.xmi.uml': {'classes': ['MyClass']},
#  '_AkJqwL2EEeirD7wkg7WdAw.xmi.uml': {'classes': ['CUSTOMER', 'USER'],
#   'attributes': ['csname',
#    'cs_phon no.',
#    'address',
#    'credit_cardinfo',
#    'email',
#    'user_id',
#    'password',
#    'login_status']},
#  '_B4ZY0F8QEeepGY91r9Nuow.xmi.uml': {'classes': ['Vente',
#    'Promotion',
#    'Magasin',
#    'Article',
#    'Periode'],
#   'attributes': ['id_magasin',
#    'id_client',
#    'id_periode',
#    'id_article',
#    'id_promotion',
#    'montant_vente',
#    'taxe',
#    'unités_vendes',
#    'numero_ticket_caisse',
#    'id_promotion',
#    'nom_promotion',
#    'taux_remise',
#    'id_magasin',
#    'nom_magasin',
#    'adresse_magasin',
#    'nom_gérant',
#    'département',
#    'id_article',
#    'nom_article',
#    'marque_article',
#    'attribute',
#    'id_periode',
#    'année',
#    'mois',
#    'jour']},
#  '_xoz1gHe2EeiFX4HwoivBqg.xmi.uml': {'classes': ['Batisseur',
#    'Case',
#    'Domino',
#    'IHMKingdomino',
#    'IHMSantorini',
#    'Index',
#    'KingDomino',
#    'PiocheDomino',
#    'Plateau',
#    'Santorini'],
#   'attributes': ['posX',
#    'posY',
#    'hauteur',
#    'nom',
#    'nbCouronnes',
#    'numero',
#    'roi',
#    'pPrincipal',
#    'grille1',
#    'grille2',
#    'pDomino',
#    'pBasDroite',
#    'pBouton',
#    'pDirection',
#    'ensDominos',
#    'ensBoutonsGauche',
#    'ensBoutonsDroite',
#    'ensDominos1',
#    'boutonNord',
#    'boutonSud',
#    'boutonEst',
#    'boutonOuest',
#    'retour',
#    'regles',
#    'quitter',
#    'action',
#    'ligne',
#    'colonne',
#    'nbTours',
#    'ordre',
#    'principal',
#    'visionJeu',
#    'buttonJeu',
#    'panelDroite',
#    'panelLogo',
#    'retour',
#    'regle',
#    'quitter',
#    'bouton',
#    'action',
#    'conteurBati',
#    'choixBati',
#    'tourJoueur',
#    'tempPosX',
#    'tempPosY',
#    'posX',
#    'posY',
#    'tempEtage',
#    'ensBati',
#    'principal',
#    'santorini',
#    'regleSantorini',
#    'kingDomino',
#    'allRois',
#    'nbRois',
#    'nbJoueurs',
#    'nbDominos',
#    'player',
#    'royaumeJoueur1',
#    'royaumeJoueur2',
#    'plateau',
#    'ensBati',
#    'conteurBati',
#    'joueur1',
#    'joueur2']},
#  '_C3TewPaFEeWolbMxsR5EUQ.xmi.uml': {'classes': ['File'],
#   'attributes': ['File server', 'File local']},
#  '_2Jq9QK0KEDGNWLI2ml8Hng.xmi.uml': {'classes': ['Lab3',
#    'ServerConnection',
#    'Gameboard',
#    'JFrame',
#    'JPanel',
#    'Server']},
#  '_GbX-wK10EemHYc7DDM2g2A.xmi.uml': {'classes': ['Animal',
#    'Employee',
#    'Tortoise',
#    'Otter',
#    'Slow Loris',
#    'Sea Urchin',
#    'Creep',
#    'Lobby',
#    'Bathroom',
#    'Visitor Center'],
#   'attributes': ['name',
#    'id',
#    'age',
#    'weight',
#    'name',
#    'employeeId',
#    'phone',
#    'department',
#    'whiskerLength']},
#  '_WZQeEMJ8EeSII650IQ0Z1w.xmi.uml': {'classes': ['ReportSettings<T>',
#    'ReportSettingsAccessor',
#    'ReportDataManager<T>',
#    'ReportAccessor<T>',
#    'Report<T>',
#    'aaaa']},
#  '_rGklUKQCEeWJIdgJ_zFBoQ.xmi.uml': {'classes': ['ENTREPRISE',
#    'PRODUIT',
#    'MyClass'],
#   'attributes': ['Nom', 'NomProd', 'Num']},
#  '_n6vpQN9FEea4oJwuIIj5Zg.xmi.uml': {'classes': ['Golpes', 'Tipo'],
#   'attributes': ['codigo', 'nome', 'tipo', 'categoria', 'codigo', 'nome']},
#  '_UBfU4MCnEeeEXb8Dudo6PQ.xmi.uml': {'classes': ['CloneDetectionNewUI',
#    'ddgRightDialog',
#    'ddgBottomDialog',
#    'historySpreadSheetSource',
#    'SpreadSheetObjectTreeView',
#    'treeViewSpreadSheetSource',
#    'SpreadSheetObjectListView',
#    'listViewSpreadSheetSource',
#    'HistorySpreadSheetObj',
#    'SimilarityPlotSpreadSheetObj',
#    'similarityPlotSpredSheetSource']},
#  '_TCwTALi_Eeaud6jyFEReOw.xmi.uml': {'classes': ['Casino',
#    'admin',
#    'game',
#    'table',
#    'player',
#    'gametype',
#    'rule'],
#   'attributes': ['id',
#    'name',
#    'id',
#    'password',
#    'starttime',
#    'number',
#    'connectedplrs',
#    'id',
#    'password',
#    'balance',
#    'game',
#    'maxplayer',
#    'id',
#    'desc']},
#  '_Eta50N0oEeS1iL_C3WP8Cw.xmi.uml': {'classes': ['tblUsers', 'tblOrder'],
#   'attributes': ['UserID',
#    'UserName',
#    'Password',
#    'FullName',
#    'Role',
#    'VIP',
#    'Status',
#    'OrderID',
#    'UserName',
#    'Password',
#    'FullName',
#    'Role',
#    'VIP',
#    'Status']},
#  '_YlTgsCASEeiv8MB6k6XBAg.xmi.uml': {'classes': ['MyFrame',
#    'ControlPanel',
#    'DrawingPanel',
#    'Rect',
#    'Class',
#    'Graphics',
#    'DrawingPanel',
#    'Shape',
#    'Circle',
#    'Rect',
#    'DrawingPanel',
#    'Circle',
#    'Rect',
#    'Circle',
#    'DrawingPanel',
#    'Rect',
#    'DrawingPanel',
#    'Shape',
#    'Circle',
#    'Dog',
#    'Test',
#    'IdGenerator',
#    'Cat',
#    'Rect',
#    'CanBeDrawn',
#    'PolyGen',
#    'Slacker'],
#   'attributes': ['name', 'id', 'CURRENT_ID', 'id', 'name']},
#  '_O9PI8GyeEDGXH9FO528ZpA.xmi.uml': {'classes': ['DVD',
#    'Book',
#    'Library_Managnment_System',
#    'Item',
#    'Staff',
#    'Libarian',
#    'Member',
#    'Clerk'],
#   'attributes': ['Type',
#    'count1',
#    'Type',
#    'count',
#    'ItemLinker',
#    'Mem',
#    'Cler',
#    'availability',
#    'issued',
#    'onloan',
#    'reference',
#    'Name',
#    'ID',
#    'Name',
#    'ID']},
#  '93552bd2-6e15-45b3-b1dd-3a4aa6b3b0b3.xmi.uml': {'classes': ['ChatServer',
#    'ChatClient',
#    'Couleur',
#    'History',
#    'User',
#    'Session',
#    'JFrame']},
#  '_UWr2cM_JEeeLcIicqHdTUQ.xmi.uml': {'classes': ['CurrencyConverter',
#    'USCurrencyConverter',
#    'CanadianCurrencyConverter',
#    'TaskController',
#    'SalesOrder',
#    'MyClass',
#    'CalcTax']},
#  '_tGyV0EbLEeeTJ_4Vl2J2rQ.xmi.uml': {'classes': ['ExampleInstrumentedTest',
#    'FightScreen',
#    'StartMenu',
#    'AboutFragment',
#    'CustomHealthBar',
#    'CustomManaBar',
#    'CustomMenuButton',
#    'CustomMenuPlayButton',
#    'LogoFragment',
#    'SettingsFragment',
#    'Game',
#    'GamePanel',
#    'MainThread',
#    'Singleton',
#    'BitmapCache',
#    'Character',
#    'Dummy',
#    'Enemy',
#    'Exit',
#    'GameObject',
#    'Ground',
#    'Player',
#    'Wall',
#    'Level',
#    'Section',
#    'ExampleUnitTest'],
#   'attributes': ['playerHealthText',
#    'enemyHealthText',
#    'playerManaText',
#    'playerActionText',
#    'enemyActionText',
#    'playerImage',
#    'enemyImage',
#    'healthPotionButton',
#    'manaPotionButton',
#    'attackButton',
#    'specialAttackButton',
#    'MAX_VOLUME',
#    'mediaPlayer',
#    'volumeForPlayer',
#    'health',
#    'maxHealth',
#    'blackPaint',
#    'redPaint',
#    'mana',
#    'maxMana',
#    'blackPaint',
#    'bluePaint',
#    'WIDTH',
#    'HEIGHT',
#    'horizontalTiles',
#    'verticalTiles',
#    'tileWidth',
#    'tileHeight',
#    'paint',
#    'FPS',
#    'averageFPS',
#    'surfaceHolder',
#    'running',
#    'canvas',
#    'context',
#    'cache',
#    'name',
#    'health',
#    'maxHealth',
#    'attack',
#    'health',
#    'attack',
#    'maxHealth',
#    'specialAtack',
#    'maxMana',
#    'mana',
#    'name',
#    'amountOfHealthPotions',
#    'amountOfManaPotions',
#    'toSection',
#    'solid',
#    'image',
#    'imageRef',
#    'amountOfHealthPotions',
#    'amountOfManaPotions',
#    'mana',
#    'maxMana',
#    'specialAttack']},
#  '_rRbrsL2FEeedTfUoC-GfaA.xmi.uml': {'classes': ['Snake'],
#   'attributes': ['attribute']},
#  '_r3GXcCFEEeiv8MB6k6XBAg.xmi.uml': {'classes': ['Utilisateur',
#    'Profil',
#    'Système',
#    'Base de données',
#    'Serveur'],
#   'attributes': ['profil', 'nom', 'âge', 'mot de passe', 'genre']},
#  '_UvEXMEGiEemokbRu9Ld3Pw.xmi.uml': {'classes': ['Individu',
#    'Film',
#    'Cinéma',
#    'Séance',
#    'Individu',
#    'Groupe',
#    'Contacts',
#    'Individu2',
#    'Film2',
#    'Cinéma2',
#    'Séance2',
#    'Groupe',
#    'Contact'],
#   'attributes': ['Nom',
#    'Age',
#    'Nom',
#    'Nom',
#    'Ville',
#    'Date',
#    'Heure',
#    'Nom',
#    'Age',
#    'Nom',
#    'Nom',
#    'Ville',
#    'Date',
#    'Heure']},
#  '_0se6kFNjEeS7SK6lkmJgjw.xmi.uml': {'classes': ['$.insmRegionView',
#    '$.insmBase',
#    '$.insmRestService',
#    '$.insmAssetLoaderIndicator',
#    'insmRegionEventConstant',
#    '$.insmPlayListGrid',
#    'insmPlayListGridEventConstant',
#    '$.insmPlayListManager',
#    'insmPlayListManagerEventConstant',
#    'Object',
#    '$.insmPlayListEditor',
#    '$.insmAddNewPopup'],
#   'attributes': ['CurrentSelectedNodes',
#    'tag',
#    '$.deffer',
#    'RegionDatacollection',
#    'PlayListItems',
#    'AddOnTeamplateCollection',
#    'ONCHECKNODE',
#    'ONCLICKNODE',
#    'CurrentSelectedRow',
#    'ONREMOVEITEM',
#    'ONEDITITEM',
#    'SEARCHREGION',
#    'CLEARRELATION',
#    'REMOVESELECTION',
#    'SEARCHPLAYLIST',
#    'GETDATA',
#    'CurrentMediaType',
#    'Settings']},
#  '48ecca9d-91d4-44f2-a21f-b0285228d504.xmi.uml': {'classes': ['jsdf',
#    'className',
#    'MyClass'],
#   'attributes': ['dfsd']},
#  '45467683-bfda-4a59-aee6-262b47b819db.xmi.uml': {'classes': ['Level',
#    'Category'],
#   'attributes': ['State', 'Name', 'id', 'level']},
#  '_qlo-cJalEeaLdJY0NVKqzQ.xmi.uml': {'classes': ['User']},
#  '_bTMxUGfCEDGY580vxrGduA.xmi.uml': {'classes': ['MyClass']},
#  '_IjzBoFWBEemYjay6yoFVQw.xmi.uml': {'classes': ['Prodavac',
#    'Nabavka',
#    'Dobavljač',
#    'Račun',
#    'Proizvod',
#    'Vrsta proizvoda',
#    'Kupac',
#    'Plaćanje u gotovini',
#    'Plaćanje',
#    'Plaćanje sa karticom',
#    'Plaćanje karticom',
#    'Plaćanje u gotovini'],
#   'attributes': ['ProdavacID',
#    'Ime',
#    'Prezime',
#    'e-mail',
#    'Kontakt telefon',
#    'Napomena',
#    'NabavkaID',
#    'Datum',
#    'Kolicina',
#    'Iznos',
#    'Vreme',
#    'Napomena',
#    'ProdavacID',
#    'DobavljacID',
#    'ProizvodID',
#    'DobavljacID',
#    'Naziv',
#    'Maticni broj',
#    'Kontakt telefon',
#    'Adresa',
#    'Mesto',
#    'Napomena',
#    'RacunID',
#    'Datum',
#    'Vreme',
#    'Kolicina',
#    'Iznos',
#    'ProdavacID',
#    'Napomena',
#    'PlaćanjeID',
#    'ProizvodID',
#    'Naziv',
#    'Napomena',
#    'DobavljacID',
#    'VrstaProizvodaID',
#    'NabavkaID',
#    'Iznos',
#    'Napomena',
#    'ProdavacID',
#    'Ime',
#    'Prezime',
#    'e-mail',
#    'Kontakt telefon',
#    'Napomena',
#    'ProdavacID',
#    'Ime',
#    'Prezime',
#    'e-mail',
#    'Kontakt telefon',
#    'Napomena',
#    'ProizvodID',
#    'RačunID',
#    'ProdavacID',
#    'Ime',
#    'Prezime',
#    'Kontakt telefon',
#    'ProizvodID',
#    'RačunID',
#    'ProizvodID',
#    'RačunID']},
#  '_kUTfkMkMEeeM1PgT03-3Vg.xmi.uml': {'classes': ['LoginTbl',
#    'AddNewsTbl',
#    'FeedbackTbl',
#    'EmployeeTbl',
#    'RegistrationTbl'],
#   'attributes': ['UserName',
#    'Password',
#    'ID',
#    'News_Image',
#    'News_Description',
#    'Bookmark',
#    'ID',
#    'feedback',
#    'ID',
#    'MailAddress',
#    'UserName',
#    'Password',
#    'City',
#    'Dob',
#    'Gender']},
#  '_89yH0D-DEeWH0sFqYQQ8Cg.xmi.uml': {'classes': ['Server'],
#   'attributes': ['var1']},
#  '_Mx7t0OmWEeaowdqlt8Dqsg.xmi.uml': {'classes': ['Déplacement',
#    'Etape',
#    'Station',
#    'StationExtrémité',
#    'StationNoeud'],
#   'attributes': ['idContainer',
#    'date',
#    'heureDépart',
#    'heureArrivée',
#    'priorité',
#    'numEtape',
#    'heureArrivée',
#    'heureDépart',
#    'idStation',
#    'nom',
#    'localisation',
#    'tailleZoneDeGroupage',
#    'occupée']},
#  '_m43vEEhOEemB7r6RYSs12w.xmi.uml': {'classes': ['Ads', 'Event', 'Product']},
#  '_pBW_QHLCEee5HMQDnOR-kg.xmi.uml': {'classes': ['Crew',
#    'CrewPilot',
#    'Plane',
#    'Schedule'],
#   'attributes': ['crewID',
#    'crewName',
#    'crewAddress',
#    'crewPhone',
#    'pilotLicense',
#    'planeID',
#    'scheduleTime',
#    'schedulePlane',
#    'scheduleCrew',
#    'scheduleDeparture',
#    'scheduleNote',
#    'scheduleArrival']},
#  '_7Qd5sHVJEeSZWo9AFr5YZg.xmi.uml': {'classes': ['Benchmark-Controller',
#    'LoadDriver',
#    'Database',
#    'Transaktions',
#    'Remote',
#    'InitDatabase']},
#  '4465670b-b7f1-4505-8c09-e163b6a629a7.xmi.uml': {'classes': ['ShoppingCart']},
#  'b66a0071-5321-4795-a59c-96ff8cc34f37.xmi.uml': {'classes': ['Worker',
#    'People',
#    'Customer',
#    'Cook',
#    'Waiter',
#    'Cashier'],
#   'attributes': ['name']},
#  '42797400-89dc-4192-8cac-7f67e4e4fbc3.xmi.uml': {'classes': ['Registration'],
#   'attributes': ['attribute']},
#  '19cf5401-6e76-4e4d-81d8-309f156151f5.xmi.uml': {'classes': ['SessionRepositoryFilter',
#    'ExpiringSessionHttpSession',
#    'MultiHttpSessionStrategyAdapter',
#    'HeaderHttpSessionStrategy',
#    'ExpiringSession']},
#  '_GhGBELsKEeWdWJbDFmNa8w.xmi.uml': {'classes': ['Conta', 'Ganho', 'Pessoa'],
#   'attributes': ['numero',
#    'nome',
#    'valor',
#    'situacao',
#    'id',
#    'nome',
#    'valor',
#    'situacao',
#    'id']},
#  '_zeUN8FJjEeeTnI9B59buBQ.xmi.uml': {'classes': ['AdminHomeActivity',
#    'BackgroundMaterialActivity',
#    'CategoryActivity',
#    'EditDomainsActivity',
#    'LeaderboardActivity',
#    'PasswordResetActivity',
#    'PerformanceActivity',
#    'QuizActivity',
#    'RemoveUserActivity',
#    'DomainAdapter',
#    'LeaderboardAdapter',
#    'QuestionAdapter',
#    'UserAdapter',
#    'Answer',
#    'CategoryContent',
#    'Material',
#    'Question',
#    'QuestionItem',
#    'Score',
#    'User',
#    'UserScore',
#    'LoginFragment',
#    'PasswordRecoveryFragment',
#    'PasswordResetFragment',
#    'QuizResultDialogFragment',
#    'RegisterFragment',
#    'Constants',
#    'StringUtils',
#    'ArrayAdapter<String>',
#    'ArrayAdapter<QuestionItem>',
#    'ArrayAdapter<User>'],
#   'attributes': ['mAuth',
#    'mAuthStateListener',
#    'mLeaderboardBtn',
#    'mEditDomainsBtn',
#    'mAddUserBtn',
#    'mRemoveUserBtn',
#    'mLogoutBtn',
#    'mCategory',
#    'mCategoryTextView',
#    'mStartQuizBtn',
#    'mBackgroundText',
#    'mDatabase',
#    'mCategoryList',
#    'mProgressDialog',
#    'mListView',
#    'mBtnContainer',
#    'addDomainBtn',
#    'saveDomainBtn',
#    'mDatabase',
#    'mDomains',
#    'mKeys',
#    'mDomain',
#    'mPosition',
#    'mEditMode',
#    'mDatabase',
#    'mProgressDialog',
#    'tabLayout',
#    'mViewPager',
#    'mAuth',
#    'user',
#    'mCurrentPasswordView',
#    'mNewPasswordView',
#    'mNewPassword2View',
#    'mChangePasswordButton',
#    'mCancelButton',
#    'mResetProgressView',
#    'mPasswordResetFormView',
#    'cancel',
#    'focusView',
#    'mQuizzesTextView',
#    'mScoreTextView',
#    'mCurrentRankTextView',
#    'mBestRankTextView',
#    'mProgressDialog',
#    'mDatabase',
#    'mCategory',
#    'mDatabase',
#    'mQuizScore',
#    'isReviewMode',
#    'mQuestionListView',
#    'mCategoryTextView',
#    'mViewPager',
#    'mResultTextView',
#    'mListView',
#    'mDatabase',
#    'mUserKeyList',
#    'mAuth',
#    'mDomains',
#    'mContext',
#    'mEditableList',
#    'mEditableBtnList',
#    'mEditedDomainName',
#    'mActivity',
#    'mContext',
#    'mQuestions',
#    'mLayoutId',
#    'isReview',
#    'mTextView',
#    'mActivity',
#    'text',
#    'isCorrect',
#    'img',
#    'isSelected',
#    'questions',
#    'text',
#    'imgs',
#    'text',
#    'img',
#    'answers',
#    'isAnswered',
#    'number',
#    'isSelected',
#    'isCorrect',
#    'isAttempted',
#    'correct',
#    'quizzes',
#    'bestRank',
#    'currentRank',
#    'percentage',
#    'firstName',
#    'lastName',
#    'email',
#    'password',
#    'isAdmin',
#    'mEmailView',
#    'mPasswordView',
#    'mProgressView',
#    'mLoginFormView',
#    'mEmailEditText',
#    'mUrl',
#    'ARG_PARAM_URL',
#    'mWebView',
#    'mProgressDialog',
#    'mQuizResultTextView',
#    'mEmailView',
#    'mPasswordView',
#    'mPasswordView2',
#    'mFirstName',
#    'mLastName',
#    'mProgressView',
#    'mRegisterFormView',
#    'mRegisterButton',
#    'ARG_PARAM1',
#    'ARG_PARAM2',
#    'mParam1',
#    'mParam2',
#    'mDatabase',
#    'domainRef',
#    'mDomains',
#    'CATEGORY_NAME',
#    'NUM_QUESTIONS_PER_QUIZ',
#    'QUESTION_PREFIX',
#    'COLOR_QUESTION_SELECTED',
#    'COLOR_QUESTION_CORRECT',
#    'COLOR_QUESTION_INCORRECT',
#    'DB_QUESTIONS',
#    'DB_SCORES',
#    'DB_SCORES_UPDATED',
#    'DB_USERS',
#    'DB_DOMAINS',
#    'HOST']},
#  '_8y0sAIKDEeeveJPbhFhy-g.xmi.uml': {'classes': ['STUDENT REGISTRATION',
#    'TEACHERS REGISTRATION',
#    'MyClass']},
#  '_YRK-gLc7EeWh17zD5SB95Q.xmi.uml': {'classes': ['Request',
#    'Status',
#    'Department',
#    'ApplicationUser',
#    'RequestEvent',
#    'RequestEventDetail'],
#   'attributes': ['id',
#    'topic',
#    'status',
#    'department',
#    'citizen',
#    'assignee',
#    'events',
#    'id',
#    'comment',
#    'date',
#    'attribute',
#    'isPublic',
#    'Author',
#    'details',
#    'id',
#    'text']},
#  '_0fYbULfaEee7sYPkE4-GPA.xmi.uml': {'classes': ['library',
#    'librarian',
#    'books database',
#    'student',
#    'vendor',
#    'student record'],
#   'attributes': ['location',
#    'name',
#    'book title',
#    'author',
#    'book id',
#    'details',
#    'book details',
#    'attribute',
#    'name',
#    'address',
#    'phone number',
#    'fines']},
#  '_P5FiwC-mEeme-prEJQaJbA.xmi.uml': {'classes': ['Ebook',
#    'Configuracoes',
#    'Decodificador',
#    'CelulaBraille']},
#  '_VTRjAHomEeSdXJMJcKNKoQ.xmi.uml': {'classes': ['Personal',
#    'Användare',
#    'Elev',
#    'Lågstadiet',
#    'Mellanstad',
#    'MyClass'],
#   'attributes': ['namn',
#    'behörighet',
#    'ID',
#    'yrkesroll',
#    'namn',
#    'behörighet',
#    'Id',
#    'namn',
#    'behörighet',
#    'Id',
#    'attribute']},
#  '_Vfe9wHL5EeSxHp9pHOThjg.xmi.uml': {'classes': ['Trader']},
#  'a093a6c4-4491-4b65-b79a-19be1bd57765.xmi.uml': {'classes': ['Customer',
#    'Payment',
#    'ShoppingCart',
#    'Account',
#    'WebUser',
#    'Order',
#    'LineItem',
#    'Product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paidDate',
#    'total',
#    'details',
#    'creationDate',
#    'billingAddress',
#    'open',
#    'closed',
#    'isClosed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'shipTo',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description']},
#  '_NpOgoK7zEee6S77dw3LIvQ.xmi.uml': {'classes': ['AppPartidoBasketball',
#    'Equipo',
#    'PartidoBasketball',
#    'Jugador'],
#   'attributes': ['nombre',
#    'ciudad',
#    'titulo: String',
#    'dia: byte',
#    'nombre',
#    'apellido',
#    'estatura']},
#  '_2A0eUK99EealN5YbbDMqoA.xmi.uml': {'classes': ['Modification',
#    'DegreeModifacion',
#    'ModuleModification',
#    'Obsever',
#    'Observable',
#    'ModifyDegree',
#    'DeleteDegree',
#    'ModifyModule',
#    'DeleteModule'],
#   'attributes': ['modId',
#    'status',
#    'title',
#    'degreeCode',
#    'level',
#    'moduleCode',
#    'level',
#    'update',
#    'addObserver(observer:Observer',
#    'removeObserver(observer:Observer',
#    'notifyAll']},
#  '_fRRYMELoEeavkcsFwndrbA.xmi.uml': {'classes': ['Animal'],
#   'attributes': ['name', 'size', 'color']},
#  '_xOaacKYVEeaiBJ7PH1W80g.xmi.uml': {'classes': ['Personel',
#    'Ticket',
#    'Yetkilendirme'],
#   'attributes': ['PersonelID',
#    'Personelİsim',
#    'PersonelMevki',
#    'PersonelBolum',
#    'TicketID',
#    'TicketTarih',
#    'TicketDetay',
#    'PersonelID',
#    'TicketDurum',
#    'SorunCesidi',
#    'Cozum',
#    'TicketID',
#    'PersonelID']},
#  '_bunGYGkdEeSmTqqtE6wM_Q.xmi.uml': {'classes': ['Guest',
#    'User',
#    'Player',
#    'Moderator',
#    'Email Server',
#    'Database',
#    'Android Application Instance',
#    'Clarification Request',
#    'Game',
#    'Mission',
#    'Kill',
#    'GeoFence',
#    'GeoPoint',
#    'Page',
#    'Global Update',
#    'Dynamic Game Map'],
#   'attributes': ['roleID',
#    'HVZID',
#    'email',
#    'password',
#    'firstName',
#    'lastName',
#    'kills',
#    'createdAt',
#    'playedGames',
#    'paidDues',
#    'isSubscribed',
#    'phoneNumber',
#    'playerType',
#    'inGame',
#    'GPSTrackingOn',
#    'name',
#    'IP',
#    'subscribedEmails',
#    'username',
#    'password',
#    'emailsToSend',
#    'name',
#    'IP',
#    'username',
#    'password',
#    'instanceID',
#    'userLoggedIn',
#    'deviceName',
#    'latitude',
#    'longitude',
#    'timeOfGPS',
#    'isTracking',
#    'missionID',
#    'isAnswered',
#    'responseUser',
#    'sourceUser',
#    'message',
#    'response',
#    'gameID',
#    'missions',
#    'description',
#    'players',
#    'isCurrent',
#    'missionID',
#    'gameID',
#    'geoFences',
#    'geoPoints',
#    'description',
#    'roleID',
#    'vicitmUser',
#    'killerUser',
#    'timeOfDeath',
#    'inGameID',
#    'centerLatitude',
#    'centerLongitude',
#    'radius',
#    'triggerPlayers',
#    'score',
#    'scoreModifier',
#    'endScore',
#    'description',
#    'inMissionID',
#    'triggerRate',
#    'seenByPlayers',
#    'isVisible',
#    'latitude',
#    'longitude',
#    'description',
#    'inMissionID',
#    'seenByPlayers',
#    'isVisible',
#    'url',
#    'information',
#    'title',
#    'message',
#    'sourceUser',
#    'pushNotificationSent',
#    'emailNotificationSent',
#    'mission']},
#  'dc7ae9ed-7cf7-4298-844e-489bbc9faeea.xmi.uml': {'classes': ['ShoppingCart']},
#  '_zkx8wOKPEeiZY7VjYQykuQ.xmi.uml': {'classes': ['Control',
#    'SuperBKCompare',
#    'BKCompareWriteToExcel',
#    'BKCompareWriteToText',
#    'SuperBKReader',
#    'BKWriter']},
#  '_SaUicIB4Eei-m5BAOg12zA.xmi.uml': {'classes': ['Character',
#    'SavingThrow',
#    'Weapon'],
#   'attributes': ['name',
#    'race',
#    'vocation',
#    'isPlayer',
#    'str',
#    'dex',
#    'cons',
#    'intel',
#    'wis',
#    'chr',
#    'saveThrow',
#    'hp',
#    'hitDice',
#    'equipped',
#    'isProficient',
#    'profBonus',
#    'name',
#    'range',
#    'damage',
#    'atkBonus']},
#  '_Sefo0H_cEDGdNIjA6xbcew.xmi.uml': {'classes': ['UITextView',
#    'UIImagePickerController',
#    'UITextField',
#    'UIAlertView',
#    'UIImageView',
#    'UIView',
#    'UIControl',
#    'Button',
#    'UIActivityIndicatorView',
#    'PerformEncript',
#    'StagoCustomView',
#    'StagoDisplayUpdater',
#    'PerformDecrypt',
#    'StaganographyManager']},
#  '_34klgCFXEeqqcaoAsxFIeg.xmi.uml': {'classes': ['Book',
#    'Reader',
#    'Librarian',
#    'Borrowing',
#    'User'],
#   'attributes': ['id',
#    'name',
#    'no',
#    'writer',
#    'press',
#    'address',
#    'total',
#    'id',
#    'name',
#    'no',
#    'age',
#    'sex',
#    'department',
#    'telephoneNumber',
#    'id',
#    'name',
#    'no',
#    'sex',
#    'age',
#    'telephoneNumber',
#    'date',
#    'id',
#    'username',
#    'password']},
#  '_JuQ-QJvREeSW9selBczv3Q.xmi.uml': {'classes': ['IFigura',
#    'IColor',
#    'Rectangulo',
#    'Circulo',
#    'Cuadrilatero'],
#   'attributes': ['PI', 'base', 'altura', 'radio']},
#  '_lC7ZAGxcEem8aOzn3EOqfg.xmi.uml': {'classes': ['Order']},
#  '_tHhBAFSKEei2efM7H4gIXw.xmi.uml': {'classes': ['Boleto',
#    'Contrato',
#    'Parcela',
#    'flo'],
#   'attributes': ['numBoleto',
#    'codCliente',
#    'codBarra',
#    'datReneg',
#    'datVencimento',
#    'valSaldoDev',
#    'valSaldoReneg',
#    'valPercDesc',
#    'indCampanha',
#    'numQtdeParc',
#    'valPrest',
#    'valDescPrest',
#    'valLiquPrest',
#    'numBoleto',
#    'codCliente',
#    'codProduto',
#    'numContrato',
#    'nomProduto',
#    'valSaldoDev',
#    'valSaldoReneg',
#    'valEncargo',
#    'valTarifa',
#    'numBoleto',
#    'codProduto',
#    'numContrato',
#    'numParcela']},
#  '1071140d-9c5d-46d3-aa90-f9b348ebfac9.xmi.uml': {'classes': ['Customer',
#    'Payment',
#    'ShoppingCart',
#    'Account',
#    'WebUser',
#    'Order',
#    'LineItem',
#    'Product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paidDate',
#    'total',
#    'details',
#    'creationDate',
#    'billingAddress',
#    'open',
#    'closed',
#    'isClosed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'shipTo',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description']},
#  '72bffa82-db26-4d26-a139-b38884dada59.xmi.uml': {'classes': ['Clients',
#    'Login',
#    'Administrator',
#    'WhoMadeChanges',
#    'AccountExpired',
#    'MakePay',
#    'ChangePassword',
#    'Events',
#    'AddAdditionalData',
#    'AdvanceSearch']},
#  '_z-y1oKPNEeikWfbDNPV9UQ.xmi.uml': {'classes': ['Class']},
#  '_iAN1sIYZEeS_9vPfFC3tSQ.xmi.uml': {'classes': ['Dog',
#    'Lab',
#    'Poodle',
#    'Shepard',
#    'Pitbull',
#    'Pug',
#    'Beagle'],
#   'attributes': ['gender', 'breed', 'weight', 'color', 'eyeColor']},
#  '43125ec2-0e31-4d4d-98d2-2ca18c1a08ba.xmi.uml': {'classes': ['Client',
#    'Adaptor',
#    'Adaptee']},
#  'b11d83f2-57be-4197-b073-33b29a12e551.xmi.uml': {'classes': ['Worker',
#    'People',
#    'Customer',
#    'Cook',
#    'Waiter',
#    'Cashier'],
#   'attributes': ['name']},
#  '_CwucMBNMEeSTV6l4790RsQ.xmi.uml': {'classes': ['Mensagem',
#    'Twitter',
#    'Facebook',
#    'Utilizador']},
#  '_ozUCAFmYEeaQF8q9ZsVYhQ.xmi.uml': {'classes': ['SingleDataCombiner',
#    'LatestValueCombiner',
#    'GreatestValueCombiner',
#    'CustomCombiner',
#    'CombinedCombiner',
#    'PriorityCombiner',
#    'RuleBasedCombiner']},
#  '_mu7qEH1yEeShroDxTnL5_A.xmi.uml': {'classes': ['SingleDataCombiner',
#    'LatestValueCombiner',
#    'GreatestValueCombiner',
#    'CustomCombiner',
#    'CombinedCombiner',
#    'PriorityCombiner',
#    'RuleBasedCombiner']},
#  '_vgKXsMUIEeadwOIOqK-0Fw.xmi.uml': {'classes': ['MyClass']},
#  'd5c157b6-912e-4995-9d8f-bd5f2aa2ee9f.xmi.uml': {'classes': ['Client',
#    'AdapterImpl',
#    'Adaptee',
#    'Context',
#    'StateA',
#    'StateB',
#    'Singleton',
#    'Abstraction',
#    'RefinedAbstraction',
#    'ConcreteImplementor',
#    'CreatorImpl',
#    'Product',
#    'ConcreteObserver',
#    'ConcreteSubject'],
#   'attributes': ['instance']},
#  '_Hr1JoIwLEeewrIfYd5mf8Q.xmi.uml': {'classes': ['MonetateEvent',
#    'MonetateEventProductView',
#    'MonetateEventPurchase',
#    'MonetateProcessor',
#    'Product',
#    'MessageProcessor'],
#   'attributes': ['eventType',
#    'products',
#    'purchaseLines',
#    'NAME',
#    'SETTING_API_KEY',
#    'SETTING_MAILING_LIST_ID',
#    'domain',
#    'instance',
#    'accountId',
#    'apiURL',
#    'sku',
#    'pid',
#    'quantity',
#    'currency',
#    'value']},
#  '_1ybHgIT-EeS-18kfrtGUQQ.xmi.uml': {'classes': ['Quran surah'],
#   'attributes': ['Surah_no', 'Name_of_surah', 'Type_of_surah']},
#  'f959fb74-a45e-4e26-a37d-ff5dad352c49.xmi.uml': {'classes': ['Worker',
#    'People',
#    'Customer',
#    'Cook',
#    'Waiter',
#    'Cashier'],
#   'attributes': ['name']},
#  'e62c26ba-de91-443d-8dec-baa035e40d26.xmi.uml': {'classes': ['ShoppingCart',
#    'Order',
#    'LineItem',
#    'Account',
#    'Customer'],
#   'attributes': ['creationDate', 'id', 'quantity', 'price', 'id']},
#  '_SHt8QP2_EeOTCK1Mp6laew.xmi.uml': {'classes': ['Main_class',
#    'About',
#    'Documents',
#    'Encryption',
#    'Decryption',
#    'SS_generator',
#    'App_Password']},
#  '_tWiXAE-oEeeu8_4LH_yuyg.xmi.uml': {'classes': ['_core', 'person', 'company'],
#   'attributes': ['id', 'value', 'PersonCode', 'RegistrationNr', 'VATNr']},
#  '_0ato4He_EeeZ3IbHHpTTiA.xmi.uml': {'classes': ['AdapterFactory',
#    'GoogleAdapterFactory',
#    'Class',
#    'Adapter',
#    'Class2',
#    'AmazonAdapterFactory',
#    'GoogleAdapter',
#    'AmazonAdapter',
#    'GenericRequestStreamHandler'],
#   'attributes': ['OBJECT_MAPPER']},
#  '_yIWRYChXEeShcfbUiDP6ug.xmi.uml': {'classes': ['MyClass', 'MyClass2'],
#   'attributes': ['name']},
#  '67ed9d27-56e3-4b81-8050-6e03eda242b5.xmi.uml': {'classes': ['Worker',
#    'People',
#    'Customer',
#    'Cook',
#    'Waiter',
#    'Cashier'],
#   'attributes': ['name']},
#  '_cOog0CIgEeisAYMSV00L2Q.xmi.uml': {'classes': ['FieldsModification',
#    'CreatedUserModification',
#    'DeletedUserModification',
#    'UserMovedToGroupModification',
#    'GridIndex',
#    'GridIndex2']},
#  'a670164a-9f45-46fe-bade-23f443485ab4.xmi.uml': {'classes': ['Customer',
#    'Account',
#    'Transaction',
#    'CheckingAccount',
#    'SavingsAccount',
#    'Login',
#    'DepositTransaction',
#    'WithdrawTransaction',
#    'TransferTransaction',
#    'CertificatesOfDepositAccount'],
#   'attributes': ['name',
#    'dateOfBirth',
#    'address',
#    'phoneNumber',
#    'emailAddress',
#    'accountNo',
#    'type',
#    'balance',
#    'id',
#    'type',
#    'transactionTime',
#    'amount',
#    'interestRate',
#    'username',
#    'password',
#    'securityQuestion',
#    'securityAnswer',
#    'lastLoginTime',
#    'targetAccount',
#    'sourceAccount',
#    'interestRate',
#    'timePeriod']},
#  'efd35011-a6c9-4b9a-b62e-d5daa9b58968.xmi.uml': {'classes': ['user'],
#   'attributes': ['attribute']},
#  'd779e6fe-c0ae-4f71-816a-5cdd632e89f1.xmi.uml': {'classes': ['Customer',
#    'Payment',
#    'ShoppingCart',
#    'Account',
#    'WebUser',
#    'Order',
#    'LineItem',
#    'Product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paidDate',
#    'total',
#    'details',
#    'creationDate',
#    'billingAddress',
#    'open',
#    'closed',
#    'isClosed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'shipTo',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description']},
#  '597093bc-31ce-4808-b763-c29d6f680f32.xmi.uml': {'classes': ['чч',
#    'MyClass',
#    'MyClass2']},
#  '_OxdDoEymEeS9L4cMWDc7Qg.xmi.uml': {'attributes': ['load']},
#  '_I_lnENTGEeehRMl7r1-c5g.xmi.uml': {'classes': ['CurvedLine',
#    'SketchyEllipse',
#    'SketchyRectangle',
#    'ShapeCreator',
#    'LineDrawer',
#    'ShapeMover',
#    'ShapeResizer',
#    'ShapeRotater',
#    'ShapeFiller',
#    'ShapeDeleter',
#    'ShapeRaiser',
#    'ShapeLowerer']},
#  '_zTvrkGm3EDGB-uCsYzbtRg.xmi.uml': {'classes': ['GameWindow']},
#  'af8ad990-19e3-488e-b4b8-846b6643f25b.xmi.uml': {'classes': ['Customer',
#    'Payment',
#    'ShoppinCart',
#    'Account',
#    'WebUser',
#    'Order',
#    'LineItem',
#    'Product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paidDate',
#    'total',
#    'details',
#    'creationDate',
#    'billingAddress',
#    'open',
#    'closed',
#    'isClosed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'shipTo',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description']},
#  'd6ed4740-d12b-4899-a2db-2374a6c7c4b5.xmi.uml': {'classes': ['Client',
#    'AdapterImpl',
#    'Adaptee',
#    'Context',
#    'StateA',
#    'StateB',
#    'Singleton',
#    'Abstraction',
#    'RefinedAbstraction',
#    'ConcreteImplementor',
#    'CreatorImpl',
#    'Product',
#    'ConcreteObserver',
#    'ConcreteSubject',
#    'MethodClass',
#    'ClassObject'],
#   'attributes': ['instance']},
#  '_NI0-EMYEEeeWu-SLkciAbg.xmi.uml': {'classes': ['temp sensor', 'arduino'],
#   'attributes': ['vout', 'volts', 'celsius', 'farfahrenheit']},
#  'b9dfe65c-12b6-498b-a151-0343da867aef.xmi.uml': {'classes': ['Client',
#    'AdapterImpl',
#    'Adaptee',
#    'Context',
#    'StateA',
#    'StateB',
#    'Singleton',
#    'Abstraction',
#    'RefinedAbstraction',
#    'ConcreteImplementor',
#    'CreatorImpl',
#    'Product',
#    'ConcreteObserver',
#    'ConcreteSubject'],
#   'attributes': ['instance']},
#  '0d0ec5dd-c762-405a-8a86-9d23a126537b.xmi.uml': {'classes': ['MyClassAOim'],
#   'attributes': ['attribute']},
#  '_RwyPkIPfEeaY2ZFk8hIg9A.xmi.uml': {'classes': ['DBObject'],
#   'attributes': ['TABLE',
#    'INDEX',
#    'UID',
#    'UID_LENGTH',
#    'DELETE',
#    '_columns',
#    '_fillable',
#    '_hidden',
#    '_generators']},
#  '431e2d5d-fa76-4ca1-a879-a927d293c394.xmi.uml': {'classes': ['Client',
#    'AdapterImpl',
#    'Adaptee',
#    'Context',
#    'StateA',
#    'StateB',
#    'Singleton',
#    'Abstraction',
#    'RefinedAbstraction',
#    'ConcreteImplementor',
#    'CreatorImpl',
#    'Product',
#    'ConcreteObserver',
#    'ConcreteSubject'],
#   'attributes': ['instance']},
#  '_42UqgMaLEeWmANB_14dU0A.xmi.uml': {'classes': ['prueba', 'prueba2'],
#   'attributes': ['nombre', 'lugar', 'pais', 'color', 'tamanio']},
#  '_OJVuMFlJEeWH7tmnkVHu6g.xmi.uml': {'classes': ['Patrons', 'LibraryStaff'],
#   'attributes': ['holder',
#    'name',
#    'date',
#    'student',
#    'faculty',
#    'libraryStaff',
#    'books',
#    'overdueFee',
#    'checkOutTime']},
#  '_butz8NjbEeWjYr7I4V0e0A.xmi.uml': {'classes': ['Charge Account'],
#   'attributes': ['CustomerNo(key)', 'attribute']},
#  '310b8bef-1a4e-4692-b437-a6a5453e1c31.xmi.uml': {'classes': ['Customer',
#    'Payment',
#    'ShoppingCart',
#    'Account',
#    'WebUser',
#    'Order',
#    'LineItem',
#    'Product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paidDate',
#    'total',
#    'details',
#    'creationDate',
#    'billingAddress',
#    'open',
#    'closed',
#    'isClosed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'shipTo',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description']},
#  '7aff64ad-90b0-450f-bf8c-1f4b9c3b8f37.xmi.uml': {'classes': ['ShoppingCart']},
#  'f34f1233-c3f1-48df-b830-6c1e81f51751.xmi.uml': {'classes': ['Abstraction',
#    'RefinedAbstraction',
#    'ConcreteImplementor']},
#  'f6e1ef7a-107f-419e-ab7d-a51aa49c13d2.xmi.uml': {'classes': ['Snake',
#    'Game',
#    'Program',
#    'Food',
#    'Display',
#    'Player',
#    'Unit',
#    'Random'],
#   'attributes': ['face',
#    'speed',
#    'size',
#    '[]unit',
#    'snake',
#    'food',
#    'display',
#    'player',
#    'life',
#    'face',
#    'toBe',
#    'height',
#    'width',
#    'space',
#    'wall',
#    'scorePosition',
#    'gameResumePosition',
#    'gameOverPostion',
#    'command']},
#  '_-g260KW7EeaiBJ7PH1W80g.xmi.uml': {'classes': ['Event',
#    'Customer',
#    'Agency',
#    'SevenUser',
#    'UserActivityRelation',
#    'UserRegisterEventRelation',
#    'Activity',
#    'LogAttendee',
#    'AttendeeActivity',
#    'Survey',
#    'Question',
#    'ResponseAttendee',
#    'Attendee',
#    'RoleMapping'],
#   'attributes': ['id',
#    'title',
#    'dateCreated',
#    'dateStarted',
#    'description',
#    'place',
#    'status',
#    'stage',
#    'brochure',
#    'timezone',
#    'userId',
#    'customerId',
#    'id',
#    'name',
#    'description',
#    'agencyId',
#    'userId',
#    'id',
#    'name',
#    'description',
#    'userId',
#    'id',
#    'type',
#    'firstname',
#    'lastname',
#    'email',
#    'created',
#    'lastupdated',
#    'imageUser',
#    'id',
#    'sevenuserId',
#    'activityId',
#    'id',
#    'sevenuserId',
#    'eventId',
#    'id',
#    'name',
#    'description',
#    'start',
#    'duration',
#    'limit',
#    'eventId',
#    'userId',
#    'onDemandCount',
#    'evaluationCount',
#    'registers',
#    'spaceAvailbale',
#    'id',
#    'status',
#    'date',
#    'attendeeId',
#    'eventId',
#    'id',
#    'attendeeId',
#    'activityId',
#    'id',
#    'eventId',
#    'activityId',
#    'userId',
#    'id',
#    'text',
#    'type',
#    'answer',
#    'time',
#    'send',
#    'surveyId',
#    'id',
#    'date',
#    'response',
#    'attendeeId',
#    'questionId',
#    'id',
#    'age',
#    'emailOriginal',
#    'organization',
#    'status',
#    'location',
#    'birthyear',
#    'notification',
#    'email',
#    'platform',
#    'typecheck',
#    'eventId',
#    'userId',
#    'id',
#    'sevenuserId',
#    'roleId',
#    'type']},
#  '19515821-de9c-4371-ab13-0c10c1f0741e.xmi.uml': {'classes': ['Client',
#    'AdapterImpl',
#    'Adaptee',
#    'Context',
#    'StateA',
#    'StateB',
#    'Singleton',
#    'Abstraction',
#    'RefinedAbstraction',
#    'ConcreteImplementor',
#    'CreatorImpl',
#    'Product',
#    'ConcreteObserver',
#    'ConcreteSubject'],
#   'attributes': ['instance']},
#  '_iY65cGqwEeepGY91r9Nuow.xmi.uml': {'classes': ['order'],
#   'attributes': ['userName',
#    'attribute2',
#    'attribute3',
#    'attribute4',
#    'attribute5',
#    'attribute6',
#    'attribute7',
#    'attribute8',
#    'attribute9',
#    'attribute10']},
#  '_ICx4IDeZEemHKq5iZQi_Zw.xmi.uml': {'classes': ['Estudiante',
#    'Profesor',
#    'Materias',
#    'Salones',
#    'Rol',
#    'Edificio',
#    'Programa',
#    'Facultad',
#    'Horario'],
#   'attributes': ['id_estudiante',
#    'nombre',
#    'apellidos',
#    'cedula',
#    'correo',
#    'estado',
#    'id_rol',
#    'id_programa',
#    'id_profesor',
#    'nombre',
#    'cedula',
#    'correo',
#    'id_salon',
#    'id_rol',
#    'id_materia',
#    'nombre',
#    'NRC',
#    'cupo',
#    'creditos',
#    'id_estudiante',
#    'id_profesor',
#    'id_salon',
#    'id_horario',
#    'id_salon',
#    'piso',
#    'numero_salon',
#    'capacidad',
#    'id_edificio',
#    'id_horario',
#    'id_rol',
#    'nombre',
#    'id_edificio',
#    'nombre',
#    'id_programa',
#    'nombre',
#    'ISUM',
#    'id_facultad',
#    'id_facultad',
#    'nombre',
#    'id_horario',
#    'hora_inicio',
#    'hora_final']},
#  '_w3lJ8AP7Eeewntt9CKbg3g.xmi.uml': {'classes': ['User',
#    'Team',
#    'Channel',
#    'Message',
#    'UserSettings',
#    'TeamSettings',
#    'ChannelSettings',
#    'ChannelActivity',
#    'UserAccount',
#    'DirrectMessage'],
#   'attributes': ['username',
#    'team',
#    'name',
#    'url',
#    'name',
#    'status',
#    'purpose',
#    'date',
#    'content',
#    'notifications',
#    'sound',
#    'display',
#    'threads',
#    'highlightWords',
#    'doNotDisturbFrom',
#    'doNotDisturbTo',
#    'signUpMode',
#    'defaultChannels',
#    'usernameGuidelines',
#    'nameDisplay',
#    'requireForMention',
#    'emailDisplay',
#    'doNotDisturbFrom',
#    'doNotDisturbTo',
#    'hideUrl',
#    'enableCalls',
#    'callingApp',
#    'messageRetention',
#    'fileRetention',
#    'teamIcon',
#    'desktopNotifications',
#    'pushNotificationa',
#    'muteChannel',
#    'includeUserGroupMentions',
#    'includeChannelMentions',
#    'firstName',
#    'lastName',
#    'whatIDo',
#    'email',
#    'phone',
#    'timezone',
#    'skypeId',
#    'photo',
#    'password']},
#  'e9599e4d-25c4-48e4-8fe3-fc14e2c55dce.xmi.uml': {'classes': ['Employee',
#    'Salary',
#    'Authenticate_staff',
#    'Leave',
#    'Attendance',
#    'Login'],
#   'attributes': ['Emp_Id',
#    'Emp_Name',
#    'Emp_ContactNo',
#    'Emp_Email',
#    'Emp_NIC',
#    'Emp_Address',
#    'Emp_DOB',
#    'Emp_Department',
#    'Emp-Date_Of_Joint',
#    'Emp_Position',
#    'Emp_Salary',
#    'Emp_Id',
#    'Sly_Basic',
#    'Sly_Increment',
#    'Sly_Decrement',
#    'Sly_Netgross',
#    'OverTime',
#    'UserName',
#    'Password',
#    'Authendication_Mood',
#    'leave_id',
#    'Emp_Id',
#    'Leave_Title',
#    'Leave_detail',
#    'Leave_ApplyDate',
#    'Leave_StartDate',
#    'Leave_EndDate',
#    'Leave_NoOfDays',
#    'Leave_Status',
#    'Attend_date',
#    'Emp_id',
#    'AttendTime',
#    'Leaving_Time',
#    'UserName',
#    'Password']},
#  '49a9a179-f2f3-4517-994e-148391be8053.xmi.uml': {'classes': ['Client',
#    'Adaptor',
#    'Adaptee',
#    'MyClass']},
#  '_1fv_cGAzEeepGY91r9Nuow.xmi.uml': {'classes': ['Category',
#    'Products',
#    'ProductSize',
#    'OrderDetails',
#    'MyClass',
#    'MyClass2',
#    'MyClass3',
#    'MyClass4',
#    'MyClass5',
#    'Orders',
#    'OrderCategory',
#    'MyClass8',
#    'MyClass9',
#    'MyClass10'],
#   'attributes': ['categoryId',
#    'categoryDescription',
#    'productID',
#    'productName',
#    'Image',
#    'categoryId',
#    'isActive',
#    'prodSizeId',
#    'productId',
#    'sizeId',
#    'Price',
#    'orderDetailsId',
#    'orderId',
#    'productSizeId',
#    'Quantity',
#    'pricePerProduct',
#    'orderId',
#    'adderess',
#    'clientId',
#    'orderDate',
#    'centerId',
#    'categoryId',
#    'orderCatId',
#    'categoryDesc']},
#  '8b08c90b-c7d3-4afd-b0e9-3dfe67ed7de3.xmi.uml': {'classes': ['ShoppingCart',
#    'Order',
#    'LineItem',
#    'Account',
#    'Customer'],
#   'attributes': ['creationDate', 'id', 'quantity', 'price', 'id']},
#  'd29cd2f3-9ae8-4c52-97f5-7cf07f4cdd10.xmi.uml': {'classes': ['Singleton'],
#   'attributes': ['instance']},
#  '6c84d80a-0e28-40ab-957c-531b57921306.xmi.uml': {'classes': ['Customer',
#    'Payment',
#    'ShoppingCart',
#    'Account',
#    'WebUser',
#    'Order',
#    'LineItem',
#    'Product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paidDate',
#    'total',
#    'details',
#    'creationDate',
#    'billingAddress',
#    'open',
#    'closed',
#    'isClosed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'shipTo',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description']},
#  '9232d81e-dab5-49d8-9e89-8a4ff91278b1.xmi.uml': {'classes': ['Create Analysis Action',
#    'Service',
#    'AnalysisDAO',
#    'AnalysisDAO'],
#   'attributes': ['analysisName']},
#  '_WfyX0MIFEeacM55raX9d3Q.xmi.uml': {'classes': ['ProducerTextGenerator',
#    'Text',
#    'ConsumerTextAnalyz',
#    'ScannerText']},
#  '_KlkTALgHEeSzkacHLregNQ.xmi.uml': {'classes': ['Order'],
#   'attributes': ['OrderID;', '+Order(...)']},
#  '_XgXMwH_9EeW4cd-qm4QbpA.xmi.uml': {'classes': ['Employee', 'Rooms'],
#   'attributes': ['id', 'first_name', 'last_name', 'Number']},
#  '40adfe9e-25a9-426a-806e-9ff9a56b4da2.xmi.uml': {'classes': ['Worker',
#    'People',
#    'Customer',
#    'Cook',
#    'Waiter',
#    'Cashier'],
#   'attributes': ['name']},
#  '_lWq_kF4WEeSmRKwulsG6-Q.xmi.uml': {'classes': ['user',
#    'massage',
#    'profile',
#    'post',
#    'group',
#    'friends',
#    'login',
#    'notification',
#    'admin',
#    'member']},
#  '2c3b7982-340a-4627-9c85-6b1a36347b78.xmi.uml': {'classes': ['TimetableEvent',
#    'TimetableReader',
#    'TimetableValidator',
#    'TimetableValidationError',
#    'CalendarImporter',
#    'GoogleCalendarImporter']},
#  '_JkGroH2TEeShroDxTnL5_A.xmi.uml': {'classes': ['Caisse'],
#   'attributes': ['test']},
#  '9462f4aa-aea2-4c9e-afcb-cfcfbd414c85.xmi.uml': {'classes': ['ShoppingCart',
#    'Order',
#    'LineItem',
#    'Account',
#    'Customer'],
#   'attributes': ['creationDate', 'id', 'quantity', 'price', 'id']},
#  '538864d8-e066-49c5-8edd-4ab0fca7f62b.xmi.uml': {'classes': ['Person',
#    'Professor',
#    'Employee',
#    'FullProfessor',
#    'Associate',
#    'Assistant',
#    'Office',
#    'University',
#    'Classroom',
#    'Room',
#    'Building'],
#   'attributes': ['id', 'name', 'seatsNumber', 'floor', 'number']},
#  '_5pZpkNHiEeaJwt5yAqWnTg.xmi.uml': {'classes': ['Class',
#    'Class2',
#    'Wifi',
#    'Class3',
#    'Simcard',
#    'System',
#    'Database']},
#  'e12b7943-feab-4c7d-9330-61358c7afece.xmi.uml': {'classes': ['Customer',
#    'Payment',
#    'ShoppingCart',
#    'Account',
#    'WebUser',
#    'Order',
#    'LineItem',
#    'Product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paidDate',
#    'total',
#    'details',
#    'creationDate',
#    'billingAddress',
#    'open',
#    'closed',
#    'isClosed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'shipTo',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description']},
#  '_IC_G0MiPEeeM1PgT03-3Vg.xmi.uml': {'classes': ['Physical Users',
#    'Online Users',
#    'Clerk',
#    'Admin',
#    'Database',
#    'Payment',
#    'Mobile User',
#    'Online Ticket',
#    'Physical Ticket']},
#  '_P7zdMN_uEeS6FO4vn2oOjA.xmi.uml': {'classes': ['suit'],
#   'attributes': ['inputCode']},
#  '3d99155b-5099-4121-bba7-934dfece62cb.xmi.uml': {'classes': ['ShoppingCart',
#    'Order',
#    'LineItem',
#    'Account',
#    'Customer',
#    'Class',
#    'Client',
#    'Client',
#    'Platform'],
#   'attributes': ['creationDate', 'id', 'quantity', 'price', 'id']},
#  '_DF3R0BwbEeig8qiayYYCew.xmi.uml': {'classes': ['Person',
#    'Faculty',
#    'Student',
#    'Raffle',
#    'Prize'],
#   'attributes': ['firstName',
#    'lastName',
#    'Gender',
#    'yearsOfService',
#    'subjectArea',
#    'prize',
#    'class',
#    'age',
#    'prize',
#    'registrants',
#    'sortedRegistrants',
#    'prizes',
#    'name',
#    'companyName']},
#  '_-WIY4KnoEeS9iunt9iMoeg.xmi.uml': {'classes': ['AbstractGame',
#    'Chess',
#    'Monopoly']},
#  '_FOQ0QCMXEeisAYMSV00L2Q.xmi.uml': {'classes': ['CourrierCUAU'],
#   'attributes': ['CelluleAUCU',
#    'ServiceInstructeur',
#    'Interlocuteur',
#    'Objet',
#    'Date',
#    'VotreConseiller']},
#  'cccd46b7-9b3e-44d4-84fc-e2153cf70d58.xmi.uml': {'classes': ['Client',
#    'Adaptor',
#    'Adaptee']},
#  '_6I0ZIPjzEeSE6sazzutmkA.xmi.uml': {'classes': ['ScheduleTimezoneConverter',
#    'ScheduleMgmtApiResponseDetVO',
#    'AllSchedules',
#    'CustomScheduleJSON_VO',
#    'DailyScheduleJSON_VO',
#    'OneTimeScheduleJSON_VO'],
#   'attributes': ['scheduleTimezoneConverter',
#    'SHIFT_LABEL_RIGHT',
#    'SHIFT_LABEL_LEFT',
#    'SHIFT_LABEL_NA']},
#  '_bEYN8LBCEee6S77dw3LIvQ.xmi.uml': {'classes': ['Person', 'Class'],
#   'attributes': ['name', 'email']},
#  '_2p9bEMasEeadwOIOqK-0Fw.xmi.uml': {'classes': ['PayU',
#    'OrderStatusAbstract',
#    'PaymentStatus',
#    'Con',
#    'Configuration'],
#   'attributes': ['$configuration']},
#  '3bddae18-8bff-498f-b478-8d075c718bdb.xmi.uml': {'classes': ['Adaptor',
#    'Adaptee',
#    'MyClass2']},
#  '813d3f22-4f16-4bd5-8e87-290334d4102b.xmi.uml': {'classes': ['Advokat',
#    'Predmet Advokatske kancelarije',
#    'Rociste',
#    'Stranka',
#    'Punomocje',
#    'TipPunomocja',
#    'Obaveza',
#    'IzlaznaFaktura'],
#   'attributes': ['IDadvokat',
#    'ImeAdvokata',
#    'BrojTelefona',
#    'PrezimeAdvokata',
#    'EmailAdresa',
#    'AdresaAdvokata',
#    'Username',
#    'Password',
#    'BrojPredmetaAK',
#    'DatumPokretanja',
#    'DatumZavrsetka',
#    'NazivPredmeta',
#    'VrednostSpora',
#    'IDAdvokat',
#    'IDPunomocja',
#    'IDRocista',
#    'ImeSudije',
#    'PrezimeSudije',
#    'IDStranke',
#    'IDAdvokat',
#    'IDStranke',
#    'NazivStranke',
#    'BrojTelefonaStranke',
#    'EmailStranke',
#    'AdresaStranke',
#    'MestoStanovanjaStranke',
#    'IDPunomocja',
#    'PeriodVazenjaPun',
#    'DatumPotpisivanjaPun',
#    'IDTipPun',
#    'IDStranke',
#    'IDTipPun',
#    'NazivPun',
#    'IDObaveze',
#    'NazivObaveze',
#    'VremeObaveze',
#    'DatumObaveze',
#    'IDAdvokata',
#    'IDIzlazneFakture',
#    'DatumFakturisanja',
#    'IznosFakture',
#    'PrimalacFakture',
#    'BrojRacuna',
#    'IDAdvokat']},
#  '_AhnLoDyqEeW9u4XU-cgAEg.xmi.uml': {'classes': ['Users',
#    'Administrator',
#    'Moderator'],
#   'attributes': ['username',
#    'userId',
#    'password',
#    'email',
#    'isReported',
#    'reportedBy',
#    'gender',
#    'interests',
#    'level']},
#  '7f09e59b-ca7a-4f32-ba33-39e6aad74ffb.xmi.uml': {'classes': ['Fascia',
#    'MyClass',
#    'MyClass2',
#    'MyClass3',
#    'MyClass4',
#    'MyClass5',
#    'MyClass6',
#    'MyClass7',
#    'MyClass8',
#    'MyClass9'],
#   'attributes': ['sku', 'location']},
#  '1c86b445-6a08-4061-8e8d-713470a1a5a1.xmi.uml': {'classes': ['GameCharacter',
#    'GameCharacterYoung',
#    'GameCharacterHendrix',
#    'GameCharacterSlash',
#    'Fire',
#    'Jump',
#    'Smash',
#    'FenderTelecaster',
#    'GibsonSG',
#    'GibsonFlyingV'],
#   'attributes': ['soloBehavior', 'guitar']},
#  '_FaeXALpDEeiBfp11hItRuw.xmi.uml': {'classes': ['Utilisateur',
#    'Sport',
#    'Lieu',
#    'Seance'],
#   'attributes': ['nom',
#    'nom',
#    'temperatureMinimum',
#    'temperatureMaximum',
#    'dateHeureDebut']},
#  '_w1dYIBQJEeSTV6l4790RsQ.xmi.uml': {'classes': ['group']},
#  '_Obp_gA1fEDGXt505FSVm0A.xmi.uml': {'classes': ['Customer',
#    'CustomerSettings'],
#   'attributes': ['CustomerId', 'CustomerSettingsId', 'CustomerSettingsName']},
#  '276f29cd-9e94-4d30-9297-419d311bf7f1.xmi.uml': {'classes': ['ShoppingCart']},
#  '8215be91-0cfa-4ab7-914a-8727d270fada.xmi.uml': {'classes': ['ClaseSingleton',
#    'cliente'],
# ...
#    'StateA',
#    'StateB',
#    'Singleton',
#    'Abstraction',
#    'RefinedAbstraction',
#    'ConcreteImplementor',
#    'CreatorImpl',
#    'Product',
#    'ConcreteObserver',
#    'ConcreteSubject'],
#   'attributes': ['instance']},
#  '_lrCmsDchEDGTp7v8NTrInw.xmi.uml': {'classes': ['Flight',
#    'Aerobatic',
#    'Scenic',
#    'Custom Flight'],
#   'attributes': ['attribute']},
#  '5a35d6a5-c851-4a85-8b21-330c58625831.xmi.uml': {'classes': ['ShoppingCart']},
#  '_g48V0Mw-EeaAf-R7dg0GCw.xmi.uml': {'classes': ['TramTicketMachine',
#    'CashChecker',
#    'DisplayScreen',
#    'TicketDispenser',
#    'CardTransaction',
#    'ATMCard',
#    'TramCard',
#    'CardScanner',
#    'TramUser'],
#   'attributes': ["company's_name",
#    'isCurrencyNote',
#    'isCurrencyCoins',
#    'Amount',
#    'inputEntered',
#    'no_of_available_ticket',
#    'cardID',
#    'pin',
#    'bankCard',
#    'tramCard']},
#  '_bK7soLVKEee7sYPkE4-GPA.xmi.uml': {'classes': ['Hero'],
#   'attributes': ['returnHP();']},
#  '_wyN9EONxEeSyAtfQFgWBxA.xmi.uml': {'classes': ['as', 'asd']},
#  '4eee6bdf-ab66-4aa5-adcf-8217d11926fe.xmi.uml': {'classes': ['ShoppingCart',
#    'Order',
#    'LineItem',
#    'Account',
#    'Customer',
#    'Class'],
#   'attributes': ['creationDate', 'id', 'quantity', 'price', 'id']},
#  '_52gvsJwlEDGdyoFyp4l9hw.xmi.uml': {'classes': ['SistemskeOperacije(SO)']},
#  '_DErG4HseEeSdXJMJcKNKoQ.xmi.uml': {'classes': ['user', 'IT Website', 'User'],
#   'attributes': ['attribute', 'ID', 'Password']},
#  '_8-EMANc5Eei47sN0sCkjiA.xmi.uml': {'classes': ['LAla'],
#   'attributes': ['sd']},
#  '3c85cf04-8dba-4aee-bb97-59cb0048da7b.xmi.uml': {'classes': ['Client',
#    'Adaptor',
#    'Adaptee']},
#  '_FzAzoMENEeeEXb8Dudo6PQ.xmi.uml': {'classes': ['Avion', 'Pasajero', 'Silla'],
#   'attributes': ['SILLAS_EJECUTIVAS',
#    'SILLAS_ECONOMICAS',
#    'cedula',
#    'nombre',
#    'CLASE_EJECUTIVA',
#    'CLASE_ECONOMICA',
#    'VENTANA',
#    'CENTRAL',
#    'PASILLO',
#    'numero',
#    'clase',
#    'ubicacion']},
#  '08440044-d6fd-4fe9-b4b9-485af8ec84ab.xmi.uml': {'classes': ['Worker',
#    'People',
#    'Customer',
#    'Cook',
#    'Waiter',
#    'Cashier'],
#   'attributes': ['name']},
#  '_8MyUoObSEeiDGLvZhbPYyA.xmi.uml': {'classes': ['Person', 'MALE']},
#  '_TgYHsEMgEeSyYeDoyPirvg.xmi.uml': {'classes': ['Event',
#    'FlightManager',
#    'FlightPlanning',
#    'InterventionPlanning',
#    'Planning',
#    'EmployeeManager',
#    'EmployeePlanning',
#    'ReportManager',
#    'Report',
#    'DistributionManager',
#    'MarketingManager',
#    'TicketDistributorManager',
#    'ProviderManager',
#    'FlightEvent',
#    'PlaneIntervention',
#    'PlaneRevision',
#    'PlaneImmobilization',
#    'PlaneFuel',
#    'CleaningService',
#    'Steward',
#    'Pilot',
#    'AirportEmployee',
#    'Employee',
#    'Company',
#    'Airport',
#    'StandardFlight',
#    'Flight',
#    'FreeTimeFlight',
#    'Plane',
#    'Fuel',
#    'FuelProvider',
#    'ConsomationProvider',
#    'Consomation',
#    'ServiceProvider',
#    'Provider',
#    'ConsomationStock',
#    'Ticket',
#    'BoardingPass',
#    'Customer',
#    'TicketDistributor',
#    'Promotion',
#    'Advertising',
#    'News',
#    'Reservation',
#    'FreeMiles',
#    'EarlyOrder',
#    'EmployeeManagerView',
#    'TicketDistributionView',
#    'CompanyManagementView'],
#   'attributes': ['_dateBegin',
#    '_dateEnd',
#    '_title',
#    'isSuperUser',
#    'date',
#    'category',
#    'flight',
#    'millesOnIntervention',
#    'plane',
#    'flight',
#    'plane',
#    'airport',
#    'plane',
#    'airport',
#    'airport',
#    'dayByWeek',
#    'name',
#    'gender',
#    'JobType',
#    'isSuperUser',
#    'name',
#    'stewards',
#    'pilots',
#    'airportEmployees',
#    'city',
#    'ticketPrice',
#    'ticketCharges',
#    'beginSchedule',
#    'endSchedule',
#    'surbookingPercent',
#    'reservationPercent',
#    'airportFrom',
#    'airportTo',
#    '/duration',
#    'flightType',
#    'schedule',
#    '/miles',
#    'confirmationPercent',
#    'row',
#    'seatPerRow',
#    '/seat',
#    'nbPilote',
#    'nbSteward',
#    '/crew',
#    '/millesFlyed',
#    '/flySinceRefuel',
#    '/state',
#    '/location',
#    '/millesSinceRevisionned',
#    'date',
#    '/price',
#    'volme',
#    'plane',
#    'name',
#    'pricePerUnit',
#    'pricePerUnit',
#    'name',
#    '_capacity',
#    'from',
#    'payment',
#    '/price',
#    'promotion',
#    'isRegistered',
#    '_numberPlace',
#    'price',
#    'row',
#    'seat',
#    'isValidated',
#    'dateOfPurchase',
#    'flight',
#    '/milesFlyed',
#    'Luggage',
#    'name',
#    'surbooking',
#    'freeFlyPerWeek',
#    'from',
#    'payment',
#    '/discount',
#    'percentPerFlight',
#    'picture',
#    'date',
#    'text',
#    'title',
#    'discountPercent',
#    'millesPerMillesPromotion',
#    'cashPerMilesPromotion',
#    'discountPercent']},
#  '_L7BoAFTIEeSu48YT12vqpQ.xmi.uml': {'classes': ['Player'],
#   'attributes': ['Name', 'Score', 'CardContainer']},
#  '9e620e9c-e98c-44f2-be8d-849cc420126d.xmi.uml': {'classes': ['Customer',
#    'Payment',
#    'ShoppingCart',
#    'Account',
#    'WebUser',
#    'Order',
#    'LineItem',
#    'Product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paidDate',
#    'total',
#    'details',
#    'creationDate',
#    'billingAddress',
#    'open',
#    'closed',
#    'isClosed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'shipTo',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description']},
#  '_PbRXUNuREeiJYbNjsZ3wUw.xmi.uml': {'classes': ['TypeatorContainer',
#    'DefaultTypeator',
#    'TypeatorFactory',
#    'TypeatorRunner']},
#  'd5320ba4-ef0b-4a62-9a28-70d63e9861f7.xmi.uml': {'classes': ['BankAccount',
#    'ClassA',
#    'ClassB',
#    'ClassC',
#    'ClassD',
#    'ClassE',
#    'ClassF',
#    'ClassG',
#    'ClassJ',
#    'ClassH',
#    'ClassK',
#    'ClassM',
#    'ClassN',
#    'ClassP',
#    'ClassQ',
#    'ClassR',
#    'ClassS',
#    'ClassT',
#    'ClassU',
#    'ClassV'],
#   'attributes': ['ownerName',
#    'balance',
#    'publicAttribute',
#    'privateAttribute',
#    'protectedAttribute',
#    'packageAttribute',
#    'publicAttribute',
#    'privateAttribute',
#    'protectedAttribute',
#    'packageAttribute']},
#  '_zmijUKT-EeScLuNN63kNaQ.xmi.uml': {'classes': ['Sensor', 'Device', 'Menu'],
#   'attributes': ['Sensor']},
#  '_WhW-AJc2EeS67M2cXIV9Bg.xmi.uml': {'classes': ['Dienblad',
#    'Docent',
#    'Student',
#    'KantineMedewerker',
#    'PersoonsVergelijker',
#    'KassaRij',
#    'Kantine',
#    'Kassa',
#    'Administratie'],
#   'attributes': ['artikelen',
#    'Totaalprijs',
#    'afkorting',
#    'afdeling',
#    'studentnummer',
#    'studierichting',
#    'medewerkersnummer',
#    'magAchterKassa',
#    'kassaRij',
#    'kassa',
#    'kassarij',
#    'persoon1',
#    'dienblad1',
#    'artikel1',
#    'artikel2',
#    'kantineaanbod',
#    'rij',
#    'artikelen',
#    'geld',
#    'aantalKlanten',
#    'DAYS_IN_WEEK']},
#  '3dabd4fe-d23c-4cf6-bbe6-510a8a5b7722.xmi.uml': {'classes': ['Client',
#    'Adaptor',
#    'Adaptee']},
#  '_-iZxYP76EeSpvbjLqY_W3Q.xmi.uml': {'classes': ['User'],
#   'attributes': ['userID',
#    'userType',
#    'firstName',
#    'lastName',
#    'employeeID',
#    'dateJoined',
#    'role',
#    'allocationStatus',
#    'email',
#    'phone',
#    'officeAddress',
#    'baseBranch',
#    'city',
#    'state',
#    'country',
#    'specialization',
#    'institution',
#    'years_company',
#    'profile_picture']},
#  '_FIzVsGTjEDGvYZ_luPE2qw.xmi.uml': {'classes': ['Curso',
#    'Seccion',
#    'Estudiante',
#    'SistemaArchivos',
#    'Archivo'],
#   'attributes': ['profesor', 'salon', 'hora']},
#  '_v6vVID3VEDG1DfFOPLjuGA.xmi.uml': {'classes': ['OrderingSystem',
#    'OrderingSystem',
#    'OrderingSystem',
#    'List',
#    'OrderingSystem',
#    'List'],
#   'attributes': ['costCoffeeA',
#    'costCoffeeB',
#    'costCoffeeC',
#    'costCoffeeD',
#    'costCoffeeA',
#    'costCoffeeB',
#    'costCoffeeC',
#    'costCoffeeD',
#    'costCondimentA',
#    'costCondimentB',
#    'costCondimentC',
#    'listCostCoffee',
#    'listCostCondiment',
#    'values',
#    'names',
#    'listCost',
#    'values',
#    'names']},
#  'e2b23b9a-8b69-4537-95d9-9a62d0468ccf.xmi.uml': {'classes': ['Customer',
#    'Payment',
#    'ShoppingCart',
#    'Account',
#    'WebUser',
#    'Order',
#    'LineItem',
#    'Product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paidDate',
#    'total',
#    'details',
#    'creationDate',
#    'billingAddress',
#    'open',
#    'closed',
#    'isClosed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'shipTo',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description']},
#  'fe31c34b-968d-4bcd-a8e7-6fd9b9dfa284.xmi.uml': {'classes': ['Game1',
#    'Car',
#    'Rock',
#    'Wheel',
#    'Player',
#    'Score'],
#   'attributes': ['speed', 'colission']},
#  '_0FTU8KveEeiHR4AK89CXpg.xmi.uml': {'classes': ['Buffer',
#    'int',
#    'Productor',
#    'Consumidor'],
#   'attributes': ['capacidad', 'buffer']},
#  '_K-stgPXsEei5Pecz43plcg.xmi.uml': {'classes': ['MacAuto',
#    'Cuenta',
#    'JFrame',
#    'ArithmeticException',
#    'Refresco',
#    'Hamburguesa',
#    'papas',
#    'Nombre',
#    'Maquina',
#    'Creditos',
#    'Variables',
#    'Maquina2',
#    'JFrame'],
#   'attributes': ['Creditos', 'Cambio', 'Total']},
#  '_VFimkNVkEeWUcZFfD54kTA.xmi.uml': {'classes': ['ConfigurationRoot',
#    'SDPServices',
#    'ConfigureAndActivateService',
#    'SDPServicesMethodsIL']},
#  '7602e9c9-601a-4f92-8c40-09e8901b162b.xmi.uml': {'classes': ['ShoppingCart']},
#  '_XuwfQHz2EeW4cd-qm4QbpA.xmi.uml': {'classes': ['FileBuffer',
#    'ParentModul',
#    'Work Modul A',
#    'GUI',
#    'Visualisation'],
#   'attributes': ['originalData']},
#  '_Wk5_IAdjEeeoBvzX9wJhsQ.xmi.uml': {'classes': ['Super_Parser',
#    'Sub_Parser',
#    'String []'],
#   'attributes': ['parser_name',
#    'covered_program',
#    'start_time',
#    'end_time',
#    'String',
#    'active_parser',
#    'parser_stack',
#    'log_stack']},
#  '8a4b7913-39fb-43c6-a37e-5ae3264dc75d.xmi.uml': {'classes': ['Equipo',
#    'Jugador',
#    'Entrenador',
#    'Arbitro',
#    'Partido',
#    'Evento',
#    'TipoDeEvento',
#    'Lesion',
#    'Liga',
#    'Clasificacion',
#    'Persona',
#    'Estadio'],
#   'attributes': ['Cod_equipo',
#    'Nombre',
#    'F_fundacion',
#    'Ciudad',
#    'Titulos',
#    'Cod_Entrenador',
#    'Cod_jugador',
#    'Dorsal',
#    'Posicion',
#    'Altura',
#    'Peso',
#    'Titulos',
#    'Cod_equipo',
#    'Cod_persona',
#    'Cod_Entrenador',
#    'Titulos',
#    'Cod_persona',
#    'Cod_Arbitro',
#    'Partidos',
#    'Cod_persona',
#    'Cod_partido',
#    'Fecha',
#    'Hora',
#    'Local',
#    'Visita',
#    'GolLocal',
#    'GolVisita',
#    'Ganador',
#    'Cod_liga',
#    'Cod_partido',
#    'Cod_jugador',
#    'Cod_TipodeEvento',
#    'Cod_TipodeEvento',
#    'Evento',
#    'Cod_jugador',
#    'FechaLesion',
#    'TiempoLesion',
#    'Condicion',
#    'Cod_liga',
#    'Nombre',
#    'Num_equipos',
#    'Superior',
#    'Inferior',
#    'Cod_Clasificacion',
#    'Cod_Equipo',
#    'Posicion',
#    'JJ',
#    'JP',
#    'JE',
#    'JG',
#    'GF',
#    'GC',
#    'DG',
#    'Puntos',
#    'Cod_persona',
#    'Nombre',
#    'Apellido',
#    'NombreCorto',
#    'FechaNacimiento',
#    'Nacionalidad',
#    'Cod_Estadio',
#    'Nombre',
#    'Ubicacion',
#    'Capacidad',
#    'Terreno',
#    'Ubicacion',
#    'Cod_equipo']},
#  '07ebe3fa-a9ec-466e-9aab-4c84c0e06b8f.xmi.uml': {'classes': ['Customer',
#    'Payment',
#    'ShoppingCart',
#    'Account',
#    'WebUser',
#    'Order',
#    'LineItem',
#    'Product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paidDate',
#    'total',
#    'details',
#    'creationDate',
#    'billingAddress',
#    'open',
#    'closed',
#    'isClosed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'shipTo',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description']},
#  '90de3c08-1e92-4c95-a8d2-6e9b6e6a3bb2.xmi.uml': {'classes': ['Singleton'],
#   'attributes': ['instance']},
#  '_7o7moCfVEeiYD9TOdwevwA.xmi.uml': {'classes': ['Operador',
#    'Hotel',
#    'Hostal',
#    'Reserva',
#    'Cliente',
#    'HabitacionPersona',
#    'ApartamentoAlquiler',
#    'ViviendaPersona',
#    'ViviendaUniversitaria',
#    'Persona',
#    'MiembroComunidad',
#    'Empresa',
#    'HabitacionHotel',
#    'Habitacion',
#    'HabitacionVivienda',
#    'ReservaColectiva'],
#   'attributes': ['id',
#    'tipoOperador',
#    'restaurante',
#    'piscina',
#    'parqueadero',
#    'wifi',
#    'TVCable',
#    'Recepcion24Horas',
#    'estaDeshabilitado',
#    'horarioApertura',
#    'horarioCierre',
#    'Capacidad',
#    'precioNoche',
#    'estaDeshabilitado',
#    'id',
#    'FechaIncioServicio',
#    'FechaReserva',
#    'dias',
#    'tipo',
#    'FechaPago',
#    'fueCancelado',
#    'idReservaColectiva',
#    'Capacidad',
#    'Comidas',
#    'accesoCocina',
#    'tipoBaño',
#    'tipoHabitacion',
#    'costoLuz',
#    'costoTelefono',
#    'costoTV',
#    'costoInternet',
#    'costoAgua',
#    'PrecioMes',
#    'DescuentoMesPrepagado',
#    'PrecioMes',
#    'costoTelefono',
#    'costoLuz',
#    'costoTV',
#    'costoInternet',
#    'costoAgua',
#    'administracionCosto',
#    'capacidad',
#    'estaDeshabilitado',
#    'capacidad',
#    'numeroHabitaciones',
#    'Ubicacion',
#    'CostoDia',
#    'caracteristicasSeguro',
#    'estaDeshabilitado',
#    'amoblamientoBasico',
#    'cocineta',
#    'Internet',
#    'Tv',
#    'aseo',
#    'apoyoSocial',
#    'apoyoAcedemico',
#    'RestauranteCosto',
#    'SalasEstudioCosto',
#    'SalasEsparcimiento',
#    'GimnasioCosto',
#    'estaDeshabilitado',
#    'id',
#    'tipoPersona',
#    'tipoMiembro',
#    'id',
#    'numerCamaraComercio',
#    'tipo',
#    'Banera',
#    'jacuzzi',
#    'sala',
#    'cocineta',
#    'PrecioNoche',
#    'capacidad',
#    'tipo',
#    'tipoMenaje',
#    'capacidad',
#    'PrecioNoche',
#    'PrecioMes',
#    'PrecioSemestre',
#    'id',
#    'tipo',
#    'cantidad',
#    'idCliente']},
#  '_XPjZsGdzEeS3yOrtnopAkA.xmi.uml': {'classes': ['Document',
#    'Livre',
#    'Revue',
#    'Dictionnaire',
#    'Roman',
#    'Manuel',
#    'Animal',
#    'Mammifere',
#    'Chien',
#    'Cheval']},
#  '0d92d5b5-5707-41da-8461-a9e9de0fc0f0.xmi.uml': {'classes': ['Sword',
#    'Axe',
#    'EnchancedWeapon',
#    'FireWeapon',
#    'HolyWeapon'],
#   'attributes': ['weapon']},
#  '_iiwTkHbaEeSfPZ7vcufCPw.xmi.uml': {'classes': ['Location',
#    'Zuordnung',
#    'Software'],
#   'attributes': ['Location_ID',
#    'Netz_ID',
#    'Route',
#    'Raumname',
#    'Betreuer',
#    'Location_ID',
#    'Software_ID',
#    'Software_ID',
#    'Softwarename']},
#  '_PmSUUOyDEei9dNtZPq67hQ.xmi.uml': {'classes': ['JobListHelper',
#    'JobListHelper'],
#   'attributes': ['context',
#    'mItems',
#    'recyclerView',
#    'context',
#    'mItems',
#    'recyclerView']},
#  'ca95bf9d-6107-478d-ae28-5dd662a4b3d4.xmi.uml': {'classes': ['Object',
#    'Component',
#    'Behaviour',
#    'Camera',
#    'Animation',
#    'MonoBehaviour',
#    'NetworkMessageInfo',
#    'BitStream',
#    'NetworkView',
#    'NetworkPlayer',
#    'NetworkViewID',
#    'Transform',
#    'Rigidbody'],
#   'attributes': ['name',
#    'tag',
#    'enabled',
#    'networkView',
#    'sender',
#    'timestamp',
#    'group',
#    'isMine',
#    'observed',
#    'position',
#    'rotation',
#    'eularAngles',
#    'localToWorldMatrix',
#    'worldToLocalMatrix',
#    'root',
#    'parent',
#    'position',
#    'rotation',
#    'velocity',
#    'angularVelocity',
#    'mass',
#    'inertiaTensor',
#    'collisionDetectionMode',
#    'isKinematic',
#    'interpolation']},
#  '_816IMIJkEemGPZyN8msRcg.xmi.uml': {'classes': ['Dim Cocinera',
#    'Localización',
#    'FactEntrega',
#    'DimCliente',
#    'DimDomiciliario',
#    'BridgeCambio',
#    'BridgeAdicion',
#    'DimIngrediente',
#    'DimTiempo',
#    'DimFecha',
#    'BridgeIngredientes'],
#   'attributes': ['id',
#    'cedula',
#    'nombre',
#    'fecha nacimiento',
#    'cantidadAlmuerzos',
#    'salario',
#    'direccionResidencia',
#    'validoDesde',
#    'validoHasta',
#    'actual',
#    'id',
#    'direccion',
#    'localidad',
#    'barrio',
#    'ciudad',
#    'departamento',
#    'idEntrega',
#    'costo',
#    'satisfaccion',
#    'tiempoEntrega',
#    'calificacionIngredienteMasGusto',
#    'calificacionIngredienteMenosGusto',
#    'Cliente',
#    'Domiciliario',
#    'Cocinera',
#    'Fecha',
#    'horaSolicitada',
#    'horaEntrega',
#    'direccionEntrega',
#    'ingredienteMasGusto',
#    'ingredienteMenosGusto',
#    'id',
#    'cedula',
#    'nombre',
#    'direccion',
#    'id',
#    'cedula',
#    'nombre',
#    'FKEntrega',
#    'FKIngredienteQuitado',
#    'FKIngredienteNuevo',
#    'calificacion',
#    'FKEntrega',
#    'FKIngrediente',
#    'calificacion',
#    'id',
#    'nombre',
#    'categoría',
#    'id',
#    'Hora',
#    'Minuto',
#    'MomentoDia',
#    'id',
#    'Dia',
#    'Mes',
#    'Año',
#    'FKEntrega',
#    'FKIngrediente',
#    'calificacion']},
#  ...}

# %% [markdown]
# ## Language detection
#
# Because the dataset contains attributes and classes in lots of languages, we want to identify all the English files that contain attributes and classes, and filter out all the rest. For this, we use FastText.

# %%
# Reload data_dict from file
with open('data/genmymodel_uml_extracted_metadata_cleaned1.json') as json_file:
    data_dict = json.load(json_file)

    # Make sure all programmic cases are turned into spaces like "normal" text for better language detection
    cleaned_data = {
        file: {
            key: list(map(lambda x: ' '.join(list(map(lambda data_str: re.sub(r'((?<=[a-z])[A-Z]|(?<!\A)[A-Z](?=[a-z]))', r' \1', data_str.replace('_', ' ').strip()).lower(), x.split(' ')))), value))
            for key, value in metadata.items()
        } 
        for file, metadata in tqdm(data_dict.items())
    }
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=186573.0), HTML(value='')))

# %%
cleaned_data
# Out:
# {'5fae885c-3fde-430f-a3c5-ff44b81f2668.xmi.uml': {'classes': ['class a',
#    'class b',
#    'class c',
#    'class d',
#    'class e',
#    'class f',
#    'class g',
#    'class h',
#    'class i']},
#  '_oVCEUIHiEeeveJPbhFhy-g.xmi.uml': {'classes': ['site page', 'site section'],
#   'attributes': ['id',
#    'status',
#    'name',
#    'url',
#    'id',
#    'locked',
#    'name',
#    'default page']},
#  '20b51f77-a952-4206-b35c-b47acd0c631f.xmi.uml': {'classes': ['moteur impl',
#    'buffer',
#    'selection',
#    'presse papier'],
#   'attributes': ['texte', 'sel', 'attribute']},
#  'e8a7e84d-73b3-40d2-ac78-f550566b4de8.xmi.uml': {'classes': ['client',
#    'adapter impl',
#    'adaptee',
#    'context',
#    'state a',
#    'state b',
#    'singleton',
#    'abstraction',
#    'refined abstraction',
#    'concrete implementor',
#    'creator impl',
#    'product',
#    'concrete observer',
#    'concrete subject'],
#   'attributes': ['instance']},
#  '_oWwJoHfLEeqeQcxm9hmzHw.xmi.uml': {'classes': ['shopping cart',
#    'order',
#    'line item',
#    'account',
#    'customer'],
#   'attributes': ['creation date', 'id', 'quantity', 'price', 'id']},
#  '_wWY9wDZWEeewJqDqgRk6VA.xmi.uml': {'classes': ['bilal']},
#  '_OR8QgFq_EeeTF9GWmq2Xvg.xmi.uml': {'classes': ['exam',
#    'question',
#    'lead exam',
#    'school',
#    'lead report',
#    'lead school',
#    'class'],
#   'attributes': ['id',
#    'name',
#    'response columns',
#    'description',
#    'id',
#    'text',
#    'video unit',
#    'unit title',
#    'video chapter',
#    'subject',
#    'id',
#    'lead name',
#    'lead phone',
#    'lead last name',
#    'group',
#    'school',
#    'result',
#    'exam',
#    'application date',
#    'id',
#    'identifier',
#    'kind',
#    'maximum score',
#    'minimum score',
#    'name',
#    'city',
#    'state',
#    'country',
#    'id',
#    'school',
#    'exam',
#    'lead exam',
#    'lead name',
#    'school name',
#    'school group',
#    'rank',
#    'version',
#    'correct answers',
#    'subject diagnostic',
#    'study plan',
#    'id',
#    'lead reports',
#    'school name',
#    'school average',
#    'group diagnostic',
#    'area diagnostic',
#    'version']},
#  '331af011-1b93-4a9b-abb7-f53d3cfb2a88.xmi.uml': {'classes': ['client',
#    'adaptor',
#    'adaptee']},
#  '9f510af6-1690-4d09-b973-5069cf83647a.xmi.uml': {'classes': ['system',
#    'sensor',
#    'motion sensor',
#    'pressure sensor',
#    'home security system',
#    'alert',
#    'door',
#    'camera',
#    'speakers',
#    'micro phone',
#    'light',
#    'start of day',
#    'end of day',
#    'tv',
#    'home theatre',
#    'house holds',
#    'entertainment'],
#   'attributes': ['status',
#    'update',
#    'sensor id',
#    'sensor type',
#    'user id',
#    'alert id',
#    'door id',
#    'camera id',
#    'speaker id',
#    'mic id',
#    'light id',
#    'sot',
#    'eot',
#    'tvid',
#    'htid',
#    'time id',
#    'coffee',
#    'dish washer',
#    'alarm',
#    'washing machine',
#    'device id']},
#  '_3tGxoCVhEeiYD9TOdwevwA.xmi.uml': {'classes': ['collaborateur',
#    'pronostique',
#    'poule',
#    'competition',
#    'match',
#    'equipe'],
#   'attributes': ['id collaborateur',
#    'nom',
#    'prenom',
#    'email',
#    'password',
#    'role',
#    'id collaborateur',
#    'id match',
#    'score domicile',
#    'score exterieur',
#    'id poule',
#    'competition',
#    'libele',
#    'id competition',
#    'libele',
#    'nombre poules',
#    'id match',
#    'poule',
#    'date',
#    'equipe domicile',
#    'equipe exterieur',
#    'score domicile',
#    'score exterieur',
#    'id equipe',
#    'logo']},
#  '_CFTYQLf4Eee7sYPkE4-GPA.xmi.uml': {'classes': ['my class']},
#  '_AkJqwL2EEeirD7wkg7WdAw.xmi.uml': {'classes': ['customer', 'user'],
#   'attributes': ['csname',
#    'cs phon no.',
#    'address',
#    'credit cardinfo',
#    'email',
#    'user id',
#    'password',
#    'login status']},
#  '_B4ZY0F8QEeepGY91r9Nuow.xmi.uml': {'classes': ['vente',
#    'promotion',
#    'magasin',
#    'article',
#    'periode'],
#   'attributes': ['id magasin',
#    'id client',
#    'id periode',
#    'id article',
#    'id promotion',
#    'montant vente',
#    'taxe',
#    'unités vendes',
#    'numero ticket caisse',
#    'id promotion',
#    'nom promotion',
#    'taux remise',
#    'id magasin',
#    'nom magasin',
#    'adresse magasin',
#    'nom gérant',
#    'département',
#    'id article',
#    'nom article',
#    'marque article',
#    'attribute',
#    'id periode',
#    'année',
#    'mois',
#    'jour']},
#  '_xoz1gHe2EeiFX4HwoivBqg.xmi.uml': {'classes': ['batisseur',
#    'case',
#    'domino',
#    'ihm kingdomino',
#    'ihm santorini',
#    'index',
#    'king domino',
#    'pioche domino',
#    'plateau',
#    'santorini'],
#   'attributes': ['pos x',
#    'pos y',
#    'hauteur',
#    'nom',
#    'nb couronnes',
#    'numero',
#    'roi',
#    'p principal',
#    'grille1',
#    'grille2',
#    'p domino',
#    'p bas droite',
#    'p bouton',
#    'p direction',
#    'ens dominos',
#    'ens boutons gauche',
#    'ens boutons droite',
#    'ens dominos1',
#    'bouton nord',
#    'bouton sud',
#    'bouton est',
#    'bouton ouest',
#    'retour',
#    'regles',
#    'quitter',
#    'action',
#    'ligne',
#    'colonne',
#    'nb tours',
#    'ordre',
#    'principal',
#    'vision jeu',
#    'button jeu',
#    'panel droite',
#    'panel logo',
#    'retour',
#    'regle',
#    'quitter',
#    'bouton',
#    'action',
#    'conteur bati',
#    'choix bati',
#    'tour joueur',
#    'temp pos x',
#    'temp pos y',
#    'pos x',
#    'pos y',
#    'temp etage',
#    'ens bati',
#    'principal',
#    'santorini',
#    'regle santorini',
#    'king domino',
#    'all rois',
#    'nb rois',
#    'nb joueurs',
#    'nb dominos',
#    'player',
#    'royaume joueur1',
#    'royaume joueur2',
#    'plateau',
#    'ens bati',
#    'conteur bati',
#    'joueur1',
#    'joueur2']},
#  '_C3TewPaFEeWolbMxsR5EUQ.xmi.uml': {'classes': ['file'],
#   'attributes': ['file server', 'file local']},
#  '_2Jq9QK0KEDGNWLI2ml8Hng.xmi.uml': {'classes': ['lab3',
#    'server connection',
#    'gameboard',
#    'j frame',
#    'j panel',
#    'server']},
#  '_GbX-wK10EemHYc7DDM2g2A.xmi.uml': {'classes': ['animal',
#    'employee',
#    'tortoise',
#    'otter',
#    'slow loris',
#    'sea urchin',
#    'creep',
#    'lobby',
#    'bathroom',
#    'visitor center'],
#   'attributes': ['name',
#    'id',
#    'age',
#    'weight',
#    'name',
#    'employee id',
#    'phone',
#    'department',
#    'whisker length']},
#  '_WZQeEMJ8EeSII650IQ0Z1w.xmi.uml': {'classes': ['report settings<t>',
#    'report settings accessor',
#    'report data manager<t>',
#    'report accessor<t>',
#    'report<t>',
#    'aaaa']},
#  '_rGklUKQCEeWJIdgJ_zFBoQ.xmi.uml': {'classes': ['entreprise',
#    'produit',
#    'my class'],
#   'attributes': ['nom', 'nom prod', 'num']},
#  '_n6vpQN9FEea4oJwuIIj5Zg.xmi.uml': {'classes': ['golpes', 'tipo'],
#   'attributes': ['codigo', 'nome', 'tipo', 'categoria', 'codigo', 'nome']},
#  '_UBfU4MCnEeeEXb8Dudo6PQ.xmi.uml': {'classes': ['clone detection new ui',
#    'ddg right dialog',
#    'ddg bottom dialog',
#    'history spread sheet source',
#    'spread sheet object tree view',
#    'tree view spread sheet source',
#    'spread sheet object list view',
#    'list view spread sheet source',
#    'history spread sheet obj',
#    'similarity plot spread sheet obj',
#    'similarity plot spred sheet source']},
#  '_TCwTALi_Eeaud6jyFEReOw.xmi.uml': {'classes': ['casino',
#    'admin',
#    'game',
#    'table',
#    'player',
#    'gametype',
#    'rule'],
#   'attributes': ['id',
#    'name',
#    'id',
#    'password',
#    'starttime',
#    'number',
#    'connectedplrs',
#    'id',
#    'password',
#    'balance',
#    'game',
#    'maxplayer',
#    'id',
#    'desc']},
#  '_Eta50N0oEeS1iL_C3WP8Cw.xmi.uml': {'classes': ['tbl users', 'tbl order'],
#   'attributes': ['user id',
#    'user name',
#    'password',
#    'full name',
#    'role',
#    'vip',
#    'status',
#    'order id',
#    'user name',
#    'password',
#    'full name',
#    'role',
#    'vip',
#    'status']},
#  '_YlTgsCASEeiv8MB6k6XBAg.xmi.uml': {'classes': ['my frame',
#    'control panel',
#    'drawing panel',
#    'rect',
#    'class',
#    'graphics',
#    'drawing panel',
#    'shape',
#    'circle',
#    'rect',
#    'drawing panel',
#    'circle',
#    'rect',
#    'circle',
#    'drawing panel',
#    'rect',
#    'drawing panel',
#    'shape',
#    'circle',
#    'dog',
#    'test',
#    'id generator',
#    'cat',
#    'rect',
#    'can be drawn',
#    'poly gen',
#    'slacker'],
#   'attributes': ['name', 'id', 'current id', 'id', 'name']},
#  '_O9PI8GyeEDGXH9FO528ZpA.xmi.uml': {'classes': ['dvd',
#    'book',
#    'library  managnment  system',
#    'item',
#    'staff',
#    'libarian',
#    'member',
#    'clerk'],
#   'attributes': ['type',
#    'count1',
#    'type',
#    'count',
#    'item linker',
#    'mem',
#    'cler',
#    'availability',
#    'issued',
#    'onloan',
#    'reference',
#    'name',
#    'id',
#    'name',
#    'id']},
#  '93552bd2-6e15-45b3-b1dd-3a4aa6b3b0b3.xmi.uml': {'classes': ['chat server',
#    'chat client',
#    'couleur',
#    'history',
#    'user',
#    'session',
#    'j frame']},
#  '_UWr2cM_JEeeLcIicqHdTUQ.xmi.uml': {'classes': ['currency converter',
#    'us currency converter',
#    'canadian currency converter',
#    'task controller',
#    'sales order',
#    'my class',
#    'calc tax']},
#  '_tGyV0EbLEeeTJ_4Vl2J2rQ.xmi.uml': {'classes': ['example instrumented test',
#    'fight screen',
#    'start menu',
#    'about fragment',
#    'custom health bar',
#    'custom mana bar',
#    'custom menu button',
#    'custom menu play button',
#    'logo fragment',
#    'settings fragment',
#    'game',
#    'game panel',
#    'main thread',
#    'singleton',
#    'bitmap cache',
#    'character',
#    'dummy',
#    'enemy',
#    'exit',
#    'game object',
#    'ground',
#    'player',
#    'wall',
#    'level',
#    'section',
#    'example unit test'],
#   'attributes': ['player health text',
#    'enemy health text',
#    'player mana text',
#    'player action text',
#    'enemy action text',
#    'player image',
#    'enemy image',
#    'health potion button',
#    'mana potion button',
#    'attack button',
#    'special attack button',
#    'max volume',
#    'media player',
#    'volume for player',
#    'health',
#    'max health',
#    'black paint',
#    'red paint',
#    'mana',
#    'max mana',
#    'black paint',
#    'blue paint',
#    'width',
#    'height',
#    'horizontal tiles',
#    'vertical tiles',
#    'tile width',
#    'tile height',
#    'paint',
#    'fps',
#    'average fps',
#    'surface holder',
#    'running',
#    'canvas',
#    'context',
#    'cache',
#    'name',
#    'health',
#    'max health',
#    'attack',
#    'health',
#    'attack',
#    'max health',
#    'special atack',
#    'max mana',
#    'mana',
#    'name',
#    'amount of health potions',
#    'amount of mana potions',
#    'to section',
#    'solid',
#    'image',
#    'image ref',
#    'amount of health potions',
#    'amount of mana potions',
#    'mana',
#    'max mana',
#    'special attack']},
#  '_rRbrsL2FEeedTfUoC-GfaA.xmi.uml': {'classes': ['snake'],
#   'attributes': ['attribute']},
#  '_r3GXcCFEEeiv8MB6k6XBAg.xmi.uml': {'classes': ['utilisateur',
#    'profil',
#    'système',
#    'base de données',
#    'serveur'],
#   'attributes': ['profil', 'nom', 'âge', 'mot de passe', 'genre']},
#  '_UvEXMEGiEemokbRu9Ld3Pw.xmi.uml': {'classes': ['individu',
#    'film',
#    'cinéma',
#    'séance',
#    'individu',
#    'groupe',
#    'contacts',
#    'individu2',
#    'film2',
#    'cinéma2',
#    'séance2',
#    'groupe',
#    'contact'],
#   'attributes': ['nom',
#    'age',
#    'nom',
#    'nom',
#    'ville',
#    'date',
#    'heure',
#    'nom',
#    'age',
#    'nom',
#    'nom',
#    'ville',
#    'date',
#    'heure']},
#  '_0se6kFNjEeS7SK6lkmJgjw.xmi.uml': {'classes': ['$.insm region view',
#    '$.insm base',
#    '$.insm rest service',
#    '$.insm asset loader indicator',
#    'insm region event constant',
#    '$.insm play list grid',
#    'insm play list grid event constant',
#    '$.insm play list manager',
#    'insm play list manager event constant',
#    'object',
#    '$.insm play list editor',
#    '$.insm add new popup'],
#   'attributes': ['current selected nodes',
#    'tag',
#    '$.deffer',
#    'region datacollection',
#    'play list items',
#    'add on teamplate collection',
#    'onchecknode',
#    'onclicknode',
#    'current selected row',
#    'onremoveitem',
#    'onedititem',
#    'searchregion',
#    'clearrelation',
#    'removeselection',
#    'searchplaylist',
#    'getdata',
#    'current media type',
#    'settings']},
#  '48ecca9d-91d4-44f2-a21f-b0285228d504.xmi.uml': {'classes': ['jsdf',
#    'class name',
#    'my class'],
#   'attributes': ['dfsd']},
#  '45467683-bfda-4a59-aee6-262b47b819db.xmi.uml': {'classes': ['level',
#    'category'],
#   'attributes': ['state', 'name', 'id', 'level']},
#  '_qlo-cJalEeaLdJY0NVKqzQ.xmi.uml': {'classes': ['user']},
#  '_bTMxUGfCEDGY580vxrGduA.xmi.uml': {'classes': ['my class']},
#  '_IjzBoFWBEemYjay6yoFVQw.xmi.uml': {'classes': ['prodavac',
#    'nabavka',
#    'dobavljač',
#    'račun',
#    'proizvod',
#    'vrsta proizvoda',
#    'kupac',
#    'plaćanje u gotovini',
#    'plaćanje',
#    'plaćanje sa karticom',
#    'plaćanje karticom',
#    'plaćanje u gotovini'],
#   'attributes': ['prodavac id',
#    'ime',
#    'prezime',
#    'e-mail',
#    'kontakt telefon',
#    'napomena',
#    'nabavka id',
#    'datum',
#    'kolicina',
#    'iznos',
#    'vreme',
#    'napomena',
#    'prodavac id',
#    'dobavljac id',
#    'proizvod id',
#    'dobavljac id',
#    'naziv',
#    'maticni broj',
#    'kontakt telefon',
#    'adresa',
#    'mesto',
#    'napomena',
#    'racun id',
#    'datum',
#    'vreme',
#    'kolicina',
#    'iznos',
#    'prodavac id',
#    'napomena',
#    'plaćanje id',
#    'proizvod id',
#    'naziv',
#    'napomena',
#    'dobavljac id',
#    'vrsta proizvoda id',
#    'nabavka id',
#    'iznos',
#    'napomena',
#    'prodavac id',
#    'ime',
#    'prezime',
#    'e-mail',
#    'kontakt telefon',
#    'napomena',
#    'prodavac id',
#    'ime',
#    'prezime',
#    'e-mail',
#    'kontakt telefon',
#    'napomena',
#    'proizvod id',
#    'račun id',
#    'prodavac id',
#    'ime',
#    'prezime',
#    'kontakt telefon',
#    'proizvod id',
#    'račun id',
#    'proizvod id',
#    'račun id']},
#  '_kUTfkMkMEeeM1PgT03-3Vg.xmi.uml': {'classes': ['login tbl',
#    'add news tbl',
#    'feedback tbl',
#    'employee tbl',
#    'registration tbl'],
#   'attributes': ['user name',
#    'password',
#    'id',
#    'news  image',
#    'news  description',
#    'bookmark',
#    'id',
#    'feedback',
#    'id',
#    'mail address',
#    'user name',
#    'password',
#    'city',
#    'dob',
#    'gender']},
#  '_89yH0D-DEeWH0sFqYQQ8Cg.xmi.uml': {'classes': ['server'],
#   'attributes': ['var1']},
#  '_Mx7t0OmWEeaowdqlt8Dqsg.xmi.uml': {'classes': ['déplacement',
#    'etape',
#    'station',
#    'station extrémité',
#    'station noeud'],
#   'attributes': ['id container',
#    'date',
#    'heure départ',
#    'heure arrivée',
#    'priorité',
#    'num etape',
#    'heure arrivée',
#    'heure départ',
#    'id station',
#    'nom',
#    'localisation',
#    'taille zone de groupage',
#    'occupée']},
#  '_m43vEEhOEemB7r6RYSs12w.xmi.uml': {'classes': ['ads', 'event', 'product']},
#  '_pBW_QHLCEee5HMQDnOR-kg.xmi.uml': {'classes': ['crew',
#    'crew pilot',
#    'plane',
#    'schedule'],
#   'attributes': ['crew id',
#    'crew name',
#    'crew address',
#    'crew phone',
#    'pilot license',
#    'plane id',
#    'schedule time',
#    'schedule plane',
#    'schedule crew',
#    'schedule departure',
#    'schedule note',
#    'schedule arrival']},
#  '_7Qd5sHVJEeSZWo9AFr5YZg.xmi.uml': {'classes': ['benchmark- controller',
#    'load driver',
#    'database',
#    'transaktions',
#    'remote',
#    'init database']},
#  '4465670b-b7f1-4505-8c09-e163b6a629a7.xmi.uml': {'classes': ['shopping cart']},
#  'b66a0071-5321-4795-a59c-96ff8cc34f37.xmi.uml': {'classes': ['worker',
#    'people',
#    'customer',
#    'cook',
#    'waiter',
#    'cashier'],
#   'attributes': ['name']},
#  '42797400-89dc-4192-8cac-7f67e4e4fbc3.xmi.uml': {'classes': ['registration'],
#   'attributes': ['attribute']},
#  '19cf5401-6e76-4e4d-81d8-309f156151f5.xmi.uml': {'classes': ['session repository filter',
#    'expiring session http session',
#    'multi http session strategy adapter',
#    'header http session strategy',
#    'expiring session']},
#  '_GhGBELsKEeWdWJbDFmNa8w.xmi.uml': {'classes': ['conta', 'ganho', 'pessoa'],
#   'attributes': ['numero',
#    'nome',
#    'valor',
#    'situacao',
#    'id',
#    'nome',
#    'valor',
#    'situacao',
#    'id']},
#  '_zeUN8FJjEeeTnI9B59buBQ.xmi.uml': {'classes': ['admin home activity',
#    'background material activity',
#    'category activity',
#    'edit domains activity',
#    'leaderboard activity',
#    'password reset activity',
#    'performance activity',
#    'quiz activity',
#    'remove user activity',
#    'domain adapter',
#    'leaderboard adapter',
#    'question adapter',
#    'user adapter',
#    'answer',
#    'category content',
#    'material',
#    'question',
#    'question item',
#    'score',
#    'user',
#    'user score',
#    'login fragment',
#    'password recovery fragment',
#    'password reset fragment',
#    'quiz result dialog fragment',
#    'register fragment',
#    'constants',
#    'string utils',
#    'array adapter< string>',
#    'array adapter< question item>',
#    'array adapter< user>'],
#   'attributes': ['m auth',
#    'm auth state listener',
#    'm leaderboard btn',
#    'm edit domains btn',
#    'm add user btn',
#    'm remove user btn',
#    'm logout btn',
#    'm category',
#    'm category text view',
#    'm start quiz btn',
#    'm background text',
#    'm database',
#    'm category list',
#    'm progress dialog',
#    'm list view',
#    'm btn container',
#    'add domain btn',
#    'save domain btn',
#    'm database',
#    'm domains',
#    'm keys',
#    'm domain',
#    'm position',
#    'm edit mode',
#    'm database',
#    'm progress dialog',
#    'tab layout',
#    'm view pager',
#    'm auth',
#    'user',
#    'm current password view',
#    'm new password view',
#    'm new password2 view',
#    'm change password button',
#    'm cancel button',
#    'm reset progress view',
#    'm password reset form view',
#    'cancel',
#    'focus view',
#    'm quizzes text view',
#    'm score text view',
#    'm current rank text view',
#    'm best rank text view',
#    'm progress dialog',
#    'm database',
#    'm category',
#    'm database',
#    'm quiz score',
#    'is review mode',
#    'm question list view',
#    'm category text view',
#    'm view pager',
#    'm result text view',
#    'm list view',
#    'm database',
#    'm user key list',
#    'm auth',
#    'm domains',
#    'm context',
#    'm editable list',
#    'm editable btn list',
#    'm edited domain name',
#    'm activity',
#    'm context',
#    'm questions',
#    'm layout id',
#    'is review',
#    'm text view',
#    'm activity',
#    'text',
#    'is correct',
#    'img',
#    'is selected',
#    'questions',
#    'text',
#    'imgs',
#    'text',
#    'img',
#    'answers',
#    'is answered',
#    'number',
#    'is selected',
#    'is correct',
#    'is attempted',
#    'correct',
#    'quizzes',
#    'best rank',
#    'current rank',
#    'percentage',
#    'first name',
#    'last name',
#    'email',
#    'password',
#    'is admin',
#    'm email view',
#    'm password view',
#    'm progress view',
#    'm login form view',
#    'm email edit text',
#    'm url',
#    'arg param url',
#    'm web view',
#    'm progress dialog',
#    'm quiz result text view',
#    'm email view',
#    'm password view',
#    'm password view2',
#    'm first name',
#    'm last name',
#    'm progress view',
#    'm register form view',
#    'm register button',
#    'arg param1',
#    'arg param2',
#    'm param1',
#    'm param2',
#    'm database',
#    'domain ref',
#    'm domains',
#    'category name',
#    'num questions per quiz',
#    'question prefix',
#    'color question selected',
#    'color question correct',
#    'color question incorrect',
#    'db questions',
#    'db scores',
#    'db scores updated',
#    'db users',
#    'db domains',
#    'host']},
#  '_8y0sAIKDEeeveJPbhFhy-g.xmi.uml': {'classes': ['student registration',
#    'teachers registration',
#    'my class']},
#  '_YRK-gLc7EeWh17zD5SB95Q.xmi.uml': {'classes': ['request',
#    'status',
#    'department',
#    'application user',
#    'request event',
#    'request event detail'],
#   'attributes': ['id',
#    'topic',
#    'status',
#    'department',
#    'citizen',
#    'assignee',
#    'events',
#    'id',
#    'comment',
#    'date',
#    'attribute',
#    'is public',
#    'author',
#    'details',
#    'id',
#    'text']},
#  '_0fYbULfaEee7sYPkE4-GPA.xmi.uml': {'classes': ['library',
#    'librarian',
#    'books database',
#    'student',
#    'vendor',
#    'student record'],
#   'attributes': ['location',
#    'name',
#    'book title',
#    'author',
#    'book id',
#    'details',
#    'book details',
#    'attribute',
#    'name',
#    'address',
#    'phone number',
#    'fines']},
#  '_P5FiwC-mEeme-prEJQaJbA.xmi.uml': {'classes': ['ebook',
#    'configuracoes',
#    'decodificador',
#    'celula braille']},
#  '_VTRjAHomEeSdXJMJcKNKoQ.xmi.uml': {'classes': ['personal',
#    'användare',
#    'elev',
#    'lågstadiet',
#    'mellanstad',
#    'my class'],
#   'attributes': ['namn',
#    'behörighet',
#    'id',
#    'yrkesroll',
#    'namn',
#    'behörighet',
#    'id',
#    'namn',
#    'behörighet',
#    'id',
#    'attribute']},
#  '_Vfe9wHL5EeSxHp9pHOThjg.xmi.uml': {'classes': ['trader']},
#  'a093a6c4-4491-4b65-b79a-19be1bd57765.xmi.uml': {'classes': ['customer',
#    'payment',
#    'shopping cart',
#    'account',
#    'web user',
#    'order',
#    'line item',
#    'product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paid date',
#    'total',
#    'details',
#    'creation date',
#    'billing address',
#    'open',
#    'closed',
#    'is closed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'ship to',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description']},
#  '_NpOgoK7zEee6S77dw3LIvQ.xmi.uml': {'classes': ['app partido basketball',
#    'equipo',
#    'partido basketball',
#    'jugador'],
#   'attributes': ['nombre',
#    'ciudad',
#    'titulo: string',
#    'dia: byte',
#    'nombre',
#    'apellido',
#    'estatura']},
#  '_2A0eUK99EealN5YbbDMqoA.xmi.uml': {'classes': ['modification',
#    'degree modifacion',
#    'module modification',
#    'obsever',
#    'observable',
#    'modify degree',
#    'delete degree',
#    'modify module',
#    'delete module'],
#   'attributes': ['mod id',
#    'status',
#    'title',
#    'degree code',
#    'level',
#    'module code',
#    'level',
#    'update',
#    'add observer(observer: observer',
#    'remove observer(observer: observer',
#    'notify all']},
#  '_fRRYMELoEeavkcsFwndrbA.xmi.uml': {'classes': ['animal'],
#   'attributes': ['name', 'size', 'color']},
#  '_xOaacKYVEeaiBJ7PH1W80g.xmi.uml': {'classes': ['personel',
#    'ticket',
#    'yetkilendirme'],
#   'attributes': ['personel id',
#    'personeli̇sim',
#    'personel mevki',
#    'personel bolum',
#    'ticket id',
#    'ticket tarih',
#    'ticket detay',
#    'personel id',
#    'ticket durum',
#    'sorun cesidi',
#    'cozum',
#    'ticket id',
#    'personel id']},
#  '_bunGYGkdEeSmTqqtE6wM_Q.xmi.uml': {'classes': ['guest',
#    'user',
#    'player',
#    'moderator',
#    'email server',
#    'database',
#    'android application instance',
#    'clarification request',
#    'game',
#    'mission',
#    'kill',
#    'geo fence',
#    'geo point',
#    'page',
#    'global update',
#    'dynamic game map'],
#   'attributes': ['role id',
#    'hvzid',
#    'email',
#    'password',
#    'first name',
#    'last name',
#    'kills',
#    'created at',
#    'played games',
#    'paid dues',
#    'is subscribed',
#    'phone number',
#    'player type',
#    'in game',
#    'gps tracking on',
#    'name',
#    'ip',
#    'subscribed emails',
#    'username',
#    'password',
#    'emails to send',
#    'name',
#    'ip',
#    'username',
#    'password',
#    'instance id',
#    'user logged in',
#    'device name',
#    'latitude',
#    'longitude',
#    'time of gps',
#    'is tracking',
#    'mission id',
#    'is answered',
#    'response user',
#    'source user',
#    'message',
#    'response',
#    'game id',
#    'missions',
#    'description',
#    'players',
#    'is current',
#    'mission id',
#    'game id',
#    'geo fences',
#    'geo points',
#    'description',
#    'role id',
#    'vicitm user',
#    'killer user',
#    'time of death',
#    'in game id',
#    'center latitude',
#    'center longitude',
#    'radius',
#    'trigger players',
#    'score',
#    'score modifier',
#    'end score',
#    'description',
#    'in mission id',
#    'trigger rate',
#    'seen by players',
#    'is visible',
#    'latitude',
#    'longitude',
#    'description',
#    'in mission id',
#    'seen by players',
#    'is visible',
#    'url',
#    'information',
#    'title',
#    'message',
#    'source user',
#    'push notification sent',
#    'email notification sent',
#    'mission']},
#  'dc7ae9ed-7cf7-4298-844e-489bbc9faeea.xmi.uml': {'classes': ['shopping cart']},
#  '_zkx8wOKPEeiZY7VjYQykuQ.xmi.uml': {'classes': ['control',
#    'super bk compare',
#    'bk compare write to excel',
#    'bk compare write to text',
#    'super bk reader',
#    'bk writer']},
#  '_SaUicIB4Eei-m5BAOg12zA.xmi.uml': {'classes': ['character',
#    'saving throw',
#    'weapon'],
#   'attributes': ['name',
#    'race',
#    'vocation',
#    'is player',
#    'str',
#    'dex',
#    'cons',
#    'intel',
#    'wis',
#    'chr',
#    'save throw',
#    'hp',
#    'hit dice',
#    'equipped',
#    'is proficient',
#    'prof bonus',
#    'name',
#    'range',
#    'damage',
#    'atk bonus']},
#  '_Sefo0H_cEDGdNIjA6xbcew.xmi.uml': {'classes': ['ui text view',
#    'ui image picker controller',
#    'ui text field',
#    'ui alert view',
#    'ui image view',
#    'ui view',
#    'ui control',
#    'button',
#    'ui activity indicator view',
#    'perform encript',
#    'stago custom view',
#    'stago display updater',
#    'perform decrypt',
#    'staganography manager']},
#  '_34klgCFXEeqqcaoAsxFIeg.xmi.uml': {'classes': ['book',
#    'reader',
#    'librarian',
#    'borrowing',
#    'user'],
#   'attributes': ['id',
#    'name',
#    'no',
#    'writer',
#    'press',
#    'address',
#    'total',
#    'id',
#    'name',
#    'no',
#    'age',
#    'sex',
#    'department',
#    'telephone number',
#    'id',
#    'name',
#    'no',
#    'sex',
#    'age',
#    'telephone number',
#    'date',
#    'id',
#    'username',
#    'password']},
#  '_JuQ-QJvREeSW9selBczv3Q.xmi.uml': {'classes': ['i figura',
#    'i color',
#    'rectangulo',
#    'circulo',
#    'cuadrilatero'],
#   'attributes': ['pi', 'base', 'altura', 'radio']},
#  '_lC7ZAGxcEem8aOzn3EOqfg.xmi.uml': {'classes': ['order']},
#  '_tHhBAFSKEei2efM7H4gIXw.xmi.uml': {'classes': ['boleto',
#    'contrato',
#    'parcela',
#    'flo'],
#   'attributes': ['num boleto',
#    'cod cliente',
#    'cod barra',
#    'dat reneg',
#    'dat vencimento',
#    'val saldo dev',
#    'val saldo reneg',
#    'val perc desc',
#    'ind campanha',
#    'num qtde parc',
#    'val prest',
#    'val desc prest',
#    'val liqu prest',
#    'num boleto',
#    'cod cliente',
#    'cod produto',
#    'num contrato',
#    'nom produto',
#    'val saldo dev',
#    'val saldo reneg',
#    'val encargo',
#    'val tarifa',
#    'num boleto',
#    'cod produto',
#    'num contrato',
#    'num parcela']},
#  '1071140d-9c5d-46d3-aa90-f9b348ebfac9.xmi.uml': {'classes': ['customer',
#    'payment',
#    'shopping cart',
#    'account',
#    'web user',
#    'order',
#    'line item',
#    'product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paid date',
#    'total',
#    'details',
#    'creation date',
#    'billing address',
#    'open',
#    'closed',
#    'is closed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'ship to',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description']},
#  '72bffa82-db26-4d26-a139-b38884dada59.xmi.uml': {'classes': ['clients',
#    'login',
#    'administrator',
#    'who made changes',
#    'account expired',
#    'make pay',
#    'change password',
#    'events',
#    'add additional data',
#    'advance search']},
#  '_z-y1oKPNEeikWfbDNPV9UQ.xmi.uml': {'classes': ['class']},
#  '_iAN1sIYZEeS_9vPfFC3tSQ.xmi.uml': {'classes': ['dog',
#    'lab',
#    'poodle',
#    'shepard',
#    'pitbull',
#    'pug',
#    'beagle'],
#   'attributes': ['gender', 'breed', 'weight', 'color', 'eye color']},
#  '43125ec2-0e31-4d4d-98d2-2ca18c1a08ba.xmi.uml': {'classes': ['client',
#    'adaptor',
#    'adaptee']},
#  'b11d83f2-57be-4197-b073-33b29a12e551.xmi.uml': {'classes': ['worker',
#    'people',
#    'customer',
#    'cook',
#    'waiter',
#    'cashier'],
#   'attributes': ['name']},
#  '_CwucMBNMEeSTV6l4790RsQ.xmi.uml': {'classes': ['mensagem',
#    'twitter',
#    'facebook',
#    'utilizador']},
#  '_ozUCAFmYEeaQF8q9ZsVYhQ.xmi.uml': {'classes': ['single data combiner',
#    'latest value combiner',
#    'greatest value combiner',
#    'custom combiner',
#    'combined combiner',
#    'priority combiner',
#    'rule based combiner']},
#  '_mu7qEH1yEeShroDxTnL5_A.xmi.uml': {'classes': ['single data combiner',
#    'latest value combiner',
#    'greatest value combiner',
#    'custom combiner',
#    'combined combiner',
#    'priority combiner',
#    'rule based combiner']},
#  '_vgKXsMUIEeadwOIOqK-0Fw.xmi.uml': {'classes': ['my class']},
#  'd5c157b6-912e-4995-9d8f-bd5f2aa2ee9f.xmi.uml': {'classes': ['client',
#    'adapter impl',
#    'adaptee',
#    'context',
#    'state a',
#    'state b',
#    'singleton',
#    'abstraction',
#    'refined abstraction',
#    'concrete implementor',
#    'creator impl',
#    'product',
#    'concrete observer',
#    'concrete subject'],
#   'attributes': ['instance']},
#  '_Hr1JoIwLEeewrIfYd5mf8Q.xmi.uml': {'classes': ['monetate event',
#    'monetate event product view',
#    'monetate event purchase',
#    'monetate processor',
#    'product',
#    'message processor'],
#   'attributes': ['event type',
#    'products',
#    'purchase lines',
#    'name',
#    'setting api key',
#    'setting mailing list id',
#    'domain',
#    'instance',
#    'account id',
#    'api url',
#    'sku',
#    'pid',
#    'quantity',
#    'currency',
#    'value']},
#  '_1ybHgIT-EeS-18kfrtGUQQ.xmi.uml': {'classes': ['quran surah'],
#   'attributes': ['surah no', 'name of surah', 'type of surah']},
#  'f959fb74-a45e-4e26-a37d-ff5dad352c49.xmi.uml': {'classes': ['worker',
#    'people',
#    'customer',
#    'cook',
#    'waiter',
#    'cashier'],
#   'attributes': ['name']},
#  'e62c26ba-de91-443d-8dec-baa035e40d26.xmi.uml': {'classes': ['shopping cart',
#    'order',
#    'line item',
#    'account',
#    'customer'],
#   'attributes': ['creation date', 'id', 'quantity', 'price', 'id']},
#  '_SHt8QP2_EeOTCK1Mp6laew.xmi.uml': {'classes': ['main class',
#    'about',
#    'documents',
#    'encryption',
#    'decryption',
#    'ss generator',
#    'app  password']},
#  '_tWiXAE-oEeeu8_4LH_yuyg.xmi.uml': {'classes': ['core', 'person', 'company'],
#   'attributes': ['id', 'value', 'person code', 'registration nr', 'vat nr']},
#  '_0ato4He_EeeZ3IbHHpTTiA.xmi.uml': {'classes': ['adapter factory',
#    'google adapter factory',
#    'class',
#    'adapter',
#    'class2',
#    'amazon adapter factory',
#    'google adapter',
#    'amazon adapter',
#    'generic request stream handler'],
#   'attributes': ['object mapper']},
#  '_yIWRYChXEeShcfbUiDP6ug.xmi.uml': {'classes': ['my class', 'my class2'],
#   'attributes': ['name']},
#  '67ed9d27-56e3-4b81-8050-6e03eda242b5.xmi.uml': {'classes': ['worker',
#    'people',
#    'customer',
#    'cook',
#    'waiter',
#    'cashier'],
#   'attributes': ['name']},
#  '_cOog0CIgEeisAYMSV00L2Q.xmi.uml': {'classes': ['fields modification',
#    'created user modification',
#    'deleted user modification',
#    'user moved to group modification',
#    'grid index',
#    'grid index2']},
#  'a670164a-9f45-46fe-bade-23f443485ab4.xmi.uml': {'classes': ['customer',
#    'account',
#    'transaction',
#    'checking account',
#    'savings account',
#    'login',
#    'deposit transaction',
#    'withdraw transaction',
#    'transfer transaction',
#    'certificates of deposit account'],
#   'attributes': ['name',
#    'date of birth',
#    'address',
#    'phone number',
#    'email address',
#    'account no',
#    'type',
#    'balance',
#    'id',
#    'type',
#    'transaction time',
#    'amount',
#    'interest rate',
#    'username',
#    'password',
#    'security question',
#    'security answer',
#    'last login time',
#    'target account',
#    'source account',
#    'interest rate',
#    'time period']},
#  'efd35011-a6c9-4b9a-b62e-d5daa9b58968.xmi.uml': {'classes': ['user'],
#   'attributes': ['attribute']},
#  'd779e6fe-c0ae-4f71-816a-5cdd632e89f1.xmi.uml': {'classes': ['customer',
#    'payment',
#    'shopping cart',
#    'account',
#    'web user',
#    'order',
#    'line item',
#    'product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paid date',
#    'total',
#    'details',
#    'creation date',
#    'billing address',
#    'open',
#    'closed',
#    'is closed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'ship to',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description']},
#  '597093bc-31ce-4808-b763-c29d6f680f32.xmi.uml': {'classes': ['чч',
#    'my class',
#    'my class2']},
#  '_OxdDoEymEeS9L4cMWDc7Qg.xmi.uml': {'attributes': ['load']},
#  '_I_lnENTGEeehRMl7r1-c5g.xmi.uml': {'classes': ['curved line',
#    'sketchy ellipse',
#    'sketchy rectangle',
#    'shape creator',
#    'line drawer',
#    'shape mover',
#    'shape resizer',
#    'shape rotater',
#    'shape filler',
#    'shape deleter',
#    'shape raiser',
#    'shape lowerer']},
#  '_zTvrkGm3EDGB-uCsYzbtRg.xmi.uml': {'classes': ['game window']},
#  'af8ad990-19e3-488e-b4b8-846b6643f25b.xmi.uml': {'classes': ['customer',
#    'payment',
#    'shoppin cart',
#    'account',
#    'web user',
#    'order',
#    'line item',
#    'product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paid date',
#    'total',
#    'details',
#    'creation date',
#    'billing address',
#    'open',
#    'closed',
#    'is closed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'ship to',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description']},
#  'd6ed4740-d12b-4899-a2db-2374a6c7c4b5.xmi.uml': {'classes': ['client',
#    'adapter impl',
#    'adaptee',
#    'context',
#    'state a',
#    'state b',
#    'singleton',
#    'abstraction',
#    'refined abstraction',
#    'concrete implementor',
#    'creator impl',
#    'product',
#    'concrete observer',
#    'concrete subject',
#    'method class',
#    'class object'],
#   'attributes': ['instance']},
#  '_NI0-EMYEEeeWu-SLkciAbg.xmi.uml': {'classes': ['temp sensor', 'arduino'],
#   'attributes': ['vout', 'volts', 'celsius', 'farfahrenheit']},
#  'b9dfe65c-12b6-498b-a151-0343da867aef.xmi.uml': {'classes': ['client',
#    'adapter impl',
#    'adaptee',
#    'context',
#    'state a',
#    'state b',
#    'singleton',
#    'abstraction',
#    'refined abstraction',
#    'concrete implementor',
#    'creator impl',
#    'product',
#    'concrete observer',
#    'concrete subject'],
#   'attributes': ['instance']},
#  '0d0ec5dd-c762-405a-8a86-9d23a126537b.xmi.uml': {'classes': ['my class a oim'],
#   'attributes': ['attribute']},
#  '_RwyPkIPfEeaY2ZFk8hIg9A.xmi.uml': {'classes': ['db object'],
#   'attributes': ['table',
#    'index',
#    'uid',
#    'uid length',
#    'delete',
#    'columns',
#    'fillable',
#    'hidden',
#    'generators']},
#  '431e2d5d-fa76-4ca1-a879-a927d293c394.xmi.uml': {'classes': ['client',
#    'adapter impl',
#    'adaptee',
#    'context',
#    'state a',
#    'state b',
#    'singleton',
#    'abstraction',
#    'refined abstraction',
#    'concrete implementor',
#    'creator impl',
#    'product',
#    'concrete observer',
#    'concrete subject'],
#   'attributes': ['instance']},
#  '_42UqgMaLEeWmANB_14dU0A.xmi.uml': {'classes': ['prueba', 'prueba2'],
#   'attributes': ['nombre', 'lugar', 'pais', 'color', 'tamanio']},
#  '_OJVuMFlJEeWH7tmnkVHu6g.xmi.uml': {'classes': ['patrons', 'library staff'],
#   'attributes': ['holder',
#    'name',
#    'date',
#    'student',
#    'faculty',
#    'library staff',
#    'books',
#    'overdue fee',
#    'check out time']},
#  '_butz8NjbEeWjYr7I4V0e0A.xmi.uml': {'classes': ['charge account'],
#   'attributes': ['customer no(key)', 'attribute']},
#  '310b8bef-1a4e-4692-b437-a6a5453e1c31.xmi.uml': {'classes': ['customer',
#    'payment',
#    'shopping cart',
#    'account',
#    'web user',
#    'order',
#    'line item',
#    'product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paid date',
#    'total',
#    'details',
#    'creation date',
#    'billing address',
#    'open',
#    'closed',
#    'is closed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'ship to',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description']},
#  '7aff64ad-90b0-450f-bf8c-1f4b9c3b8f37.xmi.uml': {'classes': ['shopping cart']},
#  'f34f1233-c3f1-48df-b830-6c1e81f51751.xmi.uml': {'classes': ['abstraction',
#    'refined abstraction',
#    'concrete implementor']},
#  'f6e1ef7a-107f-419e-ab7d-a51aa49c13d2.xmi.uml': {'classes': ['snake',
#    'game',
#    'program',
#    'food',
#    'display',
#    'player',
#    'unit',
#    'random'],
#   'attributes': ['face',
#    'speed',
#    'size',
#    '[]unit',
#    'snake',
#    'food',
#    'display',
#    'player',
#    'life',
#    'face',
#    'to be',
#    'height',
#    'width',
#    'space',
#    'wall',
#    'score position',
#    'game resume position',
#    'game over postion',
#    'command']},
#  '_-g260KW7EeaiBJ7PH1W80g.xmi.uml': {'classes': ['event',
#    'customer',
#    'agency',
#    'seven user',
#    'user activity relation',
#    'user register event relation',
#    'activity',
#    'log attendee',
#    'attendee activity',
#    'survey',
#    'question',
#    'response attendee',
#    'attendee',
#    'role mapping'],
#   'attributes': ['id',
#    'title',
#    'date created',
#    'date started',
#    'description',
#    'place',
#    'status',
#    'stage',
#    'brochure',
#    'timezone',
#    'user id',
#    'customer id',
#    'id',
#    'name',
#    'description',
#    'agency id',
#    'user id',
#    'id',
#    'name',
#    'description',
#    'user id',
#    'id',
#    'type',
#    'firstname',
#    'lastname',
#    'email',
#    'created',
#    'lastupdated',
#    'image user',
#    'id',
#    'sevenuser id',
#    'activity id',
#    'id',
#    'sevenuser id',
#    'event id',
#    'id',
#    'name',
#    'description',
#    'start',
#    'duration',
#    'limit',
#    'event id',
#    'user id',
#    'on demand count',
#    'evaluation count',
#    'registers',
#    'space availbale',
#    'id',
#    'status',
#    'date',
#    'attendee id',
#    'event id',
#    'id',
#    'attendee id',
#    'activity id',
#    'id',
#    'event id',
#    'activity id',
#    'user id',
#    'id',
#    'text',
#    'type',
#    'answer',
#    'time',
#    'send',
#    'survey id',
#    'id',
#    'date',
#    'response',
#    'attendee id',
#    'question id',
#    'id',
#    'age',
#    'email original',
#    'organization',
#    'status',
#    'location',
#    'birthyear',
#    'notification',
#    'email',
#    'platform',
#    'typecheck',
#    'event id',
#    'user id',
#    'id',
#    'sevenuser id',
#    'role id',
#    'type']},
#  '19515821-de9c-4371-ab13-0c10c1f0741e.xmi.uml': {'classes': ['client',
#    'adapter impl',
#    'adaptee',
#    'context',
#    'state a',
#    'state b',
#    'singleton',
#    'abstraction',
#    'refined abstraction',
#    'concrete implementor',
#    'creator impl',
#    'product',
#    'concrete observer',
#    'concrete subject'],
#   'attributes': ['instance']},
#  '_iY65cGqwEeepGY91r9Nuow.xmi.uml': {'classes': ['order'],
#   'attributes': ['user name',
#    'attribute2',
#    'attribute3',
#    'attribute4',
#    'attribute5',
#    'attribute6',
#    'attribute7',
#    'attribute8',
#    'attribute9',
#    'attribute10']},
#  '_ICx4IDeZEemHKq5iZQi_Zw.xmi.uml': {'classes': ['estudiante',
#    'profesor',
#    'materias',
#    'salones',
#    'rol',
#    'edificio',
#    'programa',
#    'facultad',
#    'horario'],
#   'attributes': ['id estudiante',
#    'nombre',
#    'apellidos',
#    'cedula',
#    'correo',
#    'estado',
#    'id rol',
#    'id programa',
#    'id profesor',
#    'nombre',
#    'cedula',
#    'correo',
#    'id salon',
#    'id rol',
#    'id materia',
#    'nombre',
#    'nrc',
#    'cupo',
#    'creditos',
#    'id estudiante',
#    'id profesor',
#    'id salon',
#    'id horario',
#    'id salon',
#    'piso',
#    'numero salon',
#    'capacidad',
#    'id edificio',
#    'id horario',
#    'id rol',
#    'nombre',
#    'id edificio',
#    'nombre',
#    'id programa',
#    'nombre',
#    'isum',
#    'id facultad',
#    'id facultad',
#    'nombre',
#    'id horario',
#    'hora inicio',
#    'hora final']},
#  '_w3lJ8AP7Eeewntt9CKbg3g.xmi.uml': {'classes': ['user',
#    'team',
#    'channel',
#    'message',
#    'user settings',
#    'team settings',
#    'channel settings',
#    'channel activity',
#    'user account',
#    'dirrect message'],
#   'attributes': ['username',
#    'team',
#    'name',
#    'url',
#    'name',
#    'status',
#    'purpose',
#    'date',
#    'content',
#    'notifications',
#    'sound',
#    'display',
#    'threads',
#    'highlight words',
#    'do not disturb from',
#    'do not disturb to',
#    'sign up mode',
#    'default channels',
#    'username guidelines',
#    'name display',
#    'require for mention',
#    'email display',
#    'do not disturb from',
#    'do not disturb to',
#    'hide url',
#    'enable calls',
#    'calling app',
#    'message retention',
#    'file retention',
#    'team icon',
#    'desktop notifications',
#    'push notificationa',
#    'mute channel',
#    'include user group mentions',
#    'include channel mentions',
#    'first name',
#    'last name',
#    'what i do',
#    'email',
#    'phone',
#    'timezone',
#    'skype id',
#    'photo',
#    'password']},
#  'e9599e4d-25c4-48e4-8fe3-fc14e2c55dce.xmi.uml': {'classes': ['employee',
#    'salary',
#    'authenticate staff',
#    'leave',
#    'attendance',
#    'login'],
#   'attributes': ['emp  id',
#    'emp  name',
#    'emp  contact no',
#    'emp  email',
#    'emp nic',
#    'emp  address',
#    'emp dob',
#    'emp  department',
#    'emp- date  of  joint',
#    'emp  position',
#    'emp  salary',
#    'emp  id',
#    'sly  basic',
#    'sly  increment',
#    'sly  decrement',
#    'sly  netgross',
#    'over time',
#    'user name',
#    'password',
#    'authendication  mood',
#    'leave id',
#    'emp  id',
#    'leave  title',
#    'leave detail',
#    'leave  apply date',
#    'leave  start date',
#    'leave  end date',
#    'leave  no of days',
#    'leave  status',
#    'attend date',
#    'emp id',
#    'attend time',
#    'leaving  time',
#    'user name',
#    'password']},
#  '49a9a179-f2f3-4517-994e-148391be8053.xmi.uml': {'classes': ['client',
#    'adaptor',
#    'adaptee',
#    'my class']},
#  '_1fv_cGAzEeepGY91r9Nuow.xmi.uml': {'classes': ['category',
#    'products',
#    'product size',
#    'order details',
#    'my class',
#    'my class2',
#    'my class3',
#    'my class4',
#    'my class5',
#    'orders',
#    'order category',
#    'my class8',
#    'my class9',
#    'my class10'],
#   'attributes': ['category id',
#    'category description',
#    'product id',
#    'product name',
#    'image',
#    'category id',
#    'is active',
#    'prod size id',
#    'product id',
#    'size id',
#    'price',
#    'order details id',
#    'order id',
#    'product size id',
#    'quantity',
#    'price per product',
#    'order id',
#    'adderess',
#    'client id',
#    'order date',
#    'center id',
#    'category id',
#    'order cat id',
#    'category desc']},
#  '8b08c90b-c7d3-4afd-b0e9-3dfe67ed7de3.xmi.uml': {'classes': ['shopping cart',
#    'order',
#    'line item',
#    'account',
#    'customer'],
#   'attributes': ['creation date', 'id', 'quantity', 'price', 'id']},
#  'd29cd2f3-9ae8-4c52-97f5-7cf07f4cdd10.xmi.uml': {'classes': ['singleton'],
#   'attributes': ['instance']},
#  '6c84d80a-0e28-40ab-957c-531b57921306.xmi.uml': {'classes': ['customer',
#    'payment',
#    'shopping cart',
#    'account',
#    'web user',
#    'order',
#    'line item',
#    'product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paid date',
#    'total',
#    'details',
#    'creation date',
#    'billing address',
#    'open',
#    'closed',
#    'is closed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'ship to',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description']},
#  '9232d81e-dab5-49d8-9e89-8a4ff91278b1.xmi.uml': {'classes': ['create analysis action',
#    'service',
#    'analysis dao',
#    'analysis dao'],
#   'attributes': ['analysis name']},
#  '_WfyX0MIFEeacM55raX9d3Q.xmi.uml': {'classes': ['producer text generator',
#    'text',
#    'consumer text analyz',
#    'scanner text']},
#  '_KlkTALgHEeSzkacHLregNQ.xmi.uml': {'classes': ['order'],
#   'attributes': ['order id;', '+ order(...)']},
#  '_XgXMwH_9EeW4cd-qm4QbpA.xmi.uml': {'classes': ['employee', 'rooms'],
#   'attributes': ['id', 'first name', 'last name', 'number']},
#  '40adfe9e-25a9-426a-806e-9ff9a56b4da2.xmi.uml': {'classes': ['worker',
#    'people',
#    'customer',
#    'cook',
#    'waiter',
#    'cashier'],
#   'attributes': ['name']},
#  '_lWq_kF4WEeSmRKwulsG6-Q.xmi.uml': {'classes': ['user',
#    'massage',
#    'profile',
#    'post',
#    'group',
#    'friends',
#    'login',
#    'notification',
#    'admin',
#    'member']},
#  '2c3b7982-340a-4627-9c85-6b1a36347b78.xmi.uml': {'classes': ['timetable event',
#    'timetable reader',
#    'timetable validator',
#    'timetable validation error',
#    'calendar importer',
#    'google calendar importer']},
#  '_JkGroH2TEeShroDxTnL5_A.xmi.uml': {'classes': ['caisse'],
#   'attributes': ['test']},
#  '9462f4aa-aea2-4c9e-afcb-cfcfbd414c85.xmi.uml': {'classes': ['shopping cart',
#    'order',
#    'line item',
#    'account',
#    'customer'],
#   'attributes': ['creation date', 'id', 'quantity', 'price', 'id']},
#  '538864d8-e066-49c5-8edd-4ab0fca7f62b.xmi.uml': {'classes': ['person',
#    'professor',
#    'employee',
#    'full professor',
#    'associate',
#    'assistant',
#    'office',
#    'university',
#    'classroom',
#    'room',
#    'building'],
#   'attributes': ['id', 'name', 'seats number', 'floor', 'number']},
#  '_5pZpkNHiEeaJwt5yAqWnTg.xmi.uml': {'classes': ['class',
#    'class2',
#    'wifi',
#    'class3',
#    'simcard',
#    'system',
#    'database']},
#  'e12b7943-feab-4c7d-9330-61358c7afece.xmi.uml': {'classes': ['customer',
#    'payment',
#    'shopping cart',
#    'account',
#    'web user',
#    'order',
#    'line item',
#    'product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paid date',
#    'total',
#    'details',
#    'creation date',
#    'billing address',
#    'open',
#    'closed',
#    'is closed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'ship to',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description']},
#  '_IC_G0MiPEeeM1PgT03-3Vg.xmi.uml': {'classes': ['physical users',
#    'online users',
#    'clerk',
#    'admin',
#    'database',
#    'payment',
#    'mobile user',
#    'online ticket',
#    'physical ticket']},
#  '_P7zdMN_uEeS6FO4vn2oOjA.xmi.uml': {'classes': ['suit'],
#   'attributes': ['input code']},
#  '3d99155b-5099-4121-bba7-934dfece62cb.xmi.uml': {'classes': ['shopping cart',
#    'order',
#    'line item',
#    'account',
#    'customer',
#    'class',
#    'client',
#    'client',
#    'platform'],
#   'attributes': ['creation date', 'id', 'quantity', 'price', 'id']},
#  '_DF3R0BwbEeig8qiayYYCew.xmi.uml': {'classes': ['person',
#    'faculty',
#    'student',
#    'raffle',
#    'prize'],
#   'attributes': ['first name',
#    'last name',
#    'gender',
#    'years of service',
#    'subject area',
#    'prize',
#    'class',
#    'age',
#    'prize',
#    'registrants',
#    'sorted registrants',
#    'prizes',
#    'name',
#    'company name']},
#  '_-WIY4KnoEeS9iunt9iMoeg.xmi.uml': {'classes': ['abstract game',
#    'chess',
#    'monopoly']},
#  '_FOQ0QCMXEeisAYMSV00L2Q.xmi.uml': {'classes': ['courrier cuau'],
#   'attributes': ['cellule aucu',
#    'service instructeur',
#    'interlocuteur',
#    'objet',
#    'date',
#    'votre conseiller']},
#  'cccd46b7-9b3e-44d4-84fc-e2153cf70d58.xmi.uml': {'classes': ['client',
#    'adaptor',
#    'adaptee']},
#  '_6I0ZIPjzEeSE6sazzutmkA.xmi.uml': {'classes': ['schedule timezone converter',
#    'schedule mgmt api response det vo',
#    'all schedules',
#    'custom schedule json vo',
#    'daily schedule json vo',
#    'one time schedule json vo'],
#   'attributes': ['schedule timezone converter',
#    'shift label right',
#    'shift label left',
#    'shift label na']},
#  '_bEYN8LBCEee6S77dw3LIvQ.xmi.uml': {'classes': ['person', 'class'],
#   'attributes': ['name', 'email']},
#  '_2p9bEMasEeadwOIOqK-0Fw.xmi.uml': {'classes': ['pay u',
#    'order status abstract',
#    'payment status',
#    'con',
#    'configuration'],
#   'attributes': ['$configuration']},
#  '3bddae18-8bff-498f-b478-8d075c718bdb.xmi.uml': {'classes': ['adaptor',
#    'adaptee',
#    'my class2']},
#  '813d3f22-4f16-4bd5-8e87-290334d4102b.xmi.uml': {'classes': ['advokat',
#    'predmet advokatske kancelarije',
#    'rociste',
#    'stranka',
#    'punomocje',
#    'tip punomocja',
#    'obaveza',
#    'izlazna faktura'],
#   'attributes': ['i dadvokat',
#    'ime advokata',
#    'broj telefona',
#    'prezime advokata',
#    'email adresa',
#    'adresa advokata',
#    'username',
#    'password',
#    'broj predmeta ak',
#    'datum pokretanja',
#    'datum zavrsetka',
#    'naziv predmeta',
#    'vrednost spora',
#    'id advokat',
#    'id punomocja',
#    'id rocista',
#    'ime sudije',
#    'prezime sudije',
#    'id stranke',
#    'id advokat',
#    'id stranke',
#    'naziv stranke',
#    'broj telefona stranke',
#    'email stranke',
#    'adresa stranke',
#    'mesto stanovanja stranke',
#    'id punomocja',
#    'period vazenja pun',
#    'datum potpisivanja pun',
#    'id tip pun',
#    'id stranke',
#    'id tip pun',
#    'naziv pun',
#    'id obaveze',
#    'naziv obaveze',
#    'vreme obaveze',
#    'datum obaveze',
#    'id advokata',
#    'id izlazne fakture',
#    'datum fakturisanja',
#    'iznos fakture',
#    'primalac fakture',
#    'broj racuna',
#    'id advokat']},
#  '_AhnLoDyqEeW9u4XU-cgAEg.xmi.uml': {'classes': ['users',
#    'administrator',
#    'moderator'],
# ...
#  '_g48V0Mw-EeaAf-R7dg0GCw.xmi.uml': {'classes': ['tram ticket machine',
#    'cash checker',
#    'display screen',
#    'ticket dispenser',
#    'card transaction',
#    'atm card',
#    'tram card',
#    'card scanner',
#    'tram user'],
#   'attributes': ["company's name",
#    'is currency note',
#    'is currency coins',
#    'amount',
#    'input entered',
#    'no of available ticket',
#    'card id',
#    'pin',
#    'bank card',
#    'tram card']},
#  '_bK7soLVKEee7sYPkE4-GPA.xmi.uml': {'classes': ['hero'],
#   'attributes': ['return hp();']},
#  '_wyN9EONxEeSyAtfQFgWBxA.xmi.uml': {'classes': ['as', 'asd']},
#  '4eee6bdf-ab66-4aa5-adcf-8217d11926fe.xmi.uml': {'classes': ['shopping cart',
#    'order',
#    'line item',
#    'account',
#    'customer',
#    'class'],
#   'attributes': ['creation date', 'id', 'quantity', 'price', 'id']},
#  '_52gvsJwlEDGdyoFyp4l9hw.xmi.uml': {'classes': ['sistemske operacije(so)']},
#  '_DErG4HseEeSdXJMJcKNKoQ.xmi.uml': {'classes': ['user', 'it website', 'user'],
#   'attributes': ['attribute', 'id', 'password']},
#  '_8-EMANc5Eei47sN0sCkjiA.xmi.uml': {'classes': ['l ala'],
#   'attributes': ['sd']},
#  '3c85cf04-8dba-4aee-bb97-59cb0048da7b.xmi.uml': {'classes': ['client',
#    'adaptor',
#    'adaptee']},
#  '_FzAzoMENEeeEXb8Dudo6PQ.xmi.uml': {'classes': ['avion', 'pasajero', 'silla'],
#   'attributes': ['sillas ejecutivas',
#    'sillas economicas',
#    'cedula',
#    'nombre',
#    'clase ejecutiva',
#    'clase economica',
#    'ventana',
#    'central',
#    'pasillo',
#    'numero',
#    'clase',
#    'ubicacion']},
#  '08440044-d6fd-4fe9-b4b9-485af8ec84ab.xmi.uml': {'classes': ['worker',
#    'people',
#    'customer',
#    'cook',
#    'waiter',
#    'cashier'],
#   'attributes': ['name']},
#  '_8MyUoObSEeiDGLvZhbPYyA.xmi.uml': {'classes': ['person', 'male']},
#  '_TgYHsEMgEeSyYeDoyPirvg.xmi.uml': {'classes': ['event',
#    'flight manager',
#    'flight planning',
#    'intervention planning',
#    'planning',
#    'employee manager',
#    'employee planning',
#    'report manager',
#    'report',
#    'distribution manager',
#    'marketing manager',
#    'ticket distributor manager',
#    'provider manager',
#    'flight event',
#    'plane intervention',
#    'plane revision',
#    'plane immobilization',
#    'plane fuel',
#    'cleaning service',
#    'steward',
#    'pilot',
#    'airport employee',
#    'employee',
#    'company',
#    'airport',
#    'standard flight',
#    'flight',
#    'free time flight',
#    'plane',
#    'fuel',
#    'fuel provider',
#    'consomation provider',
#    'consomation',
#    'service provider',
#    'provider',
#    'consomation stock',
#    'ticket',
#    'boarding pass',
#    'customer',
#    'ticket distributor',
#    'promotion',
#    'advertising',
#    'news',
#    'reservation',
#    'free miles',
#    'early order',
#    'employee manager view',
#    'ticket distribution view',
#    'company management view'],
#   'attributes': ['date begin',
#    'date end',
#    'title',
#    'is super user',
#    'date',
#    'category',
#    'flight',
#    'milles on intervention',
#    'plane',
#    'flight',
#    'plane',
#    'airport',
#    'plane',
#    'airport',
#    'airport',
#    'day by week',
#    'name',
#    'gender',
#    'job type',
#    'is super user',
#    'name',
#    'stewards',
#    'pilots',
#    'airport employees',
#    'city',
#    'ticket price',
#    'ticket charges',
#    'begin schedule',
#    'end schedule',
#    'surbooking percent',
#    'reservation percent',
#    'airport from',
#    'airport to',
#    '/duration',
#    'flight type',
#    'schedule',
#    '/miles',
#    'confirmation percent',
#    'row',
#    'seat per row',
#    '/seat',
#    'nb pilote',
#    'nb steward',
#    '/crew',
#    '/milles flyed',
#    '/fly since refuel',
#    '/state',
#    '/location',
#    '/milles since revisionned',
#    'date',
#    '/price',
#    'volme',
#    'plane',
#    'name',
#    'price per unit',
#    'price per unit',
#    'name',
#    'capacity',
#    'from',
#    'payment',
#    '/price',
#    'promotion',
#    'is registered',
#    'number place',
#    'price',
#    'row',
#    'seat',
#    'is validated',
#    'date of purchase',
#    'flight',
#    '/miles flyed',
#    'luggage',
#    'name',
#    'surbooking',
#    'free fly per week',
#    'from',
#    'payment',
#    '/discount',
#    'percent per flight',
#    'picture',
#    'date',
#    'text',
#    'title',
#    'discount percent',
#    'milles per milles promotion',
#    'cash per miles promotion',
#    'discount percent']},
#  '_L7BoAFTIEeSu48YT12vqpQ.xmi.uml': {'classes': ['player'],
#   'attributes': ['name', 'score', 'card container']},
#  '9e620e9c-e98c-44f2-be8d-849cc420126d.xmi.uml': {'classes': ['customer',
#    'payment',
#    'shopping cart',
#    'account',
#    'web user',
#    'order',
#    'line item',
#    'product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paid date',
#    'total',
#    'details',
#    'creation date',
#    'billing address',
#    'open',
#    'closed',
#    'is closed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'ship to',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description']},
#  '_PbRXUNuREeiJYbNjsZ3wUw.xmi.uml': {'classes': ['typeator container',
#    'default typeator',
#    'typeator factory',
#    'typeator runner']},
#  'd5320ba4-ef0b-4a62-9a28-70d63e9861f7.xmi.uml': {'classes': ['bank account',
#    'class a',
#    'class b',
#    'class c',
#    'class d',
#    'class e',
#    'class f',
#    'class g',
#    'class j',
#    'class h',
#    'class k',
#    'class m',
#    'class n',
#    'class p',
#    'class q',
#    'class r',
#    'class s',
#    'class t',
#    'class u',
#    'class v'],
#   'attributes': ['owner name',
#    'balance',
#    'public attribute',
#    'private attribute',
#    'protected attribute',
#    'package attribute',
#    'public attribute',
#    'private attribute',
#    'protected attribute',
#    'package attribute']},
#  '_zmijUKT-EeScLuNN63kNaQ.xmi.uml': {'classes': ['sensor', 'device', 'menu'],
#   'attributes': ['sensor']},
#  '_WhW-AJc2EeS67M2cXIV9Bg.xmi.uml': {'classes': ['dienblad',
#    'docent',
#    'student',
#    'kantine medewerker',
#    'persoons vergelijker',
#    'kassa rij',
#    'kantine',
#    'kassa',
#    'administratie'],
#   'attributes': ['artikelen',
#    'totaalprijs',
#    'afkorting',
#    'afdeling',
#    'studentnummer',
#    'studierichting',
#    'medewerkersnummer',
#    'mag achter kassa',
#    'kassa rij',
#    'kassa',
#    'kassarij',
#    'persoon1',
#    'dienblad1',
#    'artikel1',
#    'artikel2',
#    'kantineaanbod',
#    'rij',
#    'artikelen',
#    'geld',
#    'aantal klanten',
#    'days in week']},
#  '3dabd4fe-d23c-4cf6-bbe6-510a8a5b7722.xmi.uml': {'classes': ['client',
#    'adaptor',
#    'adaptee']},
#  '_-iZxYP76EeSpvbjLqY_W3Q.xmi.uml': {'classes': ['user'],
#   'attributes': ['user id',
#    'user type',
#    'first name',
#    'last name',
#    'employee id',
#    'date joined',
#    'role',
#    'allocation status',
#    'email',
#    'phone',
#    'office address',
#    'base branch',
#    'city',
#    'state',
#    'country',
#    'specialization',
#    'institution',
#    'years company',
#    'profile picture']},
#  '_FIzVsGTjEDGvYZ_luPE2qw.xmi.uml': {'classes': ['curso',
#    'seccion',
#    'estudiante',
#    'sistema archivos',
#    'archivo'],
#   'attributes': ['profesor', 'salon', 'hora']},
#  '_v6vVID3VEDG1DfFOPLjuGA.xmi.uml': {'classes': ['ordering system',
#    'ordering system',
#    'ordering system',
#    'list',
#    'ordering system',
#    'list'],
#   'attributes': ['cost coffee a',
#    'cost coffee b',
#    'cost coffee c',
#    'cost coffee d',
#    'cost coffee a',
#    'cost coffee b',
#    'cost coffee c',
#    'cost coffee d',
#    'cost condiment a',
#    'cost condiment b',
#    'cost condiment c',
#    'list cost coffee',
#    'list cost condiment',
#    'values',
#    'names',
#    'list cost',
#    'values',
#    'names']},
#  'e2b23b9a-8b69-4537-95d9-9a62d0468ccf.xmi.uml': {'classes': ['customer',
#    'payment',
#    'shopping cart',
#    'account',
#    'web user',
#    'order',
#    'line item',
#    'product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paid date',
#    'total',
#    'details',
#    'creation date',
#    'billing address',
#    'open',
#    'closed',
#    'is closed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'ship to',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description']},
#  'fe31c34b-968d-4bcd-a8e7-6fd9b9dfa284.xmi.uml': {'classes': ['game1',
#    'car',
#    'rock',
#    'wheel',
#    'player',
#    'score'],
#   'attributes': ['speed', 'colission']},
#  '_0FTU8KveEeiHR4AK89CXpg.xmi.uml': {'classes': ['buffer',
#    'int',
#    'productor',
#    'consumidor'],
#   'attributes': ['capacidad', 'buffer']},
#  '_K-stgPXsEei5Pecz43plcg.xmi.uml': {'classes': ['mac auto',
#    'cuenta',
#    'j frame',
#    'arithmetic exception',
#    'refresco',
#    'hamburguesa',
#    'papas',
#    'nombre',
#    'maquina',
#    'creditos',
#    'variables',
#    'maquina2',
#    'j frame'],
#   'attributes': ['creditos', 'cambio', 'total']},
#  '_VFimkNVkEeWUcZFfD54kTA.xmi.uml': {'classes': ['configuration root',
#    'sdp services',
#    'configure and activate service',
#    'sdp services methods il']},
#  '7602e9c9-601a-4f92-8c40-09e8901b162b.xmi.uml': {'classes': ['shopping cart']},
#  '_XuwfQHz2EeW4cd-qm4QbpA.xmi.uml': {'classes': ['file buffer',
#    'parent modul',
#    'work modul a',
#    'gui',
#    'visualisation'],
#   'attributes': ['original data']},
#  '_Wk5_IAdjEeeoBvzX9wJhsQ.xmi.uml': {'classes': ['super  parser',
#    'sub  parser',
#    'string []'],
#   'attributes': ['parser name',
#    'covered program',
#    'start time',
#    'end time',
#    'string',
#    'active parser',
#    'parser stack',
#    'log stack']},
#  '8a4b7913-39fb-43c6-a37e-5ae3264dc75d.xmi.uml': {'classes': ['equipo',
#    'jugador',
#    'entrenador',
#    'arbitro',
#    'partido',
#    'evento',
#    'tipo de evento',
#    'lesion',
#    'liga',
#    'clasificacion',
#    'persona',
#    'estadio'],
#   'attributes': ['cod equipo',
#    'nombre',
#    'f fundacion',
#    'ciudad',
#    'titulos',
#    'cod  entrenador',
#    'cod jugador',
#    'dorsal',
#    'posicion',
#    'altura',
#    'peso',
#    'titulos',
#    'cod equipo',
#    'cod persona',
#    'cod  entrenador',
#    'titulos',
#    'cod persona',
#    'cod  arbitro',
#    'partidos',
#    'cod persona',
#    'cod partido',
#    'fecha',
#    'hora',
#    'local',
#    'visita',
#    'gol local',
#    'gol visita',
#    'ganador',
#    'cod liga',
#    'cod partido',
#    'cod jugador',
#    'cod  tipode evento',
#    'cod  tipode evento',
#    'evento',
#    'cod jugador',
#    'fecha lesion',
#    'tiempo lesion',
#    'condicion',
#    'cod liga',
#    'nombre',
#    'num equipos',
#    'superior',
#    'inferior',
#    'cod  clasificacion',
#    'cod  equipo',
#    'posicion',
#    'jj',
#    'jp',
#    'je',
#    'jg',
#    'gf',
#    'gc',
#    'dg',
#    'puntos',
#    'cod persona',
#    'nombre',
#    'apellido',
#    'nombre corto',
#    'fecha nacimiento',
#    'nacionalidad',
#    'cod  estadio',
#    'nombre',
#    'ubicacion',
#    'capacidad',
#    'terreno',
#    'ubicacion',
#    'cod equipo']},
#  '07ebe3fa-a9ec-466e-9aab-4c84c0e06b8f.xmi.uml': {'classes': ['customer',
#    'payment',
#    'shopping cart',
#    'account',
#    'web user',
#    'order',
#    'line item',
#    'product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paid date',
#    'total',
#    'details',
#    'creation date',
#    'billing address',
#    'open',
#    'closed',
#    'is closed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'ship to',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description']},
#  '90de3c08-1e92-4c95-a8d2-6e9b6e6a3bb2.xmi.uml': {'classes': ['singleton'],
#   'attributes': ['instance']},
#  '_7o7moCfVEeiYD9TOdwevwA.xmi.uml': {'classes': ['operador',
#    'hotel',
#    'hostal',
#    'reserva',
#    'cliente',
#    'habitacion persona',
#    'apartamento alquiler',
#    'vivienda persona',
#    'vivienda universitaria',
#    'persona',
#    'miembro comunidad',
#    'empresa',
#    'habitacion hotel',
#    'habitacion',
#    'habitacion vivienda',
#    'reserva colectiva'],
#   'attributes': ['id',
#    'tipo operador',
#    'restaurante',
#    'piscina',
#    'parqueadero',
#    'wifi',
#    'tv cable',
#    'recepcion24 horas',
#    'esta deshabilitado',
#    'horario apertura',
#    'horario cierre',
#    'capacidad',
#    'precio noche',
#    'esta deshabilitado',
#    'id',
#    'fecha incio servicio',
#    'fecha reserva',
#    'dias',
#    'tipo',
#    'fecha pago',
#    'fue cancelado',
#    'id reserva colectiva',
#    'capacidad',
#    'comidas',
#    'acceso cocina',
#    'tipo baño',
#    'tipo habitacion',
#    'costo luz',
#    'costo telefono',
#    'costo tv',
#    'costo internet',
#    'costo agua',
#    'precio mes',
#    'descuento mes prepagado',
#    'precio mes',
#    'costo telefono',
#    'costo luz',
#    'costo tv',
#    'costo internet',
#    'costo agua',
#    'administracion costo',
#    'capacidad',
#    'esta deshabilitado',
#    'capacidad',
#    'numero habitaciones',
#    'ubicacion',
#    'costo dia',
#    'caracteristicas seguro',
#    'esta deshabilitado',
#    'amoblamiento basico',
#    'cocineta',
#    'internet',
#    'tv',
#    'aseo',
#    'apoyo social',
#    'apoyo acedemico',
#    'restaurante costo',
#    'salas estudio costo',
#    'salas esparcimiento',
#    'gimnasio costo',
#    'esta deshabilitado',
#    'id',
#    'tipo persona',
#    'tipo miembro',
#    'id',
#    'numer camara comercio',
#    'tipo',
#    'banera',
#    'jacuzzi',
#    'sala',
#    'cocineta',
#    'precio noche',
#    'capacidad',
#    'tipo',
#    'tipo menaje',
#    'capacidad',
#    'precio noche',
#    'precio mes',
#    'precio semestre',
#    'id',
#    'tipo',
#    'cantidad',
#    'id cliente']},
#  '_XPjZsGdzEeS3yOrtnopAkA.xmi.uml': {'classes': ['document',
#    'livre',
#    'revue',
#    'dictionnaire',
#    'roman',
#    'manuel',
#    'animal',
#    'mammifere',
#    'chien',
#    'cheval']},
#  '0d92d5b5-5707-41da-8461-a9e9de0fc0f0.xmi.uml': {'classes': ['sword',
#    'axe',
#    'enchanced weapon',
#    'fire weapon',
#    'holy weapon'],
#   'attributes': ['weapon']},
#  '_iiwTkHbaEeSfPZ7vcufCPw.xmi.uml': {'classes': ['location',
#    'zuordnung',
#    'software'],
#   'attributes': ['location id',
#    'netz id',
#    'route',
#    'raumname',
#    'betreuer',
#    'location id',
#    'software id',
#    'software id',
#    'softwarename']},
#  '_PmSUUOyDEei9dNtZPq67hQ.xmi.uml': {'classes': ['job list helper',
#    'job list helper'],
#   'attributes': ['context',
#    'm items',
#    'recycler view',
#    'context',
#    'm items',
#    'recycler view']},
#  'ca95bf9d-6107-478d-ae28-5dd662a4b3d4.xmi.uml': {'classes': ['object',
#    'component',
#    'behaviour',
#    'camera',
#    'animation',
#    'mono behaviour',
#    'network message info',
#    'bit stream',
#    'network view',
#    'network player',
#    'network view id',
#    'transform',
#    'rigidbody'],
#   'attributes': ['name',
#    'tag',
#    'enabled',
#    'network view',
#    'sender',
#    'timestamp',
#    'group',
#    'is mine',
#    'observed',
#    'position',
#    'rotation',
#    'eular angles',
#    'local to world matrix',
#    'world to local matrix',
#    'root',
#    'parent',
#    'position',
#    'rotation',
#    'velocity',
#    'angular velocity',
#    'mass',
#    'inertia tensor',
#    'collision detection mode',
#    'is kinematic',
#    'interpolation']},
#  '_816IMIJkEemGPZyN8msRcg.xmi.uml': {'classes': ['dim cocinera',
#    'localización',
#    'fact entrega',
#    'dim cliente',
#    'dim domiciliario',
#    'bridge cambio',
#    'bridge adicion',
#    'dim ingrediente',
#    'dim tiempo',
#    'dim fecha',
#    'bridge ingredientes'],
#   'attributes': ['id',
#    'cedula',
#    'nombre',
#    'fecha nacimiento',
#    'cantidad almuerzos',
#    'salario',
#    'direccion residencia',
#    'valido desde',
#    'valido hasta',
#    'actual',
#    'id',
#    'direccion',
#    'localidad',
#    'barrio',
#    'ciudad',
#    'departamento',
#    'id entrega',
#    'costo',
#    'satisfaccion',
#    'tiempo entrega',
#    'calificacion ingrediente mas gusto',
#    'calificacion ingrediente menos gusto',
#    'cliente',
#    'domiciliario',
#    'cocinera',
#    'fecha',
#    'hora solicitada',
#    'hora entrega',
#    'direccion entrega',
#    'ingrediente mas gusto',
#    'ingrediente menos gusto',
#    'id',
#    'cedula',
#    'nombre',
#    'direccion',
#    'id',
#    'cedula',
#    'nombre',
#    'fk entrega',
#    'fk ingrediente quitado',
#    'fk ingrediente nuevo',
#    'calificacion',
#    'fk entrega',
#    'fk ingrediente',
#    'calificacion',
#    'id',
#    'nombre',
#    'categoría',
#    'id',
#    'hora',
#    'minuto',
#    'momento dia',
#    'id',
#    'dia',
#    'mes',
#    'año',
#    'fk entrega',
#    'fk ingrediente',
#    'calificacion']},
#  ...}

# %%
PRETRAINED_MODEL_PATH = 'data/lid.176.bin'

model = fasttext.load_model(PRETRAINED_MODEL_PATH)
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
# Approximate the language from the extracted classes and attributes
def get_file_language(metadata):
    # Combine all classes and attributes into one array
    all_metadata = sum(metadata.values(), [])
    
    # Detect language for each word
    predictions = model.predict(all_metadata)
    
    # Specific approach for longer texts due to issue with habit of using English in programming
    def get_field_level_prediction(string):
        # Split into single words to detect on word level
        words = string.split(' ')
        
        # Get single-word predictions
        string_predictions = np.array(model.predict(words))
        
        # Return the appropriate language
        if len(string_predictions) == 1:
            return string_predictions[0][0][0]
        else:
            # Option 1: all identical language identification
            if len(np.unique(string_predictions[0])) == 1:
                return string_predictions[0][0][0]
            
            # Option 2: combination of an English programmatic word with another language, e.g. "hovedmenu view"
            elif len(string_predictions) == 2 and any('__label__en' in label for label in string_predictions):
                return [x for x in map(lambda x: x[0], string_predictions[0]) if x != '__label__en'][0]
            
            # Option 3: majority vote
            else:
                return Counter(map(lambda x: x[0], string_predictions[0])).most_common(1)[0][0]
        
    # Apply to all fields, identify language for all classes and attributes
    predictions = list(map(lambda x: get_field_level_prediction(x), all_metadata))

    # Get the most common language from all attributes
    return Counter(predictions).most_common(1)[0][0]

# %%
labeled_cleaned_data = {
    key: {**value, **{'lang': get_file_language(value)}}
    for key, value in tqdm(cleaned_data.items())
}
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=186573.0), HTML(value='')))

# %%
labeled_cleaned_data
# Out:
# {'5fae885c-3fde-430f-a3c5-ff44b81f2668.xmi.uml': {'classes': ['class a',
#    'class b',
#    'class c',
#    'class d',
#    'class e',
#    'class f',
#    'class g',
#    'class h',
#    'class i'],
#   'lang': '__label__en'},
#  '_oVCEUIHiEeeveJPbhFhy-g.xmi.uml': {'classes': ['site page', 'site section'],
#   'attributes': ['id',
#    'status',
#    'name',
#    'url',
#    'id',
#    'locked',
#    'name',
#    'default page'],
#   'lang': '__label__en'},
#  '20b51f77-a952-4206-b35c-b47acd0c631f.xmi.uml': {'classes': ['moteur impl',
#    'buffer',
#    'selection',
#    'presse papier'],
#   'attributes': ['texte', 'sel', 'attribute'],
#   'lang': '__label__fr'},
#  'e8a7e84d-73b3-40d2-ac78-f550566b4de8.xmi.uml': {'classes': ['client',
#    'adapter impl',
#    'adaptee',
#    'context',
#    'state a',
#    'state b',
#    'singleton',
#    'abstraction',
#    'refined abstraction',
#    'concrete implementor',
#    'creator impl',
#    'product',
#    'concrete observer',
#    'concrete subject'],
#   'attributes': ['instance'],
#   'lang': '__label__en'},
#  '_oWwJoHfLEeqeQcxm9hmzHw.xmi.uml': {'classes': ['shopping cart',
#    'order',
#    'line item',
#    'account',
#    'customer'],
#   'attributes': ['creation date', 'id', 'quantity', 'price', 'id'],
#   'lang': '__label__en'},
#  '_wWY9wDZWEeewJqDqgRk6VA.xmi.uml': {'classes': ['bilal'],
#   'lang': '__label__cy'},
#  '_OR8QgFq_EeeTF9GWmq2Xvg.xmi.uml': {'classes': ['exam',
#    'question',
#    'lead exam',
#    'school',
#    'lead report',
#    'lead school',
#    'class'],
#   'attributes': ['id',
#    'name',
#    'response columns',
#    'description',
#    'id',
#    'text',
#    'video unit',
#    'unit title',
#    'video chapter',
#    'subject',
#    'id',
#    'lead name',
#    'lead phone',
#    'lead last name',
#    'group',
#    'school',
#    'result',
#    'exam',
#    'application date',
#    'id',
#    'identifier',
#    'kind',
#    'maximum score',
#    'minimum score',
#    'name',
#    'city',
#    'state',
#    'country',
#    'id',
#    'school',
#    'exam',
#    'lead exam',
#    'lead name',
#    'school name',
#    'school group',
#    'rank',
#    'version',
#    'correct answers',
#    'subject diagnostic',
#    'study plan',
#    'id',
#    'lead reports',
#    'school name',
#    'school average',
#    'group diagnostic',
#    'area diagnostic',
#    'version'],
#   'lang': '__label__en'},
#  '331af011-1b93-4a9b-abb7-f53d3cfb2a88.xmi.uml': {'classes': ['client',
#    'adaptor',
#    'adaptee'],
#   'lang': '__label__en'},
#  '9f510af6-1690-4d09-b973-5069cf83647a.xmi.uml': {'classes': ['system',
#    'sensor',
#    'motion sensor',
#    'pressure sensor',
#    'home security system',
#    'alert',
#    'door',
#    'camera',
#    'speakers',
#    'micro phone',
#    'light',
#    'start of day',
#    'end of day',
#    'tv',
#    'home theatre',
#    'house holds',
#    'entertainment'],
#   'attributes': ['status',
#    'update',
#    'sensor id',
#    'sensor type',
#    'user id',
#    'alert id',
#    'door id',
#    'camera id',
#    'speaker id',
#    'mic id',
#    'light id',
#    'sot',
#    'eot',
#    'tvid',
#    'htid',
#    'time id',
#    'coffee',
#    'dish washer',
#    'alarm',
#    'washing machine',
#    'device id'],
#   'lang': '__label__en'},
#  '_3tGxoCVhEeiYD9TOdwevwA.xmi.uml': {'classes': ['collaborateur',
#    'pronostique',
#    'poule',
#    'competition',
#    'match',
#    'equipe'],
#   'attributes': ['id collaborateur',
#    'nom',
#    'prenom',
#    'email',
#    'password',
#    'role',
#    'id collaborateur',
#    'id match',
#    'score domicile',
#    'score exterieur',
#    'id poule',
#    'competition',
#    'libele',
#    'id competition',
#    'libele',
#    'nombre poules',
#    'id match',
#    'poule',
#    'date',
#    'equipe domicile',
#    'equipe exterieur',
#    'score domicile',
#    'score exterieur',
#    'id equipe',
#    'logo'],
#   'lang': '__label__fr'},
#  '_CFTYQLf4Eee7sYPkE4-GPA.xmi.uml': {'classes': ['my class'],
#   'lang': '__label__en'},
#  '_AkJqwL2EEeirD7wkg7WdAw.xmi.uml': {'classes': ['customer', 'user'],
#   'attributes': ['csname',
#    'cs phon no.',
#    'address',
#    'credit cardinfo',
#    'email',
#    'user id',
#    'password',
#    'login status'],
#   'lang': '__label__en'},
#  '_B4ZY0F8QEeepGY91r9Nuow.xmi.uml': {'classes': ['vente',
#    'promotion',
#    'magasin',
#    'article',
#    'periode'],
#   'attributes': ['id magasin',
#    'id client',
#    'id periode',
#    'id article',
#    'id promotion',
#    'montant vente',
#    'taxe',
#    'unités vendes',
#    'numero ticket caisse',
#    'id promotion',
#    'nom promotion',
#    'taux remise',
#    'id magasin',
#    'nom magasin',
#    'adresse magasin',
#    'nom gérant',
#    'département',
#    'id article',
#    'nom article',
#    'marque article',
#    'attribute',
#    'id periode',
#    'année',
#    'mois',
#    'jour'],
#   'lang': '__label__fr'},
#  '_xoz1gHe2EeiFX4HwoivBqg.xmi.uml': {'classes': ['batisseur',
#    'case',
#    'domino',
#    'ihm kingdomino',
#    'ihm santorini',
#    'index',
#    'king domino',
#    'pioche domino',
#    'plateau',
#    'santorini'],
#   'attributes': ['pos x',
#    'pos y',
#    'hauteur',
#    'nom',
#    'nb couronnes',
#    'numero',
#    'roi',
#    'p principal',
#    'grille1',
#    'grille2',
#    'p domino',
#    'p bas droite',
#    'p bouton',
#    'p direction',
#    'ens dominos',
#    'ens boutons gauche',
#    'ens boutons droite',
#    'ens dominos1',
#    'bouton nord',
#    'bouton sud',
#    'bouton est',
#    'bouton ouest',
#    'retour',
#    'regles',
#    'quitter',
#    'action',
#    'ligne',
#    'colonne',
#    'nb tours',
#    'ordre',
#    'principal',
#    'vision jeu',
#    'button jeu',
#    'panel droite',
#    'panel logo',
#    'retour',
#    'regle',
#    'quitter',
#    'bouton',
#    'action',
#    'conteur bati',
#    'choix bati',
#    'tour joueur',
#    'temp pos x',
#    'temp pos y',
#    'pos x',
#    'pos y',
#    'temp etage',
#    'ens bati',
#    'principal',
#    'santorini',
#    'regle santorini',
#    'king domino',
#    'all rois',
#    'nb rois',
#    'nb joueurs',
#    'nb dominos',
#    'player',
#    'royaume joueur1',
#    'royaume joueur2',
#    'plateau',
#    'ens bati',
#    'conteur bati',
#    'joueur1',
#    'joueur2'],
#   'lang': '__label__fr'},
#  '_C3TewPaFEeWolbMxsR5EUQ.xmi.uml': {'classes': ['file'],
#   'attributes': ['file server', 'file local'],
#   'lang': '__label__en'},
#  '_2Jq9QK0KEDGNWLI2ml8Hng.xmi.uml': {'classes': ['lab3',
#    'server connection',
#    'gameboard',
#    'j frame',
#    'j panel',
#    'server'],
#   'lang': '__label__en'},
#  '_GbX-wK10EemHYc7DDM2g2A.xmi.uml': {'classes': ['animal',
#    'employee',
#    'tortoise',
#    'otter',
#    'slow loris',
#    'sea urchin',
#    'creep',
#    'lobby',
#    'bathroom',
#    'visitor center'],
#   'attributes': ['name',
#    'id',
#    'age',
#    'weight',
#    'name',
#    'employee id',
#    'phone',
#    'department',
#    'whisker length'],
#   'lang': '__label__en'},
#  '_WZQeEMJ8EeSII650IQ0Z1w.xmi.uml': {'classes': ['report settings<t>',
#    'report settings accessor',
#    'report data manager<t>',
#    'report accessor<t>',
#    'report<t>',
#    'aaaa'],
#   'lang': '__label__en'},
#  '_rGklUKQCEeWJIdgJ_zFBoQ.xmi.uml': {'classes': ['entreprise',
#    'produit',
#    'my class'],
#   'attributes': ['nom', 'nom prod', 'num'],
#   'lang': '__label__fr'},
#  '_n6vpQN9FEea4oJwuIIj5Zg.xmi.uml': {'classes': ['golpes', 'tipo'],
#   'attributes': ['codigo', 'nome', 'tipo', 'categoria', 'codigo', 'nome'],
#   'lang': '__label__es'},
#  '_UBfU4MCnEeeEXb8Dudo6PQ.xmi.uml': {'classes': ['clone detection new ui',
#    'ddg right dialog',
#    'ddg bottom dialog',
#    'history spread sheet source',
#    'spread sheet object tree view',
#    'tree view spread sheet source',
#    'spread sheet object list view',
#    'list view spread sheet source',
#    'history spread sheet obj',
#    'similarity plot spread sheet obj',
#    'similarity plot spred sheet source'],
#   'lang': '__label__en'},
#  '_TCwTALi_Eeaud6jyFEReOw.xmi.uml': {'classes': ['casino',
#    'admin',
#    'game',
#    'table',
#    'player',
#    'gametype',
#    'rule'],
#   'attributes': ['id',
#    'name',
#    'id',
#    'password',
#    'starttime',
#    'number',
#    'connectedplrs',
#    'id',
#    'password',
#    'balance',
#    'game',
#    'maxplayer',
#    'id',
#    'desc'],
#   'lang': '__label__en'},
#  '_Eta50N0oEeS1iL_C3WP8Cw.xmi.uml': {'classes': ['tbl users', 'tbl order'],
#   'attributes': ['user id',
#    'user name',
#    'password',
#    'full name',
#    'role',
#    'vip',
#    'status',
#    'order id',
#    'user name',
#    'password',
#    'full name',
#    'role',
#    'vip',
#    'status'],
#   'lang': '__label__fa'},
#  '_YlTgsCASEeiv8MB6k6XBAg.xmi.uml': {'classes': ['my frame',
#    'control panel',
#    'drawing panel',
#    'rect',
#    'class',
#    'graphics',
#    'drawing panel',
#    'shape',
#    'circle',
#    'rect',
#    'drawing panel',
#    'circle',
#    'rect',
#    'circle',
#    'drawing panel',
#    'rect',
#    'drawing panel',
#    'shape',
#    'circle',
#    'dog',
#    'test',
#    'id generator',
#    'cat',
#    'rect',
#    'can be drawn',
#    'poly gen',
#    'slacker'],
#   'attributes': ['name', 'id', 'current id', 'id', 'name'],
#   'lang': '__label__en'},
#  '_O9PI8GyeEDGXH9FO528ZpA.xmi.uml': {'classes': ['dvd',
#    'book',
#    'library  managnment  system',
#    'item',
#    'staff',
#    'libarian',
#    'member',
#    'clerk'],
#   'attributes': ['type',
#    'count1',
#    'type',
#    'count',
#    'item linker',
#    'mem',
#    'cler',
#    'availability',
#    'issued',
#    'onloan',
#    'reference',
#    'name',
#    'id',
#    'name',
#    'id'],
#   'lang': '__label__en'},
#  '93552bd2-6e15-45b3-b1dd-3a4aa6b3b0b3.xmi.uml': {'classes': ['chat server',
#    'chat client',
#    'couleur',
#    'history',
#    'user',
#    'session',
#    'j frame'],
#   'lang': '__label__en'},
#  '_UWr2cM_JEeeLcIicqHdTUQ.xmi.uml': {'classes': ['currency converter',
#    'us currency converter',
#    'canadian currency converter',
#    'task controller',
#    'sales order',
#    'my class',
#    'calc tax'],
#   'lang': '__label__en'},
#  '_tGyV0EbLEeeTJ_4Vl2J2rQ.xmi.uml': {'classes': ['example instrumented test',
#    'fight screen',
#    'start menu',
#    'about fragment',
#    'custom health bar',
#    'custom mana bar',
#    'custom menu button',
#    'custom menu play button',
#    'logo fragment',
#    'settings fragment',
#    'game',
#    'game panel',
#    'main thread',
#    'singleton',
#    'bitmap cache',
#    'character',
#    'dummy',
#    'enemy',
#    'exit',
#    'game object',
#    'ground',
#    'player',
#    'wall',
#    'level',
#    'section',
#    'example unit test'],
#   'attributes': ['player health text',
#    'enemy health text',
#    'player mana text',
#    'player action text',
#    'enemy action text',
#    'player image',
#    'enemy image',
#    'health potion button',
#    'mana potion button',
#    'attack button',
#    'special attack button',
#    'max volume',
#    'media player',
#    'volume for player',
#    'health',
#    'max health',
#    'black paint',
#    'red paint',
#    'mana',
#    'max mana',
#    'black paint',
#    'blue paint',
#    'width',
#    'height',
#    'horizontal tiles',
#    'vertical tiles',
#    'tile width',
#    'tile height',
#    'paint',
#    'fps',
#    'average fps',
#    'surface holder',
#    'running',
#    'canvas',
#    'context',
#    'cache',
#    'name',
#    'health',
#    'max health',
#    'attack',
#    'health',
#    'attack',
#    'max health',
#    'special atack',
#    'max mana',
#    'mana',
#    'name',
#    'amount of health potions',
#    'amount of mana potions',
#    'to section',
#    'solid',
#    'image',
#    'image ref',
#    'amount of health potions',
#    'amount of mana potions',
#    'mana',
#    'max mana',
#    'special attack'],
#   'lang': '__label__en'},
#  '_rRbrsL2FEeedTfUoC-GfaA.xmi.uml': {'classes': ['snake'],
#   'attributes': ['attribute'],
#   'lang': '__label__en'},
#  '_r3GXcCFEEeiv8MB6k6XBAg.xmi.uml': {'classes': ['utilisateur',
#    'profil',
#    'système',
#    'base de données',
#    'serveur'],
#   'attributes': ['profil', 'nom', 'âge', 'mot de passe', 'genre'],
#   'lang': '__label__fr'},
#  '_UvEXMEGiEemokbRu9Ld3Pw.xmi.uml': {'classes': ['individu',
#    'film',
#    'cinéma',
#    'séance',
#    'individu',
#    'groupe',
#    'contacts',
#    'individu2',
#    'film2',
#    'cinéma2',
#    'séance2',
#    'groupe',
#    'contact'],
#   'attributes': ['nom',
#    'age',
#    'nom',
#    'nom',
#    'ville',
#    'date',
#    'heure',
#    'nom',
#    'age',
#    'nom',
#    'nom',
#    'ville',
#    'date',
#    'heure'],
#   'lang': '__label__fr'},
#  '_0se6kFNjEeS7SK6lkmJgjw.xmi.uml': {'classes': ['$.insm region view',
#    '$.insm base',
#    '$.insm rest service',
#    '$.insm asset loader indicator',
#    'insm region event constant',
#    '$.insm play list grid',
#    'insm play list grid event constant',
#    '$.insm play list manager',
#    'insm play list manager event constant',
#    'object',
#    '$.insm play list editor',
#    '$.insm add new popup'],
#   'attributes': ['current selected nodes',
#    'tag',
#    '$.deffer',
#    'region datacollection',
#    'play list items',
#    'add on teamplate collection',
#    'onchecknode',
#    'onclicknode',
#    'current selected row',
#    'onremoveitem',
#    'onedititem',
#    'searchregion',
#    'clearrelation',
#    'removeselection',
#    'searchplaylist',
#    'getdata',
#    'current media type',
#    'settings'],
#   'lang': '__label__en'},
#  '48ecca9d-91d4-44f2-a21f-b0285228d504.xmi.uml': {'classes': ['jsdf',
#    'class name',
#    'my class'],
#   'attributes': ['dfsd'],
#   'lang': '__label__en'},
#  '45467683-bfda-4a59-aee6-262b47b819db.xmi.uml': {'classes': ['level',
#    'category'],
#   'attributes': ['state', 'name', 'id', 'level'],
#   'lang': '__label__en'},
#  '_qlo-cJalEeaLdJY0NVKqzQ.xmi.uml': {'classes': ['user'],
#   'lang': '__label__en'},
#  '_bTMxUGfCEDGY580vxrGduA.xmi.uml': {'classes': ['my class'],
#   'lang': '__label__en'},
#  '_IjzBoFWBEemYjay6yoFVQw.xmi.uml': {'classes': ['prodavac',
#    'nabavka',
#    'dobavljač',
#    'račun',
#    'proizvod',
#    'vrsta proizvoda',
#    'kupac',
#    'plaćanje u gotovini',
#    'plaćanje',
#    'plaćanje sa karticom',
#    'plaćanje karticom',
#    'plaćanje u gotovini'],
#   'attributes': ['prodavac id',
#    'ime',
#    'prezime',
#    'e-mail',
#    'kontakt telefon',
#    'napomena',
#    'nabavka id',
#    'datum',
#    'kolicina',
#    'iznos',
#    'vreme',
#    'napomena',
#    'prodavac id',
#    'dobavljac id',
#    'proizvod id',
#    'dobavljac id',
#    'naziv',
#    'maticni broj',
#    'kontakt telefon',
#    'adresa',
#    'mesto',
#    'napomena',
#    'racun id',
#    'datum',
#    'vreme',
#    'kolicina',
#    'iznos',
#    'prodavac id',
#    'napomena',
#    'plaćanje id',
#    'proizvod id',
#    'naziv',
#    'napomena',
#    'dobavljac id',
#    'vrsta proizvoda id',
#    'nabavka id',
#    'iznos',
#    'napomena',
#    'prodavac id',
#    'ime',
#    'prezime',
#    'e-mail',
#    'kontakt telefon',
#    'napomena',
#    'prodavac id',
#    'ime',
#    'prezime',
#    'e-mail',
#    'kontakt telefon',
#    'napomena',
#    'proizvod id',
#    'račun id',
#    'prodavac id',
#    'ime',
#    'prezime',
#    'kontakt telefon',
#    'proizvod id',
#    'račun id',
#    'proizvod id',
#    'račun id'],
#   'lang': '__label__hr'},
#  '_kUTfkMkMEeeM1PgT03-3Vg.xmi.uml': {'classes': ['login tbl',
#    'add news tbl',
#    'feedback tbl',
#    'employee tbl',
#    'registration tbl'],
#   'attributes': ['user name',
#    'password',
#    'id',
#    'news  image',
#    'news  description',
#    'bookmark',
#    'id',
#    'feedback',
#    'id',
#    'mail address',
#    'user name',
#    'password',
#    'city',
#    'dob',
#    'gender'],
#   'lang': '__label__en'},
#  '_89yH0D-DEeWH0sFqYQQ8Cg.xmi.uml': {'classes': ['server'],
#   'attributes': ['var1'],
#   'lang': '__label__en'},
#  '_Mx7t0OmWEeaowdqlt8Dqsg.xmi.uml': {'classes': ['déplacement',
#    'etape',
#    'station',
#    'station extrémité',
#    'station noeud'],
#   'attributes': ['id container',
#    'date',
#    'heure départ',
#    'heure arrivée',
#    'priorité',
#    'num etape',
#    'heure arrivée',
#    'heure départ',
#    'id station',
#    'nom',
#    'localisation',
#    'taille zone de groupage',
#    'occupée'],
#   'lang': '__label__fr'},
#  '_m43vEEhOEemB7r6RYSs12w.xmi.uml': {'classes': ['ads', 'event', 'product'],
#   'lang': '__label__en'},
#  '_pBW_QHLCEee5HMQDnOR-kg.xmi.uml': {'classes': ['crew',
#    'crew pilot',
#    'plane',
#    'schedule'],
#   'attributes': ['crew id',
#    'crew name',
#    'crew address',
#    'crew phone',
#    'pilot license',
#    'plane id',
#    'schedule time',
#    'schedule plane',
#    'schedule crew',
#    'schedule departure',
#    'schedule note',
#    'schedule arrival'],
#   'lang': '__label__en'},
#  '_7Qd5sHVJEeSZWo9AFr5YZg.xmi.uml': {'classes': ['benchmark- controller',
#    'load driver',
#    'database',
#    'transaktions',
#    'remote',
#    'init database'],
#   'lang': '__label__en'},
#  '4465670b-b7f1-4505-8c09-e163b6a629a7.xmi.uml': {'classes': ['shopping cart'],
#   'lang': '__label__en'},
#  'b66a0071-5321-4795-a59c-96ff8cc34f37.xmi.uml': {'classes': ['worker',
#    'people',
#    'customer',
#    'cook',
#    'waiter',
#    'cashier'],
#   'attributes': ['name'],
#   'lang': '__label__en'},
#  '42797400-89dc-4192-8cac-7f67e4e4fbc3.xmi.uml': {'classes': ['registration'],
#   'attributes': ['attribute'],
#   'lang': '__label__en'},
#  '19cf5401-6e76-4e4d-81d8-309f156151f5.xmi.uml': {'classes': ['session repository filter',
#    'expiring session http session',
#    'multi http session strategy adapter',
#    'header http session strategy',
#    'expiring session'],
#   'lang': '__label__en'},
#  '_GhGBELsKEeWdWJbDFmNa8w.xmi.uml': {'classes': ['conta', 'ganho', 'pessoa'],
#   'attributes': ['numero',
#    'nome',
#    'valor',
#    'situacao',
#    'id',
#    'nome',
#    'valor',
#    'situacao',
#    'id'],
#   'lang': '__label__es'},
#  '_zeUN8FJjEeeTnI9B59buBQ.xmi.uml': {'classes': ['admin home activity',
#    'background material activity',
#    'category activity',
#    'edit domains activity',
#    'leaderboard activity',
#    'password reset activity',
#    'performance activity',
#    'quiz activity',
#    'remove user activity',
#    'domain adapter',
#    'leaderboard adapter',
#    'question adapter',
#    'user adapter',
#    'answer',
#    'category content',
#    'material',
#    'question',
#    'question item',
#    'score',
#    'user',
#    'user score',
#    'login fragment',
#    'password recovery fragment',
#    'password reset fragment',
#    'quiz result dialog fragment',
#    'register fragment',
#    'constants',
#    'string utils',
#    'array adapter< string>',
#    'array adapter< question item>',
#    'array adapter< user>'],
#   'attributes': ['m auth',
#    'm auth state listener',
#    'm leaderboard btn',
#    'm edit domains btn',
#    'm add user btn',
#    'm remove user btn',
#    'm logout btn',
#    'm category',
#    'm category text view',
#    'm start quiz btn',
#    'm background text',
#    'm database',
#    'm category list',
#    'm progress dialog',
#    'm list view',
#    'm btn container',
#    'add domain btn',
#    'save domain btn',
#    'm database',
#    'm domains',
#    'm keys',
#    'm domain',
#    'm position',
#    'm edit mode',
#    'm database',
#    'm progress dialog',
#    'tab layout',
#    'm view pager',
#    'm auth',
#    'user',
#    'm current password view',
#    'm new password view',
#    'm new password2 view',
#    'm change password button',
#    'm cancel button',
#    'm reset progress view',
#    'm password reset form view',
#    'cancel',
#    'focus view',
#    'm quizzes text view',
#    'm score text view',
#    'm current rank text view',
#    'm best rank text view',
#    'm progress dialog',
#    'm database',
#    'm category',
#    'm database',
#    'm quiz score',
#    'is review mode',
#    'm question list view',
#    'm category text view',
#    'm view pager',
#    'm result text view',
#    'm list view',
#    'm database',
#    'm user key list',
#    'm auth',
#    'm domains',
#    'm context',
#    'm editable list',
#    'm editable btn list',
#    'm edited domain name',
#    'm activity',
#    'm context',
#    'm questions',
#    'm layout id',
#    'is review',
#    'm text view',
#    'm activity',
#    'text',
#    'is correct',
#    'img',
#    'is selected',
#    'questions',
#    'text',
#    'imgs',
#    'text',
#    'img',
#    'answers',
#    'is answered',
#    'number',
#    'is selected',
#    'is correct',
#    'is attempted',
#    'correct',
#    'quizzes',
#    'best rank',
#    'current rank',
#    'percentage',
#    'first name',
#    'last name',
#    'email',
#    'password',
#    'is admin',
#    'm email view',
#    'm password view',
#    'm progress view',
#    'm login form view',
#    'm email edit text',
#    'm url',
#    'arg param url',
#    'm web view',
#    'm progress dialog',
#    'm quiz result text view',
#    'm email view',
#    'm password view',
#    'm password view2',
#    'm first name',
#    'm last name',
#    'm progress view',
#    'm register form view',
#    'm register button',
#    'arg param1',
#    'arg param2',
#    'm param1',
#    'm param2',
#    'm database',
#    'domain ref',
#    'm domains',
#    'category name',
#    'num questions per quiz',
#    'question prefix',
#    'color question selected',
#    'color question correct',
#    'color question incorrect',
#    'db questions',
#    'db scores',
#    'db scores updated',
#    'db users',
#    'db domains',
#    'host'],
#   'lang': '__label__en'},
#  '_8y0sAIKDEeeveJPbhFhy-g.xmi.uml': {'classes': ['student registration',
#    'teachers registration',
#    'my class'],
#   'lang': '__label__en'},
#  '_YRK-gLc7EeWh17zD5SB95Q.xmi.uml': {'classes': ['request',
#    'status',
#    'department',
#    'application user',
#    'request event',
#    'request event detail'],
#   'attributes': ['id',
#    'topic',
#    'status',
#    'department',
#    'citizen',
#    'assignee',
#    'events',
#    'id',
#    'comment',
#    'date',
#    'attribute',
#    'is public',
#    'author',
#    'details',
#    'id',
#    'text'],
#   'lang': '__label__en'},
#  '_0fYbULfaEee7sYPkE4-GPA.xmi.uml': {'classes': ['library',
#    'librarian',
#    'books database',
#    'student',
#    'vendor',
#    'student record'],
#   'attributes': ['location',
#    'name',
#    'book title',
#    'author',
#    'book id',
#    'details',
#    'book details',
#    'attribute',
#    'name',
#    'address',
#    'phone number',
#    'fines'],
#   'lang': '__label__en'},
#  '_P5FiwC-mEeme-prEJQaJbA.xmi.uml': {'classes': ['ebook',
#    'configuracoes',
#    'decodificador',
#    'celula braille'],
#   'lang': '__label__es'},
#  '_VTRjAHomEeSdXJMJcKNKoQ.xmi.uml': {'classes': ['personal',
#    'användare',
#    'elev',
#    'lågstadiet',
#    'mellanstad',
#    'my class'],
#   'attributes': ['namn',
#    'behörighet',
#    'id',
#    'yrkesroll',
#    'namn',
#    'behörighet',
#    'id',
#    'namn',
#    'behörighet',
#    'id',
#    'attribute'],
#   'lang': '__label__sv'},
#  '_Vfe9wHL5EeSxHp9pHOThjg.xmi.uml': {'classes': ['trader'],
#   'lang': '__label__en'},
#  'a093a6c4-4491-4b65-b79a-19be1bd57765.xmi.uml': {'classes': ['customer',
#    'payment',
#    'shopping cart',
#    'account',
#    'web user',
#    'order',
#    'line item',
#    'product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paid date',
#    'total',
#    'details',
#    'creation date',
#    'billing address',
#    'open',
#    'closed',
#    'is closed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'ship to',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description'],
#   'lang': '__label__en'},
#  '_NpOgoK7zEee6S77dw3LIvQ.xmi.uml': {'classes': ['app partido basketball',
#    'equipo',
#    'partido basketball',
#    'jugador'],
#   'attributes': ['nombre',
#    'ciudad',
#    'titulo: string',
#    'dia: byte',
#    'nombre',
#    'apellido',
#    'estatura'],
#   'lang': '__label__es'},
#  '_2A0eUK99EealN5YbbDMqoA.xmi.uml': {'classes': ['modification',
#    'degree modifacion',
#    'module modification',
#    'obsever',
#    'observable',
#    'modify degree',
#    'delete degree',
#    'modify module',
#    'delete module'],
#   'attributes': ['mod id',
#    'status',
#    'title',
#    'degree code',
#    'level',
#    'module code',
#    'level',
#    'update',
#    'add observer(observer: observer',
#    'remove observer(observer: observer',
#    'notify all'],
#   'lang': '__label__en'},
#  '_fRRYMELoEeavkcsFwndrbA.xmi.uml': {'classes': ['animal'],
#   'attributes': ['name', 'size', 'color'],
#   'lang': '__label__en'},
#  '_xOaacKYVEeaiBJ7PH1W80g.xmi.uml': {'classes': ['personel',
#    'ticket',
#    'yetkilendirme'],
#   'attributes': ['personel id',
#    'personeli̇sim',
#    'personel mevki',
#    'personel bolum',
#    'ticket id',
#    'ticket tarih',
#    'ticket detay',
#    'personel id',
#    'ticket durum',
#    'sorun cesidi',
#    'cozum',
#    'ticket id',
#    'personel id'],
#   'lang': '__label__it'},
#  '_bunGYGkdEeSmTqqtE6wM_Q.xmi.uml': {'classes': ['guest',
#    'user',
#    'player',
#    'moderator',
#    'email server',
#    'database',
#    'android application instance',
#    'clarification request',
#    'game',
#    'mission',
#    'kill',
#    'geo fence',
#    'geo point',
#    'page',
#    'global update',
#    'dynamic game map'],
#   'attributes': ['role id',
#    'hvzid',
#    'email',
#    'password',
#    'first name',
#    'last name',
#    'kills',
#    'created at',
#    'played games',
#    'paid dues',
#    'is subscribed',
#    'phone number',
#    'player type',
#    'in game',
#    'gps tracking on',
#    'name',
#    'ip',
#    'subscribed emails',
#    'username',
#    'password',
#    'emails to send',
#    'name',
#    'ip',
#    'username',
#    'password',
#    'instance id',
#    'user logged in',
#    'device name',
#    'latitude',
#    'longitude',
#    'time of gps',
#    'is tracking',
#    'mission id',
#    'is answered',
#    'response user',
#    'source user',
#    'message',
#    'response',
#    'game id',
#    'missions',
#    'description',
#    'players',
#    'is current',
#    'mission id',
#    'game id',
#    'geo fences',
#    'geo points',
#    'description',
#    'role id',
#    'vicitm user',
#    'killer user',
#    'time of death',
#    'in game id',
#    'center latitude',
#    'center longitude',
#    'radius',
#    'trigger players',
#    'score',
#    'score modifier',
#    'end score',
#    'description',
#    'in mission id',
#    'trigger rate',
#    'seen by players',
#    'is visible',
#    'latitude',
#    'longitude',
#    'description',
#    'in mission id',
#    'seen by players',
#    'is visible',
#    'url',
#    'information',
#    'title',
#    'message',
#    'source user',
#    'push notification sent',
#    'email notification sent',
#    'mission'],
#   'lang': '__label__en'},
#  'dc7ae9ed-7cf7-4298-844e-489bbc9faeea.xmi.uml': {'classes': ['shopping cart'],
#   'lang': '__label__en'},
#  '_zkx8wOKPEeiZY7VjYQykuQ.xmi.uml': {'classes': ['control',
#    'super bk compare',
#    'bk compare write to excel',
#    'bk compare write to text',
#    'super bk reader',
#    'bk writer'],
#   'lang': '__label__nl'},
#  '_SaUicIB4Eei-m5BAOg12zA.xmi.uml': {'classes': ['character',
#    'saving throw',
#    'weapon'],
#   'attributes': ['name',
#    'race',
#    'vocation',
#    'is player',
#    'str',
#    'dex',
#    'cons',
#    'intel',
#    'wis',
#    'chr',
#    'save throw',
#    'hp',
#    'hit dice',
#    'equipped',
#    'is proficient',
#    'prof bonus',
#    'name',
#    'range',
#    'damage',
#    'atk bonus'],
#   'lang': '__label__en'},
#  '_Sefo0H_cEDGdNIjA6xbcew.xmi.uml': {'classes': ['ui text view',
#    'ui image picker controller',
#    'ui text field',
#    'ui alert view',
#    'ui image view',
#    'ui view',
#    'ui control',
#    'button',
#    'ui activity indicator view',
#    'perform encript',
#    'stago custom view',
#    'stago display updater',
#    'perform decrypt',
#    'staganography manager'],
#   'lang': '__label__jbo'},
#  '_34klgCFXEeqqcaoAsxFIeg.xmi.uml': {'classes': ['book',
#    'reader',
#    'librarian',
#    'borrowing',
#    'user'],
#   'attributes': ['id',
#    'name',
#    'no',
#    'writer',
#    'press',
#    'address',
#    'total',
#    'id',
#    'name',
#    'no',
#    'age',
#    'sex',
#    'department',
#    'telephone number',
#    'id',
#    'name',
#    'no',
#    'sex',
#    'age',
#    'telephone number',
#    'date',
#    'id',
#    'username',
#    'password'],
#   'lang': '__label__en'},
#  '_JuQ-QJvREeSW9selBczv3Q.xmi.uml': {'classes': ['i figura',
#    'i color',
#    'rectangulo',
#    'circulo',
#    'cuadrilatero'],
#   'attributes': ['pi', 'base', 'altura', 'radio'],
#   'lang': '__label__sv'},
#  '_lC7ZAGxcEem8aOzn3EOqfg.xmi.uml': {'classes': ['order'],
#   'lang': '__label__en'},
#  '_tHhBAFSKEei2efM7H4gIXw.xmi.uml': {'classes': ['boleto',
#    'contrato',
#    'parcela',
#    'flo'],
#   'attributes': ['num boleto',
#    'cod cliente',
#    'cod barra',
#    'dat reneg',
#    'dat vencimento',
#    'val saldo dev',
#    'val saldo reneg',
#    'val perc desc',
#    'ind campanha',
#    'num qtde parc',
#    'val prest',
#    'val desc prest',
#    'val liqu prest',
#    'num boleto',
#    'cod cliente',
#    'cod produto',
#    'num contrato',
#    'nom produto',
#    'val saldo dev',
#    'val saldo reneg',
#    'val encargo',
#    'val tarifa',
#    'num boleto',
#    'cod produto',
#    'num contrato',
#    'num parcela'],
#   'lang': '__label__pt'},
#  '1071140d-9c5d-46d3-aa90-f9b348ebfac9.xmi.uml': {'classes': ['customer',
#    'payment',
#    'shopping cart',
#    'account',
#    'web user',
#    'order',
#    'line item',
#    'product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paid date',
#    'total',
#    'details',
#    'creation date',
#    'billing address',
#    'open',
#    'closed',
#    'is closed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'ship to',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description'],
#   'lang': '__label__en'},
#  '72bffa82-db26-4d26-a139-b38884dada59.xmi.uml': {'classes': ['clients',
#    'login',
#    'administrator',
#    'who made changes',
#    'account expired',
#    'make pay',
#    'change password',
#    'events',
#    'add additional data',
#    'advance search'],
#   'lang': '__label__en'},
#  '_z-y1oKPNEeikWfbDNPV9UQ.xmi.uml': {'classes': ['class'],
#   'lang': '__label__en'},
#  '_iAN1sIYZEeS_9vPfFC3tSQ.xmi.uml': {'classes': ['dog',
#    'lab',
#    'poodle',
#    'shepard',
#    'pitbull',
#    'pug',
#    'beagle'],
#   'attributes': ['gender', 'breed', 'weight', 'color', 'eye color'],
#   'lang': '__label__en'},
#  '43125ec2-0e31-4d4d-98d2-2ca18c1a08ba.xmi.uml': {'classes': ['client',
#    'adaptor',
#    'adaptee'],
#   'lang': '__label__en'},
#  'b11d83f2-57be-4197-b073-33b29a12e551.xmi.uml': {'classes': ['worker',
#    'people',
#    'customer',
#    'cook',
#    'waiter',
#    'cashier'],
#   'attributes': ['name'],
#   'lang': '__label__en'},
#  '_CwucMBNMEeSTV6l4790RsQ.xmi.uml': {'classes': ['mensagem',
#    'twitter',
#    'facebook',
#    'utilizador'],
#   'lang': '__label__es'},
#  '_ozUCAFmYEeaQF8q9ZsVYhQ.xmi.uml': {'classes': ['single data combiner',
#    'latest value combiner',
#    'greatest value combiner',
#    'custom combiner',
#    'combined combiner',
#    'priority combiner',
#    'rule based combiner'],
#   'lang': '__label__en'},
#  '_mu7qEH1yEeShroDxTnL5_A.xmi.uml': {'classes': ['single data combiner',
#    'latest value combiner',
#    'greatest value combiner',
#    'custom combiner',
#    'combined combiner',
#    'priority combiner',
#    'rule based combiner'],
#   'lang': '__label__en'},
#  '_vgKXsMUIEeadwOIOqK-0Fw.xmi.uml': {'classes': ['my class'],
#   'lang': '__label__en'},
#  'd5c157b6-912e-4995-9d8f-bd5f2aa2ee9f.xmi.uml': {'classes': ['client',
#    'adapter impl',
#    'adaptee',
#    'context',
#    'state a',
#    'state b',
#    'singleton',
#    'abstraction',
#    'refined abstraction',
#    'concrete implementor',
#    'creator impl',
#    'product',
#    'concrete observer',
#    'concrete subject'],
#   'attributes': ['instance'],
#   'lang': '__label__en'},
#  '_Hr1JoIwLEeewrIfYd5mf8Q.xmi.uml': {'classes': ['monetate event',
#    'monetate event product view',
#    'monetate event purchase',
#    'monetate processor',
#    'product',
#    'message processor'],
#   'attributes': ['event type',
#    'products',
#    'purchase lines',
#    'name',
#    'setting api key',
#    'setting mailing list id',
#    'domain',
#    'instance',
#    'account id',
#    'api url',
#    'sku',
#    'pid',
#    'quantity',
#    'currency',
#    'value'],
#   'lang': '__label__en'},
#  '_1ybHgIT-EeS-18kfrtGUQQ.xmi.uml': {'classes': ['quran surah'],
#   'attributes': ['surah no', 'name of surah', 'type of surah'],
#   'lang': '__label__tl'},
#  'f959fb74-a45e-4e26-a37d-ff5dad352c49.xmi.uml': {'classes': ['worker',
#    'people',
#    'customer',
#    'cook',
#    'waiter',
#    'cashier'],
#   'attributes': ['name'],
#   'lang': '__label__en'},
#  'e62c26ba-de91-443d-8dec-baa035e40d26.xmi.uml': {'classes': ['shopping cart',
#    'order',
#    'line item',
#    'account',
#    'customer'],
#   'attributes': ['creation date', 'id', 'quantity', 'price', 'id'],
#   'lang': '__label__en'},
#  '_SHt8QP2_EeOTCK1Mp6laew.xmi.uml': {'classes': ['main class',
#    'about',
#    'documents',
#    'encryption',
#    'decryption',
#    'ss generator',
#    'app  password'],
#   'lang': '__label__en'},
#  '_tWiXAE-oEeeu8_4LH_yuyg.xmi.uml': {'classes': ['core', 'person', 'company'],
#   'attributes': ['id', 'value', 'person code', 'registration nr', 'vat nr'],
#   'lang': '__label__en'},
#  '_0ato4He_EeeZ3IbHHpTTiA.xmi.uml': {'classes': ['adapter factory',
#    'google adapter factory',
#    'class',
#    'adapter',
#    'class2',
#    'amazon adapter factory',
#    'google adapter',
#    'amazon adapter',
#    'generic request stream handler'],
#   'attributes': ['object mapper'],
#   'lang': '__label__en'},
#  '_yIWRYChXEeShcfbUiDP6ug.xmi.uml': {'classes': ['my class', 'my class2'],
#   'attributes': ['name'],
#   'lang': '__label__en'},
#  '67ed9d27-56e3-4b81-8050-6e03eda242b5.xmi.uml': {'classes': ['worker',
#    'people',
#    'customer',
#    'cook',
#    'waiter',
#    'cashier'],
#   'attributes': ['name'],
#   'lang': '__label__en'},
#  '_cOog0CIgEeisAYMSV00L2Q.xmi.uml': {'classes': ['fields modification',
#    'created user modification',
#    'deleted user modification',
#    'user moved to group modification',
#    'grid index',
#    'grid index2'],
#   'lang': '__label__en'},
#  'a670164a-9f45-46fe-bade-23f443485ab4.xmi.uml': {'classes': ['customer',
#    'account',
#    'transaction',
#    'checking account',
#    'savings account',
#    'login',
#    'deposit transaction',
#    'withdraw transaction',
#    'transfer transaction',
#    'certificates of deposit account'],
#   'attributes': ['name',
#    'date of birth',
#    'address',
#    'phone number',
#    'email address',
#    'account no',
#    'type',
#    'balance',
#    'id',
#    'type',
#    'transaction time',
#    'amount',
#    'interest rate',
#    'username',
#    'password',
#    'security question',
#    'security answer',
#    'last login time',
#    'target account',
#    'source account',
#    'interest rate',
#    'time period'],
#   'lang': '__label__en'},
#  'efd35011-a6c9-4b9a-b62e-d5daa9b58968.xmi.uml': {'classes': ['user'],
#   'attributes': ['attribute'],
#   'lang': '__label__en'},
#  'd779e6fe-c0ae-4f71-816a-5cdd632e89f1.xmi.uml': {'classes': ['customer',
#    'payment',
#    'shopping cart',
#    'account',
#    'web user',
#    'order',
#    'line item',
#    'product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paid date',
#    'total',
#    'details',
#    'creation date',
#    'billing address',
#    'open',
#    'closed',
#    'is closed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'ship to',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description'],
#   'lang': '__label__en'},
#  '597093bc-31ce-4808-b763-c29d6f680f32.xmi.uml': {'classes': ['чч',
#    'my class',
#    'my class2'],
#   'lang': '__label__uk'},
#  '_OxdDoEymEeS9L4cMWDc7Qg.xmi.uml': {'attributes': ['load'],
#   'lang': '__label__en'},
#  '_I_lnENTGEeehRMl7r1-c5g.xmi.uml': {'classes': ['curved line',
#    'sketchy ellipse',
#    'sketchy rectangle',
#    'shape creator',
#    'line drawer',
#    'shape mover',
#    'shape resizer',
#    'shape rotater',
#    'shape filler',
#    'shape deleter',
#    'shape raiser',
#    'shape lowerer'],
#   'lang': '__label__en'},
#  '_zTvrkGm3EDGB-uCsYzbtRg.xmi.uml': {'classes': ['game window'],
#   'lang': '__label__en'},
#  'af8ad990-19e3-488e-b4b8-846b6643f25b.xmi.uml': {'classes': ['customer',
#    'payment',
#    'shoppin cart',
#    'account',
#    'web user',
#    'order',
#    'line item',
#    'product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paid date',
#    'total',
#    'details',
#    'creation date',
#    'billing address',
#    'open',
#    'closed',
#    'is closed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'ship to',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description'],
#   'lang': '__label__en'},
#  'd6ed4740-d12b-4899-a2db-2374a6c7c4b5.xmi.uml': {'classes': ['client',
#    'adapter impl',
#    'adaptee',
#    'context',
#    'state a',
#    'state b',
#    'singleton',
#    'abstraction',
#    'refined abstraction',
#    'concrete implementor',
#    'creator impl',
#    'product',
#    'concrete observer',
#    'concrete subject',
#    'method class',
#    'class object'],
#   'attributes': ['instance'],
#   'lang': '__label__en'},
#  '_NI0-EMYEEeeWu-SLkciAbg.xmi.uml': {'classes': ['temp sensor', 'arduino'],
#   'attributes': ['vout', 'volts', 'celsius', 'farfahrenheit'],
#   'lang': '__label__en'},
#  'b9dfe65c-12b6-498b-a151-0343da867aef.xmi.uml': {'classes': ['client',
#    'adapter impl',
#    'adaptee',
#    'context',
#    'state a',
#    'state b',
#    'singleton',
#    'abstraction',
#    'refined abstraction',
#    'concrete implementor',
#    'creator impl',
#    'product',
#    'concrete observer',
#    'concrete subject'],
#   'attributes': ['instance'],
#   'lang': '__label__en'},
#  '0d0ec5dd-c762-405a-8a86-9d23a126537b.xmi.uml': {'classes': ['my class a oim'],
#   'attributes': ['attribute'],
#   'lang': '__label__vep'},
#  '_RwyPkIPfEeaY2ZFk8hIg9A.xmi.uml': {'classes': ['db object'],
#   'attributes': ['table',
#    'index',
#    'uid',
#    'uid length',
#    'delete',
#    'columns',
#    'fillable',
#    'hidden',
#    'generators'],
#   'lang': '__label__en'},
#  '431e2d5d-fa76-4ca1-a879-a927d293c394.xmi.uml': {'classes': ['client',
#    'adapter impl',
#    'adaptee',
#    'context',
#    'state a',
#    'state b',
#    'singleton',
#    'abstraction',
#    'refined abstraction',
#    'concrete implementor',
#    'creator impl',
#    'product',
#    'concrete observer',
#    'concrete subject'],
#   'attributes': ['instance'],
#   'lang': '__label__en'},
#  '_42UqgMaLEeWmANB_14dU0A.xmi.uml': {'classes': ['prueba', 'prueba2'],
#   'attributes': ['nombre', 'lugar', 'pais', 'color', 'tamanio'],
#   'lang': '__label__es'},
#  '_OJVuMFlJEeWH7tmnkVHu6g.xmi.uml': {'classes': ['patrons', 'library staff'],
#   'attributes': ['holder',
#    'name',
#    'date',
#    'student',
#    'faculty',
#    'library staff',
#    'books',
#    'overdue fee',
#    'check out time'],
#   'lang': '__label__en'},
#  '_butz8NjbEeWjYr7I4V0e0A.xmi.uml': {'classes': ['charge account'],
#   'attributes': ['customer no(key)', 'attribute'],
#   'lang': '__label__en'},
#  '310b8bef-1a4e-4692-b437-a6a5453e1c31.xmi.uml': {'classes': ['customer',
#    'payment',
#    'shopping cart',
#    'account',
#    'web user',
#    'order',
#    'line item',
#    'product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paid date',
#    'total',
#    'details',
#    'creation date',
#    'billing address',
#    'open',
#    'closed',
#    'is closed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'ship to',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description'],
#   'lang': '__label__en'},
#  '7aff64ad-90b0-450f-bf8c-1f4b9c3b8f37.xmi.uml': {'classes': ['shopping cart'],
#   'lang': '__label__en'},
#  'f34f1233-c3f1-48df-b830-6c1e81f51751.xmi.uml': {'classes': ['abstraction',
#    'refined abstraction',
#    'concrete implementor'],
#   'lang': '__label__en'},
#  'f6e1ef7a-107f-419e-ab7d-a51aa49c13d2.xmi.uml': {'classes': ['snake',
#    'game',
#    'program',
#    'food',
#    'display',
#    'player',
#    'unit',
#    'random'],
#   'attributes': ['face',
#    'speed',
#    'size',
#    '[]unit',
#    'snake',
#    'food',
#    'display',
#    'player',
#    'life',
#    'face',
#    'to be',
#    'height',
#    'width',
#    'space',
#    'wall',
#    'score position',
#    'game resume position',
#    'game over postion',
#    'command'],
#   'lang': '__label__en'},
#  '_-g260KW7EeaiBJ7PH1W80g.xmi.uml': {'classes': ['event',
#    'customer',
#    'agency',
#    'seven user',
#    'user activity relation',
#    'user register event relation',
#    'activity',
#    'log attendee',
#    'attendee activity',
#    'survey',
#    'question',
#    'response attendee',
#    'attendee',
#    'role mapping'],
#   'attributes': ['id',
#    'title',
#    'date created',
#    'date started',
#    'description',
#    'place',
#    'status',
#    'stage',
#    'brochure',
#    'timezone',
#    'user id',
#    'customer id',
#    'id',
#    'name',
#    'description',
#    'agency id',
#    'user id',
#    'id',
#    'name',
#    'description',
#    'user id',
#    'id',
#    'type',
#    'firstname',
#    'lastname',
#    'email',
#    'created',
#    'lastupdated',
#    'image user',
#    'id',
#    'sevenuser id',
#    'activity id',
#    'id',
#    'sevenuser id',
#    'event id',
#    'id',
#    'name',
#    'description',
#    'start',
#    'duration',
#    'limit',
#    'event id',
#    'user id',
#    'on demand count',
#    'evaluation count',
#    'registers',
#    'space availbale',
#    'id',
#    'status',
#    'date',
#    'attendee id',
#    'event id',
#    'id',
#    'attendee id',
#    'activity id',
#    'id',
#    'event id',
#    'activity id',
#    'user id',
#    'id',
#    'text',
#    'type',
#    'answer',
#    'time',
#    'send',
#    'survey id',
#    'id',
#    'date',
#    'response',
#    'attendee id',
#    'question id',
#    'id',
#    'age',
#    'email original',
#    'organization',
#    'status',
#    'location',
#    'birthyear',
#    'notification',
#    'email',
#    'platform',
#    'typecheck',
#    'event id',
#    'user id',
#    'id',
#    'sevenuser id',
#    'role id',
#    'type'],
#   'lang': '__label__en'},
#  '19515821-de9c-4371-ab13-0c10c1f0741e.xmi.uml': {'classes': ['client',
#    'adapter impl',
#    'adaptee',
#    'context',
#    'state a',
#    'state b',
#    'singleton',
#    'abstraction',
#    'refined abstraction',
#    'concrete implementor',
#    'creator impl',
#    'product',
#    'concrete observer',
#    'concrete subject'],
#   'attributes': ['instance'],
#   'lang': '__label__en'},
#  '_iY65cGqwEeepGY91r9Nuow.xmi.uml': {'classes': ['order'],
#   'attributes': ['user name',
#    'attribute2',
#    'attribute3',
#    'attribute4',
#    'attribute5',
#    'attribute6',
#    'attribute7',
#    'attribute8',
#    'attribute9',
#    'attribute10'],
#   'lang': '__label__it'},
#  '_ICx4IDeZEemHKq5iZQi_Zw.xmi.uml': {'classes': ['estudiante',
#    'profesor',
#    'materias',
#    'salones',
#    'rol',
#    'edificio',
#    'programa',
#    'facultad',
#    'horario'],
#   'attributes': ['id estudiante',
#    'nombre',
#    'apellidos',
#    'cedula',
#    'correo',
#    'estado',
#    'id rol',
#    'id programa',
#    'id profesor',
#    'nombre',
#    'cedula',
#    'correo',
#    'id salon',
#    'id rol',
#    'id materia',
#    'nombre',
#    'nrc',
#    'cupo',
#    'creditos',
#    'id estudiante',
#    'id profesor',
#    'id salon',
#    'id horario',
#    'id salon',
#    'piso',
#    'numero salon',
#    'capacidad',
#    'id edificio',
#    'id horario',
#    'id rol',
#    'nombre',
#    'id edificio',
#    'nombre',
#    'id programa',
#    'nombre',
#    'isum',
#    'id facultad',
#    'id facultad',
#    'nombre',
#    'id horario',
#    'hora inicio',
#    'hora final'],
#   'lang': '__label__es'},
#  '_w3lJ8AP7Eeewntt9CKbg3g.xmi.uml': {'classes': ['user',
#    'team',
#    'channel',
#    'message',
#    'user settings',
#    'team settings',
#    'channel settings',
#    'channel activity',
#    'user account',
#    'dirrect message'],
#   'attributes': ['username',
#    'team',
#    'name',
#    'url',
#    'name',
#    'status',
#    'purpose',
#    'date',
#    'content',
#    'notifications',
#    'sound',
#    'display',
#    'threads',
#    'highlight words',
#    'do not disturb from',
#    'do not disturb to',
#    'sign up mode',
#    'default channels',
#    'username guidelines',
#    'name display',
#    'require for mention',
#    'email display',
#    'do not disturb from',
#    'do not disturb to',
#    'hide url',
#    'enable calls',
#    'calling app',
#    'message retention',
#    'file retention',
#    'team icon',
#    'desktop notifications',
#    'push notificationa',
#    'mute channel',
#    'include user group mentions',
#    'include channel mentions',
#    'first name',
#    'last name',
#    'what i do',
#    'email',
#    'phone',
#    'timezone',
#    'skype id',
#    'photo',
#    'password'],
#   'lang': '__label__en'},
#  'e9599e4d-25c4-48e4-8fe3-fc14e2c55dce.xmi.uml': {'classes': ['employee',
#    'salary',
#    'authenticate staff',
#    'leave',
#    'attendance',
#    'login'],
#   'attributes': ['emp  id',
#    'emp  name',
#    'emp  contact no',
#    'emp  email',
#    'emp nic',
#    'emp  address',
#    'emp dob',
#    'emp  department',
#    'emp- date  of  joint',
#    'emp  position',
#    'emp  salary',
#    'emp  id',
#    'sly  basic',
#    'sly  increment',
#    'sly  decrement',
#    'sly  netgross',
#    'over time',
#    'user name',
#    'password',
#    'authendication  mood',
#    'leave id',
#    'emp  id',
#    'leave  title',
#    'leave detail',
#    'leave  apply date',
#    'leave  start date',
#    'leave  end date',
#    'leave  no of days',
#    'leave  status',
#    'attend date',
#    'emp id',
#    'attend time',
#    'leaving  time',
#    'user name',
#    'password'],
#   'lang': '__label__fr'},
#  '49a9a179-f2f3-4517-994e-148391be8053.xmi.uml': {'classes': ['client',
#    'adaptor',
#    'adaptee',
#    'my class'],
#   'lang': '__label__en'},
#  '_1fv_cGAzEeepGY91r9Nuow.xmi.uml': {'classes': ['category',
#    'products',
#    'product size',
#    'order details',
#    'my class',
#    'my class2',
#    'my class3',
#    'my class4',
#    'my class5',
#    'orders',
#    'order category',
#    'my class8',
#    'my class9',
#    'my class10'],
#   'attributes': ['category id',
#    'category description',
#    'product id',
#    'product name',
#    'image',
#    'category id',
#    'is active',
#    'prod size id',
#    'product id',
#    'size id',
#    'price',
#    'order details id',
#    'order id',
#    'product size id',
#    'quantity',
#    'price per product',
#    'order id',
#    'adderess',
#    'client id',
#    'order date',
#    'center id',
#    'category id',
#    'order cat id',
#    'category desc'],
#   'lang': '__label__en'},
#  '8b08c90b-c7d3-4afd-b0e9-3dfe67ed7de3.xmi.uml': {'classes': ['shopping cart',
#    'order',
#    'line item',
#    'account',
#    'customer'],
#   'attributes': ['creation date', 'id', 'quantity', 'price', 'id'],
#   'lang': '__label__en'},
#  'd29cd2f3-9ae8-4c52-97f5-7cf07f4cdd10.xmi.uml': {'classes': ['singleton'],
#   'attributes': ['instance'],
#   'lang': '__label__en'},
#  '6c84d80a-0e28-40ab-957c-531b57921306.xmi.uml': {'classes': ['customer',
#    'payment',
#    'shopping cart',
#    'account',
#    'web user',
#    'order',
#    'line item',
#    'product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paid date',
#    'total',
#    'details',
#    'creation date',
#    'billing address',
#    'open',
#    'closed',
#    'is closed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'ship to',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description'],
#   'lang': '__label__en'},
#  '9232d81e-dab5-49d8-9e89-8a4ff91278b1.xmi.uml': {'classes': ['create analysis action',
#    'service',
#    'analysis dao',
#    'analysis dao'],
#   'attributes': ['analysis name'],
#   'lang': '__label__en'},
#  '_WfyX0MIFEeacM55raX9d3Q.xmi.uml': {'classes': ['producer text generator',
#    'text',
#    'consumer text analyz',
#    'scanner text'],
#   'lang': '__label__en'},
#  '_KlkTALgHEeSzkacHLregNQ.xmi.uml': {'classes': ['order'],
#   'attributes': ['order id;', '+ order(...)'],
#   'lang': '__label__en'},
#  '_XgXMwH_9EeW4cd-qm4QbpA.xmi.uml': {'classes': ['employee', 'rooms'],
#   'attributes': ['id', 'first name', 'last name', 'number'],
#   'lang': '__label__en'},
#  '40adfe9e-25a9-426a-806e-9ff9a56b4da2.xmi.uml': {'classes': ['worker',
#    'people',
#    'customer',
#    'cook',
#    'waiter',
#    'cashier'],
#   'attributes': ['name'],
#   'lang': '__label__en'},
#  '_lWq_kF4WEeSmRKwulsG6-Q.xmi.uml': {'classes': ['user',
#    'massage',
#    'profile',
#    'post',
#    'group',
#    'friends',
#    'login',
#    'notification',
#    'admin',
#    'member'],
#   'lang': '__label__en'},
#  '2c3b7982-340a-4627-9c85-6b1a36347b78.xmi.uml': {'classes': ['timetable event',
#    'timetable reader',
#    'timetable validator',
#    'timetable validation error',
#    'calendar importer',
#    'google calendar importer'],
#   'lang': '__label__es'},
#  '_JkGroH2TEeShroDxTnL5_A.xmi.uml': {'classes': ['caisse'],
#   'attributes': ['test'],
#   'lang': '__label__pt'},
#  '9462f4aa-aea2-4c9e-afcb-cfcfbd414c85.xmi.uml': {'classes': ['shopping cart',
#    'order',
#    'line item',
#    'account',
#    'customer'],
#   'attributes': ['creation date', 'id', 'quantity', 'price', 'id'],
#   'lang': '__label__en'},
#  '538864d8-e066-49c5-8edd-4ab0fca7f62b.xmi.uml': {'classes': ['person',
#    'professor',
#    'employee',
#    'full professor',
#    'associate',
#    'assistant',
#    'office',
#    'university',
#    'classroom',
#    'room',
#    'building'],
#   'attributes': ['id', 'name', 'seats number', 'floor', 'number'],
#   'lang': '__label__en'},
#  '_5pZpkNHiEeaJwt5yAqWnTg.xmi.uml': {'classes': ['class',
#    'class2',
#    'wifi',
#    'class3',
#    'simcard',
#    'system',
#    'database'],
#   'lang': '__label__en'},
#  'e12b7943-feab-4c7d-9330-61358c7afece.xmi.uml': {'classes': ['customer',
#    'payment',
#    'shopping cart',
#    'account',
#    'web user',
#    'order',
#    'line item',
#    'product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paid date',
#    'total',
#    'details',
#    'creation date',
#    'billing address',
#    'open',
#    'closed',
#    'is closed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'ship to',
# ...
#   'lang': '__label__sh'},
#  '_DErG4HseEeSdXJMJcKNKoQ.xmi.uml': {'classes': ['user', 'it website', 'user'],
#   'attributes': ['attribute', 'id', 'password'],
#   'lang': '__label__en'},
#  '_8-EMANc5Eei47sN0sCkjiA.xmi.uml': {'classes': ['l ala'],
#   'attributes': ['sd'],
#   'lang': '__label__fr'},
#  '3c85cf04-8dba-4aee-bb97-59cb0048da7b.xmi.uml': {'classes': ['client',
#    'adaptor',
#    'adaptee'],
#   'lang': '__label__en'},
#  '_FzAzoMENEeeEXb8Dudo6PQ.xmi.uml': {'classes': ['avion', 'pasajero', 'silla'],
#   'attributes': ['sillas ejecutivas',
#    'sillas economicas',
#    'cedula',
#    'nombre',
#    'clase ejecutiva',
#    'clase economica',
#    'ventana',
#    'central',
#    'pasillo',
#    'numero',
#    'clase',
#    'ubicacion'],
#   'lang': '__label__es'},
#  '08440044-d6fd-4fe9-b4b9-485af8ec84ab.xmi.uml': {'classes': ['worker',
#    'people',
#    'customer',
#    'cook',
#    'waiter',
#    'cashier'],
#   'attributes': ['name'],
#   'lang': '__label__en'},
#  '_8MyUoObSEeiDGLvZhbPYyA.xmi.uml': {'classes': ['person', 'male'],
#   'lang': '__label__en'},
#  '_TgYHsEMgEeSyYeDoyPirvg.xmi.uml': {'classes': ['event',
#    'flight manager',
#    'flight planning',
#    'intervention planning',
#    'planning',
#    'employee manager',
#    'employee planning',
#    'report manager',
#    'report',
#    'distribution manager',
#    'marketing manager',
#    'ticket distributor manager',
#    'provider manager',
#    'flight event',
#    'plane intervention',
#    'plane revision',
#    'plane immobilization',
#    'plane fuel',
#    'cleaning service',
#    'steward',
#    'pilot',
#    'airport employee',
#    'employee',
#    'company',
#    'airport',
#    'standard flight',
#    'flight',
#    'free time flight',
#    'plane',
#    'fuel',
#    'fuel provider',
#    'consomation provider',
#    'consomation',
#    'service provider',
#    'provider',
#    'consomation stock',
#    'ticket',
#    'boarding pass',
#    'customer',
#    'ticket distributor',
#    'promotion',
#    'advertising',
#    'news',
#    'reservation',
#    'free miles',
#    'early order',
#    'employee manager view',
#    'ticket distribution view',
#    'company management view'],
#   'attributes': ['date begin',
#    'date end',
#    'title',
#    'is super user',
#    'date',
#    'category',
#    'flight',
#    'milles on intervention',
#    'plane',
#    'flight',
#    'plane',
#    'airport',
#    'plane',
#    'airport',
#    'airport',
#    'day by week',
#    'name',
#    'gender',
#    'job type',
#    'is super user',
#    'name',
#    'stewards',
#    'pilots',
#    'airport employees',
#    'city',
#    'ticket price',
#    'ticket charges',
#    'begin schedule',
#    'end schedule',
#    'surbooking percent',
#    'reservation percent',
#    'airport from',
#    'airport to',
#    '/duration',
#    'flight type',
#    'schedule',
#    '/miles',
#    'confirmation percent',
#    'row',
#    'seat per row',
#    '/seat',
#    'nb pilote',
#    'nb steward',
#    '/crew',
#    '/milles flyed',
#    '/fly since refuel',
#    '/state',
#    '/location',
#    '/milles since revisionned',
#    'date',
#    '/price',
#    'volme',
#    'plane',
#    'name',
#    'price per unit',
#    'price per unit',
#    'name',
#    'capacity',
#    'from',
#    'payment',
#    '/price',
#    'promotion',
#    'is registered',
#    'number place',
#    'price',
#    'row',
#    'seat',
#    'is validated',
#    'date of purchase',
#    'flight',
#    '/miles flyed',
#    'luggage',
#    'name',
#    'surbooking',
#    'free fly per week',
#    'from',
#    'payment',
#    '/discount',
#    'percent per flight',
#    'picture',
#    'date',
#    'text',
#    'title',
#    'discount percent',
#    'milles per milles promotion',
#    'cash per miles promotion',
#    'discount percent'],
#   'lang': '__label__en'},
#  '_L7BoAFTIEeSu48YT12vqpQ.xmi.uml': {'classes': ['player'],
#   'attributes': ['name', 'score', 'card container'],
#   'lang': '__label__en'},
#  '9e620e9c-e98c-44f2-be8d-849cc420126d.xmi.uml': {'classes': ['customer',
#    'payment',
#    'shopping cart',
#    'account',
#    'web user',
#    'order',
#    'line item',
#    'product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paid date',
#    'total',
#    'details',
#    'creation date',
#    'billing address',
#    'open',
#    'closed',
#    'is closed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'ship to',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description'],
#   'lang': '__label__en'},
#  '_PbRXUNuREeiJYbNjsZ3wUw.xmi.uml': {'classes': ['typeator container',
#    'default typeator',
#    'typeator factory',
#    'typeator runner'],
#   'lang': '__label__en'},
#  'd5320ba4-ef0b-4a62-9a28-70d63e9861f7.xmi.uml': {'classes': ['bank account',
#    'class a',
#    'class b',
#    'class c',
#    'class d',
#    'class e',
#    'class f',
#    'class g',
#    'class j',
#    'class h',
#    'class k',
#    'class m',
#    'class n',
#    'class p',
#    'class q',
#    'class r',
#    'class s',
#    'class t',
#    'class u',
#    'class v'],
#   'attributes': ['owner name',
#    'balance',
#    'public attribute',
#    'private attribute',
#    'protected attribute',
#    'package attribute',
#    'public attribute',
#    'private attribute',
#    'protected attribute',
#    'package attribute'],
#   'lang': '__label__en'},
#  '_zmijUKT-EeScLuNN63kNaQ.xmi.uml': {'classes': ['sensor', 'device', 'menu'],
#   'attributes': ['sensor'],
#   'lang': '__label__en'},
#  '_WhW-AJc2EeS67M2cXIV9Bg.xmi.uml': {'classes': ['dienblad',
#    'docent',
#    'student',
#    'kantine medewerker',
#    'persoons vergelijker',
#    'kassa rij',
#    'kantine',
#    'kassa',
#    'administratie'],
#   'attributes': ['artikelen',
#    'totaalprijs',
#    'afkorting',
#    'afdeling',
#    'studentnummer',
#    'studierichting',
#    'medewerkersnummer',
#    'mag achter kassa',
#    'kassa rij',
#    'kassa',
#    'kassarij',
#    'persoon1',
#    'dienblad1',
#    'artikel1',
#    'artikel2',
#    'kantineaanbod',
#    'rij',
#    'artikelen',
#    'geld',
#    'aantal klanten',
#    'days in week'],
#   'lang': '__label__nl'},
#  '3dabd4fe-d23c-4cf6-bbe6-510a8a5b7722.xmi.uml': {'classes': ['client',
#    'adaptor',
#    'adaptee'],
#   'lang': '__label__en'},
#  '_-iZxYP76EeSpvbjLqY_W3Q.xmi.uml': {'classes': ['user'],
#   'attributes': ['user id',
#    'user type',
#    'first name',
#    'last name',
#    'employee id',
#    'date joined',
#    'role',
#    'allocation status',
#    'email',
#    'phone',
#    'office address',
#    'base branch',
#    'city',
#    'state',
#    'country',
#    'specialization',
#    'institution',
#    'years company',
#    'profile picture'],
#   'lang': '__label__en'},
#  '_FIzVsGTjEDGvYZ_luPE2qw.xmi.uml': {'classes': ['curso',
#    'seccion',
#    'estudiante',
#    'sistema archivos',
#    'archivo'],
#   'attributes': ['profesor', 'salon', 'hora'],
#   'lang': '__label__es'},
#  '_v6vVID3VEDG1DfFOPLjuGA.xmi.uml': {'classes': ['ordering system',
#    'ordering system',
#    'ordering system',
#    'list',
#    'ordering system',
#    'list'],
#   'attributes': ['cost coffee a',
#    'cost coffee b',
#    'cost coffee c',
#    'cost coffee d',
#    'cost coffee a',
#    'cost coffee b',
#    'cost coffee c',
#    'cost coffee d',
#    'cost condiment a',
#    'cost condiment b',
#    'cost condiment c',
#    'list cost coffee',
#    'list cost condiment',
#    'values',
#    'names',
#    'list cost',
#    'values',
#    'names'],
#   'lang': '__label__en'},
#  'e2b23b9a-8b69-4537-95d9-9a62d0468ccf.xmi.uml': {'classes': ['customer',
#    'payment',
#    'shopping cart',
#    'account',
#    'web user',
#    'order',
#    'line item',
#    'product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paid date',
#    'total',
#    'details',
#    'creation date',
#    'billing address',
#    'open',
#    'closed',
#    'is closed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'ship to',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description'],
#   'lang': '__label__en'},
#  'fe31c34b-968d-4bcd-a8e7-6fd9b9dfa284.xmi.uml': {'classes': ['game1',
#    'car',
#    'rock',
#    'wheel',
#    'player',
#    'score'],
#   'attributes': ['speed', 'colission'],
#   'lang': '__label__en'},
#  '_0FTU8KveEeiHR4AK89CXpg.xmi.uml': {'classes': ['buffer',
#    'int',
#    'productor',
#    'consumidor'],
#   'attributes': ['capacidad', 'buffer'],
#   'lang': '__label__en'},
#  '_K-stgPXsEei5Pecz43plcg.xmi.uml': {'classes': ['mac auto',
#    'cuenta',
#    'j frame',
#    'arithmetic exception',
#    'refresco',
#    'hamburguesa',
#    'papas',
#    'nombre',
#    'maquina',
#    'creditos',
#    'variables',
#    'maquina2',
#    'j frame'],
#   'attributes': ['creditos', 'cambio', 'total'],
#   'lang': '__label__en'},
#  '_VFimkNVkEeWUcZFfD54kTA.xmi.uml': {'classes': ['configuration root',
#    'sdp services',
#    'configure and activate service',
#    'sdp services methods il'],
#   'lang': '__label__en'},
#  '7602e9c9-601a-4f92-8c40-09e8901b162b.xmi.uml': {'classes': ['shopping cart'],
#   'lang': '__label__en'},
#  '_XuwfQHz2EeW4cd-qm4QbpA.xmi.uml': {'classes': ['file buffer',
#    'parent modul',
#    'work modul a',
#    'gui',
#    'visualisation'],
#   'attributes': ['original data'],
#   'lang': '__label__en'},
#  '_Wk5_IAdjEeeoBvzX9wJhsQ.xmi.uml': {'classes': ['super  parser',
#    'sub  parser',
#    'string []'],
#   'attributes': ['parser name',
#    'covered program',
#    'start time',
#    'end time',
#    'string',
#    'active parser',
#    'parser stack',
#    'log stack'],
#   'lang': '__label__war'},
#  '8a4b7913-39fb-43c6-a37e-5ae3264dc75d.xmi.uml': {'classes': ['equipo',
#    'jugador',
#    'entrenador',
#    'arbitro',
#    'partido',
#    'evento',
#    'tipo de evento',
#    'lesion',
#    'liga',
#    'clasificacion',
#    'persona',
#    'estadio'],
#   'attributes': ['cod equipo',
#    'nombre',
#    'f fundacion',
#    'ciudad',
#    'titulos',
#    'cod  entrenador',
#    'cod jugador',
#    'dorsal',
#    'posicion',
#    'altura',
#    'peso',
#    'titulos',
#    'cod equipo',
#    'cod persona',
#    'cod  entrenador',
#    'titulos',
#    'cod persona',
#    'cod  arbitro',
#    'partidos',
#    'cod persona',
#    'cod partido',
#    'fecha',
#    'hora',
#    'local',
#    'visita',
#    'gol local',
#    'gol visita',
#    'ganador',
#    'cod liga',
#    'cod partido',
#    'cod jugador',
#    'cod  tipode evento',
#    'cod  tipode evento',
#    'evento',
#    'cod jugador',
#    'fecha lesion',
#    'tiempo lesion',
#    'condicion',
#    'cod liga',
#    'nombre',
#    'num equipos',
#    'superior',
#    'inferior',
#    'cod  clasificacion',
#    'cod  equipo',
#    'posicion',
#    'jj',
#    'jp',
#    'je',
#    'jg',
#    'gf',
#    'gc',
#    'dg',
#    'puntos',
#    'cod persona',
#    'nombre',
#    'apellido',
#    'nombre corto',
#    'fecha nacimiento',
#    'nacionalidad',
#    'cod  estadio',
#    'nombre',
#    'ubicacion',
#    'capacidad',
#    'terreno',
#    'ubicacion',
#    'cod equipo'],
#   'lang': '__label__es'},
#  '07ebe3fa-a9ec-466e-9aab-4c84c0e06b8f.xmi.uml': {'classes': ['customer',
#    'payment',
#    'shopping cart',
#    'account',
#    'web user',
#    'order',
#    'line item',
#    'product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paid date',
#    'total',
#    'details',
#    'creation date',
#    'billing address',
#    'open',
#    'closed',
#    'is closed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'ship to',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description'],
#   'lang': '__label__en'},
#  '90de3c08-1e92-4c95-a8d2-6e9b6e6a3bb2.xmi.uml': {'classes': ['singleton'],
#   'attributes': ['instance'],
#   'lang': '__label__en'},
#  '_7o7moCfVEeiYD9TOdwevwA.xmi.uml': {'classes': ['operador',
#    'hotel',
#    'hostal',
#    'reserva',
#    'cliente',
#    'habitacion persona',
#    'apartamento alquiler',
#    'vivienda persona',
#    'vivienda universitaria',
#    'persona',
#    'miembro comunidad',
#    'empresa',
#    'habitacion hotel',
#    'habitacion',
#    'habitacion vivienda',
#    'reserva colectiva'],
#   'attributes': ['id',
#    'tipo operador',
#    'restaurante',
#    'piscina',
#    'parqueadero',
#    'wifi',
#    'tv cable',
#    'recepcion24 horas',
#    'esta deshabilitado',
#    'horario apertura',
#    'horario cierre',
#    'capacidad',
#    'precio noche',
#    'esta deshabilitado',
#    'id',
#    'fecha incio servicio',
#    'fecha reserva',
#    'dias',
#    'tipo',
#    'fecha pago',
#    'fue cancelado',
#    'id reserva colectiva',
#    'capacidad',
#    'comidas',
#    'acceso cocina',
#    'tipo baño',
#    'tipo habitacion',
#    'costo luz',
#    'costo telefono',
#    'costo tv',
#    'costo internet',
#    'costo agua',
#    'precio mes',
#    'descuento mes prepagado',
#    'precio mes',
#    'costo telefono',
#    'costo luz',
#    'costo tv',
#    'costo internet',
#    'costo agua',
#    'administracion costo',
#    'capacidad',
#    'esta deshabilitado',
#    'capacidad',
#    'numero habitaciones',
#    'ubicacion',
#    'costo dia',
#    'caracteristicas seguro',
#    'esta deshabilitado',
#    'amoblamiento basico',
#    'cocineta',
#    'internet',
#    'tv',
#    'aseo',
#    'apoyo social',
#    'apoyo acedemico',
#    'restaurante costo',
#    'salas estudio costo',
#    'salas esparcimiento',
#    'gimnasio costo',
#    'esta deshabilitado',
#    'id',
#    'tipo persona',
#    'tipo miembro',
#    'id',
#    'numer camara comercio',
#    'tipo',
#    'banera',
#    'jacuzzi',
#    'sala',
#    'cocineta',
#    'precio noche',
#    'capacidad',
#    'tipo',
#    'tipo menaje',
#    'capacidad',
#    'precio noche',
#    'precio mes',
#    'precio semestre',
#    'id',
#    'tipo',
#    'cantidad',
#    'id cliente'],
#   'lang': '__label__es'},
#  '_XPjZsGdzEeS3yOrtnopAkA.xmi.uml': {'classes': ['document',
#    'livre',
#    'revue',
#    'dictionnaire',
#    'roman',
#    'manuel',
#    'animal',
#    'mammifere',
#    'chien',
#    'cheval'],
#   'lang': '__label__fr'},
#  '0d92d5b5-5707-41da-8461-a9e9de0fc0f0.xmi.uml': {'classes': ['sword',
#    'axe',
#    'enchanced weapon',
#    'fire weapon',
#    'holy weapon'],
#   'attributes': ['weapon'],
#   'lang': '__label__en'},
#  '_iiwTkHbaEeSfPZ7vcufCPw.xmi.uml': {'classes': ['location',
#    'zuordnung',
#    'software'],
#   'attributes': ['location id',
#    'netz id',
#    'route',
#    'raumname',
#    'betreuer',
#    'location id',
#    'software id',
#    'software id',
#    'softwarename'],
#   'lang': '__label__en'},
#  '_PmSUUOyDEei9dNtZPq67hQ.xmi.uml': {'classes': ['job list helper',
#    'job list helper'],
#   'attributes': ['context',
#    'm items',
#    'recycler view',
#    'context',
#    'm items',
#    'recycler view'],
#   'lang': '__label__en'},
#  'ca95bf9d-6107-478d-ae28-5dd662a4b3d4.xmi.uml': {'classes': ['object',
#    'component',
#    'behaviour',
#    'camera',
#    'animation',
#    'mono behaviour',
#    'network message info',
#    'bit stream',
#    'network view',
#    'network player',
#    'network view id',
#    'transform',
#    'rigidbody'],
#   'attributes': ['name',
#    'tag',
#    'enabled',
#    'network view',
#    'sender',
#    'timestamp',
#    'group',
#    'is mine',
#    'observed',
#    'position',
#    'rotation',
#    'eular angles',
#    'local to world matrix',
#    'world to local matrix',
#    'root',
#    'parent',
#    'position',
#    'rotation',
#    'velocity',
#    'angular velocity',
#    'mass',
#    'inertia tensor',
#    'collision detection mode',
#    'is kinematic',
#    'interpolation'],
#   'lang': '__label__en'},
#  '_816IMIJkEemGPZyN8msRcg.xmi.uml': {'classes': ['dim cocinera',
#    'localización',
#    'fact entrega',
#    'dim cliente',
#    'dim domiciliario',
#    'bridge cambio',
#    'bridge adicion',
#    'dim ingrediente',
#    'dim tiempo',
#    'dim fecha',
#    'bridge ingredientes'],
#   'attributes': ['id',
#    'cedula',
#    'nombre',
#    'fecha nacimiento',
#    'cantidad almuerzos',
#    'salario',
#    'direccion residencia',
#    'valido desde',
#    'valido hasta',
#    'actual',
#    'id',
#    'direccion',
#    'localidad',
#    'barrio',
#    'ciudad',
#    'departamento',
#    'id entrega',
#    'costo',
#    'satisfaccion',
#    'tiempo entrega',
#    'calificacion ingrediente mas gusto',
#    'calificacion ingrediente menos gusto',
#    'cliente',
#    'domiciliario',
#    'cocinera',
#    'fecha',
#    'hora solicitada',
#    'hora entrega',
#    'direccion entrega',
#    'ingrediente mas gusto',
#    'ingrediente menos gusto',
#    'id',
#    'cedula',
#    'nombre',
#    'direccion',
#    'id',
#    'cedula',
#    'nombre',
#    'fk entrega',
#    'fk ingrediente quitado',
#    'fk ingrediente nuevo',
#    'calificacion',
#    'fk entrega',
#    'fk ingrediente',
#    'calificacion',
#    'id',
#    'nombre',
#    'categoría',
#    'id',
#    'hora',
#    'minuto',
#    'momento dia',
#    'id',
#    'dia',
#    'mes',
#    'año',
#    'fk entrega',
#    'fk ingrediente',
#    'calificacion'],
#   'lang': '__label__es'},
#  ...}

# %%
with open('data/genmymodel_uml_extracted_metadata_annotated.json', 'w') as fp:
    json.dump(labeled_cleaned_data, fp)

# %% [markdown]
# # Further data cleaning

# %%
with open('data/genmymodel_uml_extracted_metadata_annotated.json') as json_file:
    labeled_cleaned_data = json.load(json_file)

# %%
filtered_files = {key: value for key, value in labeled_cleaned_data.items() if value['lang'] == '__label__en'}

# %%
# Remove hand-picked files
for file in ['_0se6kFNjEeS7SK6lkmJgjw.xmi.uml', '_zeUN8FJjEeeTnI9B59buBQ.xmi.uml', '_HKUJMMGAEeSBntdMhqoN9Q.xmi.uml', '48ecca9d-91d4-44f2-a21f-b0285228d504.xmi.uml']:
    del filtered_files[file]

# %%
filtered_files['_vZBssKMfEeScLuNN63kNaQ.xmi.uml']
# Out:
# {'classes': ['issue',
#   'issue comparator',
#   'git issues',
#   'issue list',
#   'issues manager',
#   'parser',
#   'parser copy',
#   'pre- commit- validation- hook'],
#  'attributes': ['id', 'assignee', 'milestone', 'etc'],
#  'lang': '__label__en'}

# %%
def text_transform(text):
    # Remove HTML tags and other tags '_WZQeEMJ8EeSII650IQ0Z1w.xmi.uml'
    text = re.sub(r'<\w+?>', '', text)

    # Remove dollar sign at the beginning '_2p9bEMasEeadwOIOqK-0Fw.xmi.uml'
    text = re.sub(r'^\$(?=\w+)', '', text)
    
    # Remove all "my" things '_8y0sAIKDEeeveJPbhFhy-g.xmi.uml'
    text = text.replace('my ', '')

    # Replace all parentheses with spaces '_2A0eUK99EealN5YbbDMqoA.xmi.uml' '_UxXH4Ji_EeWP9KF1Y_wKUg.xmi.uml'
    text = re.sub(r'\(\w+?\)', '', text)
    text = text.replace('(', ' ')
    text = text.replace(')', ' ')
    
    # Remove all attached numbers '_cOog0CIgEeisAYMSV00L2Q.xmi.uml'
    text = re.sub(r'(?<=\w)\d', '', text)

    # Replace "impl" with something '19515821-de9c-4371-ab13-0c10c1f0741e.xmi.uml'
    text = re.sub(r'\bimpl\b', 'implementation', text)

    # Remove questions '_arOCQOkeEeiV94kHgjpOMg.xmi.uml'
    text = re.sub(r'(?<=\w)\?', '', text)

    # Re-combine dashes '_vZBssKMfEeScLuNN63kNaQ.xmi.uml'
    text = re.sub(r'-\s(?=\w+?)', '-', text)

    # Turn ref abbreviation into reference '_w-4dMCDQEeqqcaoAsxFIeg.xmi.uml'
    text = re.sub(r'\bref\b', 'reference', text)

    # Remove single letter with space at beginning '_zTVWYHphEeas_KSqa81bqw.xmi.uml'
    text = re.sub(r'^\w\s(?=\w+)', '', text)
    
    # Remove colons
    text = text.replace(':', ' ')

    # Remove duplicate spaces
    text = re.sub(r'\s{2,}', ' ', text)
    
    # Remove scripted pattern " comments";
    text = re.sub(r'" (.+)";{0,1}', r'\1', text)
    
    # Remove all blokhaken
    text = re.sub(r'\[.*\]', '', text)
    
    # Remove dash to start
    text = re.sub(r'^-', '', text)
    
    # Remove plus to start
    text = re.sub(r'^\+', '', text)
    
    # Replace # with number when at end
    text = re.sub(r' ?#$', ' number', text)
    
    # Replace # with number at start
    text = re.sub(r'^#', 'number ', text)
    
    # Replace all dashes with spaces
    text = text.replace('-', ' ')
    
    # Remove * + 
    text = re.sub('\*$', '', text)
    text = re.sub('[\?]', '', text)
    
    # Remove tags
    text = re.sub(r'.+?< ([\w\s]+)>', r'\1', text)
    text = re.sub(r'^<>', '', text)
    text = re.sub(r'<$', '', text)
    
    # Change ampersand to "and"
    text = text.replace(' & ', ' and ')
    
    # Replace backslash in front
    text = re.sub(r'^\\ ', '', text)
    
    # Remove duplicate spaces
    text = text.replace('  ', ' ')
    
    # Trim output
    return text.strip()

text_transform('abstract resource item< style sheet item, style sheet params,url>')
# Out:
# 'abstract resource item< style sheet item, style sheet params,url>'

# %%
filtered_files = {
    filename: {
        metadata: list(map(lambda x: text_transform(x), texts))
        for metadata, texts in extracted_data.items()
        if metadata != 'lang'
    }
    for filename, extracted_data in tqdm(filtered_files.items())
}
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=142817.0), HTML(value='')))

# %%
filtered_files
# Out:
# {'5fae885c-3fde-430f-a3c5-ff44b81f2668.xmi.uml': {'classes': ['class a',
#    'class b',
#    'class c',
#    'class d',
#    'class e',
#    'class f',
#    'class g',
#    'class h',
#    'class i']},
#  '_oVCEUIHiEeeveJPbhFhy-g.xmi.uml': {'classes': ['site page', 'site section'],
#   'attributes': ['id',
#    'status',
#    'name',
#    'url',
#    'id',
#    'locked',
#    'name',
#    'default page']},
#  'e8a7e84d-73b3-40d2-ac78-f550566b4de8.xmi.uml': {'classes': ['client',
#    'adapter implementation',
#    'adaptee',
#    'context',
#    'state a',
#    'state b',
#    'singleton',
#    'abstraction',
#    'refined abstraction',
#    'concrete implementor',
#    'creator implementation',
#    'product',
#    'concrete observer',
#    'concrete subject'],
#   'attributes': ['instance']},
#  '_oWwJoHfLEeqeQcxm9hmzHw.xmi.uml': {'classes': ['shopping cart',
#    'order',
#    'line item',
#    'account',
#    'customer'],
#   'attributes': ['creation date', 'id', 'quantity', 'price', 'id']},
#  '_OR8QgFq_EeeTF9GWmq2Xvg.xmi.uml': {'classes': ['exam',
#    'question',
#    'lead exam',
#    'school',
#    'lead report',
#    'lead school',
#    'class'],
#   'attributes': ['id',
#    'name',
#    'response columns',
#    'description',
#    'id',
#    'text',
#    'video unit',
#    'unit title',
#    'video chapter',
#    'subject',
#    'id',
#    'lead name',
#    'lead phone',
#    'lead last name',
#    'group',
#    'school',
#    'result',
#    'exam',
#    'application date',
#    'id',
#    'identifier',
#    'kind',
#    'maximum score',
#    'minimum score',
#    'name',
#    'city',
#    'state',
#    'country',
#    'id',
#    'school',
#    'exam',
#    'lead exam',
#    'lead name',
#    'school name',
#    'school group',
#    'rank',
#    'version',
#    'correct answers',
#    'subject diagnostic',
#    'study plan',
#    'id',
#    'lead reports',
#    'school name',
#    'school average',
#    'group diagnostic',
#    'area diagnostic',
#    'version']},
#  '331af011-1b93-4a9b-abb7-f53d3cfb2a88.xmi.uml': {'classes': ['client',
#    'adaptor',
#    'adaptee']},
#  '9f510af6-1690-4d09-b973-5069cf83647a.xmi.uml': {'classes': ['system',
#    'sensor',
#    'motion sensor',
#    'pressure sensor',
#    'home security system',
#    'alert',
#    'door',
#    'camera',
#    'speakers',
#    'micro phone',
#    'light',
#    'start of day',
#    'end of day',
#    'tv',
#    'home theatre',
#    'house holds',
#    'entertainment'],
#   'attributes': ['status',
#    'update',
#    'sensor id',
#    'sensor type',
#    'user id',
#    'alert id',
#    'door id',
#    'camera id',
#    'speaker id',
#    'mic id',
#    'light id',
#    'sot',
#    'eot',
#    'tvid',
#    'htid',
#    'time id',
#    'coffee',
#    'dish washer',
#    'alarm',
#    'washing machine',
#    'device id']},
#  '_CFTYQLf4Eee7sYPkE4-GPA.xmi.uml': {'classes': ['class']},
#  '_AkJqwL2EEeirD7wkg7WdAw.xmi.uml': {'classes': ['customer', 'user'],
#   'attributes': ['csname',
#    'cs phon no.',
#    'address',
#    'credit cardinfo',
#    'email',
#    'user id',
#    'password',
#    'login status']},
#  '_C3TewPaFEeWolbMxsR5EUQ.xmi.uml': {'classes': ['file'],
#   'attributes': ['file server', 'file local']},
#  '_2Jq9QK0KEDGNWLI2ml8Hng.xmi.uml': {'classes': ['lab',
#    'server connection',
#    'gameboard',
#    'frame',
#    'panel',
#    'server']},
#  '_GbX-wK10EemHYc7DDM2g2A.xmi.uml': {'classes': ['animal',
#    'employee',
#    'tortoise',
#    'otter',
#    'slow loris',
#    'sea urchin',
#    'creep',
#    'lobby',
#    'bathroom',
#    'visitor center'],
#   'attributes': ['name',
#    'id',
#    'age',
#    'weight',
#    'name',
#    'employee id',
#    'phone',
#    'department',
#    'whisker length']},
#  '_WZQeEMJ8EeSII650IQ0Z1w.xmi.uml': {'classes': ['report settings',
#    'report settings accessor',
#    'report data manager',
#    'report accessor',
#    'report',
#    'aaaa']},
#  '_UBfU4MCnEeeEXb8Dudo6PQ.xmi.uml': {'classes': ['clone detection new ui',
#    'ddg right dialog',
#    'ddg bottom dialog',
#    'history spread sheet source',
#    'spread sheet object tree view',
#    'tree view spread sheet source',
#    'spread sheet object list view',
#    'list view spread sheet source',
#    'history spread sheet obj',
#    'similarity plot spread sheet obj',
#    'similarity plot spred sheet source']},
#  '_TCwTALi_Eeaud6jyFEReOw.xmi.uml': {'classes': ['casino',
#    'admin',
#    'game',
#    'table',
#    'player',
#    'gametype',
#    'rule'],
#   'attributes': ['id',
#    'name',
#    'id',
#    'password',
#    'starttime',
#    'number',
#    'connectedplrs',
#    'id',
#    'password',
#    'balance',
#    'game',
#    'maxplayer',
#    'id',
#    'desc']},
#  '_YlTgsCASEeiv8MB6k6XBAg.xmi.uml': {'classes': ['frame',
#    'control panel',
#    'drawing panel',
#    'rect',
#    'class',
#    'graphics',
#    'drawing panel',
#    'shape',
#    'circle',
#    'rect',
#    'drawing panel',
#    'circle',
#    'rect',
#    'circle',
#    'drawing panel',
#    'rect',
#    'drawing panel',
#    'shape',
#    'circle',
#    'dog',
#    'test',
#    'id generator',
#    'cat',
#    'rect',
#    'can be drawn',
#    'poly gen',
#    'slacker'],
#   'attributes': ['name', 'id', 'current id', 'id', 'name']},
#  '_O9PI8GyeEDGXH9FO528ZpA.xmi.uml': {'classes': ['dvd',
#    'book',
#    'library managnment system',
#    'item',
#    'staff',
#    'libarian',
#    'member',
#    'clerk'],
#   'attributes': ['type',
#    'count',
#    'type',
#    'count',
#    'item linker',
#    'mem',
#    'cler',
#    'availability',
#    'issued',
#    'onloan',
#    'reference',
#    'name',
#    'id',
#    'name',
#    'id']},
#  '93552bd2-6e15-45b3-b1dd-3a4aa6b3b0b3.xmi.uml': {'classes': ['chat server',
#    'chat client',
#    'couleur',
#    'history',
#    'user',
#    'session',
#    'frame']},
#  '_UWr2cM_JEeeLcIicqHdTUQ.xmi.uml': {'classes': ['currency converter',
#    'us currency converter',
#    'canadian currency converter',
#    'task controller',
#    'sales order',
#    'class',
#    'calc tax']},
#  '_tGyV0EbLEeeTJ_4Vl2J2rQ.xmi.uml': {'classes': ['example instrumented test',
#    'fight screen',
#    'start menu',
#    'about fragment',
#    'custom health bar',
#    'custom mana bar',
#    'custom menu button',
#    'custom menu play button',
#    'logo fragment',
#    'settings fragment',
#    'game',
#    'game panel',
#    'main thread',
#    'singleton',
#    'bitmap cache',
#    'character',
#    'dummy',
#    'enemy',
#    'exit',
#    'game object',
#    'ground',
#    'player',
#    'wall',
#    'level',
#    'section',
#    'example unit test'],
#   'attributes': ['player health text',
#    'enehealth text',
#    'player mana text',
#    'player action text',
#    'eneaction text',
#    'player image',
#    'eneimage',
#    'health potion button',
#    'mana potion button',
#    'attack button',
#    'special attack button',
#    'max volume',
#    'media player',
#    'volume for player',
#    'health',
#    'max health',
#    'black paint',
#    'red paint',
#    'mana',
#    'max mana',
#    'black paint',
#    'blue paint',
#    'width',
#    'height',
#    'horizontal tiles',
#    'vertical tiles',
#    'tile width',
#    'tile height',
#    'paint',
#    'fps',
#    'average fps',
#    'surface holder',
#    'running',
#    'canvas',
#    'context',
#    'cache',
#    'name',
#    'health',
#    'max health',
#    'attack',
#    'health',
#    'attack',
#    'max health',
#    'special atack',
#    'max mana',
#    'mana',
#    'name',
#    'amount of health potions',
#    'amount of mana potions',
#    'to section',
#    'solid',
#    'image',
#    'image reference',
#    'amount of health potions',
#    'amount of mana potions',
#    'mana',
#    'max mana',
#    'special attack']},
#  '_rRbrsL2FEeedTfUoC-GfaA.xmi.uml': {'classes': ['snake'],
#   'attributes': ['attribute']},
#  '45467683-bfda-4a59-aee6-262b47b819db.xmi.uml': {'classes': ['level',
#    'category'],
#   'attributes': ['state', 'name', 'id', 'level']},
#  '_qlo-cJalEeaLdJY0NVKqzQ.xmi.uml': {'classes': ['user']},
#  '_bTMxUGfCEDGY580vxrGduA.xmi.uml': {'classes': ['class']},
#  '_kUTfkMkMEeeM1PgT03-3Vg.xmi.uml': {'classes': ['login tbl',
#    'add news tbl',
#    'feedback tbl',
#    'employee tbl',
#    'registration tbl'],
#   'attributes': ['user name',
#    'password',
#    'id',
#    'news image',
#    'news description',
#    'bookmark',
#    'id',
#    'feedback',
#    'id',
#    'mail address',
#    'user name',
#    'password',
#    'city',
#    'dob',
#    'gender']},
#  '_89yH0D-DEeWH0sFqYQQ8Cg.xmi.uml': {'classes': ['server'],
#   'attributes': ['var']},
#  '_m43vEEhOEemB7r6RYSs12w.xmi.uml': {'classes': ['ads', 'event', 'product']},
#  '_pBW_QHLCEee5HMQDnOR-kg.xmi.uml': {'classes': ['crew',
#    'crew pilot',
#    'plane',
#    'schedule'],
#   'attributes': ['crew id',
#    'crew name',
#    'crew address',
#    'crew phone',
#    'pilot license',
#    'plane id',
#    'schedule time',
#    'schedule plane',
#    'schedule crew',
#    'schedule departure',
#    'schedule note',
#    'schedule arrival']},
#  '_7Qd5sHVJEeSZWo9AFr5YZg.xmi.uml': {'classes': ['benchmark controller',
#    'load driver',
#    'database',
#    'transaktions',
#    'remote',
#    'init database']},
#  '4465670b-b7f1-4505-8c09-e163b6a629a7.xmi.uml': {'classes': ['shopping cart']},
#  'b66a0071-5321-4795-a59c-96ff8cc34f37.xmi.uml': {'classes': ['worker',
#    'people',
#    'customer',
#    'cook',
#    'waiter',
#    'cashier'],
#   'attributes': ['name']},
#  '42797400-89dc-4192-8cac-7f67e4e4fbc3.xmi.uml': {'classes': ['registration'],
#   'attributes': ['attribute']},
#  '19cf5401-6e76-4e4d-81d8-309f156151f5.xmi.uml': {'classes': ['session repository filter',
#    'expiring session http session',
#    'multi http session strategy adapter',
#    'header http session strategy',
#    'expiring session']},
#  '_8y0sAIKDEeeveJPbhFhy-g.xmi.uml': {'classes': ['student registration',
#    'teachers registration',
#    'class']},
#  '_YRK-gLc7EeWh17zD5SB95Q.xmi.uml': {'classes': ['request',
#    'status',
#    'department',
#    'application user',
#    'request event',
#    'request event detail'],
#   'attributes': ['id',
#    'topic',
#    'status',
#    'department',
#    'citizen',
#    'assignee',
#    'events',
#    'id',
#    'comment',
#    'date',
#    'attribute',
#    'is public',
#    'author',
#    'details',
#    'id',
#    'text']},
#  '_0fYbULfaEee7sYPkE4-GPA.xmi.uml': {'classes': ['library',
#    'librarian',
#    'books database',
#    'student',
#    'vendor',
#    'student record'],
#   'attributes': ['location',
#    'name',
#    'book title',
#    'author',
#    'book id',
#    'details',
#    'book details',
#    'attribute',
#    'name',
#    'address',
#    'phone number',
#    'fines']},
#  '_Vfe9wHL5EeSxHp9pHOThjg.xmi.uml': {'classes': ['trader']},
#  'a093a6c4-4491-4b65-b79a-19be1bd57765.xmi.uml': {'classes': ['customer',
#    'payment',
#    'shopping cart',
#    'account',
#    'web user',
#    'order',
#    'line item',
#    'product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paid date',
#    'total',
#    'details',
#    'creation date',
#    'billing address',
#    'open',
#    'closed',
#    'is closed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'ship to',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description']},
#  '_2A0eUK99EealN5YbbDMqoA.xmi.uml': {'classes': ['modification',
#    'degree modifacion',
#    'module modification',
#    'obsever',
#    'observable',
#    'modify degree',
#    'delete degree',
#    'modify module',
#    'delete module'],
#   'attributes': ['mod id',
#    'status',
#    'title',
#    'degree code',
#    'level',
#    'module code',
#    'level',
#    'update',
#    'add observer observer observer',
#    'remove observer observer observer',
#    'notify all']},
#  '_fRRYMELoEeavkcsFwndrbA.xmi.uml': {'classes': ['animal'],
#   'attributes': ['name', 'size', 'color']},
#  '_bunGYGkdEeSmTqqtE6wM_Q.xmi.uml': {'classes': ['guest',
#    'user',
#    'player',
#    'moderator',
#    'email server',
#    'database',
#    'android application instance',
#    'clarification request',
#    'game',
#    'mission',
#    'kill',
#    'geo fence',
#    'geo point',
#    'page',
#    'global update',
#    'dynamic game map'],
#   'attributes': ['role id',
#    'hvzid',
#    'email',
#    'password',
#    'first name',
#    'last name',
#    'kills',
#    'created at',
#    'played games',
#    'paid dues',
#    'is subscribed',
#    'phone number',
#    'player type',
#    'in game',
#    'gps tracking on',
#    'name',
#    'ip',
#    'subscribed emails',
#    'username',
#    'password',
#    'emails to send',
#    'name',
#    'ip',
#    'username',
#    'password',
#    'instance id',
#    'user logged in',
#    'device name',
#    'latitude',
#    'longitude',
#    'time of gps',
#    'is tracking',
#    'mission id',
#    'is answered',
#    'response user',
#    'source user',
#    'message',
#    'response',
#    'game id',
#    'missions',
#    'description',
#    'players',
#    'is current',
#    'mission id',
#    'game id',
#    'geo fences',
#    'geo points',
#    'description',
#    'role id',
#    'vicitm user',
#    'killer user',
#    'time of death',
#    'in game id',
#    'center latitude',
#    'center longitude',
#    'radius',
#    'trigger players',
#    'score',
#    'score modifier',
#    'end score',
#    'description',
#    'in mission id',
#    'trigger rate',
#    'seen by players',
#    'is visible',
#    'latitude',
#    'longitude',
#    'description',
#    'in mission id',
#    'seen by players',
#    'is visible',
#    'url',
#    'information',
#    'title',
#    'message',
#    'source user',
#    'push notification sent',
#    'email notification sent',
#    'mission']},
#  'dc7ae9ed-7cf7-4298-844e-489bbc9faeea.xmi.uml': {'classes': ['shopping cart']},
#  '_SaUicIB4Eei-m5BAOg12zA.xmi.uml': {'classes': ['character',
#    'saving throw',
#    'weapon'],
#   'attributes': ['name',
#    'race',
#    'vocation',
#    'is player',
#    'str',
#    'dex',
#    'cons',
#    'intel',
#    'wis',
#    'chr',
#    'save throw',
#    'hp',
#    'hit dice',
#    'equipped',
#    'is proficient',
#    'prof bonus',
#    'name',
#    'range',
#    'damage',
#    'atk bonus']},
#  '_34klgCFXEeqqcaoAsxFIeg.xmi.uml': {'classes': ['book',
#    'reader',
#    'librarian',
#    'borrowing',
#    'user'],
#   'attributes': ['id',
#    'name',
#    'no',
#    'writer',
#    'press',
#    'address',
#    'total',
#    'id',
#    'name',
#    'no',
#    'age',
#    'sex',
#    'department',
#    'telephone number',
#    'id',
#    'name',
#    'no',
#    'sex',
#    'age',
#    'telephone number',
#    'date',
#    'id',
#    'username',
#    'password']},
#  '_lC7ZAGxcEem8aOzn3EOqfg.xmi.uml': {'classes': ['order']},
#  '1071140d-9c5d-46d3-aa90-f9b348ebfac9.xmi.uml': {'classes': ['customer',
#    'payment',
#    'shopping cart',
#    'account',
#    'web user',
#    'order',
#    'line item',
#    'product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paid date',
#    'total',
#    'details',
#    'creation date',
#    'billing address',
#    'open',
#    'closed',
#    'is closed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'ship to',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description']},
#  '72bffa82-db26-4d26-a139-b38884dada59.xmi.uml': {'classes': ['clients',
#    'login',
#    'administrator',
#    'who made changes',
#    'account expired',
#    'make pay',
#    'change password',
#    'events',
#    'add additional data',
#    'advance search']},
#  '_z-y1oKPNEeikWfbDNPV9UQ.xmi.uml': {'classes': ['class']},
#  '_iAN1sIYZEeS_9vPfFC3tSQ.xmi.uml': {'classes': ['dog',
#    'lab',
#    'poodle',
#    'shepard',
#    'pitbull',
#    'pug',
#    'beagle'],
#   'attributes': ['gender', 'breed', 'weight', 'color', 'eye color']},
#  '43125ec2-0e31-4d4d-98d2-2ca18c1a08ba.xmi.uml': {'classes': ['client',
#    'adaptor',
#    'adaptee']},
#  'b11d83f2-57be-4197-b073-33b29a12e551.xmi.uml': {'classes': ['worker',
#    'people',
#    'customer',
#    'cook',
#    'waiter',
#    'cashier'],
#   'attributes': ['name']},
#  '_ozUCAFmYEeaQF8q9ZsVYhQ.xmi.uml': {'classes': ['single data combiner',
#    'latest value combiner',
#    'greatest value combiner',
#    'custom combiner',
#    'combined combiner',
#    'priority combiner',
#    'rule based combiner']},
#  '_mu7qEH1yEeShroDxTnL5_A.xmi.uml': {'classes': ['single data combiner',
#    'latest value combiner',
#    'greatest value combiner',
#    'custom combiner',
#    'combined combiner',
#    'priority combiner',
#    'rule based combiner']},
#  '_vgKXsMUIEeadwOIOqK-0Fw.xmi.uml': {'classes': ['class']},
#  'd5c157b6-912e-4995-9d8f-bd5f2aa2ee9f.xmi.uml': {'classes': ['client',
#    'adapter implementation',
#    'adaptee',
#    'context',
#    'state a',
#    'state b',
#    'singleton',
#    'abstraction',
#    'refined abstraction',
#    'concrete implementor',
#    'creator implementation',
#    'product',
#    'concrete observer',
#    'concrete subject'],
#   'attributes': ['instance']},
#  '_Hr1JoIwLEeewrIfYd5mf8Q.xmi.uml': {'classes': ['monetate event',
#    'monetate event product view',
#    'monetate event purchase',
#    'monetate processor',
#    'product',
#    'message processor'],
#   'attributes': ['event type',
#    'products',
#    'purchase lines',
#    'name',
#    'setting api key',
#    'setting mailing list id',
#    'domain',
#    'instance',
#    'account id',
#    'api url',
#    'sku',
#    'pid',
#    'quantity',
#    'currency',
#    'value']},
#  'f959fb74-a45e-4e26-a37d-ff5dad352c49.xmi.uml': {'classes': ['worker',
#    'people',
#    'customer',
#    'cook',
#    'waiter',
#    'cashier'],
#   'attributes': ['name']},
#  'e62c26ba-de91-443d-8dec-baa035e40d26.xmi.uml': {'classes': ['shopping cart',
#    'order',
#    'line item',
#    'account',
#    'customer'],
#   'attributes': ['creation date', 'id', 'quantity', 'price', 'id']},
#  '_SHt8QP2_EeOTCK1Mp6laew.xmi.uml': {'classes': ['main class',
#    'about',
#    'documents',
#    'encryption',
#    'decryption',
#    'ss generator',
#    'app password']},
#  '_tWiXAE-oEeeu8_4LH_yuyg.xmi.uml': {'classes': ['core', 'person', 'company'],
#   'attributes': ['id', 'value', 'person code', 'registration nr', 'vat nr']},
#  '_0ato4He_EeeZ3IbHHpTTiA.xmi.uml': {'classes': ['adapter factory',
#    'google adapter factory',
#    'class',
#    'adapter',
#    'class',
#    'amazon adapter factory',
#    'google adapter',
#    'amazon adapter',
#    'generic request stream handler'],
#   'attributes': ['object mapper']},
#  '_yIWRYChXEeShcfbUiDP6ug.xmi.uml': {'classes': ['class', 'class'],
#   'attributes': ['name']},
#  '67ed9d27-56e3-4b81-8050-6e03eda242b5.xmi.uml': {'classes': ['worker',
#    'people',
#    'customer',
#    'cook',
#    'waiter',
#    'cashier'],
#   'attributes': ['name']},
#  '_cOog0CIgEeisAYMSV00L2Q.xmi.uml': {'classes': ['fields modification',
#    'created user modification',
#    'deleted user modification',
#    'user moved to group modification',
#    'grid index',
#    'grid index']},
#  'a670164a-9f45-46fe-bade-23f443485ab4.xmi.uml': {'classes': ['customer',
#    'account',
#    'transaction',
#    'checking account',
#    'savings account',
#    'login',
#    'deposit transaction',
#    'withdraw transaction',
#    'transfer transaction',
#    'certificates of deposit account'],
#   'attributes': ['name',
#    'date of birth',
#    'address',
#    'phone number',
#    'email address',
#    'account no',
#    'type',
#    'balance',
#    'id',
#    'type',
#    'transaction time',
#    'amount',
#    'interest rate',
#    'username',
#    'password',
#    'security question',
#    'security answer',
#    'last login time',
#    'target account',
#    'source account',
#    'interest rate',
#    'time period']},
#  'efd35011-a6c9-4b9a-b62e-d5daa9b58968.xmi.uml': {'classes': ['user'],
#   'attributes': ['attribute']},
#  'd779e6fe-c0ae-4f71-816a-5cdd632e89f1.xmi.uml': {'classes': ['customer',
#    'payment',
#    'shopping cart',
#    'account',
#    'web user',
#    'order',
#    'line item',
#    'product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paid date',
#    'total',
#    'details',
#    'creation date',
#    'billing address',
#    'open',
#    'closed',
#    'is closed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'ship to',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description']},
#  '_OxdDoEymEeS9L4cMWDc7Qg.xmi.uml': {'attributes': ['load']},
#  '_I_lnENTGEeehRMl7r1-c5g.xmi.uml': {'classes': ['curved line',
#    'sketchy ellipse',
#    'sketchy rectangle',
#    'shape creator',
#    'line drawer',
#    'shape mover',
#    'shape resizer',
#    'shape rotater',
#    'shape filler',
#    'shape deleter',
#    'shape raiser',
#    'shape lowerer']},
#  '_zTvrkGm3EDGB-uCsYzbtRg.xmi.uml': {'classes': ['game window']},
#  'af8ad990-19e3-488e-b4b8-846b6643f25b.xmi.uml': {'classes': ['customer',
#    'payment',
#    'shoppin cart',
#    'account',
#    'web user',
#    'order',
#    'line item',
#    'product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paid date',
#    'total',
#    'details',
#    'creation date',
#    'billing address',
#    'open',
#    'closed',
#    'is closed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'ship to',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description']},
#  'd6ed4740-d12b-4899-a2db-2374a6c7c4b5.xmi.uml': {'classes': ['client',
#    'adapter implementation',
#    'adaptee',
#    'context',
#    'state a',
#    'state b',
#    'singleton',
#    'abstraction',
#    'refined abstraction',
#    'concrete implementor',
#    'creator implementation',
#    'product',
#    'concrete observer',
#    'concrete subject',
#    'method class',
#    'class object'],
#   'attributes': ['instance']},
#  '_NI0-EMYEEeeWu-SLkciAbg.xmi.uml': {'classes': ['temp sensor', 'arduino'],
#   'attributes': ['vout', 'volts', 'celsius', 'farfahrenheit']},
#  'b9dfe65c-12b6-498b-a151-0343da867aef.xmi.uml': {'classes': ['client',
#    'adapter implementation',
#    'adaptee',
#    'context',
#    'state a',
#    'state b',
#    'singleton',
#    'abstraction',
#    'refined abstraction',
#    'concrete implementor',
#    'creator implementation',
#    'product',
#    'concrete observer',
#    'concrete subject'],
#   'attributes': ['instance']},
#  '_RwyPkIPfEeaY2ZFk8hIg9A.xmi.uml': {'classes': ['db object'],
#   'attributes': ['table',
#    'index',
#    'uid',
#    'uid length',
#    'delete',
#    'columns',
#    'fillable',
#    'hidden',
#    'generators']},
#  '431e2d5d-fa76-4ca1-a879-a927d293c394.xmi.uml': {'classes': ['client',
#    'adapter implementation',
#    'adaptee',
#    'context',
#    'state a',
#    'state b',
#    'singleton',
#    'abstraction',
#    'refined abstraction',
#    'concrete implementor',
#    'creator implementation',
#    'product',
#    'concrete observer',
#    'concrete subject'],
#   'attributes': ['instance']},
#  '_OJVuMFlJEeWH7tmnkVHu6g.xmi.uml': {'classes': ['patrons', 'library staff'],
#   'attributes': ['holder',
#    'name',
#    'date',
#    'student',
#    'faculty',
#    'library staff',
#    'books',
#    'overdue fee',
#    'check out time']},
#  '_butz8NjbEeWjYr7I4V0e0A.xmi.uml': {'classes': ['charge account'],
#   'attributes': ['customer no', 'attribute']},
#  '310b8bef-1a4e-4692-b437-a6a5453e1c31.xmi.uml': {'classes': ['customer',
#    'payment',
#    'shopping cart',
#    'account',
#    'web user',
#    'order',
#    'line item',
#    'product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paid date',
#    'total',
#    'details',
#    'creation date',
#    'billing address',
#    'open',
#    'closed',
#    'is closed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'ship to',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description']},
#  '7aff64ad-90b0-450f-bf8c-1f4b9c3b8f37.xmi.uml': {'classes': ['shopping cart']},
#  'f34f1233-c3f1-48df-b830-6c1e81f51751.xmi.uml': {'classes': ['abstraction',
#    'refined abstraction',
#    'concrete implementor']},
#  'f6e1ef7a-107f-419e-ab7d-a51aa49c13d2.xmi.uml': {'classes': ['snake',
#    'game',
#    'program',
#    'food',
#    'display',
#    'player',
#    'unit',
#    'random'],
#   'attributes': ['face',
#    'speed',
#    'size',
#    'unit',
#    'snake',
#    'food',
#    'display',
#    'player',
#    'life',
#    'face',
#    'to be',
#    'height',
#    'width',
#    'space',
#    'wall',
#    'score position',
#    'game resume position',
#    'game over postion',
#    'command']},
#  '_-g260KW7EeaiBJ7PH1W80g.xmi.uml': {'classes': ['event',
#    'customer',
#    'agency',
#    'seven user',
#    'user activity relation',
#    'user register event relation',
#    'activity',
#    'log attendee',
#    'attendee activity',
#    'survey',
#    'question',
#    'response attendee',
#    'attendee',
#    'role mapping'],
#   'attributes': ['id',
#    'title',
#    'date created',
#    'date started',
#    'description',
#    'place',
#    'status',
#    'stage',
#    'brochure',
#    'timezone',
#    'user id',
#    'customer id',
#    'id',
#    'name',
#    'description',
#    'agency id',
#    'user id',
#    'id',
#    'name',
#    'description',
#    'user id',
#    'id',
#    'type',
#    'firstname',
#    'lastname',
#    'email',
#    'created',
#    'lastupdated',
#    'image user',
#    'id',
#    'sevenuser id',
#    'activity id',
#    'id',
#    'sevenuser id',
#    'event id',
#    'id',
#    'name',
#    'description',
#    'start',
#    'duration',
#    'limit',
#    'event id',
#    'user id',
#    'on demand count',
#    'evaluation count',
#    'registers',
#    'space availbale',
#    'id',
#    'status',
#    'date',
#    'attendee id',
#    'event id',
#    'id',
#    'attendee id',
#    'activity id',
#    'id',
#    'event id',
#    'activity id',
#    'user id',
#    'id',
#    'text',
#    'type',
#    'answer',
#    'time',
#    'send',
#    'survey id',
#    'id',
#    'date',
#    'response',
#    'attendee id',
#    'question id',
#    'id',
#    'age',
#    'email original',
#    'organization',
#    'status',
#    'location',
#    'birthyear',
#    'notification',
#    'email',
#    'platform',
#    'typecheck',
#    'event id',
#    'user id',
#    'id',
#    'sevenuser id',
#    'role id',
#    'type']},
#  '19515821-de9c-4371-ab13-0c10c1f0741e.xmi.uml': {'classes': ['client',
#    'adapter implementation',
#    'adaptee',
#    'context',
#    'state a',
#    'state b',
#    'singleton',
#    'abstraction',
#    'refined abstraction',
#    'concrete implementor',
#    'creator implementation',
#    'product',
#    'concrete observer',
#    'concrete subject'],
#   'attributes': ['instance']},
#  '_w3lJ8AP7Eeewntt9CKbg3g.xmi.uml': {'classes': ['user',
#    'team',
#    'channel',
#    'message',
#    'user settings',
#    'team settings',
#    'channel settings',
#    'channel activity',
#    'user account',
#    'dirrect message'],
#   'attributes': ['username',
#    'team',
#    'name',
#    'url',
#    'name',
#    'status',
#    'purpose',
#    'date',
#    'content',
#    'notifications',
#    'sound',
#    'display',
#    'threads',
#    'highlight words',
#    'do not disturb from',
#    'do not disturb to',
#    'sign up mode',
#    'default channels',
#    'username guidelines',
#    'name display',
#    'require for mention',
#    'email display',
#    'do not disturb from',
#    'do not disturb to',
#    'hide url',
#    'enable calls',
#    'calling app',
#    'message retention',
#    'file retention',
#    'team icon',
#    'desktop notifications',
#    'push notificationa',
#    'mute channel',
#    'include user group mentions',
#    'include channel mentions',
#    'first name',
#    'last name',
#    'what i do',
#    'email',
#    'phone',
#    'timezone',
#    'skype id',
#    'photo',
#    'password']},
#  '49a9a179-f2f3-4517-994e-148391be8053.xmi.uml': {'classes': ['client',
#    'adaptor',
#    'adaptee',
#    'class']},
#  '_1fv_cGAzEeepGY91r9Nuow.xmi.uml': {'classes': ['category',
#    'products',
#    'product size',
#    'order details',
#    'class',
#    'class',
#    'class',
#    'class',
#    'class',
#    'orders',
#    'order category',
#    'class',
#    'class',
#    'class'],
#   'attributes': ['category id',
#    'category description',
#    'product id',
#    'product name',
#    'image',
#    'category id',
#    'is active',
#    'prod size id',
#    'product id',
#    'size id',
#    'price',
#    'order details id',
#    'order id',
#    'product size id',
#    'quantity',
#    'price per product',
#    'order id',
#    'adderess',
#    'client id',
#    'order date',
#    'center id',
#    'category id',
#    'order cat id',
#    'category desc']},
#  '8b08c90b-c7d3-4afd-b0e9-3dfe67ed7de3.xmi.uml': {'classes': ['shopping cart',
#    'order',
#    'line item',
#    'account',
#    'customer'],
#   'attributes': ['creation date', 'id', 'quantity', 'price', 'id']},
#  'd29cd2f3-9ae8-4c52-97f5-7cf07f4cdd10.xmi.uml': {'classes': ['singleton'],
#   'attributes': ['instance']},
#  '6c84d80a-0e28-40ab-957c-531b57921306.xmi.uml': {'classes': ['customer',
#    'payment',
#    'shopping cart',
#    'account',
#    'web user',
#    'order',
#    'line item',
#    'product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paid date',
#    'total',
#    'details',
#    'creation date',
#    'billing address',
#    'open',
#    'closed',
#    'is closed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'ship to',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description']},
#  '9232d81e-dab5-49d8-9e89-8a4ff91278b1.xmi.uml': {'classes': ['create analysis action',
#    'service',
#    'analysis dao',
#    'analysis dao'],
#   'attributes': ['analysis name']},
#  '_WfyX0MIFEeacM55raX9d3Q.xmi.uml': {'classes': ['producer text generator',
#    'text',
#    'consumer text analyz',
#    'scanner text']},
#  '_KlkTALgHEeSzkacHLregNQ.xmi.uml': {'classes': ['order'],
#   'attributes': ['order id;', 'order ...']},
#  '_XgXMwH_9EeW4cd-qm4QbpA.xmi.uml': {'classes': ['employee', 'rooms'],
#   'attributes': ['id', 'first name', 'last name', 'number']},
#  '40adfe9e-25a9-426a-806e-9ff9a56b4da2.xmi.uml': {'classes': ['worker',
#    'people',
#    'customer',
#    'cook',
#    'waiter',
#    'cashier'],
#   'attributes': ['name']},
#  '_lWq_kF4WEeSmRKwulsG6-Q.xmi.uml': {'classes': ['user',
#    'massage',
#    'profile',
#    'post',
#    'group',
#    'friends',
#    'login',
#    'notification',
#    'admin',
#    'member']},
#  '9462f4aa-aea2-4c9e-afcb-cfcfbd414c85.xmi.uml': {'classes': ['shopping cart',
#    'order',
#    'line item',
#    'account',
#    'customer'],
#   'attributes': ['creation date', 'id', 'quantity', 'price', 'id']},
#  '538864d8-e066-49c5-8edd-4ab0fca7f62b.xmi.uml': {'classes': ['person',
#    'professor',
#    'employee',
#    'full professor',
#    'associate',
#    'assistant',
#    'office',
#    'university',
#    'classroom',
#    'room',
#    'building'],
#   'attributes': ['id', 'name', 'seats number', 'floor', 'number']},
#  '_5pZpkNHiEeaJwt5yAqWnTg.xmi.uml': {'classes': ['class',
#    'class',
#    'wifi',
#    'class',
#    'simcard',
#    'system',
#    'database']},
#  'e12b7943-feab-4c7d-9330-61358c7afece.xmi.uml': {'classes': ['customer',
#    'payment',
#    'shopping cart',
#    'account',
#    'web user',
#    'order',
#    'line item',
#    'product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paid date',
#    'total',
#    'details',
#    'creation date',
#    'billing address',
#    'open',
#    'closed',
#    'is closed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'ship to',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description']},
#  '_IC_G0MiPEeeM1PgT03-3Vg.xmi.uml': {'classes': ['physical users',
#    'online users',
#    'clerk',
#    'admin',
#    'database',
#    'payment',
#    'mobile user',
#    'online ticket',
#    'physical ticket']},
#  '_P7zdMN_uEeS6FO4vn2oOjA.xmi.uml': {'classes': ['suit'],
#   'attributes': ['input code']},
#  '3d99155b-5099-4121-bba7-934dfece62cb.xmi.uml': {'classes': ['shopping cart',
#    'order',
#    'line item',
#    'account',
#    'customer',
#    'class',
#    'client',
#    'client',
#    'platform'],
#   'attributes': ['creation date', 'id', 'quantity', 'price', 'id']},
#  '_DF3R0BwbEeig8qiayYYCew.xmi.uml': {'classes': ['person',
#    'faculty',
#    'student',
#    'raffle',
#    'prize'],
#   'attributes': ['first name',
#    'last name',
#    'gender',
#    'years of service',
#    'subject area',
#    'prize',
#    'class',
#    'age',
#    'prize',
#    'registrants',
#    'sorted registrants',
#    'prizes',
#    'name',
#    'company name']},
#  '_-WIY4KnoEeS9iunt9iMoeg.xmi.uml': {'classes': ['abstract game',
#    'chess',
#    'monopoly']},
#  'cccd46b7-9b3e-44d4-84fc-e2153cf70d58.xmi.uml': {'classes': ['client',
#    'adaptor',
#    'adaptee']},
#  '_bEYN8LBCEee6S77dw3LIvQ.xmi.uml': {'classes': ['person', 'class'],
#   'attributes': ['name', 'email']},
#  '_2p9bEMasEeadwOIOqK-0Fw.xmi.uml': {'classes': ['pay u',
#    'order status abstract',
#    'payment status',
#    'con',
#    'configuration'],
#   'attributes': ['configuration']},
#  '3bddae18-8bff-498f-b478-8d075c718bdb.xmi.uml': {'classes': ['adaptor',
#    'adaptee',
#    'class']},
#  '_AhnLoDyqEeW9u4XU-cgAEg.xmi.uml': {'classes': ['users',
#    'administrator',
#    'moderator'],
#   'attributes': ['username',
#    'user id',
#    'password',
#    'email',
#    'is reported',
#    'reported by',
#    'gender',
#    'interests',
#    'level']},
#  '7f09e59b-ca7a-4f32-ba33-39e6aad74ffb.xmi.uml': {'classes': ['fascia',
#    'class',
#    'class',
#    'class',
#    'class',
#    'class',
#    'class',
#    'class',
#    'class',
#    'class'],
#   'attributes': ['sku', 'location']},
#  '1c86b445-6a08-4061-8e8d-713470a1a5a1.xmi.uml': {'classes': ['game character',
#    'game character young',
#    'game character hendrix',
#    'game character slash',
#    'fire',
#    'jump',
#    'smash',
#    'fender telecaster',
#    'gibson sg',
#    'gibson flying v'],
#   'attributes': ['solo behavior', 'guitar']},
#  '_w1dYIBQJEeSTV6l4790RsQ.xmi.uml': {'classes': ['group']},
#  '_Obp_gA1fEDGXt505FSVm0A.xmi.uml': {'classes': ['customer',
#    'customer settings'],
#   'attributes': ['customer id',
#    'customer settings id',
#    'customer settings name']},
#  '276f29cd-9e94-4d30-9297-419d311bf7f1.xmi.uml': {'classes': ['shopping cart']},
#  '_h1XSAIPVEeaY2ZFk8hIg9A.xmi.uml': {'classes': ['server',
#    'client 1',
#    'client 2'],
#   'attributes': ['ip add', 'ip add', 'port', 'ip add', 'port']},
#  '_ldoVwNkxEeSpEswBeJxMRQ.xmi.uml': {'classes': ['class']},
#  '_vIhT4OgfEeaowdqlt8Dqsg.xmi.uml': {'classes': ['employee', 'maid', 'class'],
#   'attributes': ['cpf', 'name', 'rg', 'birth date', 'salary', 'manager cpf']},
#  '_L-JrsG4TEeWaXcNfe1NfXw.xmi.uml': {'classes': ['patient',
#    'doctor',
#    'insurance carrier'],
#   'attributes': ['name',
#    'age',
#    'hobbies/occupation',
#    'phone',
#    'blood type',
#    'insurance carrier',
#    'specialty',
#    'provider id',
#    'golf handicap',
#    'age',
#    'phone',
#    'name',
#    'name',
#    'plan number of patients',
#    'address',
#    'contact name',
#    'phone']},
#  '_1LmLMPQdEDC2buyP2c7R5g.xmi.uml': {'classes': ['class']},
#  '_FOrkUMkSEeS7aOEhqX8e2w.xmi.uml': {'classes': ['test']},
#  '_6fweIGWXEeaj4o_Vw1bWAQ.xmi.uml': {'classes': ['chromosome',
#    'gene',
#    'genotype'],
#   'attributes': ['length', 'genotype', 'locus', 'size', 'genes', 'sequence']},
#  '_Lb07kC62EeWNN9jB-PYuYA.xmi.uml': {'classes': ['form config assoc',
#    'form data',
#    'form date',
#    'form config org assoc',
#    'vehicle',
#    'vehicle model',
#    'vehicle category',
#    'vehicle type',
#    'order',
#    'order item',
#    'order pickup location',
#    'order item dropoff',
#    'order dropoff location'],
#   'attributes': ['form type',
#    'form',
#    'orgs',
#    'org types',
#    'form config org assoc',
#    'form date',
#    'form status',
#    'form data',
#    'form config assoc',
#    'frequency',
#    'month',
#    'day',
#    'form config assoc',
#    'task org assoc',
#    'user',
#    'id',
#    'vehicle category id',
#    'vehicle model id',
#    'imported year',
#    'manufactured year',
#    'id',
#    'name',
#    'vehicle type id',
#    'id',
#    'name',
#    'id',
#    'name',
#    'id',
#    'vehicle category id',
#    'vehicle model id',
#    'status',
#    'orderer customer id',
#    'teeverlegch customer id',
#    'price',
#    'computed price',
#    'order type id',
#    'is payed',
#    'tonog id',
#    'id',
#    'order id',
#    'order pickup location',
#    'quantity',
#    'weight',
#    'picked up quantity',
#    'name',
#    'id',
#    'order id',
#    'longitude',
#    'latitude',
#    'official address description',
#    'time to arrive',
#    'person phone number',
#    'person name',
#    'is driver arrived',
#    'arrived date',
#    'id',
#    'order id',
#    'order item id',
#    'order dropoff location',
#    'drop off quantity',
#    'dropped off quantity',
#    'dropped off weight',
#    'comment',
#    'id',
#    'order id',
#    'longitude',
#    'latitude',
#    'official address description',
#    'time to arrive',
#    'person phone number',
#    'person name',
#    'is driver arrived',
#    'arrived date']},
#  '_euYykBniEeig8qiayYYCew.xmi.uml': {'classes': ['socket adapter connection',
#    'class',
#    'class',
#    'class',
#    'class'],
#   'attributes': ['host', 'port', 'read timeout', 'attribute']},
#  '7f74e038-a2ab-490f-a947-cb693d75c7bc.xmi.uml': {'classes': ['customer',
#    'epost',
#    'custtype',
#    'custverify',
#    'employee',
#    'addresshistory',
#    'department'],
#   'attributes': ['cust id',
#    'name',
#    'dob',
#    'sex',
#    'email',
#    'telno',
#    'epostid',
#    'typeofpost',
#    'price',
#    'dateofpost',
#    'dateofdelivery',
#    'deliverystatus',
#    'custtype',
#    'proof',
#    'prooftype',
#    'proofid',
#    'employeeid',
#    'empid',
#    'enmae',
#    'empdesg',
#    'sex',
#    'dob',
#    'dept',
#    'epostid',
#    'custmerid',
#    'employeeid',
#    'houseno',
#    'streetname',
#    'state',
#    'pincode',
#    'dept',
#    'deptloc']},
#  '_MwRoEG2vEea5146oo2aJcA.xmi.uml': {'classes': ['service type']},
#  '_aRWv8JdZEeS67M2cXIV9Bg.xmi.uml': {'classes': ['registration',
#    'login',
#    'start screen',
#    'embedder',
#    'decode message'],
#   'attributes': ['name',
#    'username',
#    'password',
#    'username',
#    'password',
#    'key',
#    'secret image',
#    'cover image',
#    'stego image',
#    'secret image',
#    'stego image',
#    'cover image',
#    'key']},
#  'c3f8a27b-30d7-4977-a46f-7a8343242752.xmi.uml': {'classes': ['shopping cart',
#    'order',
#    'line item',
#    'account',
#    'customer'],
#   'attributes': ['creation date', 'id', 'quantity', 'price', 'id']},
#  'a90e2ad8-f267-4477-8b35-eb703ff5a89f.xmi.uml': {'classes': ['singleton'],
#   'attributes': ['instance']},
#  '_zQy7gLr_EeedTfUoC-GfaA.xmi.uml': {'classes': ['student',
#    'teacher',
#    'administrator',
#    'module',
#    'course',
#    'semester',
#    'schedule',
#    'news',
#    'person',
#    'group',
#    'department'],
#   'attributes': ['id',
#    'name',
#    'id',
#    'name',
#    'id',
#    'id',
#    'modulename',
#    'id',
#    'number',
#    'id',
#    'number',
#    'id',
#    'id',
#    'name',
#    'id',
#    'name',
#    'id',
#    'name',
#    'id',
#    'name']},
#  '_iMiR4LpSEeehVczkwiTSNA.xmi.uml': {'classes': ['level 1', 'class']},
#  'ac7c98a6-a92b-4471-acdc-6960b1614d09.xmi.uml': {'classes': ['client',
#    'adaptor',
#    'adaptee']},
#  '_bP9hAF49EeWRjvSzyrJtjA.xmi.uml': {'classes': ['vending machine'],
#   'attributes': ['attribute']},
#  '_Th1I8KqkEeeEQN1ZyOr-_g.xmi.uml': {'classes': ['person'],
#   'attributes': ['name']},
#  '_AMMRQO8PEeWfK4n0bJNoaw.xmi.uml': {'classes': ['comstomer',
#    'book',
#    'class',
#    'copy',
#    'car',
#    'shoping cart'],
#   'attributes': ['name',
#    'phone',
#    'email',
#    'street',
#    'city',
#    'zipcode',
#    'copy',
#    'book',
#    'number',
#    'comstomer',
#    'book']},
#  '_2BcIAJ8yEemddr62D2Sizg.xmi.uml': {'classes': ['client', 'salon'],
#   'attributes': ['encpt']},
#  '_Y8-WIOcNEeiDGLvZhbPYyA.xmi.uml': {'classes': ['account'],
#   'attributes': ['account name',
#    'account balance',
#    'account interest rate',
#    'open date',
#    'last interest date']},
#  '_NZOj8K2WEDGNWLI2ml8Hng.xmi.uml': {'classes': ['class']},
#  'c824fb04-92a0-4d0f-a04c-cdace66c7dff.xmi.uml': {'classes': ['customer',
#    'hotel',
#    'room',
#    'service'],
#   'attributes': ['name',
#    'surname',
#    'phone number',
#    'ident',
#    'email',
#    'street',
#    'city',
#    'zip',
#    'coordinates',
#    'name',
#    'phone number',
#    'website',
#    'floor',
#    'door',
#    'capacity',
#    'price',
#    'name',
#    'description',
#    'base price']},
#  '_UWBdoHjTEeSYU-Ff_V1D0Q.xmi.uml': {'classes': ['baking numbers']},
#  '_KT16wNW1EeWUcZFfD54kTA.xmi.uml': {'classes': ['exhibit e',
#    'exhibit billling cost',
#    'sys billing item',
#    'client'],
#   'attributes': ['exhibit id',
#    'exhibit name',
#    'effective date',
#    'created on',
#    'created by',
#    'deleted on',
#    'deleted by',
#    'exhibit',
#    'billing item',
#    'flat cost',
#    'per unit cost',
#    'billing item id',
#    'exhibit']},
#  '8402fdce-1e6b-429c-acfb-7fcc4f3dff2e.xmi.uml': {'classes': ['abstraction',
#    'refined abstraction',
#    'concrete implementor']},
#  '_87dtkLjcEeehVczkwiTSNA.xmi.uml': {'classes': ['customer', 'driver'],
#   'attributes': ['customer id',
#    'username',
#    'password',
#    'phone number',
#    'credit card number',
#    'expiration number',
#    'security code',
#    'driver id',
#    'user name',
#    'password',
#    'phone number',
#    'driver license',
#    'vin',
#    'car model']},
#  '45061643-114a-4737-bca8-37d19df67a31.xmi.uml': {'classes': ['customer',
#    'payment',
#    'shopping cart',
#    'account',
#    'web user',
#    'order',
#    'line item',
#    'product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paid date',
#    'total',
#    'details',
#    'creation date',
#    'billing address',
#    'open',
#    'closed',
#    'is closed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'ship to',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description']},
#  '_8Ux_QFaxEeSu48YT12vqpQ.xmi.uml': {'classes': ['game']},
#  'bba13b27-ba8f-4bc4-a40b-73995144b2f5.xmi.uml': {'classes': ['worker',
#    'people',
#    'customer',
#    'cook',
#    'waiter',
#    'cashier'],
#   'attributes': ['name']},
#  '_dhhAAFQ4EeSu48YT12vqpQ.xmi.uml': {'classes': ['client']},
#  '9a34ca4a-2350-4ee6-84f3-4e30702f7adc.xmi.uml': {'classes': ['player',
#    'card',
#    'session'],
#   'attributes': ['id',
#    'name',
#    'hand',
#    'suit',
#    'rank',
#    'color',
#    'id',
#    'players',
#    'card deck',
#    'discard pile',
#    'human turn',
#    'human pointer',
#    'current player pointer',
#    'game status',
#    'game status code']},
#  '9f4e07e1-d566-48e2-a35f-0cdcad766e68.xmi.uml': {'classes': ['shopping cart',
#    'order',
#    'line item',
#    'account',
#    'customer'],
#   'attributes': ['creation date', 'id', 'quantity', 'price', 'id']},
#  '_cgLGwBQ8EDG5BIfIHENgJA.xmi.uml': {'classes': ['borrower',
#    'user',
#    'librarian',
#    'clerk',
#    'item',
#    'lms'],
#   'attributes': ['name',
#    'phone',
#    'address',
#    'id',
#    'password',
#    'name',
#    'users',
#    'items']},
#  '27c67ae6-40d4-45b6-85aa-59bfafe83911.xmi.uml': {'classes': ['adapter implementation',
#    'adaptee',
#    'aon session',
#    'dbt session']},
#  'bbb6c8f7-6241-4cac-abd1-f65236dd440f.xmi.uml': {'classes': ['shopping cart',
#    'order',
#    'line item',
#    'account',
#    'customer'],
#   'attributes': ['creation date', 'id', 'quantity', 'price', 'id']},
#  '_arOCQOkeEeiV94kHgjpOMg.xmi.uml': {'classes': ['account',
#    'default rate',
#    'team',
#    'payment',
#    'employee',
#    'position',
#    'grade name',
#    'locaal',
#    'wing',
#    'floor',
#    'room',
#    'building',
#    'position names',
#    'work periods',
#    'phone number'],
#   'attributes': ['name',
#    'how often',
#    'default rates',
#    'payments',
#    'active',
#    'rate',
#    'team',
#    'account',
#    'person',
#    'position',
#    'grade',
#    'start date',
#    'acrive',
#    'name',
#    'positions',
#    'defalut rates',
#    'schedules',
#    'active',
#    'current period',
#    'attribute',
#    'team',
#    'position name',
#    'grade name',
#    'min',
#    'max',
#    'defalt rate list',
#    'name',
#    'active',
#    'type',
#    'value',
#    'name',
#    'building',
#    'active',
#    'phone numbers',
#    'name',
#    'wing',
#    'building',
#    'active',
#    'phone numbers',
#    'name',
#    'floor',
#    'wing',
#    'building',
#    'active',
#    'phone numbers',
#    'locaals',
#    'name',
#    'address',
#    'active',
#    'phone numbers',
#    'name',
#    'active']},
#  '_EkM5ANxPEeS1iL_C3WP8Cw.xmi.uml': {'classes': ['account',
#    'branch',
#    'customer']},
#  '_13roEJt0EDGdyoFyp4l9hw.xmi.uml': {'classes': ['http handler']},
#  '_MMXUYLMBEee7sYPkE4-GPA.xmi.uml': {'classes': ['order']},
#  '_j9d-UMNOEeiEvZKVGztTtA.xmi.uml': {'classes': ['diapo',
#    'pseudo state attribute']},
#  '_ynu5wGmjEeWV2JKytOl5tA.xmi.uml': {'classes': ['cashier',
#    'shiftmanager',
#    'storemanager',
#    'salary',
#    'cashier copy'],
#   'attributes': ['id',
#    'store id',
#    'first name',
#    'last name',
#    'description',
#    'username',
#    'password',
#    'attributesdads',
#    'id',
#    'store id',
#    'first name',
#    'last name',
#    'description',
#    'username',
#    'password']},
#  '_UxXH4Ji_EeWP9KF1Y_wKUg.xmi.uml': {'classes': ['pizza pricer'],
#   'attributes': ['ordno',
#    'pie style',
#    'qty',
#    'size',
#    'crust',
#    'topping',
#    'price',
#    'calc price']},
#  '_Y8T8YPQpEee2hpeWh535Sw.xmi.uml': {'classes': ['enroll member',
#    'member registration bo',
#    'member registration dao',
#    'insurance details dao',
#    'insurance type dao',
#    'insurance type']},
#  '_L3nBMJKwEDG_H5RkFjJqjg.xmi.uml': {'classes': ['sports statistic',
#    'sport',
#    'sport player'],
#   'attributes': ['name',
#    'value',
#    'name',
#    'number players',
#    'name',
#    'sport',
#    'statistics']},
#  '_vZBssKMfEeScLuNN63kNaQ.xmi.uml': {'classes': ['issue',
#    'issue comparator',
#    'git issues',
#    'issue list',
#    'issues manager',
#    'parser',
#    'parser copy',
#    'pre commit validation hook'],
#   'attributes': ['id', 'assignee', 'milestone', 'etc']},
#  '_TZw24D7cEeeTJ_4Vl2J2rQ.xmi.uml': {'classes': ['sound implementation'],
#   'attributes': ['sound', 'stopped']},
#  '81cc1306-0a28-4d85-9c34-200894b60533.xmi.uml': {'classes': ['doctor',
#    'department',
#    'patient',
#    'room',
#    'receptionist',
#    'person',
#    'bill',
#    'staff',
#    'nurse'],
#   'attributes': ['docid',
#    'name',
#    'department',
#    'specialization',
#    'phno',
#    'address',
#    'id',
#    'name',
#    'doctorid',
#    'id',
#    'name',
#    'telno',
#    'address',
#    'age',
#    'sex',
#    'roomno',
#    'roomno',
#    'location',
#    'id',
#    'attribute',
#    'id',
#    'name',
#    'type',
#    'billno',
#    'patientname',
#    'amount']},
#  '774cd1f7-5d0d-4b74-8f58-ea6b607ee210.xmi.uml': {'classes': ['customer',
#    'payment',
#    'shopping cart',
#    'account',
#    'web user',
#    'order',
#    'line item',
#    'product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paid date',
#    'total',
#    'details',
#    'creation date',
#    'billing address',
#    'open',
#    'closed',
#    'is closed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'ship to',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description']},
#  '5ec7b8ac-d712-4080-a14b-a3fa82254df9.xmi.uml': {'classes': ['customer',
#    'payment',
#    'shopping cart',
#    'account',
#    'web user',
#    'order',
#    'line item',
#    'product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paid date',
#    'total',
#    'details',
#    'creation date',
#    'billing address',
#    'open',
#    'closed',
#    'is closed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'ship to',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description']},
#  '_Jzr_MOUSEeiyGtLb2crGgA.xmi.uml': {'classes': ['person', 'student']},
#  'c1341031-df4f-4944-9e10-700e689e790c.xmi.uml': {'classes': ['singleton'],
#   'attributes': ['instance']},
#  '476351ef-8606-4ac0-a650-956f050782a6.xmi.uml': {'classes': ['shopping cart',
#    'order',
#    'line item',
#    'account',
#    'customer'],
#   'attributes': ['creation date', 'id', 'quantity', 'price', 'id']},
#  '_IOPOkPeNEeiqn80yrzdh8w.xmi.uml': {'classes': ['class'],
#   'attributes': ['attribute']},
#  '_1kmiUA6EEeWa5JwclR5VRw.xmi.uml': {'classes': ['king',
#    'queen',
#    'troll',
#    'knight',
#    'knife behaviour',
#    'bow and arrow behaviour',
#    'axe behaviour',
#    'sword behaviour']},
#  '_SbCXELjpEeehVczkwiTSNA.xmi.uml': {'classes': ['customer', 'driver'],
#   'attributes': ['customer id',
#    'username',
#    'password',
#    'phone number',
#    'credit card number',
#    'credit card exp date',
#    'credit card security code',
#    'driver id',
#    'username',
#    'password',
#    'phone number',
#    'drivers license',
#    'vin number',
#    'car make',
#    'car model',
#    'car color']},
#  '8a5e4649-953b-4264-a675-b4c45d360f81.xmi.uml': {'classes': ['abstraction',
#    'refined abstraction',
#    'concrete implementor']},
#  '_Fl9-0LhJEee7sYPkE4-GPA.xmi.uml': {'classes': ['vegetation',
#    'class',
#    'state'],
#   'attributes': ['state', 'attribute']},
#  '_WxBmoIdcEeS_9vPfFC3tSQ.xmi.uml': {'classes': ['start activity',
#    'message',
#    'vendor',
#    'vendor scanner le implementation',
#    'vendors no storage implementation'],
#   'attributes': ['vendors',
#    'found vendors',
#    'vendor scanner',
#    'id',
#    'text',
#    'id',
#    'name',
#    'mac address',
#    'messages list',
#    'list']},
#  '_BxQxQHgvEeiFX4HwoivBqg.xmi.uml': {'classes': ['map activity',
#    'location listener',
#    'point',
#    'lat lng',
#    'points collection',
#    'void',
#    'profile',
#    'profile collection',
#    'buttons fragment',
#    'calculations',
#    'double'],
#   'attributes': ['m buttons fragment',
#    'm ad fragment',
#    'm data display fragment',
#    'm slope selector fragment',
#    'm lat lng',
#    'm points collection']},
#  '_UGxvsDTdEeewJqDqgRk6VA.xmi.uml': {'classes': ['class']},
#  '_UaFboKhTEea217yLRs2OoA.xmi.uml': {'classes': ['class']},
#  '5d1b4386-53c4-474b-b968-39eb364759c6.xmi.uml': {'classes': ['abstraction',
#    'refined abstraction',
#    'concrete implementor']},
#  '_kpgi8PzxEeW9zv77lynsJg.xmi.uml': {'classes': ['2fa',
#    'create account',
#    'create question',
#    'review question',
#    'approve account',
#    'syllabus'],
# ...
#    'inbox',
#    'removed',
#    'working documents',
#    'working directory',
#    'drafts',
#    'sent',
#    'folder base',
#    'task',
#    'mail',
#    'user from',
#    'user to',
#    'folder repository',
#    'rules repository'],
#   'attributes': ['id', 'parent id', 'picture']},
#  '_WsPhYGheEeaj4o_Vw1bWAQ.xmi.uml': {'classes': ['validation result',
#    'validation error',
#    'class'],
#   'attributes': ['is valid', 'errors', 'subgroup', 'message']},
#  '_8M-wMGf5EeepGY91r9Nuow.xmi.uml': {'classes': ['club', 'coach', 'class'],
#   'attributes': ['name', 'name']},
#  '_EXg-YGjjEDGYiNHrhBjI_Q.xmi.uml': {'classes': ['robot',
#    'advanced robot',
#    'robot',
#    'robot base'],
#   'attributes': ['out']},
#  '_rXXRgDPzEemuL8kiMfd-Jw.xmi.uml': {'classes': ['student',
#    'level',
#    'year',
#    'attend'],
#   'attributes': ['name', 'order', 'year']},
#  '_2-YcYIVEEeaY2ZFk8hIg9A.xmi.uml': {'classes': ['entry', 'theorem'],
#   'attributes': ['subject',
#    'date',
#    'type',
#    'content',
#    'subject',
#    'date',
#    'type']},
#  'af9c1405-8551-4402-9d5c-04668e3fc66b.xmi.uml': {'classes': ['media',
#    'video media',
#    'image media',
#    'media clip',
#    'video player mediator',
#    'media player mediator'],
#   'attributes': ['height',
#    'width',
#    'path',
#    'scale',
#    'loop',
#    'auto play',
#    'ignore flip',
#    'material',
#    'image',
#    'duration',
#    'media clips',
#    'auto play',
#    'loop']},
#  '_INhjcNyGEeeFcYOwviu1pw.xmi.uml': {'classes': ['user',
#    'firebase',
#    'spotify account',
#    'billboards'],
#   'attributes': ['username',
#    'password',
#    'song searched',
#    'song info',
#    'graph data',
#    'song points',
#    'username',
#    'password',
#    'song information',
#    'chart placement']},
#  '0010f2d5-0702-4187-98e6-e6ba9f5e73a3.xmi.uml': {'classes': ['register',
#    'stream',
#    'explore',
#    'upload your music',
#    'like/ follow playlist',
#    'browse soundcloud',
#    'class',
#    'class',
#    'class',
#    'log out',
#    'class',
#    'log in']},
#  '67ab326a-4c4e-4ac0-87e3-b6c8f2399fc5.xmi.uml': {'classes': ['shopping cart',
#    'order',
#    'line item',
#    'account',
#    'customer',
#    'class',
#    'sub enrollment batch web service'],
#   'attributes': ['creation date', 'id', 'quantity', 'price', 'id']},
#  '_Y75TAASiEeeoQepBjqL-OQ.xmi.uml': {'classes': ['type',
#    'none',
#    'long',
#    'bool',
#    'float',
#    'int',
#    'iterator',
#    'dictionary',
#    'variable types',
#    'string',
#    'list',
#    'tuple',
#    'class',
#    'function',
#    'context'],
#   'attributes': ['key t',
#    'value t',
#    'context',
#    'return t',
#    'arguments t',
#    'inferred types']},
#  '_Hd4u4GPdEeSLGdVI-XsN4w.xmi.uml': {'classes': ['class']},
#  '61de250b-ea19-4fbf-8743-136d12174233.xmi.uml': {'classes': ['client',
#    'adaptor',
#    'adaptee']},
#  '_heVjcHNYEem42bdoMoG80w.xmi.uml': {'classes': ['shopping list',
#    'product',
#    'sharing list',
#    'user',
#    'suggestion'],
#   'attributes': ['id',
#    'owner',
#    'name',
#    'product',
#    'id',
#    'name',
#    'shopping list id',
#    'subscribent id',
#    'id',
#    'name',
#    'email',
#    'password']},
#  'b03afd7d-b2e5-430c-a15d-df3328355877.xmi.uml': {'classes': ['network driver base class',
#    'juniper driver',
#    'open flow driver',
#    'quantum driver',
#    'network object',
#    'switch/ node',
#    'ports',
#    'link',
#    'policy/ filters',
#    'db engine',
#    'db model',
#    'vm instance',
#    'hosts',
#    'nova driver',
#    'logpython',
#    'exception handler',
#    'config id',
#    'testing tool',
#    'monitoring tool',
#    'troubleshooting tool',
#    'm shell',
#    'parser',
#    'transaction',
#    'worker thread',
#    'master thread'],
#   'attributes': ['id',
#    'tenant id',
#    'error code',
#    'switch id',
#    'vtn id',
#    'instances',
#    'num instances',
#    'subnet address',
#    'dns address',
#    'gateway',
#    'id',
#    'link',
#    'container type',
#    'starting node',
#    'ending node',
#    'bandwidth',
#    'session id',
#    'col names',
#    'col types',
#    'table name',
#    'id',
#    'memory',
#    'host machine',
#    'vm id open stack',
#    'timeout',
#    'host id net logic',
#    'host id open stack',
#    'tenant id',
#    'vm id',
#    'host id',
#    'id',
#    'instances',
#    'transaction id',
#    'tenant id open stack',
#    'timeout',
#    'id',
#    'start time',
#    'thread num',
#    'transaction vector']},
#  '_gBMw4C4OEeaytLLEbYPIyA.xmi.uml': {'classes': ['person', 'customer'],
#   'attributes': ['id', 'lastname', 'firstname', 'customer id']},
#  '_eV9d8C66EDGZkPzbSUT8Hw.xmi.uml': {'classes': ['mc',
#    'md',
#    'force field',
#    'data base'],
#   'attributes': ['move',
#    'score',
#    'store value',
#    'force field',
#    'integrator',
#    'reader',
#    'fundamental',
#    'fragments',
#    'ligands',
#    'metals']},
#  '_LgTJoPJiEeSwa_jsJDgnuw.xmi.uml': {'classes': ['user',
#    'group',
#    'topic',
#    'post',
#    'comment',
#    'text post',
#    'image post']},
#  'a942b696-8c84-46cc-be11-9026a4adbaff.xmi.uml': {'classes': ['shopping cart',
#    'order',
#    'line item',
#    'account',
#    'customer'],
#   'attributes': ['creation date', 'id', 'quantity', 'price', 'id']},
#  '33f762db-69bc-4aa2-8f17-2f53c553337a.xmi.uml': {'classes': ['shopping cart',
#    'order',
#    'line item',
#    'account',
#    'customer'],
#   'attributes': ['creation date', 'id', 'quantity', 'price', 'id']},
#  'fb63624a-aa0e-497b-9c77-fef0cd26fb17.xmi.uml': {'classes': ['singleton'],
#   'attributes': ['instance']},
#  '_jWt1EDDjEeme-prEJQaJbA.xmi.uml': {'classes': ['system', 'user', 'file'],
#   'attributes': ['grade', 'essay', 'passed']},
#  '_Sy9PcKxrEeiHR4AK89CXpg.xmi.uml': {'classes': ['game type',
#    'game',
#    'game playground',
#    'game pack',
#    'game pack detail',
#    'game tariff',
#    'game schedule',
#    'game invoice',
#    'operation'],
#   'attributes': ['id',
#    'name',
#    'id',
#    'unit price',
#    'id',
#    'name',
#    'name',
#    'unit price',
#    'quantity',
#    'original unit price',
#    'unit price',
#    'amount',
#    'can be substitute',
#    'is substitue of',
#    'name',
#    'unit price',
#    'day',
#    'start time',
#    'end time',
#    'unit price',
#    'id',
#    'operation date',
#    'is voided']},
#  '15c377a4-e60c-4987-943f-9f717b046eb5.xmi.uml': {'classes': ['customer',
#    'payment',
#    'shopping cart',
#    'account',
#    'web user',
#    'order',
#    'line item',
#    'product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paid date',
#    'total',
#    'details',
#    'creation date',
#    'billing address',
#    'open',
#    'closed',
#    'is closed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'ship to',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description']},
#  '84a43dd1-8268-4b9b-a945-c48e755d71c3.xmi.uml': {'classes': ['customer',
#    'payment',
#    'shopping cart',
#    'account',
#    'web user',
#    'order',
#    'line item',
#    'product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paid date',
#    'total',
#    'details',
#    'creation date',
#    'billing address',
#    'open',
#    'closed',
#    'is closed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'ship to',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description']},
#  'ed9c9cdf-27b1-49d4-82d2-8629d81b32ff.xmi.uml': {'classes': ['shopping cart',
#    'order',
#    'line item',
#    'account',
#    'customer'],
#   'attributes': ['creation date', 'id', 'quantity', 'price', 'id']},
#  '_y5UjgKPzEemlGeJsLESUmg.xmi.uml': {'classes': ['sponge',
#    'water',
#    'dish washer',
#    'dishes',
#    'soap'],
#   'attributes': ['properties',
#    'properties',
#    'properties',
#    'properties',
#    'properties',
#    'properties',
#    'properties',
#    'properties',
#    'properties',
#    'properties',
#    'properties',
#    'properties',
#    'properties']},
#  '_K0WlsC56EeSxYsF3O4XI1g.xmi.uml': {'classes': ['alien entity',
#    'entity',
#    'game panel',
#    'ship entity',
#    'shot entity',
#    'space invaders app',
#    'sprite',
#    'sprite store',
#    'panel',
#    'frame']},
#  '_YzVhkKrJEea217yLRs2OoA.xmi.uml': {'classes': ['catalog entry',
#    'sentiment data',
#    'steam review scraper',
#    'review entry'],
#   'attributes': ['game name', 'review count', 'data', 'steam id']},
#  '3da50aa8-d2c7-4877-9216-3aeea1ce6379.xmi.uml': {'classes': ['shopping cart',
#    'order',
#    'line item',
#    'account',
#    'customer'],
#   'attributes': ['creation date', 'id', 'quantity', 'price', 'id']},
#  '_9ksWIEFOEeeTJ_4Vl2J2rQ.xmi.uml': {'classes': ['local ticket',
#    'season ticket',
#    'platform ticket',
#    'tourist ticket',
#    'book ticket',
#    'show ticket'],
#   'attributes': ['source',
#    'destination',
#    'adult',
#    'child',
#    'journey',
#    'fare',
#    'source',
#    'destination',
#    'validity',
#    'fare',
#    'platform',
#    'quantity',
#    'fare',
#    'adult',
#    'child',
#    'validity',
#    'fare']},
#  '_ewxDEGEGEemMYewRRb4vMg.xmi.uml': {'classes': ['class', 'event', 'member'],
#   'attributes': ['id',
#    'name',
#    'description',
#    'members',
#    'priority',
#    'start ts',
#    'end ts',
#    'id',
#    'name']},
#  '318bd1e4-767e-47f4-992f-77f66c797d55.xmi.uml': {'classes': ['customer',
#    'payment',
#    'shopping cart',
#    'account',
#    'web user',
#    'order',
#    'line item',
#    'product'],
#   'attributes': ['address',
#    'phone',
#    'email',
#    'paid date',
#    'total',
#    'details',
#    'creation date',
#    'billing address',
#    'open',
#    'closed',
#    'is closed',
#    'login',
#    'password',
#    'state',
#    'number',
#    'ordered',
#    'shipped',
#    'ship to',
#    'total',
#    'status',
#    'quantity',
#    'price',
#    'name',
#    'description']},
#  '_-i9HYNLKEemr0Oy2Fixrzg.xmi.uml': {'classes': ['user',
#    'costumer',
#    'bus',
#    'hotel',
#    'trip'],
#   'attributes': ['id user',
#    'user name',
#    'user password',
#    'id costumer',
#    'costumer name',
#    'costumer last name',
#    'costumer phone',
#    'id bus',
#    'bus seats',
#    'id hotel',
#    'hotel name',
#    'hotel rooms',
#    'id trip',
#    'destination',
#    'id bus',
#    'id hotel',
#    'id costumer']},
#  '078bf215-79fe-44f5-8c45-cd92eef0cadf.xmi.uml': {'classes': ['client',
#    'adapter implementation',
#    'adaptee',
#    'context',
#    'state a',
#    'state b',
#    'singleton',
#    'abstraction',
#    'refined abstraction',
#    'concrete implementor',
#    'creator implementation',
#    'product',
#    'concrete observer',
#    'concrete subject'],
#   'attributes': ['instance']},
#  '_T-T_UOVCEeiyGtLb2crGgA.xmi.uml': {'classes': ['class', 'class', 'class']},
#  '_BdrsgB5fEei46Ymw1f0xJQ.xmi.uml': {'classes': ['account',
#    'behavior',
#    'reaction',
#    'application',
#    'predicate',
#    'game',
#    'facade'],
#   'attributes': ['id', 'id', 'id', 'id', 'id']},
#  '0b051bd0-784c-4d23-bc66-ff3f28b85677.xmi.uml': {'classes': ['client',
#    'adapter implementation',
#    'adaptee',
#    'context',
#    'state a',
#    'state b',
#    'singleton',
#    'abstraction',
#    'refined abstraction',
#    'concrete implementor',
#    'creator implementation',
#    'product',
#    'concrete observer',
#    'concrete subject'],
#   'attributes': ['instance']},
#  '_LEbqcKKDEeeI1NNq08Z6HQ.xmi.uml': {'classes': ['store',
#    'country',
#    'employee',
#    'customer',
#    'shop',
#    'shop group',
#    'category',
#    'manufacturer',
#    'supplier'],
#   'attributes': ['id',
#    'name',
#    'id',
#    'id',
#    'email',
#    'firstname',
#    'lastname',
#    'passwd',
#    'id',
#    'email',
#    'firstname',
#    'lastname',
#    'id',
#    'active',
#    'deleted',
#    'name',
#    'theme name',
#    'id',
#    'active',
#    'deleted',
#    'name',
#    'share customer',
#    'share order',
#    'share stock',
#    'id',
#    'id',
#    'name',
#    'id',
#    'name']},
#  'ea3b738d-3ea6-4320-9b56-7ee2cabfce78.xmi.uml': {'classes': ['client',
#    'adaptor',
#    'adaptee']},
#  '317ad8e1-3d1f-40ce-8a55-30ebf796d609.xmi.uml': {'classes': ['shopping cart']},
#  '_q_v50Jb5EeeaCsv2qBF4QA.xmi.uml': {'classes': ['point', 'polygon', 'color'],
#   'attributes': ['red', 'green', 'blue', 'alpha', 'hidden']},
#  'b0215e71-7349-4b6a-8609-49de30d60f99.xmi.uml': {'classes': ['client',
#    'adapter implementation',
#    'adaptee',
#    'context',
#    'state a',
#    'state b',
#    'singleton',
#    'abstraction',
#    'refined abstraction',
#    'concrete implementor',
#    'creator implementation',
#    'product',
#    'concrete observer',
#    'concrete subject'],
#   'attributes': ['instance']},
#  '__x0F0PUUEeOxcf3LRXD4wA.xmi.uml': {'classes': ['class', 'class'],
#   'attributes': ['attribute']},
#  '1f431c38-638b-45e5-9834-819ebb780676.xmi.uml': {'classes': ['client',
#    'adaptor',
#    'adaptee']},
#  '_QN_20EMAEeeTJ_4Vl2J2rQ.xmi.uml': {'classes': ['vu book shop',
#    'customer',
#    'order',
#    'address',
#    'shopping cart',
#    'book/dvd'],
#   'attributes': ['name',
#    'customer id',
#    'password',
#    'billing address',
#    'shipping address',
#    'shipping charges',
#    'payment method',
#    'total',
#    'street',
#    'city',
#    'province',
#    'village',
#    'course']},
#  '_wDrDEHBfEee5HMQDnOR-kg.xmi.uml': {'classes': ['class', 'class', 'class']},
#  '_NvugMHdjEDGZRv1Ax7bzSg.xmi.uml': {'classes': ['user'],
#   'attributes': ['name',
#    'email',
#    'password',
#    'friends',
#    'attribute',
#    'attribute']},
#  '4289574b-82db-4146-a110-cbfff14465c8.xmi.uml': {'classes': ['shopping cart',
#    'order',
#    'line item',
#    'account',
#    'customer'],
#   'attributes': ['creation date', 'id', 'quantity', 'price', 'id']},
#  '1e072ab6-6174-4406-92dc-fd7c75808f23.xmi.uml': {'classes': ['users',
#    'table',
#    'order',
#    'membership card',
#    'view order',
#    'order item',
#    'bookings',
#    'booked tables'],
#   'attributes': ['user id',
#    'user name',
#    'user level',
#    'table no',
#    'occupied',
#    'order id',
#    'date',
#    'user id',
#    'total',
#    'dicount lvl',
#    'id',
#    'discount lvl',
#    'item name',
#    'remaning time',
#    'completed',
#    'booking id',
#    'customer name',
#    'phone',
#    'people',
#    'table no',
#    'date',
#    'time',
#    'table no',
#    'booking id']},
#  '_kPlWsI27EeewrIfYd5mf8Q.xmi.uml': {'classes': ['shape',
#    'triangle',
#    'pentagon',
#    'drawing',
#    'drawing',
#    'drawing',
#    'dp',
#    'dp']},
#  'bbc6cae7-aa97-435d-a199-0324ee846095.xmi.uml': {'classes': ['singleton'],
#   'attributes': ['instance']},
#  '_RVUFsFlvEeWH7tmnkVHu6g.xmi.uml': {'classes': ['device',
#    'station',
#    'category'],
#   'attributes': ['name', 'qr code', 'name', 'qr code', 'name']},
#  '0dd2aa44-e847-444e-8f91-ee969ae92551.xmi.uml': {'classes': ['shopping cart']},
#  '_LLNesDajEeWht9Pd0LRltA.xmi.uml': {'classes': ['engine',
#    'plugin',
#    'ida service',
#    'binnavi service',
#    'clips model',
#    'engine status',
#    'analysis plugin',
#    'analysis capability'],
#   'attributes': ['analysis capabilities', 'analysis plugins']},
#  '_mLhRoNS7Eem_DuabqFUAEg.xmi.uml': {'classes': ['marble game object']},
#  '_Lq7GMDmyEDGDM-f_ws4ZEw.xmi.uml': {'classes': ['cliente',
#    'reserva',
#    'carro',
#    'aluguel',
#    'devolucao',
#    'filial',
#    'acessorio'],
#   'attributes': ['nome',
#    'endereco',
#    'cpf',
#    'profissao',
#    'telefone',
#    'data',
#    'placa',
#    'nome',
#    'cor',
#    'tipo',
#    'data',
#    'data',
#    'valor',
#    'codigo',
#    'nome',
#    'endereco',
#    'nome']},
#  '_MoUnUJI0EeWPetZvgdr7ng.xmi.uml': {'classes': ['class']},
#  '_5EFSgL2hEeedTfUoC-GfaA.xmi.uml': {'classes': ['students',
#    'events',
#    'schedule',
#    'judge',
#    'judge panel',
#    'marks',
#    'instructor',
#    'fee',
#    'lessons'],
#   'attributes': ['student no',
#    'name',
#    'phone',
#    'address',
#    'gender',
#    'student type',
#    'event id',
#    'event name',
#    'schedule id',
#    'event id',
#    'performance no',
#    'music name',
#    'judge marks',
#    'panel id',
#    'judge id',
#    'name',
#    'panel id',
#    'judge id',
#    'mark id',
#    'enent id',
#    'marks',
#    'student no',
#    'attribute id',
#    'name',
#    'paytype',
#    'acomplish type',
#    'fee id',
#    'student type',
#    'amount',
#    'lesson id',
#    'lesson name',
#    'time span']},
#  '_2ZX4wBvBEeSCHNJdddddKw.xmi.uml': {'classes': ['game',
#    'question',
#    'chapter',
#    'test'],
#   'attributes': ['chapters',
#    'question',
#    'answer',
#    'answer',
#    'answer',
#    'correct answer',
#    'title',
#    'questions',
#    'questions']},
#  'a46c86f0-250d-409f-a316-b8882dec1eff.xmi.uml': {'classes': ['shopping cart',
#    'order',
#    'line item',
#    'account',
#    'customer'],
#   'attributes': ['creation date', 'id', 'quantity', 'price', 'id']},
#  ...}

# %%
latin_letters= {}

def is_latin(uchr):
    try: return latin_letters[uchr]
    except KeyError:
         return latin_letters.setdefault(uchr, 'LATIN' in ud.name(uchr))

def only_roman_chars(unistr):
    return all(is_latin(uchr)
           for uchr in unistr
           if uchr.isalpha())

def not_three_consecutive_chars(unistr):
    start = unistr[0]
    
    for char in unistr[1:]:
        if char == start[0]:
            start = start + char
            
            if len(start) > 2:
                return False
        else:
            start = char
    
    return True

# %%
# Create non-changing copy for iteration through the files
iteration_copy = copy.deepcopy(filtered_files)

for file in iteration_copy.keys():
    for metadata in iteration_copy[file].keys():
        # Remove all empty strings and non-alphanumerical entries
        new_metadata = list(filter(lambda x: x != '' and len(x) > 1 and x.replace(' ', '').replace("'", '').isalnum() and only_roman_chars(x) and any(c.isalpha() for c in x) and len(set(filter(str.isalpha, x))) != 1 and not re.match(r'(?:aa)|(?:uu)|(?:yy)|(?:ii)|(?:jj)', x) and not_three_consecutive_chars(x) and not '0f' in x and model.predict([x])[0][0][0] == '__label__en', filtered_files[file][metadata]))
        
        # Either remove the now-empty metadata or change it in the file
        if len(new_metadata) > 0:
            filtered_files[file][metadata] = new_metadata
        else:
            del filtered_files[file][metadata]
    
    # Remove file if it doesn't contain metadata anymore after filtering
    if len(filtered_files[file].keys()) == 0:
        del filtered_files[file]

# %%
with open('data/genmymodel_uml_extracted_metadata_final.json', 'w') as fp:
    json.dump(filtered_files, fp)
